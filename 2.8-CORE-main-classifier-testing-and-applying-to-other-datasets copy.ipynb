# %% [markdown]
# Import all necessary libraries and install everything you need for training:

# %%
# install the libraries necessary for data wrangling, prediction and result analysis
import json
import numpy as np
import pandas as pd
import logging
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, f1_score,precision_score, recall_score
import torch
from numba import cuda
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

# %%
# Install transformers
# (this needs to be done on Kaggle each time you start the session)
#!pip install -q transformers

# %%
# Install the simpletransformers
#!pip install -q simpletransformers
from simpletransformers.classification import ClassificationModel

# %%
# Install wandb
#!pip install -q wandb

# %%
import wandb

# %%
# Login to wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tajak (use `wandb login --relogin` to force relogin)
# True

# %%
# Clean the GPU cache

cuda.select_device(0)
cuda.close()
cuda.select_device(0)
torch.cuda.empty_cache()

# %% [markdown]
# ### Import the data

# %%
# CORE-main (texts annotated with main CORE labels)
train_df = pd.read_csv("data-splits/CORE-main-subset-train.csv", index_col = 0)
dev_df = pd.read_csv("data-splits/CORE-main-subset-dev.csv", index_col = 0)
test_df = pd.read_csv("data-splits/CORE-main-subset-test.csv", index_col = 0)

print("CORE-main train shape: {}, Dev shape: {}, Test shape: {}.".format(train_df.shape, dev_df.shape, test_df.shape))
# Out:
# CORE-main train shape: (10256, 2), Dev shape: (3419, 2), Test shape: (3419, 2).

# %%
train_df.head()
# Out:
#                                                     text  \
# 38864  I have never been able to ejaculate inside any...
# 22351  Testimonials We have had the privilege of find...
# 24938  Saturday, November 03, 2012 Every time I check...
# 39572  Why Didn't Nokia Use Android? Because That Wou...
# 4574   A veterinarian specialising in wild horse immu...
#
#                        labels
# 38864  Interactive Discussion
# 22351  Interactive Discussion
# 24938               Narrative
# 39572               Narrative
# 4574                Narrative

# %% [markdown]
# ## Testing

# %% [markdown]
# We will use the multilingual XLM-RoBERTa model
# https://huggingface.co/xlm-roberta-base

# %%
# Create a file to save results into (you can find it under Data: Output). Be careful, run this step only once to not overwrite the results file.
results = []

with open("results/CORE-main-Experiments-Results.json", "w") as results_file:
    json.dump(results,results_file, indent= "")

# %%
# Open the main results file:

previous_results_file = open("results/CORE-main-Experiments-Results.json")
previous_results = json.load(previous_results_file)
len(previous_results)
# Out:
# 0

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Create a list of labels
LABELS = train_df.labels.unique().tolist()
LABELS
# Out:
# ['Interactive Discussion',
#  'Narrative',
#  'Informational Description/Explanation',
#  'Lyrical',
#  'Opinion',
#  'Informational Persuasion',
#  'Spoken',
#  'How-To/Instructional',
#  'Other']

# %%
# Initialize Wandb
run = wandb.init(project="CORE-hyperparameter-search", entity="tajak", name="testing-trained-model")
# Out:
# wandb version 0.13.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20220804_150742-3ls4coku</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/CORE-hyperparameter-search/runs/3ls4coku" target="_blank">testing-trained-model</a></strong> to <a href="https://wandb.ai/tajak/CORE-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# Load the saved model
artifact = run.use_artifact('tajak/CORE-hyperparameter-search/CORE-main-classifier:v0', type='model')
artifact_dir = artifact.download()

# Loading a local save
model = ClassificationModel(
    "xlmroberta", artifact_dir)
# Out:
# wandb: Downloading large artifact CORE-main-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
def testing(test_df, test_name):
    """
    This function takes the test dataset and applies the trained model on it to infer predictions.
    It also prints and saves a confusion matrix, calculates the F1 scores and saves the results in a list of results.

    Args:
    - test_df (pandas DataFrame)
    - test_name
    """
    # Get the true labels
    y_true = test_df.labels
    
    # Calculate the model's predictions on test
    def make_prediction(input_string):
        return model.predict([input_string])[0][0]

    y_pred = test_df.text.apply(make_prediction)
    test_df["y_pred_CORE_main"] = y_pred

    # Calculate the scores
    macro = f1_score(y_true, y_pred, labels=LABELS, average="macro")
    micro = f1_score(y_true, y_pred, labels=LABELS,  average="micro")
    print(f"Macro f1: {macro:0.3}, Micro f1: {micro:0.3}")

    # Plot the confusion matrix:
    cm = confusion_matrix(y_true, y_pred, labels=LABELS)
    plt.figure(figsize=(9, 9))
    plt.imshow(cm, cmap="Oranges")
    for (i, j), z in np.ndenumerate(cm):
        plt.text(j, i, '{:d}'.format(z), ha='center', va='center')
    classNames = LABELS
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    tick_marks = np.arange(len(classNames))
    plt.xticks(tick_marks, classNames, rotation=90)
    plt.yticks(tick_marks, classNames)
    plt.title(f"{test_name}")

    plt.tight_layout()
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    fig1.savefig(f"figures/Confusion-matrix-{test_name}.png",dpi=100)

    # Save the results:
    rezdict = {
        "experiment": test_name,
        "num_train_epochs": 4,
        "train_batch_size":8,
        "learning_rate": 1e-5,
        "microF1": micro,
        "macroF1": macro,
        "y_true": y_true.to_dict(),
        "y_pred": y_pred.to_dict(),
        }
    previous_results.append(rezdict)

    #Save intermediate results (just in case)
    backup = []
    backup.append(rezdict)
    with open(f"backup-results-{test_name}.json", "w") as backup_file:
        json.dump(backup,backup_file, indent= "")

    # Save the new dataframe which contains the y_pred values as well
    test_df.to_csv(f"results/{test_name}-sheet-with-predictions.csv", sep="\t")

# %%
testing(dev_df, "testing-CORE-main-on-dev")

print("\nTesting finished.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in next(self, timeout)
#     852             try:
# --> 853                 item = self._items.popleft()
#     854             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11427/1340948626.py in <module>
# ----> 1 testing(dev_df, "testing-CORE-main-on-dev")
#       2
#       3 print("\nTesting finished.")
#
# /tmp/ipykernel_11427/3806276471.py in testing(test_df, test_name)
#      15         return model.predict([input_string])[0][0]
#      16
# ---> 17     y_pred = test_df.text.apply(make_prediction)
#      18     test_df["y_pred_CORE_main"] = y_pred
#      19
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_11427/3806276471.py in make_prediction(input_string)
#      13     # Calculate the model's predictions on test
#      14     def make_prediction(input_string):
# ---> 15         return model.predict([input_string])[0][0]
#      16
#      17     y_pred = test_df.text.apply(make_prediction)
#
# ~/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py in predict(self, to_predict, multi_label)
#    2038                     out_label_ids = np.empty((len(eval_dataset)))
#    2039             else:
# -> 2040                 eval_dataset = self.load_and_cache_examples(
#    2041                     eval_examples, evaluate=True, multi_label=multi_label, no_cache=True
#    2042                 )
#
# ~/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py in load_and_cache_examples(self, examples, evaluate, no_cache, multi_label, verbose, silent)
#    1797                 return dataset
#    1798         else:
# -> 1799             dataset = ClassificationDataset(
#    1800                 examples,
#    1801                 self.tokenizer,
#
# ~/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_utils.py in __init__(self, data, tokenizer, args, mode, multi_label, output_mode, no_cache)
#     276 class ClassificationDataset(Dataset):
#     277     def __init__(self, data, tokenizer, args, mode, multi_label, output_mode, no_cache):
# --> 278         self.examples, self.labels = build_classification_dataset(
#     279             data, tokenizer, args, mode, multi_label, output_mode, no_cache
#     280         )
#
# ~/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_utils.py in build_classification_dataset(data, tokenizer, args, mode, multi_label, output_mode, no_cache)
#     243
#     244             with Pool(args.process_count) as p:
# --> 245                 examples = list(
#     246                     tqdm(
#     247                         p.imap(preprocess_data_multiprocessing, data),
#
# ~/anaconda3/lib/python3.9/site-packages/tqdm/notebook.py in __iter__(self)
#     255     def __iter__(self):
#     256         try:
# --> 257             for obj in super(tqdm_notebook, self).__iter__():
#     258                 # return super(tqdm...) will not catch exception
#     259                 yield obj
#
# ~/anaconda3/lib/python3.9/site-packages/tqdm/std.py in __iter__(self)
#    1166         # (note: keep this check outside the loop for performance)
#    1167         if self.disable:
# -> 1168             for obj in iterable:
#    1169                 yield obj
#    1170             return
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in next(self, timeout)
#     856                     self._pool = None
#     857                     raise StopIteration from None
# --> 858                 self._cond.wait(timeout)
#     859                 try:
#     860                     item = self._items.popleft()
#
# ~/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
testing(test_df, "testing-CORE-main-on-test")
print("\nTesting finished.")
# Out:
# Macro f1: 0.723, Micro f1: 0.72
# Testing finished.

# %%
# Compare the results by creating a dataframe from the previous_results dictionary:
results_df = pd.DataFrame(previous_results)

results_df
# Out:
#                                        experiment  num_train_epochs  \
# 0                              Dev-epoch-search:1                 1
# 1                             Dev-epoch-search:12                12
# 2                             Dev-epoch-search:15                15
# 3                             Dev-epoch-search:20                20
# 4                             Dev-epoch-search:25                25
# 5             testing-GINCO-full-set-model-on-dev                20
# 6              FTD-classifier-predictions-on-test                20
# 7   GINCO-full-set-classifier-predictions-on-test                20
# 8               GINCO-downcast-dev-epoch-search:8                 8
# 9              GINCO-downcast-dev-epoch-search:10                10
# 10             GINCO-downcast-dev-epoch-search:15                15
# 11             GINCO-downcast-dev-epoch-search:20                20
# 12             GINCO-downcast-dev-epoch-search:25                25
# 13             GINCO-downcast-dev-epoch-search:30                30
# 14                  testing-GINCO-downcast-on-dev                15
# 15                 testing-GINCO-downcast-on-test                15
# 16               testing-MT-GINCO-downcast-on-dev                15
# 17              testing-MT-GINCO-downcast-on-test                15
#
#     train_batch_size  learning_rate   microF1   macroF1  \
# 0                  8        0.00001  0.238342  0.085359
# 1                  8        0.00001  0.585492  0.417602
# 2                  8        0.00001  0.658031  0.504828
# 3                  8        0.00001  0.637306  0.530084
# 4                  8        0.00001  0.626943  0.497636
# 5                  8        0.00001  0.668394  0.539277
# 6                  8        0.00001  0.590674  0.465714
# 7                  8        0.00001  0.590674  0.465714
# 8                  8        0.00001  0.527363  0.267149
# 9                  8        0.00001  0.721393  0.719435
# 10                 8        0.00001  0.776119  0.818806
# 11                 8        0.00001  0.756219  0.791577
# 12                 8        0.00001  0.766169  0.800081
# 13                 8        0.00001  0.736318  0.764189
# 14                 8        0.00001  0.701493  0.740766
# 15                 8        0.00001  0.715000  0.729721
# 16                 8        0.00001  0.781095  0.805693
# 17                 8        0.00001  0.720000  0.723423
#
#                                                y_true  \
# 0   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 1   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 2   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 3   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 4   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 5   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 6   {'574': 'Opinionated News', '636': 'Informatio...
# 7   {'574': 'Opinionated News', '636': 'Informatio...
# 8   {'648': 'Other', '992': 'Instruction', '51': '...
# 9   {'648': 'Other', '992': 'Instruction', '51': '...
# 10  {'648': 'Other', '992': 'Instruction', '51': '...
# 11  {'648': 'Other', '992': 'Instruction', '51': '...
# 12  {'648': 'Other', '992': 'Instruction', '51': '...
# 13  {'648': 'Other', '992': 'Instruction', '51': '...
# 14  {'648': 'Other', '992': 'Instruction', '51': '...
# 15  {'677': 'List of Summaries/Excerpts', '355': '...
# 16  {1: 'Information/Explanation', 6: 'Promotion',...
# 17  {0: 'News/Reporting', 2: 'Promotion', 14: 'Oth...
#
#                                                y_pred
# 0   {'245': 'News/Reporting', '143': 'Information/...
# 1   {'245': 'News/Reporting', '143': 'Invitation',...
# 2   {'245': 'News/Reporting', '143': 'Promotion of...
# 3   {'245': 'News/Reporting', '143': 'Promotion', ...
# 4   {'245': 'News/Reporting', '143': 'Promotion of...
# 5   {'245': 'News/Reporting', '143': 'Invitation',...
# 6   {'574': 'News/Reporting', '636': 'Information/...
# 7   {'574': 'News/Reporting', '636': 'Information/...
# 8   {'648': 'Opinion/Argumentation', '992': 'Promo...
# 9   {'648': 'Forum', '992': 'Instruction', '51': '...
# 10  {'648': 'Forum', '992': 'Instruction', '51': '...
# 11  {'648': 'Forum', '992': 'Instruction', '51': '...
# 12  {'648': 'Forum', '992': 'Instruction', '51': '...
# 13  {'648': 'Forum', '992': 'Instruction', '51': '...
# 14  {'648': 'Forum', '992': 'Instruction', '51': '...
# 15  {'677': 'List of Summaries/Excerpts', '355': '...
# 16  {1: 'Information/Explanation', 6: 'Promotion',...
# 17  {0: 'News/Reporting', 2: 'News/Reporting', 14:...

# %%
# Save the file with updated results.
with open("results/CORE-main-Experiments-Results.json", "w") as results_file:
    json.dump(previous_results,results_file, indent= "")

# %% [markdown]
# ## Predict CORE labels to other datasets

# %%
# Create a function to predict
def predict_CORE(df, new_file_name):
    """
    This function takes a dataset and applies the trained model on it to infer predictions.
	It returns and saves the resulting df with added columns with CORE predictions.

    Args:
    - df: dataframe on which we want to apply prediction. The text should be in a column "text".
    - new_file_name: define the name of the new file
    """
    # Predict on the df
    def make_prediction(input_string):
        return model.predict([input_string])[0][0]

    y_pred = df.text.apply(make_prediction)

    df["CORE_main_pred"] = y_pred

    # Save the new dataframe which contains the y_pred values as well
    df.to_csv(f"{new_file_name}", sep="\t")

    return df

# %% [markdown]
# Prediction takes around 22 minutes per 1000 instances.

# %% [markdown]
# ### Predict CORE to GINCO

# %%
# Import data about GINCO
ginco_df = pd.read_csv("data-sheets-with-all-info/GINCO-MT-GINCO-keeptext-with-all-information.csv", sep="\t", index_col=0)
ginco_df
# Out:
#            id                                                url  crawled  \
# 0        3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014
# 1        3726  http://www.ss-sezana.si/sss/index.php?option=c...     2014
# 2        5621  http://www.kamnik-starejsi.si/novice/144-sodel...     2014
# 3        3776  http://www.radiocelje.si/novica.php?id=13007&a...     2014
# 4        2102  http://www.mtv.si/novice/selena-gomez-ponudila...     2014
# ...       ...                                                ...      ...
# 997    374730  http://khetanes.si/sl-si/produkti/projektne-no...     2021
# 998    476885  https://www.merkur.si/navigacija/nasveti/kopal...     2021
# 999    674213        http://www.sex2.si/category/ocene-izdelkov/     2021
# 1000   975590  http://www.ipsos.si/VodenjeVIZ_VI_past_dvojne_...     2021
# 1001  1277644    https://pogajanja.si/?s=article&a=izpis&id=1221     2021
#
#        hard             primary_level_1             primary_level_2  \
# 0     False              News/Reporting              News/Reporting
# 1     False     Information/Explanation     Information/Explanation
# 2     False       Promotion of Services       Promotion of Services
# 3     False              News/Reporting              News/Reporting
# 4     False            Opinionated News            Opinionated News
# ...     ...                         ...                         ...
# 997   False     Information/Explanation     Information/Explanation
# 998   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 999   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 1000  False       Opinion/Argumentation       Opinion/Argumentation
# 1001   True  List of Summaries/Excerpts  List of Summaries/Excerpts
#
#                  primary_level_3      secondary_level_1  \
# 0                 News/Reporting                    NaN
# 1        Information/Explanation                    NaN
# 2                      Promotion  Opinion/Argumentation
# 3                 News/Reporting                    NaN
# 4               Opinionated News                    NaN
# ...                          ...                    ...
# 997      Information/Explanation                    NaN
# 998   List of Summaries/Excerpts                    NaN
# 999   List of Summaries/Excerpts                    NaN
# 1000       Opinion/Argumentation                    NaN
# 1001  List of Summaries/Excerpts                    NaN
#
#           secondary_level_2      secondary_level_3         tertiary_level_1  \
# 0                       NaN                    NaN                      NaN
# 1                       NaN                    NaN                      NaN
# 2     Opinion/Argumentation  Opinion/Argumentation  Information/Explanation
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
# ...                     ...                    ...                      ...
# 997                     NaN                    NaN   Promotion of a Product
# 998                     NaN                    NaN                      NaN
# 999                     NaN                    NaN                      NaN
# 1000                    NaN                    NaN                      NaN
# 1001                    NaN                    NaN                      NaN
#
#              tertiary_level_2         tertiary_level_3  split  \
# 0                         NaN                      NaN   test
# 1                         NaN                      NaN  train
# 2     Information/Explanation  Information/Explanation  train
# 3                         NaN                      NaN  train
# 4                         NaN                      NaN   test
# ...                       ...                      ...    ...
# 997    Promotion of a Product                Promotion  train
# 998                       NaN                      NaN  train
# 999                       NaN                      NaN  train
# 1000                      NaN                      NaN  train
# 1001                      NaN                      NaN   test
#
#                       domain                     GINCORE  \
# 0             www.pomurje.si                        News
# 1           www.ss-sezana.si     Information/Explanation
# 2     www.kamnik-starejsi.si                   Promotion
# 3          www.radiocelje.si                        News
# 4                 www.mtv.si                        News
# ...                      ...                         ...
# 997              khetanes.si     Information/Explanation
# 998            www.merkur.si  List of Summaries/Excerpts
# 999              www.sex2.si  List of Summaries/Excerpts
# 1000            www.ipsos.si       Opinion/Argumentation
# 1001            pogajanja.si  List of Summaries/Excerpts
#
#                                                    text  \
# 0     Šport <p/> Zimska liga malega nogometa sobota,...
# 1     JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2     Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
# 3     V novembru, mesecu preprečevanja odvisnosti, b...
# 4     Selena Gomez ponudila v poslušanje novi album ...
# ...                                                 ...
# 997   Projektne novine <p/> Promocijski projektni ča...
# 998   V raznoliki ponudbi tušev izberite popolno raz...
# 999   O izdelku Za znamko Dame stojita dve ženski, z...
# 1000  Razprava pogosto potegne na plano najprej tist...
# 1001  Pogajalska akadmija v letu 2014 02.02.2014 <p/...
#
#                                                 MT-text  text_length  \
# 0     Sport <p/> Winter Little League Football Satur...           93
# 1     JEDILNIK <p/> Search <p/> The main objective o...           76
# 2     Project INNOVAge and the Oreli Institute <p/> ...          232
# 3     In November, the month of addiction prevention...          158
# 4     Selena Gomez launches new album <p/> 16.07.201...           63
# ...                                                 ...          ...
# 997   Project News <p/> Promotional project newspape...           86
# 998   Choose the perfect shower to match your taste ...           50
# 999   About the product There are two women behind t...          295
# 1000  The debate often brings to the surface first t...          409
# 1001  Negotiation Academy 2014 02.02.2014 <p/> How t...           89
#
#                 FTD_pred
# 0              A8 (news)
# 1      A16 (information)
# 2        A12 (promotion)
# 3              A8 (news)
# 4              A8 (news)
# ...                  ...
# 997      A12 (promotion)
# 998      A12 (promotion)
# 999      A12 (promotion)
# 1000  A1 (argumentative)
# 1001     A12 (promotion)
#
# [1002 rows x 20 columns]

# %%
# First, use the Slovene data - rename the column with slovene text to "text"
ginco_df = ginco_df.rename(columns= {"Slovene_text": "text"})
ginco_df.head(1)
# Out:
#      id                                                url  crawled   hard  \
# 0  3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014  False
#
#   primary_level_1 primary_level_2 primary_level_3 secondary_level_1  \
# 0  News/Reporting  News/Reporting  News/Reporting               NaN
#
#   secondary_level_2 secondary_level_3 tertiary_level_1 tertiary_level_2  \
# 0               NaN               NaN              NaN              NaN
#
#   tertiary_level_3 split          domain GINCORE  \
# 0              NaN  test  www.pomurje.si    News
#
#                                                 text  \
# 0  Šport <p/> Zimska liga malega nogometa sobota,...
#
#                                              MT-text  text_length
# 0  Sport <p/> Winter Little League Football Satur...           93

# %%
# Apply predictions
ginco_df = predict_CORE(ginco_df, "GINCO-MT-GINCO-keeptext-with-all-information.csv")

# %%
ginco_df
# Out:
#            id                                                url  crawled  \
# 0        3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014
# 1        3726  http://www.ss-sezana.si/sss/index.php?option=c...     2014
# 2        5621  http://www.kamnik-starejsi.si/novice/144-sodel...     2014
# 3        3776  http://www.radiocelje.si/novica.php?id=13007&a...     2014
# 4        2102  http://www.mtv.si/novice/selena-gomez-ponudila...     2014
# ...       ...                                                ...      ...
# 997    374730  http://khetanes.si/sl-si/produkti/projektne-no...     2021
# 998    476885  https://www.merkur.si/navigacija/nasveti/kopal...     2021
# 999    674213        http://www.sex2.si/category/ocene-izdelkov/     2021
# 1000   975590  http://www.ipsos.si/VodenjeVIZ_VI_past_dvojne_...     2021
# 1001  1277644    https://pogajanja.si/?s=article&a=izpis&id=1221     2021
#
#        hard             primary_level_1             primary_level_2  \
# 0     False              News/Reporting              News/Reporting
# 1     False     Information/Explanation     Information/Explanation
# 2     False       Promotion of Services       Promotion of Services
# 3     False              News/Reporting              News/Reporting
# 4     False            Opinionated News            Opinionated News
# ...     ...                         ...                         ...
# 997   False     Information/Explanation     Information/Explanation
# 998   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 999   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 1000  False       Opinion/Argumentation       Opinion/Argumentation
# 1001   True  List of Summaries/Excerpts  List of Summaries/Excerpts
#
#                  primary_level_3      secondary_level_1  \
# 0                 News/Reporting                    NaN
# 1        Information/Explanation                    NaN
# 2                      Promotion  Opinion/Argumentation
# 3                 News/Reporting                    NaN
# 4               Opinionated News                    NaN
# ...                          ...                    ...
# 997      Information/Explanation                    NaN
# 998   List of Summaries/Excerpts                    NaN
# 999   List of Summaries/Excerpts                    NaN
# 1000       Opinion/Argumentation                    NaN
# 1001  List of Summaries/Excerpts                    NaN
#
#           secondary_level_2      secondary_level_3         tertiary_level_1  \
# 0                       NaN                    NaN                      NaN
# 1                       NaN                    NaN                      NaN
# 2     Opinion/Argumentation  Opinion/Argumentation  Information/Explanation
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
# ...                     ...                    ...                      ...
# 997                     NaN                    NaN   Promotion of a Product
# 998                     NaN                    NaN                      NaN
# 999                     NaN                    NaN                      NaN
# 1000                    NaN                    NaN                      NaN
# 1001                    NaN                    NaN                      NaN
#
#              tertiary_level_2         tertiary_level_3  split  \
# 0                         NaN                      NaN   test
# 1                         NaN                      NaN  train
# 2     Information/Explanation  Information/Explanation  train
# 3                         NaN                      NaN  train
# 4                         NaN                      NaN   test
# ...                       ...                      ...    ...
# 997    Promotion of a Product                Promotion  train
# 998                       NaN                      NaN  train
# 999                       NaN                      NaN  train
# 1000                      NaN                      NaN  train
# 1001                      NaN                      NaN   test
#
#                       domain                     GINCORE  \
# 0             www.pomurje.si                        News
# 1           www.ss-sezana.si     Information/Explanation
# 2     www.kamnik-starejsi.si                   Promotion
# 3          www.radiocelje.si                        News
# 4                 www.mtv.si                        News
# ...                      ...                         ...
# 997              khetanes.si     Information/Explanation
# 998            www.merkur.si  List of Summaries/Excerpts
# 999              www.sex2.si  List of Summaries/Excerpts
# 1000            www.ipsos.si       Opinion/Argumentation
# 1001            pogajanja.si  List of Summaries/Excerpts
#
#                                                    text  \
# 0     Šport <p/> Zimska liga malega nogometa sobota,...
# 1     JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2     Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
# 3     V novembru, mesecu preprečevanja odvisnosti, b...
# 4     Selena Gomez ponudila v poslušanje novi album ...
# ...                                                 ...
# 997   Projektne novine <p/> Promocijski projektni ča...
# 998   V raznoliki ponudbi tušev izberite popolno raz...
# 999   O izdelku Za znamko Dame stojita dve ženski, z...
# 1000  Razprava pogosto potegne na plano najprej tist...
# 1001  Pogajalska akadmija v letu 2014 02.02.2014 <p/...
#
#                                                 MT-text  text_length  \
# 0     Sport <p/> Winter Little League Football Satur...           93
# 1     JEDILNIK <p/> Search <p/> The main objective o...           76
# 2     Project INNOVAge and the Oreli Institute <p/> ...          232
# 3     In November, the month of addiction prevention...          158
# 4     Selena Gomez launches new album <p/> 16.07.201...           63
# ...                                                 ...          ...
# 997   Project News <p/> Promotional project newspape...           86
# 998   Choose the perfect shower to match your taste ...           50
# 999   About the product There are two women behind t...          295
# 1000  The debate often brings to the surface first t...          409
# 1001  Negotiation Academy 2014 02.02.2014 <p/> How t...           89
#
#                 FTD_pred
# 0              A8 (news)
# 1      A16 (information)
# 2        A12 (promotion)
# 3              A8 (news)
# 4              A8 (news)
# ...                  ...
# 997      A12 (promotion)
# 998      A12 (promotion)
# 999      A12 (promotion)
# 1000  A1 (argumentative)
# 1001     A12 (promotion)
#
# [1002 rows x 20 columns]

# %%
# Let's also apply the predictions to the MT GINCO set
ginco_df = ginco_df.rename(columns={"text":"Slovene_text", "CORE_main_pred":"CORE_main_pred_on_SL"})
ginco_df = ginco_df.rename(columns={"MT_text":"text"})

# %%
ginco_df.head(1)
# Out:
#      id                                                url  crawled   hard  \
# 0  3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014  False
#
#   primary_level_1 primary_level_2 primary_level_3 secondary_level_1  \
# 0  News/Reporting  News/Reporting  News/Reporting               NaN
#
#   secondary_level_2 secondary_level_3 tertiary_level_1 tertiary_level_2  \
# 0               NaN               NaN              NaN              NaN
#
#   tertiary_level_3 split          domain GINCORE  \
# 0              NaN  test  www.pomurje.si    News
#
#                                         Slovene_text  \
# 0  Šport <p/> Zimska liga malega nogometa sobota,...
#
#                                                 text  text_length  \
# 0  Sport <p/> Winter Little League Football Satur...           93
#
#   FTD_pred_on_SL
# 0      A8 (news)

# %%
ginco_df = predict_CORE(ginco_df, "GINCO-MT-GINCO-keeptext-with-all-information.csv")

# %%
# Let's save the final version
ginco_df = ginco_df.rename(columns={"text":"MT_text", "CORE_main_pred":"CORE_main_pred_on_MT"})

ginco_df.to_csv("GINCO-MT-GINCO-keeptext-with-all-information.csv", sep="\t")

# %%
ginco_df
# Out:
#            id                                                url  crawled  \
# 0        3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014
# 1        3726  http://www.ss-sezana.si/sss/index.php?option=c...     2014
# 2        5621  http://www.kamnik-starejsi.si/novice/144-sodel...     2014
# 3        3776  http://www.radiocelje.si/novica.php?id=13007&a...     2014
# 4        2102  http://www.mtv.si/novice/selena-gomez-ponudila...     2014
# ...       ...                                                ...      ...
# 997    374730  http://khetanes.si/sl-si/produkti/projektne-no...     2021
# 998    476885  https://www.merkur.si/navigacija/nasveti/kopal...     2021
# 999    674213        http://www.sex2.si/category/ocene-izdelkov/     2021
# 1000   975590  http://www.ipsos.si/VodenjeVIZ_VI_past_dvojne_...     2021
# 1001  1277644    https://pogajanja.si/?s=article&a=izpis&id=1221     2021
#
#        hard             primary_level_1             primary_level_2  \
# 0     False              News/Reporting              News/Reporting
# 1     False     Information/Explanation     Information/Explanation
# 2     False       Promotion of Services       Promotion of Services
# 3     False              News/Reporting              News/Reporting
# 4     False            Opinionated News            Opinionated News
# ...     ...                         ...                         ...
# 997   False     Information/Explanation     Information/Explanation
# 998   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 999   False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 1000  False       Opinion/Argumentation       Opinion/Argumentation
# 1001   True  List of Summaries/Excerpts  List of Summaries/Excerpts
#
#                  primary_level_3      secondary_level_1  \
# 0                 News/Reporting                    NaN
# 1        Information/Explanation                    NaN
# 2                      Promotion  Opinion/Argumentation
# 3                 News/Reporting                    NaN
# 4               Opinionated News                    NaN
# ...                          ...                    ...
# 997      Information/Explanation                    NaN
# 998   List of Summaries/Excerpts                    NaN
# 999   List of Summaries/Excerpts                    NaN
# 1000       Opinion/Argumentation                    NaN
# 1001  List of Summaries/Excerpts                    NaN
#
#           secondary_level_2      secondary_level_3  ...  \
# 0                       NaN                    NaN  ...
# 1                       NaN                    NaN  ...
# 2     Opinion/Argumentation  Opinion/Argumentation  ...
# 3                       NaN                    NaN  ...
# 4                       NaN                    NaN  ...
# ...                     ...                    ...  ...
# 997                     NaN                    NaN  ...
# 998                     NaN                    NaN  ...
# 999                     NaN                    NaN  ...
# 1000                    NaN                    NaN  ...
# 1001                    NaN                    NaN  ...
#
#              tertiary_level_2         tertiary_level_3  split  \
# 0                         NaN                      NaN   test
# 1                         NaN                      NaN  train
# 2     Information/Explanation  Information/Explanation  train
# 3                         NaN                      NaN  train
# 4                         NaN                      NaN   test
# ...                       ...                      ...    ...
# 997    Promotion of a Product                Promotion  train
# 998                       NaN                      NaN  train
# 999                       NaN                      NaN  train
# 1000                      NaN                      NaN  train
# 1001                      NaN                      NaN   test
#
#                       domain                     GINCORE  \
# 0             www.pomurje.si                        News
# 1           www.ss-sezana.si     Information/Explanation
# 2     www.kamnik-starejsi.si                   Promotion
# 3          www.radiocelje.si                        News
# 4                 www.mtv.si                        News
# ...                      ...                         ...
# 997              khetanes.si     Information/Explanation
# 998            www.merkur.si  List of Summaries/Excerpts
# 999              www.sex2.si  List of Summaries/Excerpts
# 1000            www.ipsos.si       Opinion/Argumentation
# 1001            pogajanja.si  List of Summaries/Excerpts
#
#                                            Slovene_text  \
# 0     Šport <p/> Zimska liga malega nogometa sobota,...
# 1     JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2     Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
# 3     V novembru, mesecu preprečevanja odvisnosti, b...
# 4     Selena Gomez ponudila v poslušanje novi album ...
# ...                                                 ...
# 997   Projektne novine <p/> Promocijski projektni ča...
# 998   V raznoliki ponudbi tušev izberite popolno raz...
# 999   O izdelku Za znamko Dame stojita dve ženski, z...
# 1000  Razprava pogosto potegne na plano najprej tist...
# 1001  Pogajalska akadmija v letu 2014 02.02.2014 <p/...
#
#                                                 MT_text text_length  \
# 0     Sport <p/> Winter Little League Football Satur...          93
# 1     JEDILNIK <p/> Search <p/> The main objective o...          76
# 2     Project INNOVAge and the Oreli Institute <p/> ...         232
# 3     In November, the month of addiction prevention...         158
# 4     Selena Gomez launches new album <p/> 16.07.201...          63
# ...                                                 ...         ...
# 997   Project News <p/> Promotional project newspape...          86
# 998   Choose the perfect shower to match your taste ...          50
# 999   About the product There are two women behind t...         295
# 1000  The debate often brings to the surface first t...         409
# 1001  Negotiation Academy 2014 02.02.2014 <p/> How t...          89
#
#           FTD_pred_on_SL      FTD_pred_on_MT
# 0              A8 (news)           A8 (news)
# 1      A16 (information)   A16 (information)
# 2        A12 (promotion)     A12 (promotion)
# 3              A8 (news)           A8 (news)
# 4              A8 (news)           A8 (news)
# ...                  ...                 ...
# 997      A12 (promotion)           A8 (news)
# 998      A12 (promotion)     A12 (promotion)
# 999      A12 (promotion)     A12 (promotion)
# 1000  A1 (argumentative)  A1 (argumentative)
# 1001     A12 (promotion)     A12 (promotion)
#
# [1002 rows x 21 columns]

# %%
# Analyse in how many cases do the labels on SL and MT text differ
ginco_df["agreement"] = np.where((ginco_df["CORE_main_pred_on_SL"] != ginco_df["CORE_main_pred_on_MT"]), "no", "yes")

ginco_df.head(3)
# Out:
#      id                                                url  crawled   hard  \
# 0  3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014  False
# 1  3726  http://www.ss-sezana.si/sss/index.php?option=c...     2014  False
# 2  5621  http://www.kamnik-starejsi.si/novice/144-sodel...     2014  False
#
#            primary_level_1          primary_level_2          primary_level_3  \
# 0           News/Reporting           News/Reporting           News/Reporting
# 1  Information/Explanation  Information/Explanation  Information/Explanation
# 2    Promotion of Services    Promotion of Services                Promotion
#
#        secondary_level_1      secondary_level_2      secondary_level_3  ...  \
# 0                    NaN                    NaN                    NaN  ...
# 1                    NaN                    NaN                    NaN  ...
# 2  Opinion/Argumentation  Opinion/Argumentation  Opinion/Argumentation  ...
#
#           tertiary_level_3  split                  domain  \
# 0                      NaN   test          www.pomurje.si
# 1                      NaN  train        www.ss-sezana.si
# 2  Information/Explanation  train  www.kamnik-starejsi.si
#
#                    GINCORE                                       Slovene_text  \
# 0                     News  Šport <p/> Zimska liga malega nogometa sobota,...
# 1  Information/Explanation  JEDILNIK <p/> Iskalnik <p/> Poglavitni cilj pr...
# 2                Promotion  Projekt INNOVAge in zavod Oreli <p/> Zavod Ore...
#
#                                              MT_text text_length  \
# 0  Sport <p/> Winter Little League Football Satur...          93
# 1  JEDILNIK <p/> Search <p/> The main objective o...          76
# 2  Project INNOVAge and the Oreli Institute <p/> ...         232
#
#       FTD_pred_on_SL     FTD_pred_on_MT agreement
# 0          A8 (news)          A8 (news)       yes
# 1  A16 (information)  A16 (information)       yes
# 2    A12 (promotion)    A12 (promotion)       yes
#
# [3 rows x 22 columns]

# %%
ginco_df[ginco_df["agreement"] == "no"]
# Out:
#              id                                                url  crawled  \
# 11         8887      http://www.zadovoljna.si/forum?post_id=960155     2014
# 13         9961  http://old.radiostudent.si/print.php?sid=30419...     2014
# 20         7967                        http://premisli.si/faq.html     2014
# 22         1247  http://zavod-emma.si/prijetno-druzenje-z-izmen...     2014
# 23         8760  http://www.viva.si/Zdrav-način-prehrane/2860/F...     2014
# ..          ...                                                ...      ...
# 968  19871313#3              https://bazar.coks.si/?cat=34&paged=9     2021
# 973    24071055   http://www.zvvs.si/?stran=novicedogodki&po=13/17     2021
# 987    33868957             http://splet.dc-dlan.si/teorija-spola/     2021
# 990    35970091  https://www.etno-muzej.si/sl/novice/sodelovanj...     2021
# 997      374730  http://khetanes.si/sl-si/produkti/projektne-no...     2021
#
#       hard             primary_level_1             primary_level_2  \
# 11   False                       Forum                       Forum
# 13   False            Opinionated News            Opinionated News
# 20   False                         FAQ                       Other
# 22   False            Opinionated News            Opinionated News
# 23   False                 Instruction                 Instruction
# ..     ...                         ...                         ...
# 968  False            Opinionated News            Opinionated News
# 973  False  List of Summaries/Excerpts  List of Summaries/Excerpts
# 987  False       Opinion/Argumentation       Opinion/Argumentation
# 990  False              News/Reporting              News/Reporting
# 997  False     Information/Explanation     Information/Explanation
#
#                 primary_level_3        secondary_level_1  \
# 11                        Forum                      NaN
# 13             Opinionated News                      NaN
# 20                        Other                      NaN
# 22             Opinionated News                      NaN
# 23                  Instruction   Promotion of a Product
# ..                          ...                      ...
# 968            Opinionated News                      NaN
# 973  List of Summaries/Excerpts                      NaN
# 987       Opinion/Argumentation  Information/Explanation
# 990              News/Reporting                      NaN
# 997     Information/Explanation                      NaN
#
#            secondary_level_2        secondary_level_3  ... tertiary_level_3  \
# 11                       NaN                      NaN  ...              NaN
# 13                       NaN                      NaN  ...              NaN
# 20                       NaN                      NaN  ...              NaN
# 22                       NaN                      NaN  ...              NaN
# 23    Promotion of a Product                Promotion  ...              NaN
# ..                       ...                      ...  ...              ...
# 968                      NaN                      NaN  ...              NaN
# 973                      NaN                      NaN  ...              NaN
# 987  Information/Explanation  Information/Explanation  ...              NaN
# 990                      NaN                      NaN  ...        Promotion
# 997                      NaN                      NaN  ...        Promotion
#
#      split               domain                     GINCORE  \
# 11   train    www.zadovoljna.si                       Forum
# 13   train  old.radiostudent.si                        News
# 20    test          premisli.si                         FAQ
# 22     dev        zavod-emma.si                        News
# 23   train          www.viva.si                 Instruction
# ..     ...                  ...                         ...
# 968   test        bazar.coks.si                        News
# 973  train          www.zvvs.si  List of Summaries/Excerpts
# 987  train     splet.dc-dlan.si       Opinion/Argumentation
# 990  train    www.etno-muzej.si                        News
# 997  train          khetanes.si     Information/Explanation
#
#                                           Slovene_text  \
# 11   Rozka30 glede Bele masajke se strinjam. Dobra ...
# 13   Lezbični in feministični klub v vsako vas Sobo...
# 20   Naročila sprejemam na elektronsko naslov emobi...
# 22   PRIJETNO DRUŽENJE Z IZMENJAVO RABLJENIH OBLAČI...
# 23   Fižol <p/> Povezano <p/> Superživilo <p/> V zg...
# ..                                                 ...
# 968  Kaj ima skupnega vseh 500 najzmogljivejših sup...
# 973  Domžalski veterani smo priredili že 24. spomin...
# 987  info@dc-dlan.si <p/> 0590 80 616 <p/> CONTACT ...
# 990  Slovenski etnografski muzej <p/> Sodelovanje S...
# 997  Projektne novine <p/> Promocijski projektni ča...
#
#                                                MT_text text_length  \
# 11   Rozka30 I agree about the White Masai. Good bo...         601
# 13   A lesbian and feminist club in every village S...         956
# 20   Orders are accepted by e-mail to emobil@premis...         686
# 22   FRIENDLY FRIENDSHIP THROUGH EXCHANGE OF USED C...         190
# 23   Beans <p/> Related <p/> Superfood <p/> Histori...         750
# ..                                                 ...         ...
# 968  What do the 500 most powerful supercomputers h...         394
# 973  Domžale veterans organised the 24th commemorat...         319
# 987  info@dc-dlan.si <p/> 0590 80 616 <p/> CONTACT ...        1879
# 990  Slovenian Ethnographic Museum <p/> Cooperation...          51
# 997  Project News <p/> Promotional project newspape...          86
#
#         FTD_pred_on_SL      FTD_pred_on_MT agreement
# 11        A17 (review)      A11 (personal)        no
# 13        A17 (review)           A8 (news)        no
# 20     A12 (promotion)    A7 (instruction)        no
# 22     A12 (promotion)  A1 (argumentative)        no
# 23   A16 (information)    A7 (instruction)        no
# ..                 ...                 ...       ...
# 968          A8 (news)  A1 (argumentative)        no
# 973       A17 (review)           A8 (news)        no
# 987  A16 (information)  A1 (argumentative)        no
# 990    A12 (promotion)           A8 (news)        no
# 997    A12 (promotion)           A8 (news)        no
#
# [227 rows x 22 columns]

# %% [markdown]
# ## Predict CORE to FTD

# %%
# Import data
ftd = pd.read_csv("data-sheets-with-all-info/FTD-dataset-with-all-information.csv", sep="\t", index_col = 0)

ftd
# Out:
#                          ID              labels Multiple labels  \
# 0         __id__1-syndicate  A1 (argumentative)             NaN
# 1         __id__2-syndicate  A1 (argumentative)             NaN
# 2         __id__3-syndicate  A1 (argumentative)             NaN
# 3         __id__4-syndicate  A1 (argumentative)             NaN
# 4         __id__5-syndicate  A1 (argumentative)             NaN
# ...                     ...                 ...             ...
# 1681  __id__1682-britannica  A1 (argumentative)             NaN
# 1682  __id__1683-britannica   A16 (information)             NaN
# 1683  __id__1684-britannica  A1 (argumentative)             NaN
# 1684  __id__1685-britannica     A12 (promotion)             NaN
# 1685  __id__1686-britannica   A16 (information)             NaN
#
#                                                    text  length  \
# 0     BMW's and Chinese Justice * * * * * In most pl...     975
# 1     China and a New Balance of Power SHANGHAI – Th...     956
# 2     China and Russia in the New World Disorder Can...     978
# 3     The Roots of Chinese / Japanese Rivalry BOSTON...     957
# 4     China's Cyber-Warriors NEW DELHI – The world n...    1034
# ...                                                 ...     ...
# 1681  In Eichmann in Jerusalem , Hannah Arendt descr...     610
# 1682  The vast expanse of the African continent span...     381
# 1683  Lance Corporal Samantha L. Jones , USMC Politi...    2482
# 1684  Courtesy of the Victoria and Albert Museum , L...     390
# 1685  In their quest for survival , plants have evol...    1027
#
#           GINCO_downcast_pred
# 0              News/Reporting
# 1     Information/Explanation
# 2       Opinion/Argumentation
# 3       Opinion/Argumentation
# 4              News/Reporting
# ...                       ...
# 1681  Information/Explanation
# 1682  Information/Explanation
# 1683  Information/Explanation
# 1684  Information/Explanation
# 1685  Information/Explanation
#
# [1553 rows x 6 columns]

# %%
ftd_predicted = predict_CORE(ftd, "FTD-dataset-with-all-information.csv")

ftd_predicted
# Out:
#                          ID              labels Multiple labels  \
# 0         __id__1-syndicate  A1 (argumentative)             NaN
# 1         __id__2-syndicate  A1 (argumentative)             NaN
# 2         __id__3-syndicate  A1 (argumentative)             NaN
# 3         __id__4-syndicate  A1 (argumentative)             NaN
# 4         __id__5-syndicate  A1 (argumentative)             NaN
# ...                     ...                 ...             ...
# 1681  __id__1682-britannica  A1 (argumentative)             NaN
# 1682  __id__1683-britannica   A16 (information)             NaN
# 1683  __id__1684-britannica  A1 (argumentative)             NaN
# 1684  __id__1685-britannica     A12 (promotion)             NaN
# 1685  __id__1686-britannica   A16 (information)             NaN
#
#                                                    text  length  \
# 0     BMW's and Chinese Justice * * * * * In most pl...     975
# 1     China and a New Balance of Power SHANGHAI – Th...     956
# 2     China and Russia in the New World Disorder Can...     978
# 3     The Roots of Chinese / Japanese Rivalry BOSTON...     957
# 4     China's Cyber-Warriors NEW DELHI – The world n...    1034
# ...                                                 ...     ...
# 1681  In Eichmann in Jerusalem , Hannah Arendt descr...     610
# 1682  The vast expanse of the African continent span...     381
# 1683  Lance Corporal Samantha L. Jones , USMC Politi...    2482
# 1684  Courtesy of the Victoria and Albert Museum , L...     390
# 1685  In their quest for survival , plants have evol...    1027
#
#           GINCO_downcast_pred   MT-GINCO_downcast_pred
# 0              News/Reporting           News/Reporting
# 1     Information/Explanation    Opinion/Argumentation
# 2       Opinion/Argumentation    Opinion/Argumentation
# 3       Opinion/Argumentation    Opinion/Argumentation
# 4              News/Reporting           News/Reporting
# ...                       ...                      ...
# 1681  Information/Explanation  Information/Explanation
# 1682  Information/Explanation  Information/Explanation
# 1683  Information/Explanation  Information/Explanation
# 1684  Information/Explanation  Information/Explanation
# 1685  Information/Explanation  Information/Explanation
#
# [1553 rows x 7 columns]
