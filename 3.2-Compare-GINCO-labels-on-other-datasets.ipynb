# %% [markdown]
# ## Compare GINCO and MT-GINCO labels with FTD

# %% [markdown]
# Based on the GINCO and MT-GINCO predictions that we applied to the FTD, I'll analyse how the FTD labels are connected with GINCO labels.

# %%
import pandas as pd
import numpy as np

# %%
# Import the FTD dataset
ftd = pd.read_csv("data-sheets-with-all-info/FTD-dataset-with-all-information.csv", sep="\t", index_col=0)
ftd.head(3)
# Out:
#                   ID              labels Multiple labels  \
# 0  __id__1-syndicate  A1 (argumentative)             NaN
# 1  __id__2-syndicate  A1 (argumentative)             NaN
# 2  __id__3-syndicate  A1 (argumentative)             NaN
#
#                                                 text  length  \
# 0  BMW's and Chinese Justice * * * * * In most pl...     975
# 1  China and a New Balance of Power SHANGHAI – Th...     956
# 2  China and Russia in the New World Disorder Can...     978
#
#        GINCO_downcast_pred MT-GINCO_downcast_pred
# 0           News/Reporting         News/Reporting
# 1  Information/Explanation  Opinion/Argumentation
# 2    Opinion/Argumentation  Opinion/Argumentation

# %%
# Analyse agreement of the labels
ftd["agreement"] = np.where(ftd['GINCO_downcast_pred'] == ftd['MT-GINCO_downcast_pred'], "yes", "no")

ftd["agreement"].value_counts()
# Out:
# yes    1206
# no      347
# Name: agreement, dtype: int64

# %%
347/1206
# Out:
# 0.2877280265339967

# %% [markdown]
# The predictions of GINCO and MT-GINCO classifier differ in 347 instances (29%).

# %%
ftd.columns
# Out:
# Index(['ID', 'labels', 'Multiple labels', 'text', 'length',
#        'GINCO_downcast_pred', 'MT-GINCO_downcast_pred', 'agreement'],
#       dtype='object')

# %%
ftd["Multiple labels"].value_counts()
# Out:
# y    139
# Name: Multiple labels, dtype: int64

# %%
# Discard texts with multiple labels
ftd = ftd[ftd["Multiple labels"] != "y"]
ftd.describe(include="all")
# Out:
#                        ID              labels Multiple labels  \
# count                1414                1414               0
# unique               1414                  10               0
# top     __id__1-syndicate  A1 (argumentative)             NaN
# freq                    1                 296             NaN
# mean                  NaN                 NaN             NaN
# std                   NaN                 NaN             NaN
# min                   NaN                 NaN             NaN
# 25%                   NaN                 NaN             NaN
# 50%                   NaN                 NaN             NaN
# 75%                   NaN                 NaN             NaN
# max                   NaN                 NaN             NaN
#
#                                                      text         length  \
# count                                                1414    1414.000000
# unique                                               1414            NaN
# top     BMW's and Chinese Justice * * * * * In most pl...            NaN
# freq                                                    1            NaN
# mean                                                  NaN    1445.212164
# std                                                   NaN    4989.570842
# min                                                   NaN      31.000000
# 25%                                                   NaN     224.000000
# 50%                                                   NaN     495.000000
# 75%                                                   NaN    1144.250000
# max                                                   NaN  146922.000000
#
#             GINCO_downcast_pred   MT-GINCO_downcast_pred agreement
# count                      1414                     1414      1414
# unique                        9                        9         2
# top     Information/Explanation  Information/Explanation       yes
# freq                        407                      311      1118
# mean                        NaN                      NaN       NaN
# std                         NaN                      NaN       NaN
# min                         NaN                      NaN       NaN
# 25%                         NaN                      NaN       NaN
# 50%                         NaN                      NaN       NaN
# 75%                         NaN                      NaN       NaN
# max                         NaN                      NaN       NaN

# %%
# Analyse how GINCO primary labels are connected with FTD labels based on the prediction
pd.crosstab(ftd['labels'], ftd["GINCO_downcast_pred"], normalize="index")
# Out:
# GINCO_downcast_pred     Forum  Information/Explanation  Instruction  \
# labels
# A1 (argumentative)   0.013514                 0.263514     0.000000
# A11 (personal)       0.088608                 0.037975     0.012658
# A12 (promotion)      0.011719                 0.156250     0.023438
# A14 (academic)       0.000000                 0.810127     0.000000
# A16 (information)    0.000000                 0.815476     0.000000
# A17 (review)         0.088235                 0.191176     0.000000
# A4 (fiction)         0.000000                 0.202128     0.000000
# A7 (instruction)     0.000000                 0.139394     0.612121
# A8 (news)            0.000000                 0.095588     0.000000
# A9 (legal)           0.000000                 0.232877     0.013699
#
# GINCO_downcast_pred  Legal/Regulation  List of Summaries/Excerpts  \
# labels
# A1 (argumentative)           0.010135                    0.091216
# A11 (personal)               0.000000                    0.037975
# A12 (promotion)              0.000000                    0.070312
# A14 (academic)               0.012658                    0.012658
# A16 (information)            0.005952                    0.053571
# A17 (review)                 0.000000                    0.147059
# A4 (fiction)                 0.000000                    0.000000
# A7 (instruction)             0.000000                    0.090909
# A8 (news)                    0.014706                    0.110294
# A9 (legal)                   0.643836                    0.000000
#
# GINCO_downcast_pred  News/Reporting  Opinion/Argumentation     Other  \
# labels
# A1 (argumentative)         0.246622               0.229730  0.094595
# A11 (personal)             0.025316               0.696203  0.101266
# A12 (promotion)            0.093750               0.015625  0.035156
# A14 (academic)             0.037975               0.088608  0.037975
# A16 (information)          0.065476               0.023810  0.005952
# A17 (review)               0.132353               0.132353  0.014706
# A4 (fiction)               0.021277               0.234043  0.542553
# A7 (instruction)           0.030303               0.030303  0.036364
# A8 (news)                  0.742647               0.007353  0.029412
# A9 (legal)                 0.013699               0.000000  0.095890
#
# GINCO_downcast_pred  Promotion
# labels
# A1 (argumentative)    0.050676
# A11 (personal)        0.000000
# A12 (promotion)       0.593750
# A14 (academic)        0.000000
# A16 (information)     0.029762
# A17 (review)          0.294118
# A4 (fiction)          0.000000
# A7 (instruction)      0.060606
# A8 (news)             0.000000
# A9 (legal)            0.000000

# %%
pd.crosstab(ftd['labels'], ftd["GINCO_downcast_pred"], normalize="index").to_dict("index")
# Out:
# {'A1 (argumentative)': {'Forum': 0.013513513513513514,
#   'Information/Explanation': 0.2635135135135135,
#   'Instruction': 0.0,
#   'Legal/Regulation': 0.010135135135135136,
#   'List of Summaries/Excerpts': 0.09121621621621621,
#   'News/Reporting': 0.24662162162162163,
#   'Opinion/Argumentation': 0.22972972972972974,
#   'Other': 0.0945945945945946,
#   'Promotion': 0.05067567567567568},
#  'A11 (personal)': {'Forum': 0.08860759493670886,
#   'Information/Explanation': 0.0379746835443038,
#   'Instruction': 0.012658227848101266,
#   'Legal/Regulation': 0.0,
#   'List of Summaries/Excerpts': 0.0379746835443038,
#   'News/Reporting': 0.02531645569620253,
#   'Opinion/Argumentation': 0.6962025316455697,
#   'Other': 0.10126582278481013,
#   'Promotion': 0.0},
#  'A12 (promotion)': {'Forum': 0.01171875,
#   'Information/Explanation': 0.15625,
#   'Instruction': 0.0234375,
#   'Legal/Regulation': 0.0,
#   'List of Summaries/Excerpts': 0.0703125,
#   'News/Reporting': 0.09375,
#   'Opinion/Argumentation': 0.015625,
#   'Other': 0.03515625,
#   'Promotion': 0.59375},
#  'A14 (academic)': {'Forum': 0.0,
#   'Information/Explanation': 0.810126582278481,
#   'Instruction': 0.0,
#   'Legal/Regulation': 0.012658227848101266,
#   'List of Summaries/Excerpts': 0.012658227848101266,
#   'News/Reporting': 0.0379746835443038,
#   'Opinion/Argumentation': 0.08860759493670886,
#   'Other': 0.0379746835443038,
#   'Promotion': 0.0},
#  'A16 (information)': {'Forum': 0.0,
#   'Information/Explanation': 0.8154761904761905,
#   'Instruction': 0.0,
#   'Legal/Regulation': 0.005952380952380952,
#   'List of Summaries/Excerpts': 0.05357142857142857,
#   'News/Reporting': 0.06547619047619048,
#   'Opinion/Argumentation': 0.023809523809523808,
#   'Other': 0.005952380952380952,
#   'Promotion': 0.02976190476190476},
#  'A17 (review)': {'Forum': 0.08823529411764706,
#   'Information/Explanation': 0.19117647058823528,
#   'Instruction': 0.0,
#   'Legal/Regulation': 0.0,
#   'List of Summaries/Excerpts': 0.14705882352941177,
#   'News/Reporting': 0.1323529411764706,
#   'Opinion/Argumentation': 0.1323529411764706,
#   'Other': 0.014705882352941176,
#   'Promotion': 0.29411764705882354},
#  'A4 (fiction)': {'Forum': 0.0,
#   'Information/Explanation': 0.20212765957446807,
#   'Instruction': 0.0,
#   'Legal/Regulation': 0.0,
#   'List of Summaries/Excerpts': 0.0,
#   'News/Reporting': 0.02127659574468085,
#   'Opinion/Argumentation': 0.23404255319148937,
#   'Other': 0.5425531914893617,
#   'Promotion': 0.0},
#  'A7 (instruction)': {'Forum': 0.0,
#   'Information/Explanation': 0.1393939393939394,
#   'Instruction': 0.6121212121212121,
#   'Legal/Regulation': 0.0,
#   'List of Summaries/Excerpts': 0.09090909090909091,
#   'News/Reporting': 0.030303030303030304,
#   'Opinion/Argumentation': 0.030303030303030304,
#   'Other': 0.03636363636363636,
#   'Promotion': 0.06060606060606061},
#  'A8 (news)': {'Forum': 0.0,
#   'Information/Explanation': 0.09558823529411764,
#   'Instruction': 0.0,
#   'Legal/Regulation': 0.014705882352941176,
#   'List of Summaries/Excerpts': 0.11029411764705882,
#   'News/Reporting': 0.7426470588235294,
#   'Opinion/Argumentation': 0.007352941176470588,
#   'Other': 0.029411764705882353,
#   'Promotion': 0.0},
#  'A9 (legal)': {'Forum': 0.0,
#   'Information/Explanation': 0.2328767123287671,
#   'Instruction': 0.0136986301369863,
#   'Legal/Regulation': 0.6438356164383562,
#   'List of Summaries/Excerpts': 0.0,
#   'News/Reporting': 0.0136986301369863,
#   'Opinion/Argumentation': 0.0,
#   'Other': 0.0958904109589041,
#   'Promotion': 0.0}}

# %% [markdown]
# What we can see based on the GINCO predictions on the FTD labels, is (first, the information for prediction of GINCO-downcast is given, followed by the information what is different on predictions by the MT-GINCO-downcast model):)

# %% [markdown]
# ## Compare GINCO labels with CORE

# %%
# Import the CORE dataset
core_df = pd.read_csv("data-sheets-with-all-info/CORE-all-information.csv", index_col = 0, sep="\t")

core_df.head(3)
# Out:
#          label                                               text  split  \
# 0  NA OP SR OB  The Top TEN 'Whiniest Sets of Fans' in English...  train
# 1        NA NE  Ferry consultation needs deeper questions, say...  train
# 2        ID DF  I'v been recording and mixing music for about ...  train
#
#   main_labels sublabels  Len  main_len  sub_len      GINCORE  \
# 0       NA OP     SR OB    4         2        2  NA OP SR OB
# 1         NaN        NE    2         1        1         News
# 2          ID        DF    2         1        1        Forum
#
#          full_names  main_labels_full_names FTD_pred GINCO_downcast_pred  \
# 0             SR OB                   NA OP      NaN                 NaN
# 1  News Report/Blog               Narrative      NaN                 NaN
# 2  Discussion Forum  Interactive Discussion      NaN                 NaN
#
#   MT-GINCO_downcast_pred
# 0                    NaN
# 1                    NaN
# 2                    NaN

# %%
# Filter out only instances that have GINCO prediction
core_df = core_df.dropna(subset = ["GINCO_downcast_pred"])

core_df.shape
# Out:
# (1500, 14)

# %%
core_df.columns
# Out:
# Index(['label', 'text', 'split', 'main_labels', 'sublabels', 'Len', 'main_len',
#        'sub_len', 'GINCORE', 'full_names', 'main_labels_full_names',
#        'FTD_pred', 'GINCO_downcast_pred', 'MT-GINCO_downcast_pred'],
#       dtype='object')

# %%
# Discard uninteresting columns
core_df = core_df[['GINCORE', 'sub_len', 'full_names', 'main_len', 'main_labels_full_names','FTD_pred', 'GINCO_downcast_pred', 'MT-GINCO_downcast_pred']]

core_df
# Out:
#                      GINCORE  sub_len        full_names  main_len  \
# 14                      News        1     Sports Report         1
# 16                      News        1  News Report/Blog         1
# 23                      News        1  News Report/Blog         1
# 54                      News        1  News Report/Blog         1
# 57                      News        1  News Report/Blog         1
# ...                      ...      ...               ...       ...
# 48378  Opinion/Argumentation        1      Opinion Blog         1
# 48403                   News        1  News Report/Blog         1
# 48405  Opinion/Argumentation        1      Opinion Blog         1
# 48419                   News        1  News Report/Blog         1
# 48423                   News        1  News Report/Blog         1
#
#       main_labels_full_names            FTD_pred         GINCO_downcast_pred  \
# 14                 Narrative  A1 (argumentative)       Opinion/Argumentation
# 16                 Narrative           A8 (news)              News/Reporting
# 23                 Narrative  A1 (argumentative)       Opinion/Argumentation
# 54                 Narrative        A17 (review)              News/Reporting
# 57                 Narrative        A17 (review)  List of Summaries/Excerpts
# ...                      ...                 ...                         ...
# 48378                Opinion  A1 (argumentative)     Information/Explanation
# 48403              Narrative  A1 (argumentative)              News/Reporting
# 48405                Opinion  A1 (argumentative)              News/Reporting
# 48419              Narrative           A8 (news)              News/Reporting
# 48423              Narrative           A8 (news)              News/Reporting
#
#            MT-GINCO_downcast_pred
# 14          Opinion/Argumentation
# 16                 News/Reporting
# 23          Opinion/Argumentation
# 54                 News/Reporting
# 57     List of Summaries/Excerpts
# ...                           ...
# 48378     Information/Explanation
# 48403              News/Reporting
# 48405              News/Reporting
# 48419              News/Reporting
# 48423              News/Reporting
#
# [1500 rows x 8 columns]

# %%
# Analyze in how many instance do GINCO and MT-GINCO predictions differ

core_df["agreement"] = np.where(core_df['GINCO_downcast_pred'] == core_df['MT-GINCO_downcast_pred'], "yes", "no")

core_df
# Out:
#                      GINCORE  sub_len        full_names  main_len  \
# 14                      News        1     Sports Report         1
# 16                      News        1  News Report/Blog         1
# 23                      News        1  News Report/Blog         1
# 54                      News        1  News Report/Blog         1
# 57                      News        1  News Report/Blog         1
# ...                      ...      ...               ...       ...
# 48378  Opinion/Argumentation        1      Opinion Blog         1
# 48403                   News        1  News Report/Blog         1
# 48405  Opinion/Argumentation        1      Opinion Blog         1
# 48419                   News        1  News Report/Blog         1
# 48423                   News        1  News Report/Blog         1
#
#       main_labels_full_names            FTD_pred         GINCO_downcast_pred  \
# 14                 Narrative  A1 (argumentative)       Opinion/Argumentation
# 16                 Narrative           A8 (news)              News/Reporting
# 23                 Narrative  A1 (argumentative)       Opinion/Argumentation
# 54                 Narrative        A17 (review)              News/Reporting
# 57                 Narrative        A17 (review)  List of Summaries/Excerpts
# ...                      ...                 ...                         ...
# 48378                Opinion  A1 (argumentative)     Information/Explanation
# 48403              Narrative  A1 (argumentative)              News/Reporting
# 48405                Opinion  A1 (argumentative)              News/Reporting
# 48419              Narrative           A8 (news)              News/Reporting
# 48423              Narrative           A8 (news)              News/Reporting
#
#            MT-GINCO_downcast_pred agreement
# 14          Opinion/Argumentation       yes
# 16                 News/Reporting       yes
# 23          Opinion/Argumentation       yes
# 54                 News/Reporting       yes
# 57     List of Summaries/Excerpts       yes
# ...                           ...       ...
# 48378     Information/Explanation       yes
# 48403              News/Reporting       yes
# 48405              News/Reporting       yes
# 48419              News/Reporting       yes
# 48423              News/Reporting       yes
#
# [1500 rows x 9 columns]

# %%
core_df.agreement.value_counts()
# Out:
# yes    1235
# no      265
# Name: agreement, dtype: int64

# %%
265/1500
# Out:
# 0.17666666666666667

# %% [markdown]
# The GINCO and MT-GINCO predictions differ only in case of 265 instances (18% of instances).

# %% [markdown]
# ### CORE-main

# %%
# Analyse how CORE main labels are connected with GINCO labels based on the prediction

# Filter out instances that have multiple main labels
main_labels = core_df[core_df["main_len"] == 1]

pd.crosstab(main_labels["main_labels_full_names"], main_labels["FTD_pred"], normalize="index")
# Out:
# FTD_pred                               A1 (argumentative)  A11 (personal)  \
# main_labels_full_names
# How-To/Instructional                             0.043011        0.118280
# Informational Description/Explanation            0.189058        0.020776
# Informational Persuasion                         0.185345        0.021552
# Interactive Discussion                           0.315702        0.289256
# Lyrical                                          0.040650        0.577236
# Narrative                                        0.228284        0.133191
# Opinion                                          0.467799        0.101203
# Spoken                                           0.304348        0.278261
#
# FTD_pred                               A12 (promotion)  A14 (academic)  \
# main_labels_full_names
# How-To/Instructional                          0.093190        0.000000
# Informational Description/Explanation         0.228532        0.052632
# Informational Persuasion                      0.400862        0.000000
# Interactive Discussion                        0.047934        0.009917
# Lyrical                                       0.048780        0.000000
# Narrative                                     0.032002        0.002743
# Opinion                                       0.061571        0.000708
# Spoken                                        0.060870        0.000000
#
# FTD_pred                               A16 (information)  A17 (review)  \
# main_labels_full_names
# How-To/Instructional                            0.003584      0.021505
# Informational Description/Explanation           0.213989      0.089335
# Informational Persuasion                        0.030172      0.258621
# Interactive Discussion                          0.028099      0.041322
# Lyrical                                         0.032520      0.121951
# Narrative                                       0.029259      0.067662
# Opinion                                         0.012739      0.230715
# Spoken                                          0.000000      0.252174
#
# FTD_pred                               A4 (fiction)  A7 (instruction)  \
# main_labels_full_names
# How-To/Instructional                       0.000000          0.713262
# Informational Description/Explanation      0.004848          0.106648
# Informational Persuasion                   0.012931          0.077586
# Interactive Discussion                     0.008264          0.239669
# Lyrical                                    0.089431          0.081301
# Narrative                                  0.017373          0.006400
# Opinion                                    0.012739          0.083510
# Spoken                                     0.017391          0.008696
#
# FTD_pred                               A8 (news)  A9 (legal)
# main_labels_full_names
# How-To/Instructional                    0.000000    0.007168
# Informational Description/Explanation   0.059557    0.034626
# Informational Persuasion                0.004310    0.008621
# Interactive Discussion                  0.014876    0.004959
# Lyrical                                 0.008130    0.000000
# Narrative                               0.480951    0.002133
# Opinion                                 0.029016    0.000000
# Spoken                                  0.078261    0.000000

# %%
main_labels["main_labels_full_names"].value_counts()
# Out:
# Narrative                                3281
# Informational Description/Explanation    1444
# Opinion                                  1413
# Interactive Discussion                    605
# How-To/Instructional                      279
# Informational Persuasion                  232
# Lyrical                                   123
# Spoken                                    115
# Name: main_labels_full_names, dtype: int64

# %%
main_labels["main_labels_full_names"].unique()
# Out:
# array(['Interactive Discussion', 'Narrative', 'Opinion',
#        'Informational Description/Explanation', 'How-To/Instructional',
#        'Lyrical', 'Informational Persuasion', 'Spoken'], dtype=object)

# %%
pd.crosstab(main_labels["main_labels_full_names"], main_labels["FTD_pred"], normalize="index").to_dict("index")
# Out:
# {'How-To/Instructional': {'A1 (argumentative)': 0.043010752688172046,
#   'A11 (personal)': 0.11827956989247312,
#   'A12 (promotion)': 0.0931899641577061,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0035842293906810036,
#   'A17 (review)': 0.021505376344086023,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.7132616487455197,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.007168458781362007},
#  'Informational Description/Explanation': {'A1 (argumentative)': 0.18905817174515235,
#   'A11 (personal)': 0.02077562326869806,
#   'A12 (promotion)': 0.22853185595567868,
#   'A14 (academic)': 0.05263157894736842,
#   'A16 (information)': 0.21398891966759004,
#   'A17 (review)': 0.08933518005540166,
#   'A4 (fiction)': 0.004847645429362881,
#   'A7 (instruction)': 0.10664819944598337,
#   'A8 (news)': 0.05955678670360111,
#   'A9 (legal)': 0.03462603878116344},
#  'Informational Persuasion': {'A1 (argumentative)': 0.1853448275862069,
#   'A11 (personal)': 0.021551724137931036,
#   'A12 (promotion)': 0.40086206896551724,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.03017241379310345,
#   'A17 (review)': 0.25862068965517243,
#   'A4 (fiction)': 0.01293103448275862,
#   'A7 (instruction)': 0.07758620689655173,
#   'A8 (news)': 0.004310344827586207,
#   'A9 (legal)': 0.008620689655172414},
#  'Interactive Discussion': {'A1 (argumentative)': 0.315702479338843,
#   'A11 (personal)': 0.2892561983471074,
#   'A12 (promotion)': 0.047933884297520664,
#   'A14 (academic)': 0.009917355371900827,
#   'A16 (information)': 0.02809917355371901,
#   'A17 (review)': 0.04132231404958678,
#   'A4 (fiction)': 0.008264462809917356,
#   'A7 (instruction)': 0.2396694214876033,
#   'A8 (news)': 0.01487603305785124,
#   'A9 (legal)': 0.0049586776859504135},
#  'Lyrical': {'A1 (argumentative)': 0.04065040650406504,
#   'A11 (personal)': 0.5772357723577236,
#   'A12 (promotion)': 0.04878048780487805,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.032520325203252036,
#   'A17 (review)': 0.12195121951219512,
#   'A4 (fiction)': 0.08943089430894309,
#   'A7 (instruction)': 0.08130081300813008,
#   'A8 (news)': 0.008130081300813009,
#   'A9 (legal)': 0.0},
#  'Narrative': {'A1 (argumentative)': 0.2282840597378848,
#   'A11 (personal)': 0.1331911002743066,
#   'A12 (promotion)': 0.03200243828101189,
#   'A14 (academic)': 0.0027430661383724473,
#   'A16 (information)': 0.02925937214263944,
#   'A17 (review)': 0.0676622980798537,
#   'A4 (fiction)': 0.017372752209692168,
#   'A7 (instruction)': 0.006400487656202377,
#   'A8 (news)': 0.48095092959463576,
#   'A9 (legal)': 0.0021334958854007926},
#  'Opinion': {'A1 (argumentative)': 0.4677990092002831,
#   'A11 (personal)': 0.10120311394196745,
#   'A12 (promotion)': 0.06157112526539278,
#   'A14 (academic)': 0.0007077140835102619,
#   'A16 (information)': 0.012738853503184714,
#   'A17 (review)': 0.23071479122434538,
#   'A4 (fiction)': 0.012738853503184714,
#   'A7 (instruction)': 0.0835102618542109,
#   'A8 (news)': 0.029016277423920735,
#   'A9 (legal)': 0.0},
#  'Spoken': {'A1 (argumentative)': 0.30434782608695654,
#   'A11 (personal)': 0.2782608695652174,
#   'A12 (promotion)': 0.06086956521739131,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.25217391304347825,
#   'A4 (fiction)': 0.017391304347826087,
#   'A7 (instruction)': 0.008695652173913044,
#   'A8 (news)': 0.0782608695652174,
#   'A9 (legal)': 0.0}}

# %% [markdown]
# Comparison of main CORE labels and FTD labels:
#
# 1. Well-connected:
# * 'How-To/Instructional': 'A7 (instruction)': 0.713
#
# 2. Not well connected (no clear majority label/majority label does not seem to be appropriate):
# * 'Interactive Discussion': mostly 'A1 (argumentative)': 0.315 (percentage of instances of Interactive Discussion, identified as A1) + 'A11 (personal)': 0.289,  'A7 (instruction)': 0.239
# * 'Narrative': 'A8 (news)': 0.48, 'A1 (argumentative)': 0.228
# * 'Opinion': 'A1 (argumentative)': 0.467, 'A17 (review)': 0.230
# * 'Informational Description/Explanation': A12 (promotion)': 0.228, 'A16 (information)': 0.21, 'A1 (argumentative)': 0.189
# * 'Lyrical': 'A11 (personal)': 0.577
# * 'Informational Persuasion': 'A12 (promotion)': 0.40, 'A1 (argumentative)': 0.185, 'A17 (review)': 0.258
# * 'Spoken': 'A1 (argumentative)': 0.30, 'A11 (personal)': 0.278, 'A17 (review)': 0.252

# %% [markdown]
# ### CORE-sub

# %%
core_df.head(2)
# Out:
#    GINCORE  sub_len        full_names  main_len  main_labels_full_names  \
# 6    Forum        1  Discussion Forum         1  Interactive Discussion
# 14    News        1     Sports Report         1               Narrative
#
#               FTD_pred
# 6       A11 (personal)
# 14  A1 (argumentative)

# %%
# Analyse how CORE sub labels are connected with FTD labels based on the prediction

# Filter out instances that have multiple main labels
sub_labels = core_df[core_df["sub_len"] == 1]

pd.crosstab(sub_labels["full_names"], sub_labels["FTD_pred"], normalize="index")
# Out:
# FTD_pred                         A1 (argumentative)  A11 (personal)  \
# full_names
# Advertisement                              0.000000        0.000000
# Advice                                     0.172043        0.139785
# Course Materials                           0.173913        0.000000
# Description of a Person                    0.098039        0.058824
# Description of a Thing                     0.139800        0.021398
# Description with Intent to Sell            0.082192        0.018265
# Discussion Forum                           0.374359        0.320513
# Editorial                                  0.923077        0.000000
# Encyclopedia Article                       0.095238        0.009524
# FAQ about How-to                           0.000000        0.000000
# FAQ about Information                      0.060000        0.020000
# Formal Speech                              0.777778        0.111111
# Historical Article                         0.364706        0.000000
# How-to                                     0.057034        0.076046
# Information Blog                           0.290850        0.039216
# Interview                                  0.180851        0.265957
# Legal terms                                0.052632        0.000000
# Letter to Editor                           0.875000        0.125000
# Magazine Article                           0.466667        0.200000
# News Report/Blog                           0.284626        0.016659
# Opinion Blog                               0.660218        0.123337
# Other Forum                                0.000000        0.750000
# Other Information                          0.000000        0.074074
# Other Informational Persuasion             1.000000        0.000000
# Other Opinion                              0.666667        0.000000
# Other Spoken                               0.333333        0.666667
# Personal Blog                              0.122744        0.676895
# Persuasive Article or Essay                0.750000        0.041667
# Poem                                       0.066667        0.200000
# Prayer                                     0.000000        0.000000
# Question/Answer Forum                      0.209524        0.233333
# Reader/Viewer Responses                    0.100000        0.100000
# Recipe                                     0.000000        0.352941
# Religious Blogs/Sermons                    0.671429        0.042857
# Research Article                           0.387879        0.006061
# Reviews                                    0.077778        0.066667
# Short Story                                0.017857        0.160714
# Song Lyrics                                0.037037        0.629630
# Sports Report                              0.163121        0.023050
# TV/Movie Script                            0.000000        0.600000
# Technical Report                           0.375000        0.125000
# Technical Support                          0.000000        0.125000
# Transcript of Video/Audio                  0.833333        0.083333
# Travel Blog                                0.070175        0.438596
#
# FTD_pred                         A12 (promotion)  A14 (academic)  \
# full_names
# Advertisement                           0.666667        0.000000
# Advice                                  0.145161        0.000000
# Course Materials                        0.130435        0.043478
# Description of a Person                 0.143791        0.000000
# Description of a Thing                  0.370899        0.007133
# Description with Intent to Sell         0.465753        0.000000
# Discussion Forum                        0.041026        0.002564
# Editorial                               0.000000        0.000000
# Encyclopedia Article                    0.000000        0.000000
# FAQ about How-to                        0.333333        0.000000
# FAQ about Information                   0.280000        0.000000
# Formal Speech                           0.111111        0.000000
# Historical Article                      0.047059        0.000000
# How-to                                  0.095057        0.000000
# Information Blog                        0.143791        0.026144
# Interview                               0.085106        0.000000
# Legal terms                             0.052632        0.000000
# Letter to Editor                        0.000000        0.000000
# Magazine Article                        0.000000        0.000000
# News Report/Blog                        0.039029        0.006663
# Opinion Blog                            0.038694        0.001209
# Other Forum                             0.000000        0.000000
# Other Information                       0.148148        0.037037
# Other Informational Persuasion          0.000000        0.000000
# Other Opinion                           0.333333        0.000000
# Other Spoken                            0.000000        0.000000
# Personal Blog                           0.043321        0.000000
# Persuasive Article or Essay             0.125000        0.000000
# Poem                                    0.000000        0.000000
# Prayer                                  0.000000        0.000000
# Question/Answer Forum                   0.047619        0.023810
# Reader/Viewer Responses                 0.300000        0.000000
# Recipe                                  0.117647        0.000000
# Religious Blogs/Sermons                 0.014286        0.000000
# Research Article                        0.018182        0.375758
# Reviews                                 0.083333        0.000000
# Short Story                             0.000000        0.000000
# Song Lyrics                             0.055556        0.000000
# Sports Report                           0.005319        0.000000
# TV/Movie Script                         0.000000        0.000000
# Technical Report                        0.000000        0.000000
# Technical Support                       0.000000        0.000000
# Transcript of Video/Audio               0.000000        0.000000
# Travel Blog                             0.192982        0.000000
#
# FTD_pred                         A16 (information)  A17 (review)  \
# full_names
# Advertisement                             0.000000      0.000000
# Advice                                    0.005376      0.016129
# Course Materials                          0.304348      0.043478
# Description of a Person                   0.339869      0.228758
# Description of a Thing                    0.152639      0.126961
# Description with Intent to Sell           0.031963      0.283105
# Discussion Forum                          0.007692      0.043590
# Editorial                                 0.000000      0.000000
# Encyclopedia Article                      0.819048      0.038095
# FAQ about How-to                          0.000000      0.000000
# FAQ about Information                     0.160000      0.000000
# Formal Speech                             0.000000      0.000000
# Historical Article                        0.423529      0.058824
# How-to                                    0.007605      0.015209
# Information Blog                          0.147059      0.055556
# Interview                                 0.000000      0.361702
# Legal terms                               0.052632      0.000000
# Letter to Editor                          0.000000      0.000000
# Magazine Article                          0.000000      0.133333
# News Report/Blog                          0.026654      0.067587
# Opinion Blog                              0.003628      0.093108
# Other Forum                               0.000000      0.000000
# Other Information                         0.185185      0.000000
# Other Informational Persuasion            0.000000      0.000000
# Other Opinion                             0.000000      0.000000
# Other Spoken                              0.000000      0.000000
# Personal Blog                             0.010830      0.084838
# Persuasive Article or Essay               0.000000      0.041667
# Poem                                      0.066667      0.266667
# Prayer                                    0.666667      0.000000
# Question/Answer Forum                     0.076190      0.028571
# Reader/Viewer Responses                   0.000000      0.300000
# Recipe                                    0.000000      0.058824
# Religious Blogs/Sermons                   0.078571      0.028571
# Research Article                          0.175758      0.018182
# Reviews                                   0.013889      0.722222
# Short Story                               0.000000      0.017857
# Song Lyrics                               0.018519      0.111111
# Sports Report                             0.007092      0.037234
# TV/Movie Script                           0.000000      0.200000
# Technical Report                          0.125000      0.000000
# Technical Support                         0.000000      0.000000
# Transcript of Video/Audio                 0.000000      0.000000
# Travel Blog                               0.000000      0.245614
#
# FTD_pred                         A4 (fiction)  A7 (instruction)  A8 (news)  \
# full_names
# Advertisement                        0.000000          0.333333   0.000000
# Advice                               0.000000          0.516129   0.005376
# Course Materials                     0.000000          0.304348   0.000000
# Description of a Person              0.013072          0.000000   0.117647
# Description of a Thing               0.002853          0.079886   0.081312
# Description with Intent to Sell      0.013699          0.086758   0.009132
# Discussion Forum                     0.005128          0.179487   0.020513
# Editorial                            0.000000          0.000000   0.076923
# Encyclopedia Article                 0.009524          0.000000   0.019048
# FAQ about How-to                     0.000000          0.666667   0.000000
# FAQ about Information                0.000000          0.440000   0.020000
# Formal Speech                        0.000000          0.000000   0.000000
# Historical Article                   0.035294          0.000000   0.070588
# How-to                               0.000000          0.737643   0.000000
# Information Blog                     0.003268          0.212418   0.065359
# Interview                            0.000000          0.010638   0.095745
# Legal terms                          0.000000          0.052632   0.000000
# Letter to Editor                     0.000000          0.000000   0.000000
# Magazine Article                     0.066667          0.000000   0.133333
# News Report/Blog                     0.001428          0.003332   0.550214
# Opinion Blog                         0.003628          0.035067   0.041112
# Other Forum                          0.000000          0.250000   0.000000
# Other Information                    0.074074          0.296296   0.148148
# Other Informational Persuasion       0.000000          0.000000   0.000000
# Other Opinion                        0.000000          0.000000   0.000000
# Other Spoken                         0.000000          0.000000   0.000000
# Personal Blog                        0.012635          0.021661   0.027076
# Persuasive Article or Essay          0.000000          0.041667   0.000000
# Poem                                 0.333333          0.066667   0.000000
# Prayer                               0.333333          0.000000   0.000000
# Question/Answer Forum                0.014286          0.357143   0.004762
# Reader/Viewer Responses              0.000000          0.200000   0.000000
# Recipe                               0.000000          0.470588   0.000000
# Religious Blogs/Sermons              0.121429          0.021429   0.021429
# Research Article                     0.000000          0.006061   0.006061
# Reviews                              0.008333          0.002778   0.025000
# Short Story                          0.803571          0.000000   0.000000
# Song Lyrics                          0.055556          0.083333   0.009259
# Sports Report                        0.001773          0.003546   0.758865
# TV/Movie Script                      0.200000          0.000000   0.000000
# Technical Report                     0.000000          0.250000   0.000000
# Technical Support                    0.000000          0.875000   0.000000
# Transcript of Video/Audio            0.083333          0.000000   0.000000
# Travel Blog                          0.000000          0.017544   0.035088
#
# FTD_pred                         A9 (legal)
# full_names
# Advertisement                      0.000000
# Advice                             0.000000
# Course Materials                   0.000000
# Description of a Person            0.000000
# Description of a Thing             0.017118
# Description with Intent to Sell    0.009132
# Discussion Forum                   0.005128
# Editorial                          0.000000
# Encyclopedia Article               0.009524
# FAQ about How-to                   0.000000
# FAQ about Information              0.020000
# Formal Speech                      0.000000
# Historical Article                 0.000000
# How-to                             0.011407
# Information Blog                   0.016340
# Interview                          0.000000
# Legal terms                        0.789474
# Letter to Editor                   0.000000
# Magazine Article                   0.000000
# News Report/Blog                   0.003808
# Opinion Blog                       0.000000
# Other Forum                        0.000000
# Other Information                  0.037037
# Other Informational Persuasion     0.000000
# Other Opinion                      0.000000
# Other Spoken                       0.000000
# Personal Blog                      0.000000
# Persuasive Article or Essay        0.000000
# Poem                               0.000000
# Prayer                             0.000000
# Question/Answer Forum              0.004762
# Reader/Viewer Responses            0.000000
# Recipe                             0.000000
# Religious Blogs/Sermons            0.000000
# Research Article                   0.006061
# Reviews                            0.000000
# Short Story                        0.000000
# Song Lyrics                        0.000000
# Sports Report                      0.000000
# TV/Movie Script                    0.000000
# Technical Report                   0.125000
# Technical Support                  0.000000
# Transcript of Video/Audio          0.000000
# Travel Blog                        0.000000

# %%
sub_labels["full_names"].value_counts()
# Out:
# News Report/Blog                   2101
# Opinion Blog                        827
# Description of a Thing              701
# Sports Report                       564
# Personal Blog                       554
# Discussion Forum                    390
# Reviews                             360
# Information Blog                    306
# How-to                              263
# Description with Intent to Sell     219
# Question/Answer Forum               210
# Advice                              186
# Research Article                    165
# Description of a Person             153
# Religious Blogs/Sermons             140
# Song Lyrics                         108
# Encyclopedia Article                105
# Interview                            94
# Historical Article                   85
# Travel Blog                          57
# Short Story                          56
# FAQ about Information                50
# Legal terms                          38
# Recipe                               34
# Other Information                    27
# Persuasive Article or Essay          24
# Course Materials                     23
# Magazine Article                     15
# Poem                                 15
# Editorial                            13
# Transcript of Video/Audio            12
# Reader/Viewer Responses              10
# FAQ about How-to                      9
# Formal Speech                         9
# Technical Support                     8
# Letter to Editor                      8
# Technical Report                      8
# TV/Movie Script                       5
# Other Forum                           4
# Other Spoken                          3
# Other Opinion                         3
# Prayer                                3
# Advertisement                         3
# Other Informational Persuasion        2
# Name: full_names, dtype: int64

# %%
len(sub_labels.full_names.unique())
# Out:
# 44

# %%
pd.crosstab(sub_labels["full_names"], sub_labels["FTD_pred"], normalize="index").to_dict("index")
# Out:
# {'Advertisement': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.6666666666666666,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.3333333333333333,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Advice': {'A1 (argumentative)': 0.17204301075268819,
#   'A11 (personal)': 0.13978494623655913,
#   'A12 (promotion)': 0.14516129032258066,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.005376344086021506,
#   'A17 (review)': 0.016129032258064516,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.5161290322580645,
#   'A8 (news)': 0.005376344086021506,
#   'A9 (legal)': 0.0},
#  'Course Materials': {'A1 (argumentative)': 0.17391304347826086,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.13043478260869565,
#   'A14 (academic)': 0.043478260869565216,
#   'A16 (information)': 0.30434782608695654,
#   'A17 (review)': 0.043478260869565216,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.30434782608695654,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Description of a Person': {'A1 (argumentative)': 0.09803921568627451,
#   'A11 (personal)': 0.058823529411764705,
#   'A12 (promotion)': 0.1437908496732026,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.33986928104575165,
#   'A17 (review)': 0.22875816993464052,
#   'A4 (fiction)': 0.013071895424836602,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.11764705882352941,
#   'A9 (legal)': 0.0},
#  'Description of a Thing': {'A1 (argumentative)': 0.1398002853067047,
#   'A11 (personal)': 0.021398002853067047,
#   'A12 (promotion)': 0.37089871611982883,
#   'A14 (academic)': 0.007132667617689016,
#   'A16 (information)': 0.15263908701854492,
#   'A17 (review)': 0.12696148359486448,
#   'A4 (fiction)': 0.0028530670470756064,
#   'A7 (instruction)': 0.07988587731811697,
#   'A8 (news)': 0.08131241084165478,
#   'A9 (legal)': 0.017118402282453638},
#  'Description with Intent to Sell': {'A1 (argumentative)': 0.0821917808219178,
#   'A11 (personal)': 0.0182648401826484,
#   'A12 (promotion)': 0.4657534246575342,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0319634703196347,
#   'A17 (review)': 0.2831050228310502,
#   'A4 (fiction)': 0.0136986301369863,
#   'A7 (instruction)': 0.0867579908675799,
#   'A8 (news)': 0.0091324200913242,
#   'A9 (legal)': 0.0091324200913242},
#  'Discussion Forum': {'A1 (argumentative)': 0.37435897435897436,
#   'A11 (personal)': 0.32051282051282054,
#   'A12 (promotion)': 0.041025641025641026,
#   'A14 (academic)': 0.002564102564102564,
#   'A16 (information)': 0.007692307692307693,
#   'A17 (review)': 0.04358974358974359,
#   'A4 (fiction)': 0.005128205128205128,
#   'A7 (instruction)': 0.1794871794871795,
#   'A8 (news)': 0.020512820512820513,
#   'A9 (legal)': 0.005128205128205128},
#  'Editorial': {'A1 (argumentative)': 0.9230769230769231,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.07692307692307693,
#   'A9 (legal)': 0.0},
#  'Encyclopedia Article': {'A1 (argumentative)': 0.09523809523809523,
#   'A11 (personal)': 0.009523809523809525,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.819047619047619,
#   'A17 (review)': 0.0380952380952381,
#   'A4 (fiction)': 0.009523809523809525,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.01904761904761905,
#   'A9 (legal)': 0.009523809523809525},
#  'FAQ about How-to': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.3333333333333333,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.6666666666666666,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'FAQ about Information': {'A1 (argumentative)': 0.06,
#   'A11 (personal)': 0.02,
#   'A12 (promotion)': 0.28,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.16,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.44,
#   'A8 (news)': 0.02,
#   'A9 (legal)': 0.02},
#  'Formal Speech': {'A1 (argumentative)': 0.7777777777777778,
#   'A11 (personal)': 0.1111111111111111,
#   'A12 (promotion)': 0.1111111111111111,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Historical Article': {'A1 (argumentative)': 0.36470588235294116,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.047058823529411764,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.4235294117647059,
#   'A17 (review)': 0.058823529411764705,
#   'A4 (fiction)': 0.03529411764705882,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.07058823529411765,
#   'A9 (legal)': 0.0},
#  'How-to': {'A1 (argumentative)': 0.057034220532319393,
#   'A11 (personal)': 0.07604562737642585,
#   'A12 (promotion)': 0.09505703422053231,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0076045627376425855,
#   'A17 (review)': 0.015209125475285171,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.7376425855513308,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.011406844106463879},
#  'Information Blog': {'A1 (argumentative)': 0.2908496732026144,
#   'A11 (personal)': 0.0392156862745098,
#   'A12 (promotion)': 0.1437908496732026,
#   'A14 (academic)': 0.026143790849673203,
#   'A16 (information)': 0.14705882352941177,
#   'A17 (review)': 0.05555555555555555,
#   'A4 (fiction)': 0.0032679738562091504,
#   'A7 (instruction)': 0.21241830065359477,
#   'A8 (news)': 0.06535947712418301,
#   'A9 (legal)': 0.016339869281045753},
#  'Interview': {'A1 (argumentative)': 0.18085106382978725,
#   'A11 (personal)': 0.26595744680851063,
#   'A12 (promotion)': 0.0851063829787234,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.3617021276595745,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.010638297872340425,
#   'A8 (news)': 0.09574468085106383,
#   'A9 (legal)': 0.0},
#  'Legal terms': {'A1 (argumentative)': 0.05263157894736842,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.05263157894736842,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.05263157894736842,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.05263157894736842,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.7894736842105263},
#  'Letter to Editor': {'A1 (argumentative)': 0.875,
#   'A11 (personal)': 0.125,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Magazine Article': {'A1 (argumentative)': 0.4666666666666667,
#   'A11 (personal)': 0.2,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.13333333333333333,
#   'A4 (fiction)': 0.06666666666666667,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.13333333333333333,
#   'A9 (legal)': 0.0},
#  'News Report/Blog': {'A1 (argumentative)': 0.2846263683960019,
#   'A11 (personal)': 0.016658733936220846,
#   'A12 (promotion)': 0.0390290337934317,
#   'A14 (academic)': 0.006663493574488339,
#   'A16 (information)': 0.026653974297953357,
#   'A17 (review)': 0.06758686339838173,
#   'A4 (fiction)': 0.0014278914802475012,
#   'A7 (instruction)': 0.0033317467872441696,
#   'A8 (news)': 0.5502141837220371,
#   'A9 (legal)': 0.0038077106139933364},
#  'Opinion Blog': {'A1 (argumentative)': 0.660217654171705,
#   'A11 (personal)': 0.12333736396614269,
#   'A12 (promotion)': 0.03869407496977025,
#   'A14 (academic)': 0.0012091898428053204,
#   'A16 (information)': 0.0036275695284159614,
#   'A17 (review)': 0.09310761789600967,
#   'A4 (fiction)': 0.0036275695284159614,
#   'A7 (instruction)': 0.03506650544135429,
#   'A8 (news)': 0.041112454655380895,
#   'A9 (legal)': 0.0},
#  'Other Forum': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.75,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.25,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Other Information': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.07407407407407407,
#   'A12 (promotion)': 0.14814814814814814,
#   'A14 (academic)': 0.037037037037037035,
#   'A16 (information)': 0.18518518518518517,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.07407407407407407,
#   'A7 (instruction)': 0.2962962962962963,
#   'A8 (news)': 0.14814814814814814,
#   'A9 (legal)': 0.037037037037037035},
#  'Other Informational Persuasion': {'A1 (argumentative)': 1.0,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Other Opinion': {'A1 (argumentative)': 0.6666666666666666,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.3333333333333333,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Other Spoken': {'A1 (argumentative)': 0.3333333333333333,
#   'A11 (personal)': 0.6666666666666666,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Personal Blog': {'A1 (argumentative)': 0.12274368231046931,
#   'A11 (personal)': 0.6768953068592057,
#   'A12 (promotion)': 0.04332129963898917,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.010830324909747292,
#   'A17 (review)': 0.08483754512635379,
#   'A4 (fiction)': 0.01263537906137184,
#   'A7 (instruction)': 0.021660649819494584,
#   'A8 (news)': 0.02707581227436823,
#   'A9 (legal)': 0.0},
#  'Persuasive Article or Essay': {'A1 (argumentative)': 0.75,
#   'A11 (personal)': 0.041666666666666664,
#   'A12 (promotion)': 0.125,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.041666666666666664,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.041666666666666664,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Poem': {'A1 (argumentative)': 0.06666666666666667,
#   'A11 (personal)': 0.2,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.06666666666666667,
#   'A17 (review)': 0.26666666666666666,
#   'A4 (fiction)': 0.3333333333333333,
#   'A7 (instruction)': 0.06666666666666667,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Prayer': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.0,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.6666666666666666,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.3333333333333333,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Question/Answer Forum': {'A1 (argumentative)': 0.20952380952380953,
#   'A11 (personal)': 0.23333333333333334,
#   'A12 (promotion)': 0.047619047619047616,
#   'A14 (academic)': 0.023809523809523808,
#   'A16 (information)': 0.0761904761904762,
#   'A17 (review)': 0.02857142857142857,
#   'A4 (fiction)': 0.014285714285714285,
#   'A7 (instruction)': 0.35714285714285715,
#   'A8 (news)': 0.004761904761904762,
#   'A9 (legal)': 0.004761904761904762},
#  'Reader/Viewer Responses': {'A1 (argumentative)': 0.1,
#   'A11 (personal)': 0.1,
#   'A12 (promotion)': 0.3,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.3,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.2,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Recipe': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.35294117647058826,
#   'A12 (promotion)': 0.11764705882352941,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.058823529411764705,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.47058823529411764,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Religious Blogs/Sermons': {'A1 (argumentative)': 0.6714285714285714,
#   'A11 (personal)': 0.04285714285714286,
#   'A12 (promotion)': 0.014285714285714285,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.07857142857142857,
#   'A17 (review)': 0.02857142857142857,
#   'A4 (fiction)': 0.12142857142857143,
#   'A7 (instruction)': 0.02142857142857143,
#   'A8 (news)': 0.02142857142857143,
#   'A9 (legal)': 0.0},
#  'Research Article': {'A1 (argumentative)': 0.3878787878787879,
#   'A11 (personal)': 0.006060606060606061,
#   'A12 (promotion)': 0.01818181818181818,
#   'A14 (academic)': 0.37575757575757573,
#   'A16 (information)': 0.17575757575757575,
#   'A17 (review)': 0.01818181818181818,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.006060606060606061,
#   'A8 (news)': 0.006060606060606061,
#   'A9 (legal)': 0.006060606060606061},
#  'Reviews': {'A1 (argumentative)': 0.07777777777777778,
#   'A11 (personal)': 0.06666666666666667,
#   'A12 (promotion)': 0.08333333333333333,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.013888888888888888,
#   'A17 (review)': 0.7222222222222222,
#   'A4 (fiction)': 0.008333333333333333,
#   'A7 (instruction)': 0.002777777777777778,
#   'A8 (news)': 0.025,
#   'A9 (legal)': 0.0},
#  'Short Story': {'A1 (argumentative)': 0.017857142857142856,
#   'A11 (personal)': 0.16071428571428573,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.017857142857142856,
#   'A4 (fiction)': 0.8035714285714286,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Song Lyrics': {'A1 (argumentative)': 0.037037037037037035,
#   'A11 (personal)': 0.6296296296296297,
#   'A12 (promotion)': 0.05555555555555555,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.018518518518518517,
#   'A17 (review)': 0.1111111111111111,
#   'A4 (fiction)': 0.05555555555555555,
#   'A7 (instruction)': 0.08333333333333333,
#   'A8 (news)': 0.009259259259259259,
#   'A9 (legal)': 0.0},
#  'Sports Report': {'A1 (argumentative)': 0.16312056737588654,
#   'A11 (personal)': 0.02304964539007092,
#   'A12 (promotion)': 0.005319148936170213,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0070921985815602835,
#   'A17 (review)': 0.03723404255319149,
#   'A4 (fiction)': 0.0017730496453900709,
#   'A7 (instruction)': 0.0035460992907801418,
#   'A8 (news)': 0.7588652482269503,
#   'A9 (legal)': 0.0},
#  'TV/Movie Script': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.6,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.2,
#   'A4 (fiction)': 0.2,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Technical Report': {'A1 (argumentative)': 0.375,
#   'A11 (personal)': 0.125,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.125,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.25,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.125},
#  'Technical Support': {'A1 (argumentative)': 0.0,
#   'A11 (personal)': 0.125,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.875,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Transcript of Video/Audio': {'A1 (argumentative)': 0.8333333333333334,
#   'A11 (personal)': 0.08333333333333333,
#   'A12 (promotion)': 0.0,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.0,
#   'A4 (fiction)': 0.08333333333333333,
#   'A7 (instruction)': 0.0,
#   'A8 (news)': 0.0,
#   'A9 (legal)': 0.0},
#  'Travel Blog': {'A1 (argumentative)': 0.07017543859649122,
#   'A11 (personal)': 0.43859649122807015,
#   'A12 (promotion)': 0.19298245614035087,
#   'A14 (academic)': 0.0,
#   'A16 (information)': 0.0,
#   'A17 (review)': 0.24561403508771928,
#   'A4 (fiction)': 0.0,
#   'A7 (instruction)': 0.017543859649122806,
#   'A8 (news)': 0.03508771929824561,
#   'A9 (legal)': 0.0}}

# %% [markdown]
# 1. Categories that match well:
# * 'Advertisement': 'A12 (promotion)': 0.67
# * 'Editorial': 'A1 (argumentative)': 0.92
# * 'Encyclopedia Article': 'A16 (information)': 0.82
# * 'FAQ about How-to':  'A7 (instruction)': 0.66
# * 'How-to':  'A7 (instruction)': 0.74
# * 'Formal Speech': 'A1 (argumentative)': 0.78
# * 'Legal terms': 'A9 (legal)': 0.789
# * 'Letter to Editor': 'A1 (argumentative)': 0.875
# * 'Opinion Blog': 'A1 (argumentative)': 0.66
# * 'Personal Blog: 'A11 (personal)': 0.677
# * 'Persuasive Article or Essay': 'A1 (argumentative)': 0.75
# * 'Religious Blogs/Sermons': 'A1 (argumentative)': 0.67
# * 'Reviews': 'A17 (review)': 0.72
# * 'Short Story': 'A4 (fiction)': 0.80
# * 'Sports Report': A8 (news)': 0.759
# * 'Technical Support': 'A7 (instruction)': 0.875
# * Other Informational Persuasion': 'A1 (argumentative)': 1.0
# * 'Other Opinion': 'A1 (argumentative)': 0.67
# * 'Other Spoken': 'A11 (personal)': 0.67
#
#
# 2. Categories that match, but less well:
# * 'Advice': 'A7 (instruction)': 0.51
# * 'Description with Intent to Sell': A12 (promotion)': 0.465, 'A17 (review)': 0.283
# * 'News Report/Blog': 'A8 (news)': 0.55, 'A1 (argumentative)': 0.28
# * 'Recipe': 'A7 (instruction)': 0.47, 'A11 (personal)': 0.35
#
# 3. CORE sub categories with no (appropriate) majority FTD label:
# * 'Course Materials': 'A7 (instruction)': 0.30 or 'A16 (information)': 0.30
# * 'Description of a Person':  'A16 (information)': 0.33, 'A17 (review)': 0.228
# * 'Description of a Thing': 'A12 (promotion)': 0.37
# * 'Discussion Forum': 'A1 (argumentative)': 0.37, 'A11 (personal)': 0.32
# * 'FAQ about Information': 'A7 (instruction)': 0.44, 'A12 (promotion)': 0.28
# * 'Historical Article': 'A16 (information)': 0.423, 'A1 (argumentative)': 0.36
# * 'Information Blog': 'A1 (argumentative)': 0.29, 'A7 (instruction)': 0.21
# * 'Interview': ''A17 (review)': 0.36, A1 (argumentative)': 0.18, 'A11 (personal)': 0.265
# * 'Magazine Article': 'A1 (argumentative)': 0.47
# * 'Poem': 'A4 (fiction)': 0.33, A11 (personal)': 0.2, 'A17 (review)': 0.27
# * 'Prayer': A16 (information)': 0.67
# * 'Question/Answer Forum':  'A7 (instruction)': 0.357, 'A11 (personal)': 0.23, A1 (argumentative)': 0.209
# * 'Reader/Viewer Responses': 'A17 (review)': 0.3, 'A12 (promotion)': 0.3, 'A7 (instruction)': 0.2
# * 'Research Article': 'A1 (argumentative)': 0.39, 'A14 (academic)': 0.376
# * 'Song Lyrics': 'A11 (personal)': 0.63 (matches well, but debatable if it's appropriate category)
# * 'TV/Movie Script': A11 (personal)': 0.6
# * 'Technical Report': 'A1 (argumentative)': 0.375, 'A7 (instruction)': 0.25
# * 'Transcript of Video/Audio': 'A1 (argumentative)': 0.83
# * 'Travel Blog': 'A11 (personal)': 0.438, A17 (review)': 0.25, 'A12 (promotion)': 0.19
# * 'Other Information':  'A7 (instruction)': 0.30, 'A16 (information)': 0.185
