# %% [markdown]
# Here, we prepare a sample from MaCoCu-sl, on which we use the genre classifiers. To prepare the sample, we first need to discard all texts with text length smaller than 75 - I created a dictionary of all domains and urls of texts that are long enough. Then I calculated the frequency of the domains. I discarded domains that have less than 10 instances (if I wouldn't, the median would be 6 texts per domain). Then I calculated the median and took the instances with the median number of instances, and the same amount of domains above and below the median, so that at the end, the sample has around 1000 different domains.

# %%
import gzip
import wget
import regex as re
import pandas as pd
import numpy as np
import json
import random
from tqdm import tqdm

# %%
# Compile regex for url and domain
url_re = re.compile('url="(.*?)"')
domain_re = re.compile('domain="(.*?)"')

# %% [markdown]
# ## Download and open the XLM file

# %%
# Download the corpus
# Download the file

#Defining the zip file URL
url = "https://www.clarin.si/repository/xmlui/bitstream/handle/11356/1517/MaCoCu-sl.xml.gz"

# Downloading the file by sending the request to the URL
corpus_file = wget.download(url)
print('Downloading Completed')
# Out:
# Downloading Completed

# %%
file = gzip.open('MaCoCu-sl.xml.gz', 'rt', encoding='utf-8')

# %% [markdown]
# ## Create a dataframe with the most frequent domains and a sample of 10 URLs from each domain

# %% [markdown]
# First, get a list of all domains and urls of texts that have are more than 75 words long.

# %%
text_counter = 0

texts = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_length = 0
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
	elif line.startswith("<p"):
		continue
	elif line.startswith("</p"):
		continue
	elif line.startswith("</doc"):
		text_length = len(pure_text.split())
		if text_length > 75:
			current_text = [current_domain, current_url]
			texts.append(current_text)
			text_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		pure_text += line
# Out:
# 151967742it [07:38, 331784.12it/s]

# %%
# Create a dataframe
df = pd.DataFrame({"domain": [x[0] for x in texts], "url": [x[1] for x in texts]})

df.head()
# Out:
#   domain                 url
# 0  e3.si  https://www.e3.si/
# 1  x5.si   http://www.x5.si/
# 2  a1.si  https://www.a1.si/
# 3  op.si  https://www.op.si/
# 4  fd.si      https://fd.si/

# %%
# Sort the df based on the domain
df = df.sort_values("domain")

df.head()
# Out:
#                     domain                                         url
# 337411          007.com.hr      http://www.007.com.hr/bugdetector.html
# 177449        090linije.si          http://www.090linije.si/pogoji.htm
# 501444        090linije.si  http://www.090linije.si/simobil/pogoji.htm
# 550412  090vedezevanje.com     https://090vedezevanje.com/tarot-karte/
# 96050   090vedezevanje.com                 https://090vedezevanje.com/

# %%
df.describe(include="all")
# Out:
#           domain                          url
# count    3787272                      3787272
# unique     49096                      3779253
# top     najdi.si  https://www.rtvslo.si/sport
# freq       41255                            8

# %% [markdown]
# We got 3,779,253 texts in 49,096 domains.

# %%
df.domain.value_counts().to_dict()
# Out:
# {'najdi.si': 41255,
#  'rtvslo.si': 39012,
#  'regionalobala.si': 35803,
#  'primorske.si': 31999,
#  'zurnal24.si': 29880,
#  '1zavse.si': 28335,
#  'sodnapraksa.si': 27388,
#  'slo-tech.com': 26412,
#  'mladina.si': 26191,
#  'uradni-list.si': 25820,
#  'radiostudent.si': 24408,
#  'novice.svet24.si': 20773,
#  'govorise.metropolitan.si': 19664,
#  'dk.um.si': 18882,
#  'radio1.si': 18151,
#  'mojmojster.net': 18087,
#  'dnevnik.si': 18001,
#  'muziker.si': 17008,
#  'tax-fin-lex.si': 16593,
#  'siol.net': 16535,
#  'ringaraja.net': 16507,
#  'monitor.si': 16082,
#  'moj-letak.si': 15774,
#  'mojaobcina.si': 15596,
#  'moja-lekarna.com': 14498,
#  'vsi.si': 14387,
#  'instore.si': 14279,
#  'publishwall.si': 14159,
#  'citymagazine.si': 14128,
#  'sloski.si': 12958,
#  'elektronik.si': 12233,
#  'nogomania.com': 12215,
#  'deloindom.delo.si': 11834,
#  'politikis.si': 11517,
#  'viva.si': 11371,
#  'joker.muzej.si': 11280,
#  'nova24tv.si': 10936,
#  'pesem.si': 10301,
#  'gov.si': 10134,
#  'blog.uporabnastran.si': 9510,
#  'sodisce.si': 9321,
#  'mladipodjetnik.si': 9287,
#  'vestnik.si': 8963,
#  'micna.slovenskenovice.si': 8883,
#  'onaplus.delo.si': 8779,
#  'pisrs.si': 8763,
#  'tenisportal.si': 8522,
#  'celje.info': 8094,
#  'radio.ognjisce.si': 8053,
#  'bambino.si': 7907,
#  'lex-localis.info': 7907,
#  'gzs.si': 7693,
#  'maribor24.si': 7658,
#  'predlagam.vladi.si': 7587,
#  'avtomanija.si': 7556,
#  'old.delo.si': 7444,
#  'alter.si': 7436,
#  'kulinarika.net': 7385,
#  'beta.publishwall.si': 7382,
#  'forum.zevs.si': 7375,
#  'bukla.si': 7337,
#  'mojaleta.si': 7303,
#  'fran.si': 7245,
#  'www2.arnes.si': 7156,
#  'vecer.com': 7151,
#  'paranoid.si': 7133,
#  'vzajemnost.si': 7110,
#  'rokometna-zveza.si': 7050,
#  'slovenska-biografija.si': 6905,
#  'kamra.si': 6883,
#  'racunovodja.com': 6797,
#  'pozitivke.net': 6716,
#  'vsikatalogi.si': 6710,
#  'fashion.si': 6565,
#  'policija.si': 6413,
#  'casnik.si': 6368,
#  'kamnik.si': 6303,
#  'tednik.si': 6299,
#  'morel.si': 6156,
#  'dkom.si': 6155,
#  'avto-fokus.si': 6154,
#  'mm-arhiv.si': 6128,
#  'mobile.si': 6068,
#  'rsg.si': 6007,
#  'pzs.si': 5997,
#  'besedilo.si': 5830,
#  'delo.si': 5824,
#  'mimovrste.com': 5821,
#  'openscience.si': 5779,
#  'dj-slovenija.si': 5725,
#  'ekipa.svet24.si': 5714,
#  'www2.gov.si': 5700,
#  'iusinfo.si': 5691,
#  'domzalec.si': 5551,
#  'edusinfo.si': 5546,
#  'druzina.si': 5508,
#  'intimatemedicine.si': 5444,
#  'zvpl.com': 5405,
#  'jabuk.si': 5351,
#  'izvozniki.finance.si': 5341,
#  'megashop.si': 5329,
#  'pefprints.pef.uni-lj.si': 5323,
#  'findinfo.si': 5219,
#  'strelec.si': 5205,
#  'mtb-forum.si': 5061,
#  'obmorju.si': 4996,
#  'avto-magazin.metropolitan.si': 4995,
#  'regionalgoriska.si': 4973,
#  'velenje.com': 4923,
#  'arhiv.gorenjskiglas.si': 4693,
#  'tocnoto.si': 4632,
#  'insolvinfo.si': 4581,
#  'bos.zrc-sazu.si': 4565,
#  'dolenjskilist.si': 4540,
#  'rastline.com': 4460,
#  'elle.metropolitan.si': 4445,
#  'dobreknjige.si': 4437,
#  'mc-celje.si': 4435,
#  'mojtv.si': 4396,
#  'nas-stik.si': 4385,
#  'dobranovica.si': 4376,
#  'forum.modelarji.com': 4343,
#  'svetloba.si': 4222,
#  'avto.finance.si': 4176,
#  'oblizniprste.si': 4160,
#  'gorenjskiglas.si': 4090,
#  'citylife.si': 4056,
#  'tabla.mtb.si': 4054,
#  'efnet.si': 4036,
#  'oglasi.si': 4008,
#  'stirikolesniki.si': 4002,
#  'us-rs.si': 3999,
#  'rocker.si': 3993,
#  'varcevanje-energije.si': 3971,
#  'avtomobilizem.com': 3947,
#  'lokalec.si': 3926,
#  'notranjskoprimorske.si': 3922,
#  'google.si': 3916,
#  'znanjesveta.com': 3916,
#  'ecommerce.sist.si': 3868,
#  'ljubljana.si': 3855,
#  'zelenaslovenija.si': 3814,
#  'cangura.com': 3784,
#  'ricinus2.mf.uni-lj.si': 3778,
#  'dostop.si': 3712,
#  'renault-klub.si': 3605,
#  'pogledi.delo.si': 3597,
#  'primerjam.si': 3582,
#  'sd-sport.si': 3569,
#  'skupaj.si': 3551,
#  'bralnica.com': 3545,
#  'eucbeniki.sio.si': 3538,
#  's5tech.net': 3510,
#  'pesjanar.si': 3467,
#  'koroski-radio.si': 3465,
#  'student.si': 3432,
#  'posavskiobzornik.si': 3395,
#  'slv.acousticbiotech.com': 3367,
#  'locutio.si': 3349,
#  'times.si': 3347,
#  'repozitorij.uni-lj.si': 3340,
#  'mbreport.si': 3330,
#  'teniska-zveza.si': 3310,
#  'vzmd.si': 3288,
#  'zenskisvet.si': 3280,
#  'portalplus.si': 3274,
#  'drugisvet.com': 3273,
#  'pomagamo-zivalim.si': 3273,
#  'povezujemo.si': 3266,
#  'merkur.si': 3240,
#  'edus.iusinfo.si': 3185,
#  'kamnik.info': 3171,
#  'enarocanje.si': 3167,
#  'blizjiknjigi.si': 3154,
#  'arhiv.kzs.si': 3148,
#  'extremevital.com': 3142,
#  'volan.si': 3125,
#  'sta.si': 3123,
#  'ktv-ormoz.si': 3113,
#  'modna.si': 3113,
#  'podjetnik.si': 3111,
#  'ludliteratura.si': 3107,
#  'gurman.eu': 3103,
#  'skuhaj.si': 3101,
#  'realmadrid.si': 3098,
#  'oblacila.si': 3093,
#  'za-misli.si': 3092,
#  'amzs.si': 3085,
#  'ecco-verde.si': 3066,
#  'zarolaj.si': 3057,
#  'paradaplesa.si': 3055,
#  'mojkraj.info': 3050,
#  'radioprvi.rtvslo.si': 3042,
#  'data.si': 3041,
#  'obramba.com': 3039,
#  'nova-gorica.si': 3034,
#  'sls.si': 2970,
#  'cek.ef.uni-lj.si': 2969,
#  'strankasmc.si': 2964,
#  'revija.ognjisce.si': 2963,
#  'maxximum.si': 2950,
#  'had.si': 2922,
#  'music24.si': 2906,
#  'dobrinasveti.si': 2876,
#  'apod.fmf.uni-lj.si': 2861,
#  'igre123.com': 2844,
#  'primorski.eu': 2808,
#  'domzalske-novice.si': 2806,
#  'sigic.si': 2805,
#  'kozjansko.info': 2801,
#  'ceneje.si': 2801,
#  'zofijini.net': 2798,
#  'robin.si': 2787,
#  'info-slovenija.si': 2771,
#  'poslovni-bazar.si': 2767,
#  'mopedist.si': 2731,
#  'zenska.hudo.com': 2715,
#  'nijz.si': 2715,
#  'telex.si': 2697,
#  'igralec.si': 2693,
#  'val202.rtvslo.si': 2685,
#  'vlaki.info': 2683,
#  'sa-agencija.si': 2676,
#  'ubuntu.si': 2671,
#  'vozimvolvo.si': 2663,
#  'bodieko.si': 2639,
#  'matejzalar.si': 2598,
#  'zares.si': 2580,
#  'zdruzenjeobcin.si': 2580,
#  'tehnozvezdje.si': 2573,
#  'lokalne-ajdovscina.si': 2564,
#  'careerjet.si': 2557,
#  'cosmopolitan.metropolitan.si': 2539,
#  'skofija-sobota.si': 2538,
#  'vsinasveti.si': 2537,
#  'bogastvozdravja.si': 2528,
#  'lekarnar.com': 2522,
#  'obrazislovenskihpokrajin.si': 2474,
#  'europarl.europa.eu': 2470,
#  'vitalabo.si': 2457,
#  'mojedelo.com': 2432,
#  'val-navtika.net': 2423,
#  'enavtika.si': 2411,
#  'arhiv.fokuspokus.si': 2407,
#  'tekaskiforum.net': 2397,
#  'katoliska-cerkev.si': 2379,
#  'financnitrgi.com': 2368,
#  'buca.si': 2361,
#  'preberite.si': 2349,
#  'gremovkino.si': 2340,
#  'konoplja.org': 2328,
#  'narobe.si': 2328,
#  'etno-muzej.si': 2282,
#  'primorskival.si': 2277,
#  'kraji.eu': 2271,
#  'omisli.si': 2268,
#  'podarimo.si': 2265,
#  'podskalco.si': 2259,
#  'grazia.si': 2247,
#  'sveterotike.si': 2244,
#  'snportal.si': 2237,
#  'biblos.si': 2233,
#  'nomago.si': 2221,
#  'forum2.arsktrp.gov.si': 2213,
#  'zoohit.si': 2209,
#  'odbojka.si': 2178,
#  'tvsporedi.si': 2167,
#  'skupnostobcin.si': 2150,
#  'rad-dobrojem.si': 2144,
#  'wwwarhiv.ozs.si': 2130,
#  'energetika-portal.si': 2130,
#  'slovenec.org': 2127,
#  'revis.openscience.si': 2126,
#  'tekac.si': 2126,
#  'vest.si': 2122,
#  'jskd.si': 2110,
#  'bajta.si': 2105,
#  'jw.org': 2104,
#  'forum.hamradio.si': 2094,
#  'slonep.net': 2093,
#  'profanity.si': 2092,
#  'uni-lj.si': 2085,
#  'audio-kontakt.com': 2085,
#  'savus.si': 2084,
#  'srce-me-povezuje.si': 2080,
#  'avtofil.si': 2077,
#  'fdv.uni-lj.si': 2073,
#  'stara.odbojka.si': 2054,
#  'velenje.si': 2048,
#  'zps.si': 2048,
#  'kum24.si': 2047,
#  'malinca.si': 2046,
#  'moski.hudo.com': 2041,
#  'smucisca.net': 2036,
#  'slovenskenovice.si': 2030,
#  'namestitev.si': 2012,
#  'nivaoffroadteam.rafter.si': 2011,
#  'up-rs.si': 2006,
#  'nivaoffroadteam.com': 2001,
#  'etransport.si': 1997,
#  'radiotomi.si': 1991,
#  'bmwblog.si': 1988,
#  'horoskop.si': 1984,
#  'nadlani.si': 1974,
#  'sos112.si': 1967,
#  'emundia.si': 1965,
#  'brezice.si': 1952,
#  'saiorg.si': 1945,
#  'fiat-klub.si': 1929,
#  '24kul.si': 1926,
#  'recepti.najdi.si': 1896,
#  'euromobil.si': 1884,
#  'dodogovor.org': 1884,
#  'cvek123.com': 1880,
#  'davkoplacevalci.com': 1873,
#  'viralko.si': 1859,
#  'forum.ssfs.si': 1857,
#  'viri.cjvt.si': 1847,
#  'topshop.si': 1842,
#  'sistory.si': 1820,
#  'mrpet.si': 1818,
#  'lekarna-soca.si': 1815,
#  'ilovejudo.com': 1807,
#  'bicikel.com': 1800,
#  'otroski.rtvslo.si': 1799,
#  'svetovalnica.zrc-sazu.si': 1799,
#  'altstore.si': 1785,
#  'socialnidemokrati.si': 1785,
#  'svet-el.si': 1785,
#  'casoris.si': 1781,
#  'skuponi.si': 1776,
#  'ung.si': 1762,
#  'mtb.si': 1755,
#  'sensa.metropolitan.si': 1755,
#  'astrologija-regulus.si': 1755,
#  'metinalista.si': 1754,
#  'aktivni.metropolitan.si': 1749,
#  'nkdomzale.si': 1748,
#  'mazda-si.net': 1747,
#  'snezak.si': 1742,
#  'sc-nm.si': 1736,
#  'eposavje.com': 1723,
#  'hokej.si': 1719,
#  'mojvideo.com': 1704,
#  'klubgromka.org': 1701,
#  'izola.si': 1699,
#  'sigledal.org': 1698,
#  'nk-bravo.si': 1698,
#  'klip.si': 1691,
#  'dobrakarma.si': 1686,
#  'kinodvor.org': 1678,
#  'e-fotografija.si': 1671,
#  'kresnik.eu': 1670,
#  'svetbesed.si': 1664,
#  'ajdovscina.si': 1630,
#  'drustvo-para-lj.si': 1628,
#  'gasilci.org': 1612,
#  'rks.si': 1610,
#  'racunalniske-novice.com': 1609,
#  'ekosola.uki.si': 1600,
#  '1nadan.si': 1595,
#  'katalogi.ceneje.si': 1578,
#  'primorskestene.com': 1570,
#  'glasdezele.si': 1567,
#  'ach-volley.si': 1565,
#  'slovreme.net': 1562,
#  'usersite.datalab.eu': 1561,
#  'mladinska-knjiga.si': 1559,
#  'arhiv.rlv.si': 1558,
#  'moc.celje.si': 1555,
#  'gore-ljudje.si': 1551,
#  'jesenice.si': 1539,
#  'mojprihranek.si': 1539,
#  'cudovita.si': 1535,
#  'test.times.si': 1531,
#  'slovenska-atletika.si': 1527,
#  'pardon.si': 1521,
#  'meganakupek.si': 1521,
#  'radiomars.si': 1517,
#  'zvvs.si': 1516,
#  'mojpogled.com': 1514,
#  'traktor.mojforum.si': 1509,
#  'bolha.com': 1508,
#  'zdis.si': 1498,
#  'njena.svet24.si': 1492,
#  'bokal-sport.si': 1491,
#  'glitter.si': 1484,
#  'ars.rtvslo.si': 1480,
#  'salonpohistva.si': 1476,
#  'sb.nuk.uni-lj.si': 1476,
#  'wiki.fkkt.uni-lj.si': 1474,
#  'ivancna-gorica.si': 1465,
#  'murska-sobota.si': 1446,
#  'nekdanji-pv.gov.si': 1433,
#  'razvoj.si': 1429,
#  'mestnik.si': 1424,
#  'yoys.si': 1424,
#  'pespoti.si': 1415,
#  'elektron.si': 1412,
#  'forum-lov.org': 1412,
#  'nepremicnine.net': 1411,
#  'sloveniaholidays.com': 1406,
#  'vrhnika.si': 1390,
#  'revije.ff.uni-lj.si': 1385,
#  'oe.finance.si': 1384,
#  'epsihologija.si': 1383,
#  'sl.wikiversity.org': 1377,
#  'nlb.si': 1377,
#  'mladi-sentjur.si': 1377,
#  'gartlc.mojforum.si': 1374,
#  'prvalekarna.com': 1370,
#  'geocacher.si': 1368,
#  'kitarist.si': 1356,
#  'sl.evidentista.org': 1351,
#  'arrs.si': 1347,
#  'telstar.si': 1347,
#  'planinsko-drustvo-ng.si': 1346,
#  'franciskani.si': 1340,
#  'zastarse.si': 1331,
#  'arhiv.mirenski-grad.si': 1322,
#  'klepetobkavi.si': 1320,
#  '1001ideja.si': 1318,
#  'eur-lex.europa.eu': 1311,
#  'enaa.com': 1308,
#  'hyde-park.si': 1307,
#  'solaokusov.si': 1304,
#  'tvsrk-11.si': 1302,
#  'prostovoljstvo.org': 1302,
#  'reporter.si': 1299,
#  'trofeja.si': 1290,
#  'e-apoteka.si': 1286,
#  'tipk.si': 1283,
#  'friko.si': 1282,
#  'srcnotrbovlje.si': 1278,
#  'saop.si': 1276,
#  'peticija.online': 1274,
#  'safe.si': 1273,
#  'e-utrip.si': 1269,
#  'prlekija-on.net': 1264,
#  'cinemania-group.si': 1264,
#  'agromet.mkgp.gov.si': 1253,
#  'punkufer.si': 1250,
#  'dominstil.si': 1248,
#  'e-kurs.si': 1244,
#  'fm-kp.si': 1236,
#  'ooz-ravne.si': 1233,
#  'zsport-jesenice.si': 1232,
#  'gnes.si': 1227,
#  'pef.uni-lj.si': 1225,
#  'mds-drustvo.si': 1222,
#  'shopbuilder.si': 1222,
#  'old.nuk.uni-lj.si': 1221,
#  'sanje.si': 1211,
#  'marmelina.si': 1206,
#  'buildingbody.si': 1206,
#  'ujusansa.si': 1205,
#  'ric-nm.si': 1202,
#  'gfml.si': 1201,
#  'dragocena.si': 1198,
#  'bead.si': 1194,
#  'drogart.org': 1188,
#  'oddaje.ognjisce.si': 1184,
#  'skoberne.si': 1184,
#  'podsvojostreho.net': 1183,
#  'studiofaca.com': 1182,
#  'bigbang.si': 1180,
#  'sony.si': 1179,
#  'forum.finance.si': 1178,
#  'mma.si': 1177,
#  'automobil.si': 1170,
#  'sobotainfo.com': 1165,
#  'gradbenistvo.finance.si': 1164,
#  'startup.si': 1159,
#  'pugi.si': 1156,
#  'planetaudio.si': 1155,
#  'mojpes.net': 1147,
#  'eu2008.si': 1147,
#  'film-center.si': 1142,
#  'cosmeterie.si': 1139,
#  'imedi.si': 1138,
#  'kibla.org': 1135,
#  'cobiss.si': 1135,
#  'sanolabor.si': 1134,
#  'primus.si': 1133,
#  'medikus.hr': 1132,
#  'eetaq.si': 1125,
#  'intersport.si': 1123,
#  'lekarnanaklik.si': 1123,
#  'radeski-utrip.si': 1121,
#  'vandraj.si': 1120,
#  'pd-ljmatica.si': 1119,
#  'btps.si': 1117,
#  'gzdbk.si': 1110,
#  'tehnokrat.si': 1109,
#  'adp.fdv.uni-lj.si': 1109,
#  'tomazflegar.si': 1109,
#  'marcopolo.si': 1109,
#  'rastline.mojforum.si': 1107,
#  'vemkajjem.si': 1106,
#  'videolectures.net': 1105,
#  'arhiv.ds-rs.si': 1104,
#  'forum.alfa-klub.com': 1104,
#  'krtina.com': 1103,
#  'slovenia.info': 1103,
#  'radio-ptuj.si': 1101,
#  'svetevrope.si': 1100,
#  'vitafit.si': 1100,
#  'ljubljanskigrad.si': 1095,
#  'amnesty.si': 1093,
#  'www2.fu.uni-lj.si': 1091,
#  'arhiv.mlad.si': 1090,
#  'evsvet.eu': 1088,
#  'forum.kvarkadabra.net': 1085,
#  'gcc.si': 1083,
#  'pro.finance.si': 1081,
#  'metropolitan.si': 1080,
#  'mucek.si': 1078,
#  'varuh-rs.si': 1077,
#  'harveynorman.si': 1077,
#  'minutka.si': 1077,
#  'spomincica.si': 1074,
#  'delphi.si': 1072,
#  'pozareport.si': 1071,
#  'interismo.si': 1070,
#  'svet-me.si': 1068,
#  'ff.uni-lj.si': 1061,
#  'piccantino.si': 1056,
#  'tosamashop.si': 1055,
#  'smar-team-org.si': 1052,
#  'talentiran.si': 1051,
#  'ess.gov.si': 1049,
#  'agencija-oskar.si': 1043,
#  'nsi.si': 1043,
#  'educa.fmf.uni-lj.si': 1043,
#  'hktriglav.si': 1042,
#  'lunin.net': 1036,
#  'mini-teater.si': 1035,
#  'airbeletrina.si': 1029,
#  'kalcek.si': 1028,
#  'scca-ljubljana.si': 1027,
#  'lokalno.si': 1022,
#  'posrcumlad.si': 1020,
#  'turizem-sevnica.si': 1016,
#  'exodus.si': 1015,
#  'babycenter.si': 1013,
#  'sportnodrustvo-sencur.si': 1006,
#  'ssgt.si': 1003,
#  'vsikuponi.si': 1002,
#  'pravniki.info': 995,
#  'booking.com': 995,
#  'fclitija.si': 995,
#  'kzs.si': 993,
#  'sentjur.net': 991,
#  'gorickilist.si': 989,
#  'pf.uni-lj.si': 984,
#  'mariborinfo.com': 981,
#  'gobe.si': 979,
#  'doria.si': 976,
#  'oglasnik-plus.si': 975,
#  'avdio.ognjisce.si': 975,
#  'ezdravje.com': 975,
#  'med.over.net': 972,
#  'mg-lj.si': 970,
#  'ljudmila.org': 969,
#  'studio12.si': 969,
#  'bsi.si': 969,
#  'duj.si': 967,
#  'canon.si': 965,
#  'operi-avto.si': 962,
#  'prilevcku.si': 959,
#  'svetkapitala.delo.si': 957,
#  'luka-kp.si': 954,
#  'globetrotter.si': 952,
#  'nasvetizavas.si': 951,
#  'koridor-ku.si': 948,
#  'sketa.si': 946,
#  'seonet.ljse.si': 946,
#  'megasvet.si': 945,
#  'odprtakuhinja.delo.si': 944,
#  'consulta.si': 942,
#  'pil.si': 937,
#  'koroskenovice.si': 937,
#  'avtoblog.com': 935,
#  'ijs.si': 933,
#  'os-naklo.si': 933,
#  'arhiv.e-obcina.si': 933,
#  'unicef.si': 929,
#  'zivalskenovice.si': 928,
#  'akravne.si': 926,
#  'polleosport.si': 926,
#  'ciklon.si': 926,
#  'kulturnidom-ng.si': 925,
#  'trgovinayorki.si': 921,
#  'equusvitalis.si': 921,
#  'avogel.si': 919,
#  'forum.sota.si': 916,
#  'literarni-val.slovenianforum.com': 914,
#  'maribor.si': 914,
#  'mohorjeva.org': 913,
#  'stareslike.cerknica.org': 912,
#  'paragliding-slovenia.si': 912,
#  'zvkds.si': 911,
#  'pokukaj.si': 911,
#  'radioekspres.si': 909,
#  'uil-sipo.si': 909,
#  'lek.si': 907,
#  'kataloska-prodaja.si': 907,
#  'alaja.si': 907,
#  'zal.sik.si': 905,
#  'gigafida.net': 904,
#  'vrabecanarhist.eu': 899,
#  'bfcshop.si': 899,
#  'mirovni-institut.si': 897,
#  'zazivali.si': 896,
#  'netokracija.si': 895,
#  'pikapolonica.si': 895,
#  'strankalms.si': 894,
#  'silux.si': 892,
#  'tojeto.info': 891,
#  'natura2000.si': 890,
#  'nrpslo.org': 890,
#  'noviglas.eu': 889,
#  'ten-net.si': 889,
#  'mojmalcek.si': 888,
#  'harb.si': 887,
#  'medrazgl.si': 886,
#  'nazraku.si': 884,
#  'antene-zupancic.si': 884,
#  'tanja-fajon.si': 883,
#  'kosarka.si': 883,
#  'fe.uni-lj.si': 883,
#  'majer.si': 881,
#  'mikec.si': 879,
#  'kgzs.si': 876,
#  'mojefinance.finance.si': 872,
#  'kud.si': 870,
#  'os-bozidarjajakca.si': 869,
#  'sng-mb.si': 868,
#  'revija-tranzit.si': 866,
#  'spanskiborci.si': 860,
#  'hozana.si': 860,
#  'najlepsi-par.si': 859,
#  'gta-neptun.si': 858,
#  'webshop.schachermayer.com': 858,
#  'emajstor.hr': 856,
#  'cityofwomen.org': 856,
#  'slikarski-material.si': 855,
#  'izvoznookno.si': 855,
#  'outlaws.mojforum.si': 854,
#  'osartice.si': 854,
#  'e-kino.si': 853,
#  'zgodovina.si': 849,
#  'spins.si': 848,
#  'informacija.net': 848,
#  'croatia.hr': 847,
#  'nalepse.si': 847,
#  'lekarnaljubljana.si': 847,
#  'moja-dejavnost.si': 846,
#  'norma.si': 846,
#  'ef.uni-lj.si': 844,
#  'proviprlek.si': 843,
#  'cipra.org': 843,
#  'marketingmagazin.si': 842,
#  'kajkupiti.si': 841,
#  'prc.si': 840,
#  'zaps.si': 839,
#  'drustvo-mds.si': 836,
#  'pesmojprijatelj.si': 833,
#  'hbogo.si': 833,
#  'notino.si': 831,
#  'blog69.si': 829,
#  'britev.si': 828,
#  'arhiv.park-goricko.info': 828,
#  'stat.si': 827,
#  'skandal24.si': 826,
#  'm.planet-lepote.com': 822,
#  'eportal.mss.edus.si': 820,
#  'kuzek.si': 820,
#  'instalater.si': 819,
#  'ipop.si': 819,
#  'zemljevid.najdi.si': 817,
#  'zrc-sazu.si': 816,
#  'stajerskival.si': 814,
#  'caranduser.com': 811,
#  'noviceznotranjske.net': 810,
#  'bsf.si': 806,
#  'inst-antonatrstenjaka.si': 806,
#  'ec.europa.eu': 805,
#  'freeapproved.com': 804,
#  'philips.si': 804,
#  'aokranj.com': 802,
#  'avto.info': 797,
#  'podcrto.si': 797,
#  'potnik.si': 797,
#  'kompas.si': 796,
#  'g-sport.si': 795,
#  'trajekt.org': 794,
#  '4d.rtvslo.si': 792,
#  'karizmasport.si': 792,
#  'vsu.ung.si': 789,
#  'mevki55.mojforum.si': 788,
#  'redoljub.si': 787,
#  'um.si': 787,
#  'nib.si': 786,
#  'najnakupi.si': 785,
#  'wiki.potnik.si': 782,
#  'dk.mors.si': 781,
#  'skuterist.mojforum.si': 781,
#  'zdravstveniportal.si': 780,
#  'vesolje.net': 779,
#  'midvakuhava.si': 779,
#  'nkmura.si': 779,
#  'sviz.si': 777,
#  'mojacokolada.si': 775,
#  'lisac.si': 773,
#  'hervardi.com': 771,
#  'nasasuperhrana.si': 769,
#  'gonilniki.si': 768,
#  'sportold.amzs.si': 762,
#  'blog.ognjisce.si': 761,
#  'labelhair.si': 761,
#  'c21.si': 760,
#  'poslovno-mesto.si': 758,
#  'gor-radgona.si': 758,
#  'forum.svet-el.si': 758,
#  'agrooglasi.si': 756,
#  'strojnistvo.com': 756,
#  'agrobiznis.finance.si': 753,
#  'sam.si': 751,
#  'old.radiostudent.si': 750,
#  'ribiskekarte.si': 750,
#  'potovanja.nomago.si': 749,
#  'bimbo.si': 748,
#  'nl.ijs.si': 748,
#  'mizarstvo.si': 747,
#  'sloexport.si': 746,
#  'mgml.si': 744,
#  'szsce.si': 742,
#  'aninakuhinja.si': 741,
#  '3ksport.si': 741,
#  'bmwslo.com': 741,
#  'portal.mss.edus.si': 740,
#  'pobarvanka.gifmania.si': 738,
#  'portalvvesolje.si': 737,
#  'vrtec.os-mostnasoci.si': 736,
#  'avtoforum.net': 735,
#  'ced-slovenia.eu': 732,
#  'czk.si': 732,
#  'skrivnosti.com': 731,
#  'o-ledina.si': 731,
#  'si.openprof.com': 729,
#  'klubrg-narodnidom.si': 728,
#  'symphony.si': 727,
#  'ona-on.com': 727,
#  'kuponko.si': 724,
#  'si.rbth.com': 721,
#  'arhiv.lrf-pomurje.si': 720,
#  'potepuh.si': 719,
#  'onko-i.si': 719,
#  'uo.mojforum.si': 718,
#  'kinoteka.si': 718,
#  'kibuba.com': 717,
#  'ebm.si': 716,
#  'kpss.si': 715,
#  'a1.si': 713,
#  'maltezan.mojforum.si': 713,
#  'makspro.si': 712,
#  'emka.si': 712,
#  'poroka-bo.si': 712,
#  'posel2030.finance.si': 711,
#  'optius.com': 710,
#  'nzs.si': 710,
#  'diamond-realestate.hr': 710,
#  'isjfr.zrc-sazu.si': 710,
#  'starastran.aozeleznicar.org': 706,
#  '3djake.si': 706,
#  'varensvet.si': 704,
#  'outsider.si': 702,
#  'grasca.si': 702,
#  'factorystore.si': 700,
#  'forum.over.net': 696,
#  'matejspehar.si': 696,
#  'pocitnice.si': 695,
#  'kk-hidria.si': 695,
#  'youth-hostel.si': 694,
#  'institutfrance.si': 693,
#  'slo-fishing.si': 693,
#  'skavt.net': 691,
#  'diabetes.si': 690,
#  'kam.si': 688,
#  'helios-suns.si': 687,
#  'pdtolmin.si': 687,
#  'rockonnet.com': 685,
#  'babybook.si': 684,
#  'dmslo.si': 684,
#  'vwcampers.si': 683,
#  'goodlifestyle.si': 681,
#  'molek.si': 679,
#  'mozaik.si': 678,
#  'infomosa.si': 677,
#  'e30.si': 677,
#  'star.www.upr.si': 677,
#  'arhiv.akos-rs.si': 676,
#  'nationalgeographic.si': 676,
#  't-2.rula.net': 676,
#  'ustvarjalneroke.si': 675,
#  'wellnetica.si': 675,
#  'afibel.si': 675,
#  'mojmalipravnik.net': 674,
#  'kclj.si': 674,
#  'vegan.si': 674,
#  'mislec.net': 671,
#  'zdruzenje-sim.si': 669,
#  'mkc.si': 667,
#  'sl.ncmhcso.org': 666,
#  'nikon.si': 666,
#  'nosecka.net': 664,
#  'cd-cc.si': 663,
#  'kamzmulcem.si': 663,
#  'sportnaoprema.si': 662,
#  'sk-pomurje.si': 661,
#  'necenzurirano.si': 656,
#  'iprom.si': 655,
#  'avtofotomarket.si': 652,
#  'lahkihnog-naokrog.si': 651,
#  'loparji.si': 650,
#  'samozapunce.mojforum.si': 650,
#  'zdravniski-nasveti.net': 649,
#  'skofija-novomesto.si': 648,
#  'saleskibiografskileksikon.si': 647,
#  'v8clubforum.mojforum.si': 647,
#  'kroncek.mojforum.si': 646,
#  'cveka.com': 646,
#  'zsc.si': 646,
#  'metuljcica.mojforum.si': 645,
#  'judoklub-duplek.si': 644,
#  'volleyball.si': 643,
#  'vidaxl.si': 642,
#  'nakupek.si': 642,
#  'hrtjisvet.mojforum.si': 640,
#  'rktrimotrebnje.si': 639,
#  'arhiv.izs.si': 637,
#  'posvetu.si': 635,
#  'deloglasnik.si': 634,
#  'pgd-loka.si': 633,
#  'doktor24.si': 629,
#  'rivacic.blogspot.com': 629,
#  'mczos.si': 626,
#  'e-arhiv.org': 625,
#  'piratskastranka.si': 625,
#  'vfokusu.com': 624,
#  'zdravstvena.info': 623,
#  'ntf.uni-lj.si': 623,
#  'eracunovodstvo.org': 623,
#  'mediawatch.mirovni-institut.si': 622,
#  'nina-potuje.com': 620,
#  'biro.si': 620,
#  'o-sta.si': 619,
#  'dulitija.si': 619,
#  'zfm.si': 619,
#  'mixi-caravaning.si': 619,
#  'sodobnost.com': 617,
#  'podblegaske-novice.si': 616,
#  'rk-gorenje.com': 616,
#  'insportline.si': 615,
#  'cdk.si': 613,
#  'varuska-ziva.si': 613,
#  'mundo.si': 611,
#  'maxximum-portal.com': 610,
#  'kr.trma.si': 610,
#  'mojaizbira.si': 610,
#  'cincile.mojforum.si': 609,
#  'razstava.fa.uni-lj.si': 609,
#  'skoda-team.com': 609,
#  'novitednik.si': 609,
#  'sl.toolbox-site.com': 608,
#  'hummel.si': 607,
#  'slo-android.si': 605,
#  'forum.striparna.com': 605,
#  'os-sticna.si': 605,
#  'kakadu.si': 604,
#  'eu-skladi.si': 603,
#  'mojalbum.com': 603,
#  'aips.um.si': 602,
#  'penzionist.info': 601,
#  'nasa-lekarna.si': 601,
#  'lukvel.si': 601,
#  'evo-magazin.si': 600,
#  'telekom.si': 599,
#  'abcnovice.si': 599,
#  'click2chic.si': 598,
#  'tvambienti.si': 598,
#  'epeka.si': 598,
#  'sng-ng.si': 597,
#  'nivea.si': 596,
#  'ims-trgovina.si': 595,
#  'hisavrt.si': 594,
#  'pd-iskra-lj.com': 593,
#  'tomassport2.si': 593,
#  'sl.google-info.org': 592,
#  'zkdl.si': 592,
#  'km-z.si': 591,
#  'torekobpetih.si': 591,
#  'mojezdravje.net': 590,
#  'vezal.si': 589,
#  'zsss.si': 585,
#  'dn.mojforum.si': 585,
#  'marika.mojforum.si': 584,
#  'lovrencan.si': 584,
#  'ro.si': 583,
#  'milnica.si': 582,
#  'mc-jesenice.si': 581,
#  'repozitorij.ung.si': 580,
#  'soup.si': 580,
#  'forum.fiat-klub.si': 578,
#  'nepremagljiva.si': 577,
#  'mesarska.mojforum.si': 577,
#  'emorje.com': 575,
#  'duhovnost.si': 574,
#  'jaz-in-ti.si': 574,
#  'svobodnabeseda.si': 574,
#  'mercator.si': 573,
#  'pef.upr.si': 573,
#  'www2.amzs.si': 572,
#  'pepermint.si': 571,
#  'slovoni.blogspot.com': 571,
#  'cvilimozek.si': 569,
#  'sah-branikmb.si': 569,
#  'printink.si': 568,
#  'forum-tezave-pomagajmosi.mojforum.si': 568,
#  'aao.si': 567,
#  'fmf.uni-lj.si': 566,
#  'tovarnazdravehrane.si': 566,
#  'drustvo-sever-severnaprimorska.si': 566,
#  'crnomelj.si': 565,
#  'milenijski-cilji.si': 565,
#  'yogi.si': 564,
#  'drustvo-sovica.si': 563,
#  'zupnija-lj-zadobrova.rkc.si': 563,
#  'selectbox.si': 561,
#  'zaobljuba.si': 561,
#  'knjiznica-celje.si': 560,
#  'kolesarska-zveza.si': 560,
#  'novice.kulturnik.si': 560,
#  'preprostost.si': 560,
#  'mojbutik.si': 559,
#  'obcina-brda.si': 559,
#  'movit.si': 559,
#  'marianum.si': 556,
#  'pdrustvo-nazarje.si': 556,
#  'pag.si': 554,
#  'sezana.si': 553,
#  'esvet.com': 552,
#  'zdravo.si': 552,
#  'gimnazija-skofjaloka.si': 552,
#  'vezjak.com': 550,
#  'ffa.uni-lj.si': 549,
#  'tehnoplus.si': 549,
#  'frko.si': 548,
#  'arsq.gov.si': 548,
#  'tusdrogerija.si': 547,
#  'slavko.mojforum.si': 546,
#  'avtokampi.si': 546,
#  'barjans.si': 545,
#  'razvezanijezik.org': 544,
#  'odprtehiseslovenije.org': 543,
#  'zupnija-mb-magdalena.rkc.si': 543,
#  'mb-lekarne.si': 542,
#  'aler.si': 542,
#  'izboljsajmo.maribor.si': 541,
#  'mcp.si': 541,
#  'odkrito.svet24.si': 541,
#  'actionmama.com': 539,
#  'mjslocom.mojforum.si': 539,
#  'doggedog.mojforum.si': 538,
#  'novomesto.si': 538,
#  'ds-rs.si': 537,
#  'slo-link.si': 536,
#  'zazdravje.net': 535,
#  'storitev.com': 535,
#  'culinaryjourneybyme.com': 535,
#  'dirros.openscience.si': 535,
#  'montignac.mojforum.si': 535,
#  'rockline.si': 533,
#  'focus.si': 533,
#  'startupmaribor.si': 533,
#  'lukazoja.si': 533,
#  'stripi.si': 531,
#  'sex2.si': 531,
#  'logatec.si': 530,
#  'sportnazvezavelenje.si': 529,
#  'forum.racunovodja.com': 528,
#  'privoscite.si': 528,
#  'tisina.si': 527,
#  'zvezarfr.si': 525,
#  'ndsnumizmatika.mojforum.si': 525,
#  'levica.si': 524,
#  'slovenjgradec.si': 523,
#  'slomedia.si': 522,
#  'inovelmedia.si': 521,
#  ...}

# %%
# Calculate domain distribution
domain_distribution = pd.DataFrame({"domain": list(df.domain.value_counts().to_dict().keys()), "frequency":list(df.domain.value_counts().to_dict().values())})
domain_distribution
# Out:
#                       domain  frequency
# 0                   najdi.si      41255
# 1                  rtvslo.si      39012
# 2           regionalobala.si      35803
# 3               primorske.si      31999
# 4                zurnal24.si      29880
# ...                      ...        ...
# 49091  tapetnistvo-damjan.si          1
# 49092            eurograf.si          1
# 49093   tapetnistvo-kolar.si          1
# 49094   tapetnistvo-kopac.si          1
# 49095             007.com.hr          1
#
# [49096 rows x 2 columns]

# %%
# Discard instances with frequency less than 10
domain_distribution = domain_distribution[domain_distribution["frequency"] > 9]

domain_distribution.shape
# Out:
# (20400, 2)

# %% [markdown]
# If we don't discard domains with less than 10 texts, the median is 6 texts which is not enough. So, I first discarded domains with less than 10 texts, then calculated the median. The remaining number of domains was 20,400.

# %%
# Find the median
domain_distribution.frequency.describe()
# Out:
# count    20400.000000
# mean       181.051225
# std       1044.961694
# min         10.000000
# 25%         16.000000
# 50%         32.000000
# 75%         84.000000
# max      41255.000000
# Name: frequency, dtype: float64

# %% [markdown]
# The median number of texts per domain is 32. Now, I'll take 500 domains with frequency below this number and 500 domains with frequency above this number.

# %%
domain_distribution[domain_distribution["frequency"] == 32].shape
# Out:
# (219, 2)

# %%
# 219 instances are already at the median, so I will take 391 instances from above and below the median

domain_distribution[domain_distribution["frequency"] == 32].head(1)
# Out:
#                   domain  frequency
# 9983  lkrv.fri.uni-lj.si         32

# %%
distr_above = domain_distribution.iloc[(9983-391):9983]

distr_above
# Out:
#                             domain  frequency
# 9592                   apkhome.net         35
# 9593                    dsi2011.si         35
# 9594                 zlatarnica.si         35
# 9595                 pd-polzela.si         35
# 9596                pgd-cusperk.si         35
# ...                            ...        ...
# 9978                       kado.si         33
# 9979                      began.si         33
# 9980  manuela-aleunam.blogspot.com         33
# 9981                   mojporod.si         33
# 9982                      eurol.si         33
#
# [391 rows x 2 columns]

# %%
domain_distribution[domain_distribution["frequency"] == 32].tail(1)
# Out:
#                  domain  frequency
# 10201  diabetes-loka.si         32

# %%
distr_below = domain_distribution.iloc[10202:(10201+392)]
distr_below
# Out:
#                    domain  frequency
# 10202           luster.si         31
# 10203    sportnestave.org         31
# 10204         bodifit.net         31
# 10205      polyregion.org         31
# 10206            ma-ko.si         31
# ...                   ...        ...
# 10588  ka-komunikacije.si         30
# 10589             kubu.si         30
# 10590        troblja.info         30
# 10591          karnion.si         30
# 10592             gost.si         30
#
# [391 rows x 2 columns]

# %%
# Merge the three domain dfs
intermediate = pd.concat([domain_distribution[domain_distribution["frequency"] == 32], distr_above])

intermediate
# Out:
#                             domain  frequency
# 9983            lkrv.fri.uni-lj.si         32
# 9984                        rts.si         32
# 9985      biotechnology-gmo.gov.si         32
# 9986                gml-drustvo.si         32
# 9987              kamen-mojster.si         32
# ...                            ...        ...
# 9978                       kado.si         33
# 9979                      began.si         33
# 9980  manuela-aleunam.blogspot.com         33
# 9981                   mojporod.si         33
# 9982                      eurol.si         33
#
# [610 rows x 2 columns]

# %%
domain_sample = pd.concat([intermediate, distr_below])
domain_sample
# Out:
#                          domain  frequency
# 9983         lkrv.fri.uni-lj.si         32
# 9984                     rts.si         32
# 9985   biotechnology-gmo.gov.si         32
# 9986             gml-drustvo.si         32
# 9987           kamen-mojster.si         32
# ...                         ...        ...
# 10588        ka-komunikacije.si         30
# 10589                   kubu.si         30
# 10590              troblja.info         30
# 10591                karnion.si         30
# 10592                   gost.si         30
#
# [1001 rows x 2 columns]

# %%
# Create a list of domains
domain_sample_list = domain_sample.domain.to_list()
domain_sample_list[:10]
# Out:
# ['lkrv.fri.uni-lj.si',
#  'rts.si',
#  'biotechnology-gmo.gov.si',
#  'gml-drustvo.si',
#  'kamen-mojster.si',
#  'bio-pharma.si',
#  'binova.si',
#  'tiego.si',
#  'st-laboratoriji.si',
#  'osmatijecopa.si']

# %%
# For each domain, sample out 10 texts from the initial dataframe

# First create the initial df to which all others in the loop will be added
final_sample = df[df["domain"] == domain_sample_list[0]].sample(n=10)

final_sample
# Out:
#                      domain                                                url
# 1461252  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/seminar/in...
# 2129748  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/np_...
# 2710918  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/africa/?page=navodil...
# 2130932  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/np_...
# 1482576  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/dn/...
# 2708401  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/africa/?page=navodil...
# 1631675  lkrv.fri.uni-lj.si  https://lkrv.fri.uni-lj.si/~ajurisic/seminar/p...
# 1517203  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/mercedes/i...
# 1706165  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/tec...
# 1077648  lkrv.fri.uni-lj.si   http://lkrv.fri.uni-lj.si/~ajurisic/tex/tex.html

# %%
# Add all other domains
remaining_list = domain_sample_list[1:]

for i in remaining_list:
	added_instances = df[df["domain"] == i].sample(n=10)
	final_sample = pd.concat([final_sample, added_instances])

final_sample.shape
# Out:
# (10010, 2)

# %%
final_sample.describe()
# Out:
#                     domain                                            url
# count                10010                                          10010
# unique                1001                                          10005
# top     lkrv.fri.uni-lj.si  https://www.easistent.com/navodila_za_placilo
# freq                    10                                              2

# %% [markdown]
# The final sample has 10.010 instances from 1001 domains.

# %%
# Save the df
final_sample.to_csv("MaCoCu-sample-domains-and-urls.csv", sep="\t")

# %% [markdown]
# ## Extract the text from the TMX based on the URL list

# %%
# Open the df with domains and urls for the sample
final_sample = pd.read_csv("MaCoCu-sample-domains-and-urls.csv", sep="\t", index_col = 0)

final_sample.head(2)
# Out:
#                      domain                                                url
# 1461252  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/seminar/in...
# 2129748  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/np_...

# %%
final_sample.shape
# Out:
# (10010, 2)

# %%
# Create a list of urls in the sample
url_list = list(final_sample["url"].unique())
url_list[:10]
# Out:
# ['http://lkrv.fri.uni-lj.si/~ajurisic/seminar/index.html',
#  'http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/np_nasveti/pro_mot.html',
#  'http://lkrv.fri.uni-lj.si/africa/?page=navodila&amp;sys=lin&amp;browser=firefox&amp;lang=eng',
#  'http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/np_nasveti/nastopi.html',
#  'http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/dn/dn9.html',
#  'http://lkrv.fri.uni-lj.si/africa/?page=navodila&amp;sys=win&amp;browser=express&amp;lang=eng',
#  'https://lkrv.fri.uni-lj.si/~ajurisic/seminar/projekti.html',
#  'http://lkrv.fri.uni-lj.si/~ajurisic/mercedes/index.html',
#  'http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/tec_pro_ac.html',
#  'http://lkrv.fri.uni-lj.si/~ajurisic/tex/tex.html']

# %%
len(url_list)
# Out:
# 10005

# %%
# Now that I have the URL list, I will extract texts from the MaCoCu-sl.xml.gz for the sample based on the URL list.

text_all_counter = 0

texts_all = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_string = ""
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
		text_string += line
	elif line.startswith("<p"):
		text_string += line
	elif line.startswith("</p"):
		text_string += line
	elif line.startswith("</doc"):
		text_string += line
		if current_url in url_list:
			current_text = [current_domain, current_url, pure_text, text_string]
			texts_all.append(current_text)
			text_all_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		text_string += line
		pure_text += line
# Out:
# 151967742it [16:46, 151024.45it/s]

# %%
text_all_counter
# Out:
# 10041

# %%
# Create a dataframe out of the text file

df_long_texts = pd.DataFrame({"domain": [x[0] for x in texts_all], "url": [x[1] for x in texts_all], "text": [x[2] for x in texts_all],"doc": [x[3] for x in texts_all]})

df_long_texts.head()
# Out:
#     domain                   url  \
# 0   ahp.si       https://ahp.si/
# 1   pas.si   https://www.pas.si/
# 2   osi.si   https://www.osi.si/
# 3  ecpd.si   http://www.ecpd.si/
# 4  jeko.si  https://www.jeko.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
# 2  OSI je podjetje z dolgoletnimi izkušnjami na p...
# 3  SVETOVNI DAN HRANE 2020\nRegistracija in več i...
# 4  Oskrba z vodo\nOskrba z vodo prinaša občanom z...
#
#                                                  doc
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...
# 2  <doc id="macocu.si.712" title="OSI sistemske i...
# 3  <doc id="macocu.si.1004" title="ECPD - Domov" ...
# 4  <doc id="macocu.si.1011" title="Uvod | Jeko" c...

# %%
df_long_texts.describe(include="all")
# Out:
#                    domain                                      url  \
# count               10041                                    10041
# unique               1001                                    10005
# top     stave-sportne.com  https://europacantat.jskd.si/sl/novice/
# freq                   12                                        3
#
#                                                      text  \
# count                                               10041
# unique                                              10041
# top     Bolnica za živali Postojna\nBolnica za živali ...
# freq                                                    1
#
#                                                       doc
# count                                               10041
# unique                                              10041
# top     <doc id="macocu.si.221" title="Domov | Bolnica...
# freq                                                    1

# %%
df_long_texts.domain.value_counts()
# Out:
# stave-sportne.com    12
# oskosmac.si          12
# easistent.com        12
# belvin.si            12
# toner123.si          12
#                      ..
# luminum.si           10
# paloma.si            10
# lovska-zveza.si      10
# lekarne-ptuj.si      10
# nkt-z.si             10
# Name: domain, Length: 1001, dtype: int64

# %% [markdown]
# Some URLs appear multiple times with different texts, so at the end, our sample consits of 10.041 texts. The problem with this is a) that some domains have more instances than other, and b) that texts under some of the URLs might be shorter than 75 words. That is why we calculated the length of the texts again and discarded those with length less than 75 words. Then we also sampled out the domains with more than 10 texts, so that at the end all domains have 10 instances.

# %%
# Add information on length
df_long_texts["length"] = df_long_texts["text"].str.split().str.len()

df_long_texts.head()
# Out:
#     domain                   url  \
# 0   ahp.si       https://ahp.si/
# 1   pas.si   https://www.pas.si/
# 2   osi.si   https://www.osi.si/
# 3  ecpd.si   http://www.ecpd.si/
# 4  jeko.si  https://www.jeko.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
# 2  OSI je podjetje z dolgoletnimi izkušnjami na p...
# 3  SVETOVNI DAN HRANE 2020\nRegistracija in več i...
# 4  Oskrba z vodo\nOskrba z vodo prinaša občanom z...
#
#                                                  doc  length
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124
# 2  <doc id="macocu.si.712" title="OSI sistemske i...     173
# 3  <doc id="macocu.si.1004" title="ECPD - Domov" ...    4509
# 4  <doc id="macocu.si.1011" title="Uvod | Jeko" c...     340

# %%
df_long_texts["length"].describe()
# Out:
# count    10041.000000
# mean       411.700229
# std        890.426440
# min         16.000000
# 25%        122.000000
# 50%        212.000000
# 75%        417.000000
# max      30002.000000
# Name: length, dtype: float64

# %%
# Filter out texts, shorter than 75 words
df_long_texts = df_long_texts[df_long_texts["length"] > 75]
df_long_texts.shape
# Out:
# (10027, 5)

# %%
# Save the intermediate dataframe
df_long_texts.to_csv("MaCoCu-sl-sample.csv", sep="\t")

# %%
all_domains_frequency = df_long_texts.domain.value_counts().to_dict()

all_domains_frequency
# Out:
# {'europacantat.jskd.si': 12,
#  'easistent.com': 12,
#  'belvin.si': 11,
#  'bobri.si': 11,
#  'os-hpuhar.si': 11,
#  'gorenc.si': 11,
#  'gs-lendava.si': 11,
#  'psj.ff.uni-lj.si': 11,
#  'osdobova.si': 11,
#  'register.si': 11,
#  'os-kobarid.si': 11,
#  'oskosmac.si': 11,
#  'hram-holding.si': 11,
#  'st-garden.si': 11,
#  'prodom.si': 11,
#  'uc.fmf.uni-lj.si': 10,
#  'medica-center.si': 10,
#  'ghd-ilirskabistrica.si': 10,
#  'odpocij.si': 10,
#  'avtoplus.si': 10,
#  'spekter-kr.si': 10,
#  'nutrida.si': 10,
#  'festival-gg.si': 10,
#  'najdibon.si': 10,
#  'kdlpp.calivita.si': 10,
#  'spiklja.blogspot.com': 10,
#  'kokos.shopamine.si': 10,
#  'instalacije-strus.si': 10,
#  'legama.si': 10,
#  'lucijacevnik.si': 10,
#  'ambulanta-zdravje.si': 10,
#  'pdradovljica.si': 10,
#  'hotel-mangart.com': 10,
#  'artekcenter.com': 10,
#  'register.prohereditate.com': 10,
#  'letnoporocilo.triglav.eu': 10,
#  'zumtobel.com': 10,
#  'slo.castingbronzebushing.com': 10,
#  'my-favouriteday.blogspot.com': 10,
#  'gasilci-bistrica.org': 10,
#  'zaper-1a.si': 10,
#  'kafrca.blogspot.com': 10,
#  'fun.hudo.com': 10,
#  'ivagabund.wordpress.com': 10,
#  'teamtraining.si': 10,
#  'visitankaran.si': 10,
#  'partizan.zirovnica.si': 10,
#  'vrteckolezija.si': 10,
#  'pinokio.si': 10,
#  'ikonosmedia.si': 10,
#  'luster.si': 10,
#  'osfpmaribor.si': 10,
#  'agrosaat.si': 10,
#  'td-krim.si': 10,
#  'gorenjski-sindikati.si': 10,
#  'tgrozni.blogspot.com': 10,
#  'penzion-kracun.si': 10,
#  'namestitev-atlasa-humanup.si': 10,
#  'sozitje-ljubljana.si': 10,
#  'zagrabi.si': 10,
#  'akskofjaloka.si': 10,
#  'dso-grosuplje.si': 10,
#  'zabice.splet.arnes.si': 10,
#  'dmstudio.si': 10,
#  'fammcommerce.si': 10,
#  'firerescue.shop': 10,
#  'gradovivoblakih.blogspot.com': 10,
#  'matchme.si': 10,
#  'snjiksnjak.blogspot.com': 10,
#  'solarfocus.si': 10,
#  'ahp.si': 10,
#  'kakozavarovati.si': 10,
#  'znidarsic.net': 10,
#  'zimski-sporti.si': 10,
#  'help.vojnaplemen.si': 10,
#  'ko-rak.si': 10,
#  'tehnooptika-smolnikar.si': 10,
#  'goriske.si': 10,
#  'rc-kocevjeribnica.si': 10,
#  'drustvo-kid.si': 10,
#  'obvladajmosladkorno.si': 10,
#  'kreativne-igrace.si': 10,
#  'lesnina-kocevje.si': 10,
#  'posita.si': 10,
#  'nagodeti.com': 10,
#  'visit-prlekija.eu': 10,
#  'shopamine.com': 10,
#  'mka.si': 10,
#  'domovinasospomini.eu': 10,
#  'druzinska-terapija.com': 10,
#  'druzabne-igre.eu': 10,
#  'logarska-dolina.si': 10,
#  'outletshop.si': 10,
#  'belokranjski-vodovod.si': 10,
#  'biplus.si': 10,
#  'nanikozmetika.si': 10,
#  'ds-instrukcije.si': 10,
#  'poetikon.si': 10,
#  'maribor.volvocars.si': 10,
#  'ritemsrca.ognjisce.si': 10,
#  'amcham.si': 10,
#  'svs-servis.si': 10,
#  'nepremicninskaagencija.si': 10,
#  'akudkolo.si': 10,
#  'odvetnik-trsan.si': 10,
#  'nadjaogrinc.com': 10,
#  'carcentercerar.si': 10,
#  'planinci-cirkulane.si': 10,
#  'poseidon-navtika.si': 10,
#  'pohodobreki.si': 10,
#  'tenatrgovina.si': 10,
#  'kozmeticnisalon-nika.si': 10,
#  'ao-ajdovscina.si': 10,
#  'cityhotel.si': 10,
#  'os-miklavz.si': 10,
#  'mastatrade.si': 10,
#  'rajski-vrt.si': 10,
#  'buba-trgovina.si': 10,
#  'trebnje.os-trebnje.si': 10,
#  'zsctrbovlje.si': 10,
#  'elektrotrgovina.si': 10,
#  'eurol.si': 10,
#  'omnicom.si': 10,
#  'mojeposavje.si': 10,
#  'e-koroska.si': 10,
#  'fotoyurko.blogspot.com': 10,
#  'winterhalter.com': 10,
#  'parfemi.eu': 10,
#  'andrejblatnik.com': 10,
#  'dopolnilnozavarovanje.si': 10,
#  'studiodebeaute.si': 10,
#  'akvizitor.si': 10,
#  'jmss-mb.si': 10,
#  'bodifit-shop.com': 10,
#  'jasakoceli.com': 10,
#  'bledrose.com': 10,
#  'os-sp-kungota.si': 10,
#  'vspo.si': 10,
#  'micna-cvetlicna.si': 10,
#  'domlipa.si': 10,
#  'saubermacher.si': 10,
#  'alensa.si': 10,
#  'sola-skofije.si': 10,
#  'drzavnisvet.si': 10,
#  'markkavcic.si': 10,
#  'tnm.si': 10,
#  'golfarboretum.si': 10,
#  'oskoroskabela.si': 10,
#  'vtvstudio.com': 10,
#  'terming.eu': 10,
#  'paysafecard.com': 10,
#  'fima-znanje.b2b-group.net': 10,
#  'arnes.org': 10,
#  'arslitera.org': 10,
#  'barkahabibi.wordpress.com': 10,
#  'ma-ko.si': 10,
#  'entrada.si': 10,
#  'ka-komunikacije.si': 10,
#  'badminton-menges.si': 10,
#  'jkp-konjice.si': 10,
#  'kmetija-vrhivsek.si': 10,
#  'pravo-za-naravo.si': 10,
#  'anepremicnine.si': 10,
#  'akkbranik.si': 10,
#  'osmatijecopa.si': 10,
#  'av-studio.si': 10,
#  'metlika-turizem.si': 10,
#  'cms.center-nepremicnin.si': 10,
#  'letev.si': 10,
#  'stojanspegel.si': 10,
#  'elektrina.si': 10,
#  'bio.ijs.si': 10,
#  'geero.si': 10,
#  'ssjj.si': 10,
#  'trgovina.exmega.si': 10,
#  'filmstart.si': 10,
#  'fotoklub-kamnik.si': 10,
#  'karbonoir.si': 10,
#  'markosetinc.com': 10,
#  'bodifit.net': 10,
#  'sportnestave.org': 10,
#  'pinjadzazna.blogspot.com': 10,
#  'obcina-apace.si': 10,
#  'drustvostrojnik.si': 10,
#  'solarni-sistemi-wagner.si': 10,
#  'lesnifeniks.si': 10,
#  'vrtnarstvotement.si': 10,
#  'fancigallus.si': 10,
#  'os-franakranjca.si': 10,
#  'kkmetliskacrnina.si': 10,
#  'o-video.si': 10,
#  'epal.gzs.si': 10,
#  'zdsps.si': 10,
#  'beautybottled.si': 10,
#  'silink.si': 10,
#  'vodici.cek.ef.uni-lj.si': 10,
#  'teekanne.si': 10,
#  'martinstrel.com': 10,
#  'psbukovscica.splet.arnes.si': 10,
#  'terming.si': 10,
#  'vlakci.si': 10,
#  'softdata.si': 10,
#  'moje-izkusnje.si': 10,
#  'slogaimingforum.mojforum.si': 10,
#  'cefaly.si': 10,
#  'tiktaktest.si': 10,
#  'masazadojencka.si': 10,
#  'stajerskaprotiraku.si': 10,
#  'avon.si': 10,
#  'panevropa.si': 10,
#  'otok-sporta.si': 10,
#  'informatika.gpiran.si': 10,
#  'helenavlaj.si': 10,
#  'slovenskiavtoleta.si': 10,
#  'blog.geobunkelj.si': 10,
#  'sgls.si': 10,
#  'osorehek.si': 10,
#  'mandalavaga.si': 10,
#  'bazenar.si': 10,
#  'club.autodoc.si': 10,
#  'cistilniservis-kalpjica.com': 10,
#  'zto.taborniki.net': 10,
#  'temnonebo.com': 10,
#  'torna.si': 10,
#  'zetatalk.com': 10,
#  'hc-center.com': 10,
#  'nefrodial.si': 10,
#  'mobinetprodukcija.si': 10,
#  'fizioterapija-grosuplje.si': 10,
#  'zupnija-izola.rkc.si': 10,
#  'aoyue.si': 10,
#  'zupnija-piran.si': 10,
#  '50.radiostudent.si': 10,
#  'gost.si': 10,
#  'beamelectrolux.si': 10,
#  'centerjanezalevca.si': 10,
#  'matematiki.si': 10,
#  'drustvo-dgitmb.si': 10,
#  'art-design.si': 10,
#  'drobnovratnik.si': 10,
#  'celosten.si': 10,
#  'fitlucija.si': 10,
#  'ustvarja-anla.blogspot.com': 10,
#  'kreal962.blogspot.com': 10,
#  'cenazlata.info': 10,
#  'jezikovno-mesto.com': 10,
#  'pernod-ricard-slovenia.com': 10,
#  'si.kompass.com': 10,
#  'builddaysis.com': 10,
#  'istracamping.com': 10,
#  'domplan.si': 10,
#  'uip.si': 10,
#  'polnilne-postaje.si': 10,
#  'vremenska-napoved.si': 10,
#  'gg-steklarstvo.si': 10,
#  'brda-vipavskadolina-kras.si': 10,
#  'binova.si': 10,
#  'hisalasnihmisli.si': 10,
#  'kdrp-celje.si': 10,
#  'plesnicenter-feniks.si': 10,
#  'metameti.wordpress.com': 10,
#  'strojna.scv.si': 10,
#  'vidal.si': 10,
#  'vemvec.si': 10,
#  'bag.si': 10,
#  'zakljucevanje.si': 10,
#  'platinumsport.si': 10,
#  'originalen.si': 10,
#  'zip-inzeniring.si': 10,
#  'karateklub-ronin.si': 10,
#  'svetkaminov.si': 10,
#  'sonusart.si': 10,
#  'manuela-aleunam.blogspot.com': 10,
#  'gastrogurman.mojegostovanje.com': 10,
#  'lokarjevoleto.ajdovscina.si': 10,
#  'herbalife.si': 10,
#  'urbanistika.si': 10,
#  'r-2-r.si': 10,
#  'rksvis.si': 10,
#  'veselahiska.blogspot.com': 10,
#  'arso.gov.si': 10,
#  'trgovina.geocacher.si': 10,
#  'biroservis-zolnir.si': 10,
#  'institut-medius.si': 10,
#  'benedek.si': 10,
#  're-eko.si': 10,
#  'dskp-drustvo.si': 10,
#  'revijaglasna.si': 10,
#  'ospodzemelj1.splet.arnes.si': 10,
#  'si.oriflame.com': 10,
#  'grec.si': 10,
#  'zupnija-stepanja-vas.rkc.si': 10,
#  'kc.uni-lj.si': 10,
#  'teniski-klub-krsko.si': 10,
#  'omv.si': 10,
#  'forumzagorisko.si': 10,
#  'mazars.si': 10,
#  'lemit.si': 10,
#  'shirataki.si': 10,
#  'kupujmodomace.si': 10,
#  'henkel-adhesives.com': 10,
#  'abp-sport.com': 10,
#  'jadran303.blogspot.com': 10,
#  'dssmith.com': 10,
#  'lkrv.fri.uni-lj.si': 10,
#  'davcninasveti.si': 10,
#  '2015.tsd.si': 10,
#  'drustvo-bkb.si': 10,
#  'scpo.splet.arnes.si': 10,
#  'zd-slovenskekonjice.si': 10,
#  'jd-divaca.divaska-jama.info': 10,
#  'ljubljanica.net': 10,
#  'korenine.si': 10,
#  'kvadrat-nepremicnine.si': 10,
#  'omn-shop.si': 10,
#  'gumenadom.si': 10,
#  'knjiznica-crnomelj.si': 10,
#  'slo-akreditacija.si': 10,
#  'os-dornava.si': 10,
#  'zeljko-heimer-fame.from.hr': 10,
#  'metrel.si': 10,
#  'hise-montazne.si': 10,
#  'pamp.si': 10,
#  'magzter.com': 10,
#  'dreizinnen.com': 10,
#  'gezagrabar.kmeckiglas.com': 10,
#  'lekarna-plavz.com': 10,
#  'mobiterra.si': 10,
#  'metakocka.freshdesk.com': 10,
#  'lilijinokraljestvoustvarjanja.blogspot.com': 10,
#  'lovskaoprema.si': 10,
#  'beta.edavki.durs.si': 10,
#  'tekaskinasveti.wordpress.com': 10,
#  'kspragersko-gaj.si': 10,
#  'agroma.si': 10,
#  'stara.lasnisistem.com': 10,
#  'studio360.si': 10,
#  'neodkritaarheologijaljubljane.wordpress.com': 10,
#  'modro-jutro.si': 10,
#  'deklica.si': 10,
#  'prima-pomoc.si': 10,
#  'apkhome.net': 10,
#  'kocke.gzs.si': 10,
#  'zupnija-dovje.si': 10,
#  'otokzakladov.com': 10,
#  'galerija.klub-srecnih.si': 10,
#  'kdbrda.si': 10,
#  'zone-2000.net': 10,
#  'mnzmaribor.si': 10,
#  'koridor-kriziscaumetnosti.blogspot.com': 10,
#  'subaru-slo.net': 10,
#  'dsi2012.dsi-konferenca.si': 10,
#  'krzs.si': 10,
#  'zobozdravnik-grosuplje.si': 10,
#  'nafta1903.si': 10,
#  'innovatif.com': 10,
#  'theta.ffzg.hr': 10,
#  'nuvi-garmin.mojforum.si': 10,
#  'altright.si': 10,
#  'raziskavacrp.uni-mb.si': 10,
#  'ospuconci.splet.arnes.si': 10,
#  'dldp.wordpress.com': 10,
#  'reisenadler-poezija.blogspot.com': 10,
#  'urbaniizziv.uirs.si': 10,
#  'sampy.si': 10,
#  'drustvovidovskihribi.bahne.si': 10,
#  'vipavska-dekanija.rkc.si': 10,
#  'drivegreen.si': 10,
#  'vipa-holding.si': 10,
#  'veterinajagodic.si': 10,
#  'efekt-svetila.si': 10,
#  'medicum.si': 10,
#  'konekt.si': 10,
#  'sl.versal-wood.com': 10,
#  'kolesarskiklub-postojna.si': 10,
#  'sentiljpodturjakom-mislinja.si': 10,
#  'tvlasko.si': 10,
#  'ucilnica0506.fmf.uni-lj.si': 10,
#  'xenon-forte.hr': 10,
#  'zalozba.pef.uni-lj.si': 10,
#  'at-oprema.si': 10,
#  'interokno.si': 10,
#  'pisemozroko.si': 10,
#  'orodje-zabjek.si': 10,
#  'malabarka.eu': 10,
#  'dodatnozdravstvenozavarovanje.com': 10,
#  'malasolakritike2016.wordpress.com': 10,
#  'adss.mojforum.si': 10,
#  'trinet.si': 10,
#  'resje.mojforum.si': 10,
#  'monna-lisa.si': 10,
#  'lip-pohistvo.si': 10,
#  'dentalni-studio.si': 10,
#  'naturesfinest.si': 10,
#  'ntk-radlje.si': 10,
#  'pasjazvezda.si': 10,
#  'barbarella.si': 10,
#  'elly-zlatolasska.blogspot.com': 10,
#  'atlantomed.eu': 10,
#  'louis-vuitton-handbags.eu': 10,
#  'derekprince.ekaris.net': 10,
#  'klika-klika.si': 10,
#  'madagaskar.missio.si': 10,
#  'darilnica.si': 10,
#  'biotechnology-gmo.gov.si': 10,
#  'oceandiving.si': 10,
#  'teta-pehta.si': 10,
#  'castni.nakamniskem.si': 10,
#  'diabetes-loka.si': 10,
#  '2020.mojbosch.si': 10,
#  'turni-klub-gora.si': 10,
#  'tineserazin.si': 10,
#  'googlovprevajalnik.com': 10,
#  'atlasexpress.eu': 10,
#  'ohranimozemljo.si': 10,
#  'celostna-podpora.si': 10,
#  'gml-drustvo.si': 10,
#  'mgk.si': 10,
#  'fd-radovljica.si': 10,
#  'otroska-ocala.si': 10,
#  'radiocapris.si': 10,
#  'ossmarjeta.splet.arnes.si': 10,
#  'drustvo-lak.si': 10,
#  'vrtec.osbos.eu': 10,
#  'stadionshop.com': 10,
#  'klub.t-2.net': 10,
#  'superdavki.com': 10,
#  'svet-filmov.blogspot.com': 10,
#  'inobrezice.com': 10,
#  'digiracunovodja.si': 10,
#  'osilnica.si': 10,
#  'wellness-oprema.si': 10,
#  'e-mobilitygorenjska.si': 10,
#  'zemljevidi-vodniki.si': 10,
#  'apo-vizija.si': 10,
#  'warmup.si': 10,
#  'mm-konto.si': 10,
#  'aquas.si': 10,
#  'rk-ajdovscina.si': 10,
#  'dr-gorkic.si': 10,
#  'studio-anima.si': 10,
#  'dsi2011.si': 10,
#  'arhiv.stud-dom-lj.si': 10,
#  'pharmos-natur.si': 10,
#  'ssff.ff.uni-lj.si': 10,
#  'motogp.avtomanija.com': 10,
#  'drustvo-zoja.si': 10,
#  'osbistricaobsotli.si': 10,
#  'komunala-trzic.si': 10,
#  '2015.nocknjige.si': 10,
#  'riko-hise.si': 10,
#  'ilb-scpo.splet.arnes.si': 10,
#  'mariposacoffeeroasters.si': 10,
#  'anglistika.ff.uni-lj.si': 10,
#  'igrace-populi.com': 10,
#  'spartathlonzdravkoc.blogspot.com': 10,
#  'pizama.net': 10,
#  'zobozdravstvo.com': 10,
#  'econo.eu': 10,
#  'svetovnietos.si': 10,
#  'sever-drive.si': 10,
#  'projekt.e-prostor.gov.si': 10,
#  'ansambeltiktak.si': 10,
#  'trubarjeva-domacija.si': 10,
#  'zvezdeizjave.pozareport.si': 10,
#  'pocenielektrika.si': 10,
#  'sbextreme.si': 10,
#  'masazni-bazen.si': 10,
#  're-bo.si': 10,
#  'beta.sah-zveza.si': 10,
#  'coface.si': 10,
#  'biosistemsko-inzenirstvo.si': 10,
#  'prepihmedia.com': 10,
#  'mojmalisvet.kmeckiglas.com': 10,
#  'lotos-svetovanje.si': 10,
#  'infokart.si': 10,
#  'aba.si': 10,
#  'virtualno.si': 10,
#  'fizioterapija-cajnko.si': 10,
#  'sl.nautic-point.eu': 10,
#  'tkanjemalepajkice.blogspot.com': 10,
#  'likovni-material.si': 10,
#  'srecnozivljenje.si': 10,
#  'javno-zdravstvo.si': 10,
#  'jhp.si': 10,
#  'perzijskepreproge.si': 10,
#  'fokusmetlika.si': 10,
#  'sebur.si': 10,
#  'media-butik.si': 10,
#  'f2.ijs.si': 10,
#  'prijaznidookolja.si': 10,
#  'europereadr.eu': 10,
#  'deveturmanj.wordpress.com': 10,
#  'zupnija-sostro.squarespace.com': 10,
#  'isolacinema.org': 10,
#  'pasjapekarna.com': 10,
#  'kenwoodworld.com': 10,
#  'rosetouchmakeup.blogspot.com': 10,
#  'pd-sovodenj.si': 10,
#  'nepopustljivo-srce.si': 10,
#  'ambicij.si': 10,
#  'tu-val.si': 10,
#  'podjetjavizoli.si': 10,
#  'recepti.art-design.si': 10,
#  'ekokmetija-zvonik.si': 10,
#  'supernova-kp.si': 10,
#  'babyfit.si': 10,
#  'robertkotnik.si': 10,
#  'skratek.si': 10,
#  'zoranfurman.com': 10,
#  'eudace.eu': 10,
#  'blog-p.kage.fun': 10,
#  'sl.macspots.com': 10,
#  'laserline.hr': 10,
#  'trailrun.si': 10,
#  'aelita.si': 10,
#  'inz.si': 10,
#  'lesk-s.si': 10,
#  'tipintap.si': 10,
#  'rastocaknjiga.si': 10,
#  'pora-gr.si': 10,
#  'zascita.si': 10,
#  'rts.si': 10,
#  'adesco.si': 10,
#  'gal-lab.si': 10,
#  'lions-vrhnika.si': 10,
#  'moko.si': 10,
#  'splet.dc-dlan.si': 10,
#  'kamini.si': 10,
#  'psihosoma.si': 10,
#  'planb.si': 10,
#  'ultratrail.si': 10,
#  'srcesloveniji.si': 10,
#  'ideaz.si': 10,
#  'trgovinapukka.si': 10,
#  'fitnes-zdravo.si': 10,
#  'hc-swasthya.com': 10,
#  'luxurymarine.si': 10,
#  'otok-pag.si': 10,
#  'slovarji.dzs.si': 10,
#  'zupanciceva.si': 10,
#  'visia.si': 10,
#  'napofilm.net': 10,
#  'sl.raionka.com': 10,
#  'majamonrue.com': 10,
#  'kwslovenia.com': 10,
#  'jarc.si': 10,
#  'zamoc.si': 10,
#  'koc-inovatis.si': 10,
#  'ssrs.si': 10,
#  'mtgslo.si': 10,
#  'sgtsr.si': 10,
#  'karate-celje.si': 10,
#  'kjuc.si': 10,
#  'brinox.si': 10,
#  'dspot.si': 10,
#  'klaro.si': 10,
#  'zaplesi.si': 10,
#  'adria-center.si': 10,
#  'centerdobrna.si': 10,
#  'redbook.si': 10,
#  'zizki.si': 10,
#  'kolo.si': 10,
#  'shopsy.si': 10,
#  'klimanaprave.si': 10,
#  'hardstore.si': 10,
#  'varnost-shop.si': 10,
#  'portalzamulce.si': 10,
#  'autoanalitica.si': 10,
#  'proweb.si': 10,
#  'gibanica.si': 10,
#  'zzps.gzs.si': 10,
#  'lutra.si': 10,
#  'acer-nm.si': 10,
#  'vsm.si': 10,
#  'klsps.si': 10,
#  'najvozicki.si': 10,
#  'kunstelj.si': 10,
#  'skonji.si': 10,
#  'zodiak.si': 10,
#  'norica.si': 10,
#  'speculumartium.si': 10,
#  'i-var.si': 10,
#  'jasminaturnsek.si': 10,
#  '1ka.arnes.si': 10,
#  'restaurantclub.si': 10,
#  'pivkakk.si': 10,
#  'vitabaros.si': 10,
#  'vomberger.si': 10,
#  'napot.si': 10,
#  'sanus-statera.com': 10,
#  'polyregion.org': 10,
#  'iskraemeco.com': 10,
#  'si.usattmotor.com': 10,
#  'eedison.eu': 10,
#  'kvartir.org': 10,
#  'avanture.net': 10,
#  'stave-sportne.com': 10,
#  'i2-lj.si': 10,
#  'lea-ptuj.si': 10,
#  'slovenija2050.si': 10,
#  'ugleden.si': 10,
#  'druga.si': 10,
#  'esnm.si': 10,
#  'drustvo-breza.si': 10,
#  'remax.si': 10,
#  'portal8.si': 10,
#  'natonhr.com': 10,
#  'si.orcaenergy.eu': 10,
#  'kurjapolt.org': 10,
#  'karlaklander.com': 10,
#  'calivita.si': 10,
#  'kufer.si': 10,
#  'to-go.si': 10,
#  'kocles.si': 10,
#  'olioweb.si': 10,
#  'takolepo.si': 10,
#  'manpower.si': 10,
#  'nailsuperstore.si': 10,
#  'eurofoto.si': 10,
#  'td-brise.si': 10,
#  'spikotdojencek.si': 10,
#  'eaglepack.si': 10,
#  'trgovina.lasek.si': 10,
#  'dnla.si': 10,
#  'cd-velikelasce.si': 10,
#  'wordbz.gimptuj.si': 10,
#  'avtera.si': 10,
#  'robotika.rc-nm.si': 10,
#  'avota.si': 10,
#  'pevski-zbor.si': 10,
#  'tty.si': 10,
#  'hostko.si': 10,
#  'neoniz.si': 10,
#  'v-team.si': 10,
#  '3pharm.si': 10,
#  'ervita.si': 10,
#  'karnion.si': 10,
#  'senator.si': 10,
#  'mirjana.si': 10,
#  'las-smp.si': 10,
#  'ceu.ijs.si': 10,
#  'boncina.si': 10,
#  'pladent.si': 10,
#  'srce-si.si': 10,
#  'model-m.si': 10,
#  'bioviva.si': 10,
#  'svjozef.si': 10,
#  'domovoj.si': 10,
#  'moto-gp.si': 10,
#  'celkrog.si': 10,
#  'las-ssd.si': 10,
#  'kositer.si': 10,
#  'mirosan.si': 10,
#  'drbenko.si': 10,
#  'potjoge.si': 10,
#  'pilgrim.si': 10,
#  'salsero.si': 10,
#  'gdi.net': 10,
#  'merit-hp.si': 10,
#  'topteh.si': 10,
#  'eu.sta.si': 10,
#  'askit.si': 10,
#  'pdziri.si': 10,
#  'osi.si': 10,
#  'ecpd.si': 10,
#  'jeko.si': 10,
#  'ohra.si': 10,
#  'zbor.si': 10,
#  'inin.si': 10,
#  'icpe.si': 10,
#  'piki.si': 10,
#  'borl.si': 10,
#  'zssm.si': 10,
#  'misk.si': 10,
#  'arag.si': 10,
#  'vedun.si': 10,
#  'oblak.si': 10,
#  'k-tes.si': 10,
#  'river.si': 10,
#  'igost.si': 10,
#  'tibis.si': 10,
#  'nafta.si': 10,
#  'sikom.si': 10,
#  'horus.si': 10,
#  'dihta.si': 10,
#  'lineal.si': 10,
#  'itshop.si': 10,
#  'geolux.si': 10,
#  'doremi.si': 10,
#  'sovice.si': 10,
#  'metabond.si': 10,
#  'nkidrija.si': 10,
#  'erteh.si': 10,
#  'hisamladih.si': 10,
#  'kd-krim.si': 10,
#  'vskv.si': 10,
#  'robertsket.si': 10,
#  'web.arctur.si': 10,
#  'mtsi.si': 10,
#  'dso-fuzine.si': 10,
#  'ezs.si': 10,
#  'tehnoshop.net': 10,
#  'sol-navitas.si': 10,
#  'iskriv.si': 10,
#  'icpika.si': 10,
#  'gombac.si': 10,
#  'kacin.si': 10,
#  'kemseks.si': 10,
#  'gvar.si': 10,
#  'klin.si': 10,
#  'predsednica.si': 10,
#  'ajda-sostro.si': 10,
#  'hruska.si': 10,
#  'mojezdravje.si': 10,
#  'kosec-trade.si': 10,
#  'vucko.si': 10,
#  'murskekrone.si': 10,
#  'sb-trbovlje.si': 10,
#  'amd-kocevje.si': 10,
#  'lukasi.si': 10,
#  'usb.si': 10,
#  'szljutomer.si': 10,
#  'minikon.si': 10,
#  'proelium.si': 10,
#  'zlatarnica.si': 10,
#  'mojporod.si': 10,
#  'toner123.si': 10,
#  'slora.si': 10,
#  'gdl.si': 10,
#  'domhalas.si': 10,
#  'zavod123.si': 10,
#  'skup.si': 10,
#  'h2oteam.com': 10,
#  'yootree.net': 10,
#  'cebelca.biz': 10,
#  'mojapot.net': 10,
#  'kbp.si': 10,
#  'ooz-trzic.si': 10,
#  'vozni-red.si': 10,
#  'blog.kopa.si': 10,
#  'mars.dmfa.si': 10,
#  'elmag.si': 10,
#  'ekosystem.si': 10,
#  'aser.si': 10,
#  'pikinsvet.si': 10,
#  'hkslavija.si': 10,
#  'lentismed.si': 10,
#  'sledenje.com': 10,
#  'troblja.info': 10,
#  'coocoo.si': 10,
#  'bizart.si': 10,
#  'projekt-gt.si': 10,
#  'rkk.si': 10,
#  'noxinterier.si': 10,
#  'solazazivljenje.si': 10,
#  'odmestadovasi.si': 10,
#  'saklub-idrija.si': 10,
#  'cpr.uri-soca.si': 10,
#  'judoslo.si': 10,
#  'pekaindom.si': 10,
#  'koper.ozrk.si': 10,
#  'sdvidonci.si': 10,
#  'kongres-podjetnikov.si': 10,
#  'malamasa.si': 10,
#  'kulebike.si': 10,
#  'prezracevanje.si': 10,
#  'bell.si': 10,
#  'vrtec-prebold.si': 10,
#  'dom-streha.si': 10,
#  'zapleti.si': 10,
#  'ormoz.ozrk.si': 10,
#  'photon.si': 10,
#  'pickpack-shop.si': 10,
#  'dobrotemetka.si': 10,
#  'www2.cmepius.si': 10,
#  'enerkon.si': 10,
#  'kariera.lidl.si': 10,
#  'briljantina-muzikal.si': 10,
#  'murskival.si': 10,
#  'aksentjur.si': 10,
#  'domkuhinj.si': 10,
#  'mandolina.si': 10,
#  'scalar.si': 10,
#  'negatelesa.si': 10,
#  'itaia.islate.si': 10,
#  'kuod-bayani.com': 10,
#  'gsvd.si': 10,
#  'hkmtoplice.si': 10,
#  'vrtec-ig.si': 10,
#  'paradiznik.si': 10,
#  'zelena-streha.si': 10,
#  'vrsicek.si': 10,
#  'evang-cerkev.si': 10,
#  'baam.si': 10,
#  'gdnova.si': 10,
#  'skitti.si': 10,
#  'ritosa.si': 10,
#  'tehnologika.si': 10,
#  'sib-mb.si': 10,
#  'vrtec-ivanaglinska.si': 10,
#  'dotica.si': 10,
#  'grafik.si': 10,
#  'imovation.si': 10,
#  'hoteldobregaterana.si': 10,
#  'moj-kovcek.si': 10,
#  'moj-kuponcek.si': 10,
#  'os-spidrija.si': 10,
#  'calesitatango.si': 10,
#  'fdr.kibla.org': 10,
#  'pnevmatike.com': 10,
#  'findhealthclinics.com': 10,
#  'avtotrgovina.com': 10,
#  'tamesworld.com': 10,
#  'linguarus.si': 10,
#  'idrijskacipka.si': 10,
#  'techka-bb.blogspot.com': 10,
#  'mphisa.si': 10,
#  'medicaartis.si': 10,
#  'pivovarium.si': 10,
#  'vsvo.si': 10,
#  'kokain.si': 10,
#  'vizijanic.si': 10,
#  'e-leclerc.si': 10,
#  'antontomai.blogspot.com': 10,
#  'prometna.net': 10,
#  'si.bor-plastika.eu': 10,
#  'zakladiobpaki.com': 10,
#  'samson-slo.com': 10,
#  'breastreconstruction.eu': 10,
#  'blagajne.com': 10,
#  'sadjarstvo.com': 10,
#  'veso-art.com': 10,
#  'lesenica.com': 10,
#  'greenpeace.org': 10,
#  'etiketa.si': 10,
#  'nolik.si': 10,
#  'pokmuz-ce.si': 10,
#  'sokolbezigrad.si': 10,
#  'kubu.si': 10,
#  'ureditevokolice.si': 10,
#  'pas.si': 10,
#  'sks.si': 10,
#  'zbudiprodajalca.si': 10,
#  'manualnaterapija.si': 10,
#  'gasilcikranj.si': 10,
#  'vvdental.si': 10,
#  'marende.si': 10,
#  'samozalozba.eu': 10,
#  'zd-brezice.si': 10,
#  'spovednik.blogspot.com': 10,
#  'kwb.net': 10,
#  'palacanakita.com': 10,
#  'parket-ravbar.com': 10,
#  'danasnjenovice.com': 10,
#  'slov.si': 10,
#  'studio-legen.si': 10,
#  'lesarski-grozd.si': 10,
#  'ivsanbernard.si': 10,
#  'jogavita.si': 10,
#  'zaslon-telecom.si': 10,
#  'zaper-zaperino.si': 10,
#  'rence.si': 10,
#  'zavod14.si': 10,
#  'explorer.si': 10,
#  'bausch-lomb.si': 10,
#  'kauch.si': 10,
#  'gzmetlika.si': 10,
#  'cgp.si': 10,
#  'zadnjeupanje.si': 10,
#  'zdrava-prehrana.si': 10,
#  'muflon.si': 10,
#  'ribiska-druzina-bled.si': 10,
#  'klet-krsko.si': 10,
#  'ii.feri.um.si': 10,
#  'oskozje.si': 10,
#  'center-zarja.si': 10,
#  'kmetijskicenterlah.si': 10,
#  'samo1planet.si': 10,
#  'kamen-mojster.si': 10,
#  'marinahorak.com': 10,
#  'zd-sb.si': 10,
#  'kukusvet.si': 10,
#  '1a-pohistvo.si': 10,
#  'loomp.si': 10,
#  'najgume.si': 10,
#  'brez-gso.svoboda.si': 10,
#  'natasakogoj.si': 10,
#  'candybox.si': 10,
#  'katja-alen.si': 10,
#  'avtoservis-selan.si': 10,
#  'labcommerce.si': 10,
#  'dso-tezno.si': 10,
#  'netsport.si': 10,
#  'ribicpepe.si': 10,
#  'zdravjejevnas.si': 10,
#  'bodibio.si': 10,
#  'zupnija-velesovo.si': 10,
#  'starbirth.si': 10,
#  'sola-prihodnosti.si': 10,
#  'kvs-klub.si': 10,
#  'ingra.si': 10,
#  'hisa.si': 10,
#  'dpz.velike-lasce.si': 10,
#  'meavalens.si': 10,
#  'kamini-golob.si': 10,
#  'trenertadej.si': 10,
#  'siroljub.si': 10,
#  'izdelavakuhinj.com': 10,
#  'kompas-nm.si': 10,
#  'primorci.kcktolmin.si': 10,
#  'ddmaribor.si': 10,
#  'sladkornakratko.si': 10,
#  'mojangel.si': 10,
#  'st-laboratoriji.si': 10,
#  'sportnepriprave.si': 10,
#  'taisa.si': 10,
#  'fellowes.si': 10,
#  'pulzsport.si': 10,
#  'biologika.si': 10,
#  'iia.si': 10,
#  'semina.si': 10,
#  'spacenterlepote.si': 10,
#  'oliviers-co.si': 10,
#  'beglobal.si': 10,
#  'honda.si': 10,
#  'osv-ankaran.si': 10,
#  'fidimed.si': 10,
#  'festivalmaribor.si': 10,
#  'gzkocevje.si': 10,
#  'hausmart.si': 10,
#  'oei.si': 10,
#  'slo-tours.si': 10,
#  'hoodburger.si': 10,
#  'pgd-dobrna.si': 10,
#  'edonacije.si': 10,
#  'minisvet.si': 10,
#  'oslenart.si': 10,
#  'drustvo-rt.si': 10,
#  'podcvetococesnjo.si': 10,
#  'lu-trzic.si': 10,
#  'knjiznica-lenart.si': 10,
#  'kado.si': 10,
#  'fakro.si': 10,
#  'petrawindschnurer.si': 10,
#  'catena.si': 10,
#  'ergomed.si': 10,
#  'metuljcica.si': 10,
#  'manjjevec.si': 10,
#  'voditeljstvo.si': 10,
#  'zrszv.si': 10,
#  'prima.si': 10,
#  'michelin.si': 10,
#  'svetzdravja.si': 10,
#  'united-pop.si': 10,
#  'trma.si': 10,
#  'began.si': 10,
#  'dos2-lendava.si': 10,
#  'tatjanatrajkovska.eu': 10,
#  'vsestoritve.com': 10,
#  'studentska-iskra.org': 10,
#  'batzajla.com': 10,
#  'integragroup.hr': 10,
#  'ices.si': 10,
#  'rafting-zveza.si': 10,
#  'tiego.si': 10,
#  'ldstol.si': 10,
#  'skandinavske-hiske.si': 10,
#  'natura-sanat.si': 10,
#  'insights.si': 10,
#  'lekarne-ptuj.si': 10,
#  'lovska-zveza.si': 10,
#  'paloma.si': 10,
#  'kogovsek.si': 10,
#  'kamenko.si': 10,
#  'oskobilje.si': 10,
#  'bohinj-hotel.com': 10,
#  'internorm.com': 10,
#  'gradbenik.net': 10,
#  'kolesarji.org': 10,
#  'studiotanti.com': 10,
#  'cecilija.net': 10,
#  'kofirajd.com': 10,
#  'mvr.kibla.org': 10,
#  'nicelabel.com': 10,
#  'tvojfitnesizziv.net': 10,
#  'rajmax.si': 10,
#  'luminum.si': 10,
#  'pgd-cusperk.si': 10,
#  'lepaznaravo.si': 10,
#  'pd-polzela.si': 10,
#  'camincam.si': 10,
#  'pgd-vipava.si': 10,
#  'prosperia.si': 10,
#  'magicnost-gibanja.si': 10,
#  'bio-pharma.si': 10,
#  'merhamet.si': 10,
#  'prehranskaklinika.si': 10,
#  'belmond.si': 10,
#  'avstralija.si': 10,
#  ...}

# %%
# Filter out a part of texts from domains that have more than 10 texts
for item in ['europacantat.jskd.si', 'easistent.com']:
	df_long_texts = df_long_texts.drop(df_long_texts[df_long_texts['domain'] == item].sample(n=2).index)

for item in ['belvin.si', 'bobri.si', 'os-hpuhar.si', 'gorenc.si', 'gs-lendava.si', 'psj.ff.uni-lj.si', 'osdobova.si', 'register.si', 'os-kobarid.si', 'oskosmac.si', 'hram-holding.si', 'st-garden.si', 'prodom.si']:
	df_long_texts = df_long_texts.drop(df_long_texts[df_long_texts['domain'] == item].sample(n=1).index)

# %%
df_long_texts.describe(include="all")
# Out:
#         domain                                 url  \
# count    10010                               10010
# unique    1001                                9991
# top     ahp.si  https://psj.ff.uni-lj.si/obvestila
# freq        10                                   2
# mean       NaN                                 NaN
# std        NaN                                 NaN
# min        NaN                                 NaN
# 25%        NaN                                 NaN
# 50%        NaN                                 NaN
# 75%        NaN                                 NaN
# max        NaN                                 NaN
#
#                                                      text  \
# count                                               10010
# unique                                              10010
# top     Bolnica za živali Postojna\nBolnica za živali ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       doc       length
# count                                               10010  10010.00000
# unique                                              10010          NaN
# top     <doc id="macocu.si.221" title="Domov | Bolnica...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    412.45025
# std                                                   NaN    891.60650
# min                                                   NaN     76.00000
# 25%                                                   NaN    122.00000
# 50%                                                   NaN    213.00000
# 75%                                                   NaN    418.00000
# max                                                   NaN  30002.00000

# %%
# Check if all domains have the same number of instances
df_long_texts.domain.value_counts()
# Out:
# ahp.si                          10
# medica-center.si                10
# gradovivoblakih.blogspot.com    10
# my-favouriteday.blogspot.com    10
# snjiksnjak.blogspot.com         10
#                                 ..
# lepaznaravo.si                  10
# pd-polzela.si                   10
# camincam.si                     10
# pgd-vipava.si                   10
# nkt-z.si                        10
# Name: domain, Length: 1001, dtype: int64

# %%
# Save the final sample
df_long_texts.to_csv("MaCoCu-sl-sample.csv", sep="\t")
