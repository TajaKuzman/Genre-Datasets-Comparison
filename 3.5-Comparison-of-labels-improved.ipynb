# %% [markdown]
# I will improve the comparison of labels on which the mapping will be based, by a more automated approach (the initial X-GENRE mapping is based on my manual analysis).

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import apyori

# %% [markdown]
# ## Merging the datasets with predictions into one

# %%
# I will create a "master" sheet with predictions that includes GINCO, FTD and CORE sheets.

# Open the sheets
FTD_df = pd.read_csv("data-sheets-with-all-info/FTD-dataset-with-all-information.csv", sep="\t", index_col = 0)

# %%
FTD_df.head(1)
# Out:
#                   ID              labels Multiple labels  \
# 0  __id__1-syndicate  A1 (argumentative)             NaN
#
#                                                 text  length  \
# 0  BMW's and Chinese Justice * * * * * In most pl...     975
#
#   GINCO_downcast_pred MT-GINCO_downcast_pred CORE_main_pred     CORE_sub_pred  \
# 0      News/Reporting         News/Reporting      Narrative  News Report/Blog
#
#   labels_to_X-GENRE
# 0         discarded

# %%
FTD_df.describe(include="all")
# Out:
#                        ID              labels Multiple labels  \
# count                1553                1553             139
# unique               1553                  43               1
# top     __id__1-syndicate  A1 (argumentative)               y
# freq                    1                 296             139
# mean                  NaN                 NaN             NaN
# std                   NaN                 NaN             NaN
# min                   NaN                 NaN             NaN
# 25%                   NaN                 NaN             NaN
# 50%                   NaN                 NaN             NaN
# 75%                   NaN                 NaN             NaN
# max                   NaN                 NaN             NaN
#
#                                                      text         length  \
# count                                                1553    1553.000000
# unique                                               1553            NaN
# top     BMW's and Chinese Justice * * * * * In most pl...            NaN
# freq                                                    1            NaN
# mean                                                  NaN    1430.271732
# std                                                   NaN    4789.884538
# min                                                   NaN      31.000000
# 25%                                                   NaN     235.000000
# 50%                                                   NaN     531.000000
# 75%                                                   NaN    1203.000000
# max                                                   NaN  146922.000000
#
#             GINCO_downcast_pred   MT-GINCO_downcast_pred  \
# count                      1553                     1553
# unique                        9                        9
# top     Information/Explanation  Information/Explanation
# freq                        437                      328
# mean                        NaN                      NaN
# std                         NaN                      NaN
# min                         NaN                      NaN
# 25%                         NaN                      NaN
# 50%                         NaN                      NaN
# 75%                         NaN                      NaN
# max                         NaN                      NaN
#
#                                CORE_main_pred           CORE_sub_pred  \
# count                                    1553                    1553
# unique                                      8                      22
# top     Informational Description/Explanation  Description of a Thing
# freq                                      856                     419
# mean                                      NaN                     NaN
# std                                       NaN                     NaN
# min                                       NaN                     NaN
# 25%                                       NaN                     NaN
# 50%                                       NaN                     NaN
# 75%                                       NaN                     NaN
# max                                       NaN                     NaN
#
#        labels_to_X-GENRE
# count               1414
# unique                 8
# top            discarded
# freq                 364
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %%
# Filter out multiple texts
FTD_df = FTD_df[FTD_df["Multiple labels"] != "y"]

FTD_df.describe(include="all")
# Out:
#                        ID              labels Multiple labels  \
# count                1414                1414               0
# unique               1414                  10               0
# top     __id__1-syndicate  A1 (argumentative)             NaN
# freq                    1                 296             NaN
# mean                  NaN                 NaN             NaN
# std                   NaN                 NaN             NaN
# min                   NaN                 NaN             NaN
# 25%                   NaN                 NaN             NaN
# 50%                   NaN                 NaN             NaN
# 75%                   NaN                 NaN             NaN
# max                   NaN                 NaN             NaN
#
#                                                      text         length  \
# count                                                1414    1414.000000
# unique                                               1414            NaN
# top     BMW's and Chinese Justice * * * * * In most pl...            NaN
# freq                                                    1            NaN
# mean                                                  NaN    1445.212164
# std                                                   NaN    4989.570842
# min                                                   NaN      31.000000
# 25%                                                   NaN     224.000000
# 50%                                                   NaN     495.000000
# 75%                                                   NaN    1144.250000
# max                                                   NaN  146922.000000
#
#             GINCO_downcast_pred   MT-GINCO_downcast_pred  \
# count                      1414                     1414
# unique                        9                        9
# top     Information/Explanation  Information/Explanation
# freq                        407                      311
# mean                        NaN                      NaN
# std                         NaN                      NaN
# min                         NaN                      NaN
# 25%                         NaN                      NaN
# 50%                         NaN                      NaN
# 75%                         NaN                      NaN
# max                         NaN                      NaN
#
#                                CORE_main_pred           CORE_sub_pred  \
# count                                    1414                    1414
# unique                                      8                      22
# top     Informational Description/Explanation  Description of a Thing
# freq                                      772                     382
# mean                                      NaN                     NaN
# std                                       NaN                     NaN
# min                                       NaN                     NaN
# 25%                                       NaN                     NaN
# 50%                                       NaN                     NaN
# 75%                                       NaN                     NaN
# max                                       NaN                     NaN
#
#        labels_to_X-GENRE
# count               1414
# unique                 8
# top            discarded
# freq                 364
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %%
# Keep only relevant columns
FTD_df = FTD_df[['labels', 'text','GINCO_downcast_pred', 'MT-GINCO_downcast_pred', 'CORE_main_pred',
       'CORE_sub_pred', 'labels_to_X-GENRE']]

# Rename some of the columns
FTD_df.columns = ['FTD', 'text','GINCO_downcast', 'MT-GINCO_downcast', 'CORE_main',
       'CORE_sub', 'X-GENRE']

FTD_df.head(2)
# Out:
#                   FTD                                               text  \
# 0  A1 (argumentative)  BMW's and Chinese Justice * * * * * In most pl...
# 1  A1 (argumentative)  China and a New Balance of Power SHANGHAI – Th...
#
#             GINCO_downcast      MT-GINCO_downcast  CORE_main  \
# 0           News/Reporting         News/Reporting  Narrative
# 1  Information/Explanation  Opinion/Argumentation    Opinion
#
#            CORE_sub    X-GENRE
# 0  News Report/Blog  discarded
# 1      Opinion Blog  discarded

# %%
# Add a column with information that this is originally from FTD
FTD_df["original_label"] = "FTD"

FTD_df.head(1)
# Out:
#                   FTD                                               text  \
# 0  A1 (argumentative)  BMW's and Chinese Justice * * * * * In most pl...
#
#    GINCO_downcast MT-GINCO_downcast  CORE_main          CORE_sub    X-GENRE  \
# 0  News/Reporting    News/Reporting  Narrative  News Report/Blog  discarded
#
#   original_label
# 0            FTD

# %%
FTD_df.columns
# Out:
# Index(['FTD', 'text', 'GINCO_downcast', 'MT-GINCO_downcast', 'CORE_main',
#        'CORE_sub', 'X-GENRE', 'original_label'],
#       dtype='object')

# %%
# Reorder labels
FTD_df = FTD_df[['original_label', 'text', 'FTD', 'GINCO_downcast', 'MT-GINCO_downcast', 'CORE_main',
       'CORE_sub', 'X-GENRE']]
FTD_df.head(1)
# Out:
#   original_label                                               text  \
# 0            FTD  BMW's and Chinese Justice * * * * * In most pl...
#
#                   FTD  GINCO_downcast MT-GINCO_downcast  CORE_main  \
# 0  A1 (argumentative)  News/Reporting    News/Reporting  Narrative
#
#            CORE_sub    X-GENRE
# 0  News Report/Blog  discarded

# %%
FTD_df.columns
# Out:
# Index(['original_label', 'text', 'FTD', 'GINCO_downcast', 'MT-GINCO_downcast',
#        'CORE_main', 'CORE_sub', 'X-GENRE'],
#       dtype='object')

# %%
# Open the GINCO dataset
GINCO_df = pd.read_csv("data-sheets-with-all-info/GINCO-MT-GINCO-keeptext-with-all-information.csv", sep="\t", index_col = 0)
GINCO_df.head(1)
# Out:
#      id                                                url  crawled   hard  \
# 0  3949  http://www.pomurje.si/aktualno/sport/zimska-li...     2014  False
#
#   primary_level_1 primary_level_2 primary_level_3 secondary_level_1  \
# 0  News/Reporting  News/Reporting  News/Reporting               NaN
#
#   secondary_level_2 secondary_level_3  ... FTD_pred_on_SL FTD_pred_on_MT  \
# 0               NaN               NaN  ...      A8 (news)      A8 (news)
#
#   split-without-rare-categories primary_level_4 downcast_split  \
# 0                          test  News/Reporting           test
#
#   CORE_main_pred_on_SL CORE_main_pred_on_MT CORE_sub_pred_on_SL  \
# 0            Narrative            Narrative       Sports Report
#
#    CORE_sub_pred_on_MT primary_level_1_to_X-GENRE
# 0        Sports Report                       News
#
# [1 rows x 29 columns]

# %%
GINCO_df.columns
# Out:
# Index(['id', 'url', 'crawled', 'hard', 'primary_level_1', 'primary_level_2',
#        'primary_level_3', 'secondary_level_1', 'secondary_level_2',
#        'secondary_level_3', 'tertiary_level_1', 'tertiary_level_2',
#        'tertiary_level_3', 'split', 'domain', 'GINCORE', 'Slovene_text',
#        'MT_text', 'text_length', 'FTD_pred_on_SL', 'FTD_pred_on_MT',
#        'split-without-rare-categories', 'primary_level_4', 'downcast_split',
#        'CORE_main_pred_on_SL', 'CORE_main_pred_on_MT', 'CORE_sub_pred_on_SL',
#        'CORE_sub_pred_on_MT', 'primary_level_1_to_X-GENRE'],
#       dtype='object')

# %%
# Keep only relevant columns
GINCO_df = GINCO_df[['primary_level_4', 'Slovene_text', 'MT_text', 'FTD_pred_on_SL', 'FTD_pred_on_MT',
       'CORE_main_pred_on_SL', 'CORE_main_pred_on_MT', 'CORE_sub_pred_on_SL',
       'CORE_sub_pred_on_MT', 'primary_level_1_to_X-GENRE']]

GINCO_df.head(1)
# Out:
#   primary_level_4                                       Slovene_text  \
# 0  News/Reporting  Šport <p/> Zimska liga malega nogometa sobota,...
#
#                                              MT_text FTD_pred_on_SL  \
# 0  Sport <p/> Winter Little League Football Satur...      A8 (news)
#
#   FTD_pred_on_MT CORE_main_pred_on_SL CORE_main_pred_on_MT  \
# 0      A8 (news)            Narrative            Narrative
#
#   CORE_sub_pred_on_SL CORE_sub_pred_on_MT primary_level_1_to_X-GENRE
# 0       Sports Report       Sports Report                       News

# %%
GINCO_df.columns
# Out:
# Index(['primary_level_4', 'Slovene_text', 'MT_text', 'FTD_pred_on_SL',
#        'FTD_pred_on_MT', 'CORE_main_pred_on_SL', 'CORE_main_pred_on_MT',
#        'CORE_sub_pred_on_SL', 'CORE_sub_pred_on_MT',
#        'primary_level_1_to_X-GENRE'],
#       dtype='object')

# %%
# Separate SI-GINCO and MT-GINCO into two dataframes
SIGINCO_df = GINCO_df[['primary_level_4', 'Slovene_text', 'FTD_pred_on_SL', 'CORE_main_pred_on_SL', 'CORE_sub_pred_on_SL', 'primary_level_1_to_X-GENRE']]

MTGINCO_df = GINCO_df[['primary_level_4', 'MT_text', 'FTD_pred_on_MT', 'CORE_main_pred_on_MT', 'CORE_sub_pred_on_MT',
       'primary_level_1_to_X-GENRE']]

MTGINCO_df.head(1)
# Out:
#   primary_level_4                                            MT_text  \
# 0  News/Reporting  Sport <p/> Winter Little League Football Satur...
#
#   FTD_pred_on_MT CORE_main_pred_on_MT CORE_sub_pred_on_MT  \
# 0      A8 (news)            Narrative       Sports Report
#
#   primary_level_1_to_X-GENRE
# 0                       News

# %%
print(MTGINCO_df.columns)
# Out:
# Index(['primary_level_4', 'MT_text', 'FTD_pred_on_MT', 'CORE_main_pred_on_MT',
#        'CORE_sub_pred_on_MT', 'primary_level_1_to_X-GENRE'],
#       dtype='object')

# %%
# Rename columns
SIGINCO_df.columns = ['GINCO_downcast', 'text', 'FTD', 'CORE_main', 'CORE_sub','X-GENRE']

MTGINCO_df.columns = ['MT-GINCO_downcast', 'text', 'FTD','CORE_main', 'CORE_sub','X-GENRE']

SIGINCO_df.head(1)
# Out:
#    GINCO_downcast                                               text  \
# 0  News/Reporting  Šport <p/> Zimska liga malega nogometa sobota,...
#
#          FTD  CORE_main       CORE_sub X-GENRE
# 0  A8 (news)  Narrative  Sports Report    News

# %%
# Add column about the original label
SIGINCO_df['original_label'] = "SI-GINCO"
MTGINCO_df['original_label'] = "MT-GINCO"
# Out:
# /tmp/ipykernel_3761/1928278936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SIGINCO_df['original_label'] = "SI-GINCO"
# /tmp/ipykernel_3761/1928278936.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MTGINCO_df['original_label'] = "MT-GINCO"

# %%
MTGINCO_df.describe(include="all")
# Out:
#        MT-GINCO_downcast                                               text  \
# count               1002                                               1002
# unique                 9                                               1002
# top       News/Reporting  Sport <p/> Winter Little League Football Satur...
# freq                 221                                                  1
#
#                     FTD                              CORE_main  \
# count              1002                                   1002
# unique               10                                      8
# top     A12 (promotion)  Informational Description/Explanation
# freq                287                                    506
#
#                       CORE_sub X-GENRE original_label
# count                     1002    1002           1002
# unique                      23      10              1
# top     Description of a Thing    News       MT-GINCO
# freq                       317     221           1002

# %%
# Open the CORE df
CORE_df = pd.read_csv("data-sheets-with-all-info/CORE-all-information.csv", sep="\t", index_col = 0)

CORE_df.head(1)
# Out:
#          label                                               text  split  \
# 0  NA OP SR OB  The Top TEN 'Whiniest Sets of Fans' in English...  train
#
#   main_labels sublabels  Len  main_len  sub_len      GINCORE full_names  \
# 0       NA OP     SR OB    4         2        2  NA OP SR OB      SR OB
#
#   main_labels_full_names FTD_pred GINCO_downcast_pred MT-GINCO_downcast_pred  \
# 0                  NA OP      NaN                 NaN                    NaN
#
#   subcategories_to_X-GENRE
# 0                    check

# %%
# GINCO labels were predicted only on a sample - leave in the dataframe only instances with predictions by all classifiers
CORE_df.dropna(subset=["GINCO_downcast_pred"],inplace=True)
CORE_df.describe(include="all")
# Out:
#         label                                               text  split  \
# count    1500                                               1500   1500
# unique     77                                               1500      3
# top     NA NE  Welcome, one and all, to TheCheckingLine.com, ...  train
# freq      379                                                  1   1030
# mean      NaN                                                NaN    NaN
# std       NaN                                                NaN    NaN
# min       NaN                                                NaN    NaN
# 25%       NaN                                                NaN    NaN
# 50%       NaN                                                NaN    NaN
# 75%       NaN                                                NaN    NaN
# max       NaN                                                NaN    NaN
#
#        main_labels sublabels          Len     main_len  sub_len GINCORE  \
# count          874      1500  1500.000000  1500.000000   1500.0    1500
# unique          19        43          NaN          NaN      NaN      49
# top             OP        NE          NaN          NaN      NaN    News
# freq           270       395          NaN          NaN      NaN     484
# mean           NaN       NaN     2.052000     1.052000      1.0     NaN
# std            NaN       NaN     0.222101     0.222101      0.0     NaN
# min            NaN       NaN     2.000000     1.000000      1.0     NaN
# 25%            NaN       NaN     2.000000     1.000000      1.0     NaN
# 50%            NaN       NaN     2.000000     1.000000      1.0     NaN
# 75%            NaN       NaN     2.000000     1.000000      1.0     NaN
# max            NaN       NaN     3.000000     2.000000      1.0     NaN
#
#               full_names main_labels_full_names            FTD_pred  \
# count               1500                   1500                1500
# unique                43                     20                  10
# top     News Report/Blog              Narrative  A1 (argumentative)
# freq                 395                    626                 419
# mean                 NaN                    NaN                 NaN
# std                  NaN                    NaN                 NaN
# min                  NaN                    NaN                 NaN
# 25%                  NaN                    NaN                 NaN
# 50%                  NaN                    NaN                 NaN
# 75%                  NaN                    NaN                 NaN
# max                  NaN                    NaN                 NaN
#
#        GINCO_downcast_pred MT-GINCO_downcast_pred subcategories_to_X-GENRE
# count                 1500                   1500                     1500
# unique                   9                      9                       10
# top         News/Reporting         News/Reporting                     News
# freq                   481                    481                      501
# mean                   NaN                    NaN                      NaN
# std                    NaN                    NaN                      NaN
# min                    NaN                    NaN                      NaN
# 25%                    NaN                    NaN                      NaN
# 50%                    NaN                    NaN                      NaN
# 75%                    NaN                    NaN                      NaN
# max                    NaN                    NaN                      NaN

# %%
CORE_df.columns
# Out:
# Index(['label', 'text', 'split', 'main_labels', 'sublabels', 'Len', 'main_len',
#        'sub_len', 'GINCORE', 'full_names', 'main_labels_full_names',
#        'FTD_pred', 'GINCO_downcast_pred', 'MT-GINCO_downcast_pred',
#        'subcategories_to_X-GENRE'],
#       dtype='object')

# %%
# Leave only relevant columns
CORE_df = CORE_df[['text','full_names', 'main_labels_full_names','FTD_pred', 'GINCO_downcast_pred', 'MT-GINCO_downcast_pred', 'subcategories_to_X-GENRE']]
CORE_df.head(1)
# Out:
#                                                  text     full_names  \
# 14  Welcome, one and all, to TheCheckingLine.com, ...  Sports Report
#
#    main_labels_full_names            FTD_pred    GINCO_downcast_pred  \
# 14              Narrative  A1 (argumentative)  Opinion/Argumentation
#
#    MT-GINCO_downcast_pred subcategories_to_X-GENRE
# 14  Opinion/Argumentation                     News

# %%
# Rename the columns
CORE_df.columns = ['text','CORE_sub', 'CORE_main','FTD', 'GINCO_downcast', 'MT-GINCO_downcast', 'X-GENRE']

CORE_df.head(1)
# Out:
#                                                  text       CORE_sub  \
# 14  Welcome, one and all, to TheCheckingLine.com, ...  Sports Report
#
#     CORE_main                 FTD         GINCO_downcast  \
# 14  Narrative  A1 (argumentative)  Opinion/Argumentation
#
#         MT-GINCO_downcast X-GENRE
# 14  Opinion/Argumentation    News

# %%
# Add the column about the original schema
CORE_df['original_label'] = "CORE"
CORE_df.head(1)
# Out:
#                                                  text       CORE_sub  \
# 14  Welcome, one and all, to TheCheckingLine.com, ...  Sports Report
#
#     CORE_main                 FTD         GINCO_downcast  \
# 14  Narrative  A1 (argumentative)  Opinion/Argumentation
#
#         MT-GINCO_downcast X-GENRE original_label
# 14  Opinion/Argumentation    News           CORE

# %%
SIGINCO_df.shape, FTD_df.shape, MTGINCO_df.shape, CORE_df.shape
# Out:
# ((1002, 8), (1414, 8), (1002, 8), (1500, 8))

# %%
# Merge the datasets
merge_temp = pd.concat([FTD_df, SIGINCO_df])
merge_temp = pd.concat([merge_temp, MTGINCO_df])
merged_df = pd.concat([merge_temp, CORE_df])

merged_df.describe(include="all")
# Out:
#        original_label                                               text  \
# count            4918                                               4918
# unique              4                                               4918
# top              CORE  BMW's and Chinese Justice * * * * * In most pl...
# freq             1500                                                  1
#
#                     FTD  GINCO_downcast MT-GINCO_downcast  \
# count              4918            3916              3916
# unique               10               9                 9
# top     A12 (promotion)  News/Reporting    News/Reporting
# freq               1011             933               951
#
#                                     CORE_main                CORE_sub X-GENRE
# count                                    4918                    4918    4918
# unique                                     20                      43      10
# top     Informational Description/Explanation  Description of a Thing    News
# freq                                     2094                    1167    1079

# %%
# Reset the index
merged_df = merged_df.reset_index()
merged_df.tail()
# Out:
#       index original_label                                               text  \
# 4913  48378           CORE  Bringing You Great Ideas From The Business Wor...
# 4914  48403           CORE  In the hills outside Islamabad in Pakistan, 16...
# 4915  48405           CORE  Who Cares About the Big Bang? Senator Marco Ru...
# 4916  48419           CORE  McCabe: There was no 'toff strategy' The MP be...
# 4917  48423           CORE  Copeland looking to make statement Miserly for...
#
#                      FTD           GINCO_downcast        MT-GINCO_downcast  \
# 4913  A1 (argumentative)  Information/Explanation  Information/Explanation
# 4914  A1 (argumentative)           News/Reporting           News/Reporting
# 4915  A1 (argumentative)           News/Reporting           News/Reporting
# 4916           A8 (news)           News/Reporting           News/Reporting
# 4917           A8 (news)           News/Reporting           News/Reporting
#
#       CORE_main          CORE_sub                X-GENRE
# 4913    Opinion      Opinion Blog  Opinion/Argumentation
# 4914  Narrative  News Report/Blog                   News
# 4915    Opinion      Opinion Blog  Opinion/Argumentation
# 4916  Narrative  News Report/Blog                   News
# 4917  Narrative  News Report/Blog                   News

# %%
# Save the merged dataset
merged_df.to_csv("data-sheets-with-all-info/Merged-datasets-with-all-predictions.csv", sep="\t")

# %% [markdown]
# ## Comparison of predictions

# %% [markdown]
# To analyse how the predictions are connected, I will take each of the datasets and analyse for each of their original labels whether they are consistently predicted with a label from another schema. Then I will compare them in the other direction - by grouping the predictions of this classifier on all other datasets and seeing whether they are connected well with other labels.

# %%
# Open the dataset
merged_df = pd.read_csv("data-sheets-with-all-info/Merged-datasets-with-all-predictions.csv", sep="\t", index_col=0)

# %%
merged_df.columns
# Out:
# Index(['index', 'original_label', 'text', 'FTD', 'GINCO_downcast',
#        'MT-GINCO_downcast', 'CORE_main', 'CORE_sub', 'X-GENRE'],
#       dtype='object')

# %%
merged_df.head(1)
# Out:
#    index original_label                                               text  \
# 0      0            FTD  BMW's and Chinese Justice * * * * * In most pl...
#
#                   FTD  GINCO_downcast MT-GINCO_downcast  CORE_main  \
# 0  A1 (argumentative)  News/Reporting    News/Reporting  Narrative
#
#            CORE_sub    X-GENRE
# 0  News Report/Blog  discarded

# %%
# Count for each pair of schemata in how many times they occur together
combinations = [['FTD', 'GINCO_downcast'], ['FTD', 'MT-GINCO_downcast'], ['FTD', 'CORE_main'], ['FTD', 'CORE_sub'], ['GINCO_downcast', 'MT-GINCO_downcast'], ['GINCO_downcast', 'CORE_main'],['GINCO_downcast', 'CORE_sub'] , ['MT-GINCO_downcast', 'CORE_main'], ['MT-GINCO_downcast', 'CORE_sub'], ['CORE_main', 'CORE_sub'] ]

for i in combinations:
	merged_df[f"{i[0]} + {i[1]} count"] = merged_df.groupby([f"{i[0]}", f"{i[1]}"])[f"{i[0]}"].transform('size')
	merged_df[f"{i[0]} + {i[1]}"] = merged_df[f"{i[0]}"].str.cat(merged_df[f"{i[1]}"], sep = "+")

merged_df.head(1)
# Out:
#    index original_label                                               text  \
# 0      0            FTD  BMW's and Chinese Justice * * * * * In most pl...
#
#                   FTD  GINCO_downcast MT-GINCO_downcast  CORE_main  \
# 0  A1 (argumentative)  News/Reporting    News/Reporting  Narrative
#
#            CORE_sub    X-GENRE  FTD + GINCO_downcast count  ...  \
# 0  News Report/Blog  discarded                       225.0  ...
#
#                 FTD + GINCO_downcast            FTD + MT-GINCO_downcast  \
# 0  A1 (argumentative)+News/Reporting  A1 (argumentative)+News/Reporting
#
#                 FTD + CORE_main                       FTD + CORE_sub  \
# 0  A1 (argumentative)+Narrative  A1 (argumentative)+News Report/Blog
#
#    GINCO_downcast + MT-GINCO_downcast  GINCO_downcast + CORE_main  \
# 0       News/Reporting+News/Reporting    News/Reporting+Narrative
#
#          GINCO_downcast + CORE_sub  MT-GINCO_downcast + CORE_main  \
# 0  News/Reporting+News Report/Blog       News/Reporting+Narrative
#
#       MT-GINCO_downcast + CORE_sub        CORE_main + CORE_sub
# 0  News/Reporting+News Report/Blog  Narrative+News Report/Blog
#
# [1 rows x 29 columns]

# %%
merged_df.columns
# Out:
# Index(['index', 'original_label', 'text', 'FTD', 'GINCO_downcast',
#        'MT-GINCO_downcast', 'CORE_main', 'CORE_sub', 'X-GENRE',
#        'FTD + GINCO_downcast count', 'FTD + MT-GINCO_downcast count',
#        'FTD + CORE_main count', 'FTD + CORE_sub count',
#        'GINCO_downcast + MT-GINCO_downcast count',
#        'GINCO_downcast + CORE_main count', 'GINCO_downcast + CORE_sub count',
#        'MT-GINCO_downcast + CORE_main count',
#        'MT-GINCO_downcast + CORE_sub count', 'CORE_main + CORE_sub count',
#        'FTD + GINCO_downcast', 'FTD + MT-GINCO_downcast', 'FTD + CORE_main',
#        'FTD + CORE_sub', 'GINCO_downcast + MT-GINCO_downcast',
#        'GINCO_downcast + CORE_main', 'GINCO_downcast + CORE_sub',
#        'MT-GINCO_downcast + CORE_main', 'MT-GINCO_downcast + CORE_sub',
#        'CORE_main + CORE_sub'],
#       dtype='object')

# %%
# Let's concatenate all labels together

merged_df["merged_labels-CORE_sub"] = merged_df['FTD + GINCO_downcast'].str.cat(merged_df["CORE_sub"], sep = "+")
merged_df["merged_labels-CORE_main"] = merged_df['FTD + GINCO_downcast'].str.cat(merged_df["CORE_main"], sep = "+")

merged_df.head(1)
# Out:
#    index original_label                                               text  \
# 0      0            FTD  BMW's and Chinese Justice * * * * * In most pl...
#
#                   FTD  GINCO_downcast MT-GINCO_downcast  CORE_main  \
# 0  A1 (argumentative)  News/Reporting    News/Reporting  Narrative
#
#            CORE_sub    X-GENRE  FTD + GINCO_downcast count  \
# 0  News Report/Blog  discarded                       225.0
#
#    FTD + MT-GINCO_downcast count  FTD + CORE_main count  FTD + CORE_sub count  \
# 0                          232.0                    284                   253
#
#    GINCO_downcast + MT-GINCO_downcast count  GINCO_downcast + CORE_main count  \
# 0                                     656.0                             640.0
#
#    GINCO_downcast + CORE_sub count  MT-GINCO_downcast + CORE_main count  \
# 0                            552.0                                682.0
#
#    MT-GINCO_downcast + CORE_sub count  CORE_main + CORE_sub count  \
# 0                               576.0                         732
#
#                 FTD + GINCO_downcast            FTD + MT-GINCO_downcast  \
# 0  A1 (argumentative)+News/Reporting  A1 (argumentative)+News/Reporting
#
#                 FTD + CORE_main                       FTD + CORE_sub  \
# 0  A1 (argumentative)+Narrative  A1 (argumentative)+News Report/Blog
#
#   GINCO_downcast + MT-GINCO_downcast GINCO_downcast + CORE_main  \
# 0      News/Reporting+News/Reporting   News/Reporting+Narrative
#
#          GINCO_downcast + CORE_sub MT-GINCO_downcast + CORE_main  \
# 0  News/Reporting+News Report/Blog      News/Reporting+Narrative
#
#       MT-GINCO_downcast + CORE_sub        CORE_main + CORE_sub  \
# 0  News/Reporting+News Report/Blog  Narrative+News Report/Blog
#
#                               merged_labels-CORE_sub  \
# 0  A1 (argumentative)+News/Reporting+News Report/...
#
#                        merged_labels-CORE_main
# 0  A1 (argumentative)+News/Reporting+Narrative

# %%
# Analyze distribution of merged labels
merged_df["merged_labels-CORE_sub"].value_counts(normalize="True")[:10]
# Out:
# A8 (news)+News/Reporting+News Report/Blog                           0.085802
# A12 (promotion)+Promotion+Description of a Thing                    0.054137
# A1 (argumentative)+News/Reporting+News Report/Blog                  0.038560
# A12 (promotion)+Promotion+Description with Intent to Sell           0.034985
# A16 (information)+Information/Explanation+Description of a Thing    0.034985
# A1 (argumentative)+Opinion/Argumentation+Opinion Blog               0.031154
# A8 (news)+News/Reporting+Sports Report                              0.029367
# A11 (personal)+Opinion/Argumentation+Personal Blog                  0.027068
# A7 (instruction)+Instruction+How-to                                 0.026813
# A12 (promotion)+Information/Explanation+Description of a Thing      0.016599
# Name: merged_labels-CORE_sub, dtype: float64

# %%
# Analyze distribution of merged labels
merged_df["merged_labels-CORE_main"].value_counts(normalize="True")[:10]
# Out:
# A8 (news)+News/Reporting+Narrative                                                  0.110827
# A16 (information)+Information/Explanation+Informational Description/Explanation     0.068182
# A12 (promotion)+Promotion+Informational Description/Explanation                     0.064096
# A1 (argumentative)+News/Reporting+Narrative                                         0.036772
# A1 (argumentative)+Opinion/Argumentation+Opinion                                    0.034219
# A7 (instruction)+Instruction+How-To/Instructional                                   0.031154
# A12 (promotion)+Promotion+Informational Persuasion                                  0.028856
# A11 (personal)+Opinion/Argumentation+Narrative                                      0.028090
# A1 (argumentative)+Information/Explanation+Informational Description/Explanation    0.022472
# A14 (academic)+Information/Explanation+Informational Description/Explanation        0.021961
# Name: merged_labels-CORE_main, dtype: float64

# %%
# Show all columns
pd.set_option('display.max_columns', None)

# %%
merged_df.describe(include="all")
# Out:
#                index original_label  \
# count    4918.000000           4918
# unique           NaN              4
# top              NaN           CORE
# freq             NaN           1500
# mean     7958.074014            NaN
# std     13529.153307            NaN
# min         0.000000            NaN
# 25%       417.000000            NaN
# 50%       857.500000            NaN
# 75%      8602.250000            NaN
# max     48423.000000            NaN
#
#                                                      text              FTD  \
# count                                                4918             4918
# unique                                               4918               10
# top     BMW's and Chinese Justice * * * * * In most pl...  A12 (promotion)
# freq                                                    1             1011
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#         GINCO_downcast MT-GINCO_downcast  \
# count             3916              3916
# unique               9                 9
# top     News/Reporting    News/Reporting
# freq               933               951
# mean               NaN               NaN
# std                NaN               NaN
# min                NaN               NaN
# 25%                NaN               NaN
# 50%                NaN               NaN
# 75%                NaN               NaN
# max                NaN               NaN
#
#                                     CORE_main                CORE_sub X-GENRE  \
# count                                    4918                    4918    4918
# unique                                     20                      43      10
# top     Informational Description/Explanation  Description of a Thing    News
# freq                                     2094                    1167    1079
# mean                                      NaN                     NaN     NaN
# std                                       NaN                     NaN     NaN
# min                                       NaN                     NaN     NaN
# 25%                                       NaN                     NaN     NaN
# 50%                                       NaN                     NaN     NaN
# 75%                                       NaN                     NaN     NaN
# max                                       NaN                     NaN     NaN
#
#         FTD + GINCO_downcast count  FTD + MT-GINCO_downcast count  \
# count                  3916.000000                    3916.000000
# unique                         NaN                            NaN
# top                            NaN                            NaN
# freq                           NaN                            NaN
# mean                    211.196629                     233.837079
# std                     166.740710                     188.106191
# min                       1.000000                       1.000000
# 25%                      58.000000                      56.000000
# 50%                     192.000000                     227.000000
# 75%                     304.000000                     425.000000
# max                     506.000000                     564.000000
#
#         FTD + CORE_main count  FTD + CORE_sub count  \
# count             4918.000000           4918.000000
# unique                    NaN                   NaN
# top                       NaN                   NaN
# freq                      NaN                   NaN
# mean               304.245222            191.596584
# std                234.419321            184.788976
# min                  1.000000              1.000000
# 25%                106.000000             37.000000
# 50%                224.000000            129.000000
# 75%                629.000000            253.000000
# max                665.000000            541.000000
#
#         GINCO_downcast + MT-GINCO_downcast count  \
# count                                2914.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                  344.944406
# std                                   234.070114
# min                                     1.000000
# 25%                                    95.000000
# 50%                                   433.000000
# 75%                                   479.000000
# max                                   656.000000
#
#         GINCO_downcast + CORE_main count  GINCO_downcast + CORE_sub count  \
# count                        3916.000000                      3916.000000
# unique                               NaN                              NaN
# top                                  NaN                              NaN
# freq                                 NaN                              NaN
# mean                          291.841675                       162.086823
# std                           241.348740                       179.200385
# min                             1.000000                         1.000000
# 25%                            75.000000                        28.000000
# 50%                           224.000000                        98.000000
# 75%                           608.000000                       255.000000
# max                           640.000000                       552.000000
#
#         MT-GINCO_downcast + CORE_main count  \
# count                           3916.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                             295.577120
# std                              236.636062
# min                                1.000000
# 25%                               99.000000
# 50%                              256.000000
# 75%                              523.000000
# max                              682.000000
#
#         MT-GINCO_downcast + CORE_sub count  CORE_main + CORE_sub count  \
# count                          3916.000000                 4918.000000
# unique                                 NaN                         NaN
# top                                    NaN                         NaN
# freq                                   NaN                         NaN
# mean                            168.764556                  412.094347
# std                             187.581760                  409.323229
# min                               1.000000                    1.000000
# 25%                              29.000000                  101.000000
# 50%                              99.000000                  170.000000
# 75%                             241.000000                  732.000000
# max                             576.000000                 1066.000000
#
#             FTD + GINCO_downcast   FTD + MT-GINCO_downcast  \
# count                       3916                      3916
# unique                        73                        76
# top     A8 (news)+News/Reporting  A8 (news)+News/Reporting
# freq                         506                       564
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
#                                           FTD + CORE_main  \
# count                                                4918
# unique                                                 94
# top     A12 (promotion)+Informational Description/Expl...
# freq                                                  665
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 FTD + CORE_sub  \
# count                                     4918
# unique                                     197
# top     A12 (promotion)+Description of a Thing
# freq                                       541
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        GINCO_downcast + MT-GINCO_downcast GINCO_downcast + CORE_main  \
# count                                2914                       3916
# unique                                 57                         89
# top         News/Reporting+News/Reporting   News/Reporting+Narrative
# freq                                  656                        640
# mean                                  NaN                        NaN
# std                                   NaN                        NaN
# min                                   NaN                        NaN
# 25%                                   NaN                        NaN
# 50%                                   NaN                        NaN
# 75%                                   NaN                        NaN
# max                                   NaN                        NaN
#
#               GINCO_downcast + CORE_sub MT-GINCO_downcast + CORE_main  \
# count                              3916                          3916
# unique                              197                            87
# top     News/Reporting+News Report/Blog      News/Reporting+Narrative
# freq                                552                           682
# mean                                NaN                           NaN
# std                                 NaN                           NaN
# min                                 NaN                           NaN
# 25%                                 NaN                           NaN
# 50%                                 NaN                           NaN
# 75%                                 NaN                           NaN
# max                                 NaN                           NaN
#
#            MT-GINCO_downcast + CORE_sub  \
# count                              3916
# unique                              196
# top     News/Reporting+News Report/Blog
# freq                                576
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#                                      CORE_main + CORE_sub
# count                                                4918
# unique                                                157
# top     Informational Description/Explanation+Descript...
# freq                                                 1066
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
#Let's analyze which pairs occur together most often

# %%
# For each of the pairs, analyse how often they occur together
for i in combinations:
	print(f"Value counts for: {i[0]} + {i[1]}")
	print(merged_df[f"{i[0]} + {i[1]}"].value_counts(normalize=True).sort_values()to_markdown())
# Out:
# Value counts for: FTD + GINCO_downcast
# |                                               |   FTD + GINCO_downcast |
# |:----------------------------------------------|-----------------------:|
# | A8 (news)+News/Reporting                      |            0.129213    |
# | A12 (promotion)+Promotion                     |            0.104188    |
# | A16 (information)+Information/Explanation     |            0.0776302   |
# | A1 (argumentative)+Opinion/Argumentation      |            0.072523    |
# | A1 (argumentative)+News/Reporting             |            0.0574566   |
# | A7 (instruction)+Instruction                  |            0.0528601   |
# | A11 (personal)+Opinion/Argumentation          |            0.0490296   |
# | A1 (argumentative)+Information/Explanation    |            0.0337079   |
# | A17 (review)+Opinion/Argumentation            |            0.0247702   |
# | A12 (promotion)+Information/Explanation       |            0.023238    |
# | A14 (academic)+Information/Explanation        |            0.0224719   |
# | A17 (review)+News/Reporting                   |            0.0181307   |
# | A9 (legal)+Legal/Regulation                   |            0.01762     |
# | A12 (promotion)+News/Reporting                |            0.0168539   |
# | A4 (fiction)+Other                            |            0.0165986   |
# | A17 (review)+Promotion                        |            0.0163432   |
# | A1 (argumentative)+Forum                      |            0.014811    |
# | A12 (promotion)+List of Summaries/Excerpts    |            0.014811    |
# | A1 (argumentative)+List of Summaries/Excerpts |            0.0145557   |
# | A1 (argumentative)+Other                      |            0.0137896   |
# | A8 (news)+List of Summaries/Excerpts          |            0.0137896   |
# | A17 (review)+List of Summaries/Excerpts       |            0.0135342   |
# | A12 (promotion)+Other                         |            0.011236    |
# | A11 (personal)+Forum                          |            0.0104699   |
# | A4 (fiction)+Opinion/Argumentation            |            0.00944842  |
# | A16 (information)+News/Reporting              |            0.00944842  |
# | A7 (instruction)+Information/Explanation      |            0.00944842  |
# | A12 (promotion)+Opinion/Argumentation         |            0.00740552  |
# | A7 (instruction)+Promotion                    |            0.00663943  |
# | A7 (instruction)+List of Summaries/Excerpts   |            0.00663943  |
# | A7 (instruction)+Other                        |            0.00663943  |
# | A16 (information)+List of Summaries/Excerpts  |            0.00663943  |
# | A11 (personal)+Other                          |            0.00638407  |
# | A9 (legal)+Information/Explanation            |            0.0061287   |
# | A16 (information)+Opinion/Argumentation       |            0.00587334  |
# | A17 (review)+Information/Explanation          |            0.00510725  |
# | A4 (fiction)+Information/Explanation          |            0.00510725  |
# | A17 (review)+Forum                            |            0.00459653  |
# | A7 (instruction)+Opinion/Argumentation        |            0.00434116  |
# | A7 (instruction)+Forum                        |            0.00434116  |
# | A12 (promotion)+Instruction                   |            0.00434116  |
# | A1 (argumentative)+Promotion                  |            0.00434116  |
# | A17 (review)+Other                            |            0.0040858   |
# | A8 (news)+Information/Explanation             |            0.0040858   |
# | A11 (personal)+List of Summaries/Excerpts     |            0.00383044  |
# | A16 (information)+Promotion                   |            0.00383044  |
# | A8 (news)+Opinion/Argumentation               |            0.00357508  |
# | A12 (promotion)+Forum                         |            0.00280899  |
# | A9 (legal)+Other                              |            0.00280899  |
# | A16 (information)+Other                       |            0.00255363  |
# | A7 (instruction)+News/Reporting               |            0.00255363  |
# | A14 (academic)+Opinion/Argumentation          |            0.00178754  |
# | A8 (news)+Other                               |            0.00178754  |
# | A14 (academic)+News/Reporting                 |            0.00153218  |
# | A11 (personal)+News/Reporting                 |            0.00153218  |
# | A11 (personal)+Information/Explanation        |            0.00153218  |
# | A16 (information)+Forum                       |            0.00102145  |
# | A9 (legal)+News/Reporting                     |            0.00102145  |
# | A11 (personal)+Instruction                    |            0.000766088 |
# | A14 (academic)+Other                          |            0.000766088 |
# | A4 (fiction)+List of Summaries/Excerpts       |            0.000766088 |
# | A1 (argumentative)+Legal/Regulation           |            0.000766088 |
# | A8 (news)+Promotion                           |            0.000766088 |
# | A14 (academic)+List of Summaries/Excerpts     |            0.000510725 |
# | A4 (fiction)+News/Reporting                   |            0.000510725 |
# | A8 (news)+Legal/Regulation                    |            0.000510725 |
# | A16 (information)+Instruction                 |            0.000255363 |
# | A9 (legal)+Instruction                        |            0.000255363 |
# | A16 (information)+Legal/Regulation            |            0.000255363 |
# | A14 (academic)+Legal/Regulation               |            0.000255363 |
# | A1 (argumentative)+Instruction                |            0.000255363 |
# | A14 (academic)+Forum                          |            0.000255363 |
# | A9 (legal)+List of Summaries/Excerpts         |            0.000255363 |
# Value counts for: FTD + MT-GINCO_downcast
# |                                               |   FTD + MT-GINCO_downcast |
# |:----------------------------------------------|--------------------------:|
# | A8 (news)+News/Reporting                      |               0.144025    |
# | A12 (promotion)+Promotion                     |               0.108529    |
# | A1 (argumentative)+Opinion/Argumentation      |               0.0860572   |
# | A16 (information)+Information/Explanation     |               0.0704801   |
# | A1 (argumentative)+News/Reporting             |               0.0592441   |
# | A7 (instruction)+Instruction                  |               0.0579673   |
# | A11 (personal)+Opinion/Argumentation          |               0.0485189   |
# | A17 (review)+Opinion/Argumentation            |               0.031665    |
# | A4 (fiction)+Other                            |               0.0234934   |
# | A14 (academic)+Information/Explanation        |               0.0217058   |
# | A1 (argumentative)+Information/Explanation    |               0.0206844   |
# | A1 (argumentative)+Forum                      |               0.0183861   |
# | A12 (promotion)+Information/Explanation       |               0.0173647   |
# | A8 (news)+List of Summaries/Excerpts          |               0.0145557   |
# | A17 (review)+Promotion                        |               0.0145557   |
# | A11 (personal)+Forum                          |               0.0143003   |
# | A9 (legal)+Legal/Regulation                   |               0.0140449   |
# | A1 (argumentative)+Other                      |               0.0137896   |
# | A17 (review)+News/Reporting                   |               0.0125128   |
# | A11 (personal)+Other                          |               0.012002    |
# | A12 (promotion)+News/Reporting                |               0.0104699   |
# | A16 (information)+News/Reporting              |               0.00995914  |
# | A7 (instruction)+Promotion                    |               0.00995914  |
# | A12 (promotion)+List of Summaries/Excerpts    |               0.00944842  |
# | A1 (argumentative)+Promotion                  |               0.00868233  |
# | A12 (promotion)+Other                         |               0.00868233  |
# | A1 (argumentative)+List of Summaries/Excerpts |               0.0081716   |
# | A12 (promotion)+Opinion/Argumentation         |               0.00791624  |
# | A9 (legal)+Information/Explanation            |               0.00715015  |
# | A7 (instruction)+Other                        |               0.00689479  |
# | A7 (instruction)+Opinion/Argumentation        |               0.0061287   |
# | A17 (review)+List of Summaries/Excerpts       |               0.00587334  |
# | A7 (instruction)+Information/Explanation      |               0.00587334  |
# | A7 (instruction)+Forum                        |               0.00561798  |
# | A4 (fiction)+Opinion/Argumentation            |               0.00561798  |
# | A16 (information)+Promotion                   |               0.00536261  |
# | A12 (promotion)+Instruction                   |               0.00434116  |
# | A17 (review)+Forum                            |               0.00434116  |
# | A16 (information)+Opinion/Argumentation       |               0.00434116  |
# | A8 (news)+Promotion                           |               0.0040858   |
# | A8 (news)+Opinion/Argumentation               |               0.00383044  |
# | A16 (information)+List of Summaries/Excerpts  |               0.00357508  |
# | A17 (review)+Other                            |               0.00357508  |
# | A8 (news)+Other                               |               0.00331971  |
# | A9 (legal)+Instruction                        |               0.00331971  |
# | A9 (legal)+Other                              |               0.00306435  |
# | A17 (review)+Information/Explanation          |               0.00306435  |
# | A12 (promotion)+Forum                         |               0.00280899  |
# | A8 (news)+Information/Explanation             |               0.00255363  |
# | A7 (instruction)+List of Summaries/Excerpts   |               0.00229826  |
# | A4 (fiction)+Information/Explanation          |               0.00229826  |
# | A16 (information)+Other                       |               0.0020429   |
# | A11 (personal)+List of Summaries/Excerpts     |               0.00178754  |
# | A11 (personal)+News/Reporting                 |               0.00178754  |
# | A14 (academic)+Other                          |               0.00178754  |
# | A7 (instruction)+News/Reporting               |               0.00178754  |
# | A1 (argumentative)+Legal/Regulation           |               0.00153218  |
# | A14 (academic)+News/Reporting                 |               0.00153218  |
# | A9 (legal)+News/Reporting                     |               0.00127681  |
# | A14 (academic)+Opinion/Argumentation          |               0.00127681  |
# | A11 (personal)+Instruction                    |               0.00102145  |
# | A11 (personal)+Information/Explanation        |               0.00102145  |
# | A16 (information)+Instruction                 |               0.000766088 |
# | A16 (information)+Forum                       |               0.000766088 |
# | A16 (information)+Legal/Regulation            |               0.000766088 |
# | A1 (argumentative)+Instruction                |               0.000766088 |
# | A8 (news)+Legal/Regulation                    |               0.000766088 |
# | A9 (legal)+Promotion                          |               0.000510725 |
# | A14 (academic)+List of Summaries/Excerpts     |               0.000510725 |
# | A4 (fiction)+News/Reporting                   |               0.000255363 |
# | A14 (academic)+Instruction                    |               0.000255363 |
# | A17 (review)+Instruction                      |               0.000255363 |
# | A14 (academic)+Legal/Regulation               |               0.000255363 |
# | A4 (fiction)+List of Summaries/Excerpts       |               0.000255363 |
# | A9 (legal)+List of Summaries/Excerpts         |               0.000255363 |
# | A8 (news)+Forum                               |               0.000255363 |
# Value counts for: FTD + CORE_main
# |                                                          |   FTD + CORE_main |
# |:---------------------------------------------------------|------------------:|
# | A12 (promotion)+Informational Description/Explanation    |       0.135218    |
# | A8 (news)+Narrative                                      |       0.127898    |
# | A16 (information)+Informational Description/Explanation  |       0.0910939   |
# | A1 (argumentative)+Informational Description/Explanation |       0.0593737   |
# | A1 (argumentative)+Narrative                             |       0.0577471   |
# | A1 (argumentative)+Opinion                               |       0.045547    |
# | A12 (promotion)+Informational Persuasion                 |       0.0422936   |
# | A7 (instruction)+How-To/Instructional                    |       0.0331436   |
# | A8 (news)+Informational Description/Explanation          |       0.0325336   |
# | A11 (personal)+Narrative                                 |       0.0309069   |
# | A7 (instruction)+Informational Description/Explanation   |       0.0307035   |
# | A9 (legal)+Informational Description/Explanation         |       0.0278569   |
# | A17 (review)+Opinion                                     |       0.0225702   |
# | A14 (academic)+Informational Description/Explanation     |       0.0215535   |
# | A17 (review)+Informational Description/Explanation       |       0.0199268   |
# | A4 (fiction)+Narrative                                   |       0.0195201   |
# | A17 (review)+Narrative                                   |       0.0172834   |
# | A1 (argumentative)+Interactive Discussion                |       0.0150468   |
# | A11 (personal)+Interactive Discussion                    |       0.0138268   |
# | A1 (argumentative)+Spoken                                |       0.0117934   |
# | A17 (review)+Spoken                                      |       0.0111834   |
# | A7 (instruction)+Interactive Discussion                  |       0.0099634   |
# | A11 (personal)+Opinion                                   |       0.00833672  |
# | A7 (instruction)+Opinion                                 |       0.00793005  |
# | A16 (information)+Narrative                              |       0.00772672  |
# | A12 (promotion)+Opinion                                  |       0.00752338  |
# | A11 (personal)+Spoken                                    |       0.00711671  |
# | A12 (promotion)+Narrative                                |       0.00610004  |
# | A11 (personal)+Informational Description/Explanation     |       0.0052867   |
# | A17 (review)+Informational Persuasion                    |       0.0052867   |
# | A12 (promotion)+Interactive Discussion                   |       0.00508337  |
# | A12 (promotion)+Spoken                                   |       0.00427003  |
# | A11 (personal)+Lyrical                                   |       0.00366002  |
# | A8 (news)+Spoken                                         |       0.00284669  |
# | A16 (information)+Interactive Discussion                 |       0.00264335  |
# | A12 (promotion)+How-To/Instructional                     |       0.00264335  |
# | A17 (review)+Interactive Discussion                      |       0.00264335  |
# | A16 (information)+Spoken                                 |       0.00244002  |
# | A1 (argumentative)+Informational Persuasion              |       0.00223668  |
# | A4 (fiction)+Lyrical                                     |       0.00223668  |
# | A4 (fiction)+Opinion                                     |       0.00223668  |
# | A4 (fiction)+Informational Description/Explanation       |       0.00223668  |
# | A1 (argumentative)+NA IN                                 |       0.00203335  |
# | A8 (news)+Opinion                                        |       0.00203335  |
# | A7 (instruction)+Narrative                               |       0.00162668  |
# | A7 (instruction)+Informational Persuasion                |       0.00162668  |
# | A7 (instruction)+Spoken                                  |       0.00162668  |
# | A8 (news)+NA IN                                          |       0.00122001  |
# | A16 (information)+Lyrical                                |       0.00122001  |
# | A1 (argumentative)+NA OP                                 |       0.00101667  |
# | A14 (academic)+Narrative                                 |       0.00101667  |
# | A16 (information)+Informational Persuasion               |       0.00101667  |
# | A7 (instruction)+IN HI                                   |       0.00101667  |
# | A16 (information)+NA IN                                  |       0.00101667  |
# | A11 (personal)+NA IN                                     |       0.00101667  |
# | A1 (argumentative)+IN OP                                 |       0.000813339 |
# | A12 (promotion)+NA IN                                    |       0.000813339 |
# | A17 (review)+Lyrical                                     |       0.000813339 |
# | A1 (argumentative)+How-To/Instructional                  |       0.000813339 |
# | A11 (personal)+How-To/Instructional                      |       0.000813339 |
# | A9 (legal)+Narrative                                     |       0.000813339 |
# | A17 (review)+NA IN                                       |       0.000610004 |
# | A14 (academic)+Opinion                                   |       0.000610004 |
# | A4 (fiction)+Interactive Discussion                      |       0.000610004 |
# | A12 (promotion)+Lyrical                                  |       0.000406669 |
# | A11 (personal)+NA OP                                     |       0.000406669 |
# | A4 (fiction)+IN OP                                       |       0.000406669 |
# | A7 (instruction)+Lyrical                                 |       0.000406669 |
# | A17 (review)+NA OP                                       |       0.000406669 |
# | A8 (news)+NA OP                                          |       0.000406669 |
# | A7 (instruction)+IN OP                                   |       0.000406669 |
# | A12 (promotion)+IN OP                                    |       0.000406669 |
# | A12 (promotion)+IN IP                                    |       0.000406669 |
# | A16 (information)+Opinion                                |       0.000406669 |
# | A14 (academic)+Interactive Discussion                    |       0.000406669 |
# | A8 (news)+IN SP                                          |       0.000203335 |
# | A11 (personal)+OP ID                                     |       0.000203335 |
# | A8 (news)+Informational Persuasion                       |       0.000203335 |
# | A12 (promotion)+NA OP                                    |       0.000203335 |
# | A7 (instruction)+NA OP                                   |       0.000203335 |
# | A17 (review)+NA SP                                       |       0.000203335 |
# | A1 (argumentative)+NA IP                                 |       0.000203335 |
# | A17 (review)+OP ID                                       |       0.000203335 |
# | A9 (legal)+IN HI                                         |       0.000203335 |
# | A8 (news)+IN OP                                          |       0.000203335 |
# | A4 (fiction)+Spoken                                      |       0.000203335 |
# | A17 (review)+IN OP                                       |       0.000203335 |
# | A11 (personal)+IN ID                                     |       0.000203335 |
# | A16 (information)+IN LY                                  |       0.000203335 |
# | A16 (information)+IN ID                                  |       0.000203335 |
# | A14 (academic)+IN OP                                     |       0.000203335 |
# | A12 (promotion)+OP HI                                    |       0.000203335 |
# | A16 (information)+IN HI                                  |       0.000203335 |
# | A17 (review)+NA IP                                       |       0.000203335 |
# Value counts for: FTD + CORE_sub
# |                                                    |   FTD + CORE_sub |
# |:---------------------------------------------------|-----------------:|
# | A12 (promotion)+Description of a Thing             |      0.110004    |
# | A8 (news)+News Report/Blog                         |      0.100244    |
# | A1 (argumentative)+News Report/Blog                |      0.0514437   |
# | A12 (promotion)+Description with Intent to Sell    |      0.0502237   |
# | A16 (information)+Description of a Thing           |      0.0453436   |
# | A1 (argumentative)+Opinion Blog                    |      0.0384303   |
# | A8 (news)+Sports Report                            |      0.0355836   |
# | A11 (personal)+Personal Blog                       |      0.0292802   |
# | A7 (instruction)+How-to                            |      0.0290769   |
# | A1 (argumentative)+Description of a Thing          |      0.0262302   |
# | A17 (review)+Reviews                               |      0.0227735   |
# | A9 (legal)+Legal terms                             |      0.0209435   |
# | A4 (fiction)+Short Story                           |      0.0197235   |
# | A16 (information)+Encyclopedia Article             |      0.0189101   |
# | A8 (news)+Description of a Thing                   |      0.0178935   |
# | A17 (review)+Description of a Thing                |      0.0152501   |
# | A1 (argumentative)+Discussion Forum                |      0.0152501   |
# | A14 (academic)+Research Article                    |      0.0152501   |
# | A7 (instruction)+Description of a Thing            |      0.0132168   |
# | A11 (personal)+Discussion Forum                    |      0.0122001   |
# | A17 (review)+News Report/Blog                      |      0.0117934   |
# | A7 (instruction)+Information Blog                  |      0.00976007  |
# | A1 (argumentative)+Religious Blogs/Sermons         |      0.00915006  |
# | A1 (argumentative)+Information Blog                |      0.00915006  |
# | A16 (information)+Description of a Person          |      0.00854006  |
# | A12 (promotion)+Information Blog                   |      0.00772672  |
# | A1 (argumentative)+Interview                       |      0.00752338  |
# | A17 (review)+Interview                             |      0.00732005  |
# | A12 (promotion)+News Report/Blog                   |      0.00711671  |
# | A16 (information)+Information Blog                 |      0.00610004  |
# | A7 (instruction)+Discussion Forum                  |      0.00610004  |
# | A1 (argumentative)+Question/Answer Forum           |      0.00610004  |
# | A7 (instruction)+Question/Answer Forum             |      0.00589671  |
# | A7 (instruction)+Advice                            |      0.00549004  |
# | A1 (argumentative)+Research Article                |      0.0052867   |
# | A17 (review)+Description with Intent to Sell       |      0.00508337  |
# | A16 (information)+News Report/Blog                 |      0.00488003  |
# | A11 (personal)+Opinion Blog                        |      0.0046767   |
# | A16 (information)+Research Article                 |      0.0046767   |
# | A11 (personal)+Interview                           |      0.00447336  |
# | A1 (argumentative)+Personal Blog                   |      0.00427003  |
# | A17 (review)+Personal Blog                         |      0.00427003  |
# | A14 (academic)+Description of a Thing              |      0.00427003  |
# | A7 (instruction)+Recipe                            |      0.00406669  |
# | A17 (review)+Discussion Forum                      |      0.00406669  |
# | A12 (promotion)+Interview                          |      0.00386336  |
# | A1 (argumentative)+Sports Report                   |      0.00366002  |
# | A1 (argumentative)+Historical Article              |      0.00366002  |
# | A1 (argumentative)+Legal terms                     |      0.00345669  |
# | A9 (legal)+Description of a Thing                  |      0.00345669  |
# | A7 (instruction)+FAQ about Information             |      0.00345669  |
# | A1 (argumentative)+Encyclopedia Article            |      0.00325336  |
# | A16 (information)+Question/Answer Forum            |      0.00325336  |
# | A16 (information)+Historical Article               |      0.00305002  |
# | A12 (promotion)+Description of a Person            |      0.00284669  |
# | A11 (personal)+Song Lyrics                         |      0.00284669  |
# | A8 (news)+Interview                                |      0.00284669  |
# | A12 (promotion)+Discussion Forum                   |      0.00284669  |
# | A17 (review)+Opinion Blog                          |      0.00284669  |
# | A12 (promotion)+Question/Answer Forum              |      0.00264335  |
# | A17 (review)+Description of a Person               |      0.00244002  |
# | A1 (argumentative)+Advice                          |      0.00244002  |
# | A7 (instruction)+Legal terms                       |      0.00244002  |
# | A7 (instruction)+Description with Intent to Sell   |      0.00244002  |
# | A11 (personal)+Short Story                         |      0.00244002  |
# | A8 (news)+Legal terms                              |      0.00223668  |
# | A12 (promotion)+Personal Blog                      |      0.00223668  |
# | A12 (promotion)+Advice                             |      0.00223668  |
# | A16 (information)+Legal terms                      |      0.00223668  |
# | A12 (promotion)+FAQ about Information              |      0.00223668  |
# | A4 (fiction)+Religious Blogs/Sermons               |      0.00203335  |
# | A16 (information)+FAQ about Information            |      0.00203335  |
# | A16 (information)+Interview                        |      0.00203335  |
# | A11 (personal)+Question/Answer Forum               |      0.00203335  |
# | A11 (personal)+News Report/Blog                    |      0.00203335  |
# | A12 (promotion)+Reviews                            |      0.00203335  |
# | A7 (instruction)+Opinion Blog                      |      0.00183001  |
# | A11 (personal)+Description of a Person             |      0.00183001  |
# | A9 (legal)+News Report/Blog                        |      0.00183001  |
# | A16 (information)+Description with Intent to Sell  |      0.00162668  |
# | A1 (argumentative)+FAQ about Information           |      0.00162668  |
# | A11 (personal)+Information Blog                    |      0.00162668  |
# | A12 (promotion)+How-to                             |      0.00162668  |
# | A8 (news)+Opinion Blog                             |      0.00162668  |
# | A16 (information)+Discussion Forum                 |      0.00162668  |
# | A12 (promotion)+Research Article                   |      0.00162668  |
# | A17 (review)+Sports Report                         |      0.00142334  |
# | A9 (legal)+FAQ about Information                   |      0.00142334  |
# | A11 (personal)+Description of a Thing              |      0.00122001  |
# | A1 (argumentative)+Reviews                         |      0.00122001  |
# | A11 (personal)+Religious Blogs/Sermons             |      0.00122001  |
# | A12 (promotion)+Legal terms                        |      0.00122001  |
# | A8 (news)+Description of a Person                  |      0.00122001  |
# | A12 (promotion)+Opinion Blog                       |      0.00122001  |
# | A14 (academic)+Information Blog                    |      0.00122001  |
# | A4 (fiction)+Personal Blog                         |      0.00101667  |
# | A14 (academic)+Encyclopedia Article                |      0.00101667  |
# | A4 (fiction)+Historical Article                    |      0.00101667  |
# | A16 (information)+Song Lyrics                      |      0.00101667  |
# | A11 (personal)+Sports Report                       |      0.00101667  |
# | A7 (instruction)+Encyclopedia Article              |      0.00101667  |
# | A17 (review)+Encyclopedia Article                  |      0.000813339 |
# | A1 (argumentative)+How-to                          |      0.000813339 |
# | A11 (personal)+How-to                              |      0.000813339 |
# | A17 (review)+Song Lyrics                           |      0.000813339 |
# | A1 (argumentative)+Persuasive Article or Essay     |      0.000813339 |
# | A17 (review)+Travel Blog                           |      0.000813339 |
# | A11 (personal)+Travel Blog                         |      0.000813339 |
# | A8 (news)+Personal Blog                            |      0.000813339 |
# | A16 (information)+Religious Blogs/Sermons          |      0.000813339 |
# | A7 (instruction)+News Report/Blog                  |      0.000813339 |
# | A8 (news)+Religious Blogs/Sermons                  |      0.000813339 |
# | A11 (personal)+Historical Article                  |      0.000813339 |
# | A14 (academic)+News Report/Blog                    |      0.000813339 |
# | A12 (promotion)+Religious Blogs/Sermons            |      0.000813339 |
# | A12 (promotion)+Encyclopedia Article               |      0.000610004 |
# | A17 (review)+Information Blog                      |      0.000610004 |
# | A11 (personal)+Reviews                             |      0.000610004 |
# | A8 (news)+Reviews                                  |      0.000610004 |
# | A8 (news)+Encyclopedia Article                     |      0.000610004 |
# | A1 (argumentative)+Description with Intent to Sell |      0.000610004 |
# | A8 (news)+Discussion Forum                         |      0.000610004 |
# | A4 (fiction)+Song Lyrics                           |      0.000610004 |
# | A16 (information)+Personal Blog                    |      0.000610004 |
# | A8 (news)+Information Blog                         |      0.000610004 |
# | A11 (personal)+Advice                              |      0.000610004 |
# | A4 (fiction)+Reviews                               |      0.000610004 |
# | A1 (argumentative)+Transcript of Video/Audio       |      0.000406669 |
# | A4 (fiction)+Discussion Forum                      |      0.000406669 |
# | A4 (fiction)+Encyclopedia Article                  |      0.000406669 |
# | A4 (fiction)+Description of a Thing                |      0.000406669 |
# | A16 (information)+Course Materials                 |      0.000406669 |
# | A7 (instruction)+Personal Blog                     |      0.000406669 |
# | A1 (argumentative)+Formal Speech                   |      0.000406669 |
# | A12 (promotion)+Other Information                  |      0.000406669 |
# | A7 (instruction)+Song Lyrics                       |      0.000406669 |
# | A1 (argumentative)+Description of a Person         |      0.000406669 |
# | A17 (review)+Historical Article                    |      0.000406669 |
# | A14 (academic)+Personal Blog                       |      0.000406669 |
# | A12 (promotion)+Sports Report                      |      0.000406669 |
# | A8 (news)+Research Article                         |      0.000406669 |
# | A9 (legal)+Encyclopedia Article                    |      0.000406669 |
# | A4 (fiction)+Poem                                  |      0.000406669 |
# | A9 (legal)+Question/Answer Forum                   |      0.000406669 |
# | A8 (news)+Question/Answer Forum                    |      0.000406669 |
# | A11 (personal)+Recipe                              |      0.000406669 |
# | A8 (news)+FAQ about Information                    |      0.000406669 |
# | A4 (fiction)+Question/Answer Forum                 |      0.000203335 |
# | A1 (argumentative)+Editorial                       |      0.000203335 |
# | A17 (review)+Magazine Article                      |      0.000203335 |
# | A17 (review)+Question/Answer Forum                 |      0.000203335 |
# | A16 (information)+Prayer                           |      0.000203335 |
# | A7 (instruction)+Religious Blogs/Sermons           |      0.000203335 |
# | A12 (promotion)+FAQ about How-to                   |      0.000203335 |
# | A12 (promotion)+Other Opinion                      |      0.000203335 |
# | A9 (legal)+Technical Report                        |      0.000203335 |
# | A17 (review)+Advice                                |      0.000203335 |
# | A4 (fiction)+Magazine Article                      |      0.000203335 |
# | A8 (news)+Editorial                                |      0.000203335 |
# | A11 (personal)+Other Spoken                        |      0.000203335 |
# | A7 (instruction)+Course Materials                  |      0.000203335 |
# | A7 (instruction)+Sports Report                     |      0.000203335 |
# | A16 (information)+Opinion Blog                     |      0.000203335 |
# | A17 (review)+Short Story                           |      0.000203335 |
# | A1 (argumentative)+Magazine Article                |      0.000203335 |
# | A11 (personal)+TV/Movie Script                     |      0.000203335 |
# | A7 (instruction)+Reviews                           |      0.000203335 |
# | A7 (instruction)+Other Information                 |      0.000203335 |
# | A14 (academic)+Discussion Forum                    |      0.000203335 |
# | A9 (legal)+Other Information                       |      0.000203335 |
# | A14 (academic)+Question/Answer Forum               |      0.000203335 |
# | A7 (instruction)+Research Article                  |      0.000203335 |
# | A14 (academic)+Legal terms                         |      0.000203335 |
# | A4 (fiction)+Description of a Person               |      0.000203335 |
# | A14 (academic)+Opinion Blog                        |      0.000203335 |
# | A12 (promotion)+Song Lyrics                        |      0.000203335 |
# | A11 (personal)+Description with Intent to Sell     |      0.000203335 |
# | A7 (instruction)+Interview                         |      0.000203335 |
# | A1 (argumentative)+Song Lyrics                     |      0.000203335 |
# | A12 (promotion)+Recipe                             |      0.000203335 |
# | A7 (instruction)+Persuasive Article or Essay       |      0.000203335 |
# | A12 (promotion)+Travel Blog                        |      0.000203335 |
# | A8 (news)+Other Information                        |      0.000203335 |
# | A1 (argumentative)+Reader/Viewer Responses         |      0.000203335 |
# | A16 (information)+Sports Report                    |      0.000203335 |
# | A12 (promotion)+Course Materials                   |      0.000203335 |
# | A4 (fiction)+News Report/Blog                      |      0.000203335 |
# | A1 (argumentative)+Letter to Editor                |      0.000203335 |
# | A7 (instruction)+FAQ about How-to                  |      0.000203335 |
# | A16 (information)+How-to                           |      0.000203335 |
# | A12 (promotion)+Advertisement                      |      0.000203335 |
# | A7 (instruction)+Travel Blog                       |      0.000203335 |
# | A12 (promotion)+Reader/Viewer Responses            |      0.000203335 |
# | A16 (information)+Poem                             |      0.000203335 |
# | A8 (news)+Travel Blog                              |      0.000203335 |
# | A7 (instruction)+Technical Support                 |      0.000203335 |
# | A11 (personal)+Other Forum                         |      0.000203335 |
# Value counts for: GINCO_downcast + MT-GINCO_downcast
# |                                                       |   GINCO_downcast + MT-GINCO_downcast |
# |:------------------------------------------------------|-------------------------------------:|
# | News/Reporting+News/Reporting                         |                          0.22512     |
# | Opinion/Argumentation+Opinion/Argumentation           |                          0.164379    |
# | Information/Explanation+Information/Explanation       |                          0.148593    |
# | Promotion+Promotion                                   |                          0.0991764   |
# | Instruction+Instruction                               |                          0.0593686   |
# | Other+Other                                           |                          0.0428964   |
# | Forum+Forum                                           |                          0.0326012   |
# | List of Summaries/Excerpts+List of Summaries/Excerpts |                          0.0209334   |
# | Information/Explanation+Opinion/Argumentation         |                          0.0185312   |
# | Opinion/Argumentation+Other                           |                          0.016129    |
# | List of Summaries/Excerpts+Opinion/Argumentation      |                          0.0154427   |
# | Legal/Regulation+Legal/Regulation                     |                          0.0144132   |
# | Information/Explanation+Promotion                     |                          0.0116678   |
# | List of Summaries/Excerpts+Promotion                  |                          0.0106383   |
# | Information/Explanation+News/Reporting                |                          0.00892244  |
# | List of Summaries/Excerpts+News/Reporting             |                          0.00857927  |
# | News/Reporting+Opinion/Argumentation                  |                          0.00754976  |
# | Information/Explanation+Other                         |                          0.00754976  |
# | Information/Explanation+Instruction                   |                          0.00720659  |
# | Opinion/Argumentation+Forum                           |                          0.00583391  |
# | Other+Forum                                           |                          0.00549073  |
# | News/Reporting+Promotion                              |                          0.00549073  |
# | Promotion+Opinion/Argumentation                       |                          0.00514756  |
# | Other+Opinion/Argumentation                           |                          0.00514756  |
# | Opinion/Argumentation+News/Reporting                  |                          0.00480439  |
# | List of Summaries/Excerpts+Other                      |                          0.00377488  |
# | Other+Instruction                                     |                          0.00343171  |
# | News/Reporting+Other                                  |                          0.00308854  |
# | List of Summaries/Excerpts+Information/Explanation    |                          0.00308854  |
# | Instruction+Promotion                                 |                          0.00274537  |
# | Promotion+Instruction                                 |                          0.00274537  |
# | Opinion/Argumentation+Promotion                       |                          0.0024022   |
# | Legal/Regulation+Information/Explanation              |                          0.0024022   |
# | News/Reporting+List of Summaries/Excerpts             |                          0.00205903  |
# | Other+News/Reporting                                  |                          0.00205903  |
# | List of Summaries/Excerpts+Instruction                |                          0.00171585  |
# | Information/Explanation+List of Summaries/Excerpts    |                          0.00171585  |
# | Legal/Regulation+Other                                |                          0.00171585  |
# | Other+Legal/Regulation                                |                          0.00171585  |
# | Legal/Regulation+Instruction                          |                          0.00137268  |
# | Promotion+Other                                       |                          0.00137268  |
# | Information/Explanation+Legal/Regulation              |                          0.00137268  |
# | Promotion+List of Summaries/Excerpts                  |                          0.00137268  |
# | Opinion/Argumentation+Instruction                     |                          0.00102951  |
# | News/Reporting+Information/Explanation                |                          0.00102951  |
# | Promotion+Information/Explanation                     |                          0.000686342 |
# | Instruction+Other                                     |                          0.000686342 |
# | Forum+Opinion/Argumentation                           |                          0.000686342 |
# | Promotion+News/Reporting                              |                          0.000686342 |
# | Instruction+Opinion/Argumentation                     |                          0.000686342 |
# | List of Summaries/Excerpts+Forum                      |                          0.000686342 |
# | Opinion/Argumentation+List of Summaries/Excerpts      |                          0.000343171 |
# | Other+Information/Explanation                         |                          0.000343171 |
# | Opinion/Argumentation+Information/Explanation         |                          0.000343171 |
# | Forum+Instruction                                     |                          0.000343171 |
# | Instruction+Information/Explanation                   |                          0.000343171 |
# | Legal/Regulation+News/Reporting                       |                          0.000343171 |
# Value counts for: GINCO_downcast + CORE_main
# |                                                                  |   GINCO_downcast + CORE_main |
# |:-----------------------------------------------------------------|-----------------------------:|
# | News/Reporting+Narrative                                         |                  0.163432    |
# | Information/Explanation+Informational Description/Explanation    |                  0.15526     |
# | Promotion+Informational Description/Explanation                  |                  0.0791624   |
# | Opinion/Argumentation+Narrative                                  |                  0.0625638   |
# | Opinion/Argumentation+Opinion                                    |                  0.0572012   |
# | News/Reporting+Informational Description/Explanation             |                  0.0495403   |
# | Promotion+Informational Persuasion                               |                  0.0331971   |
# | Instruction+How-To/Instructional                                 |                  0.0321757   |
# | List of Summaries/Excerpts+Informational Description/Explanation |                  0.031665    |
# | Opinion/Argumentation+Informational Description/Explanation      |                  0.0286006   |
# | Forum+Interactive Discussion                                     |                  0.0275792   |
# | Other+Informational Description/Explanation                      |                  0.0227273   |
# | Legal/Regulation+Informational Description/Explanation           |                  0.0191522   |
# | Instruction+Informational Description/Explanation                |                  0.0186415   |
# | List of Summaries/Excerpts+Narrative                             |                  0.0178754   |
# | Other+Narrative                                                  |                  0.01762     |
# | Promotion+Opinion                                                |                  0.0135342   |
# | Information/Explanation+Narrative                                |                  0.0127681   |
# | List of Summaries/Excerpts+Opinion                               |                  0.0109806   |
# | News/Reporting+Opinion                                           |                  0.0107252   |
# | Opinion/Argumentation+Spoken                                     |                  0.00944842  |
# | Opinion/Argumentation+Interactive Discussion                     |                  0.00944842  |
# | Information/Explanation+Opinion                                  |                  0.00868233  |
# | Other+Interactive Discussion                                     |                  0.00791624  |
# | News/Reporting+Spoken                                            |                  0.00638407  |
# | Other+Opinion                                                    |                  0.00638407  |
# | Forum+Narrative                                                  |                  0.00587334  |
# | Other+Spoken                                                     |                  0.00510725  |
# | List of Summaries/Excerpts+Spoken                                |                  0.00434116  |
# | List of Summaries/Excerpts+Informational Persuasion              |                  0.00434116  |
# | Information/Explanation+Informational Persuasion                 |                  0.0040858   |
# | Other+Lyrical                                                    |                  0.0040858   |
# | Instruction+Opinion                                              |                  0.00357508  |
# | News/Reporting+NA IN                                             |                  0.00357508  |
# | Promotion+Narrative                                              |                  0.00331971  |
# | Forum+Opinion                                                    |                  0.00306435  |
# | Opinion/Argumentation+Lyrical                                    |                  0.00280899  |
# | Promotion+How-To/Instructional                                   |                  0.00255363  |
# | Opinion/Argumentation+Informational Persuasion                   |                  0.00229826  |
# | Information/Explanation+Interactive Discussion                   |                  0.0020429   |
# | List of Summaries/Excerpts+How-To/Instructional                  |                  0.0020429   |
# | Instruction+Interactive Discussion                               |                  0.0020429   |
# | Opinion/Argumentation+NA IN                                      |                  0.00178754  |
# | News/Reporting+NA OP                                             |                  0.00153218  |
# | Information/Explanation+NA IN                                    |                  0.00153218  |
# | List of Summaries/Excerpts+Lyrical                               |                  0.00153218  |
# | List of Summaries/Excerpts+Interactive Discussion                |                  0.00153218  |
# | Promotion+Spoken                                                 |                  0.00153218  |
# | Other+Informational Persuasion                                   |                  0.00153218  |
# | Opinion/Argumentation+IN OP                                      |                  0.00127681  |
# | Opinion/Argumentation+NA OP                                      |                  0.00127681  |
# | Opinion/Argumentation+How-To/Instructional                       |                  0.00127681  |
# | Information/Explanation+Spoken                                   |                  0.00127681  |
# | News/Reporting+IN OP                                             |                  0.00102145  |
# | Information/Explanation+How-To/Instructional                     |                  0.00102145  |
# | News/Reporting+Informational Persuasion                          |                  0.000766088 |
# | List of Summaries/Excerpts+NA IN                                 |                  0.000766088 |
# | Promotion+NA IN                                                  |                  0.000766088 |
# | Instruction+IN HI                                                |                  0.000766088 |
# | Forum+Informational Description/Explanation                      |                  0.000766088 |
# | Promotion+IN OP                                                  |                  0.000766088 |
# | Information/Explanation+Lyrical                                  |                  0.000766088 |
# | Instruction+Informational Persuasion                             |                  0.000766088 |
# | Promotion+IN IP                                                  |                  0.000510725 |
# | Instruction+Narrative                                            |                  0.000510725 |
# | News/Reporting+Interactive Discussion                            |                  0.000510725 |
# | Forum+Informational Persuasion                                   |                  0.000510725 |
# | Other+IN HI                                                      |                  0.000510725 |
# | Instruction+NA OP                                                |                  0.000255363 |
# | Other+OP ID                                                      |                  0.000255363 |
# | List of Summaries/Excerpts+NA IP                                 |                  0.000255363 |
# | Promotion+NA OP                                                  |                  0.000255363 |
# | Promotion+IN HI                                                  |                  0.000255363 |
# | Opinion/Argumentation+OP ID                                      |                  0.000255363 |
# | Promotion+Interactive Discussion                                 |                  0.000255363 |
# | News/Reporting+IN SP                                             |                  0.000255363 |
# ...
# | Forum+Research Article                                     |                    0.000255363 |
# | Opinion/Argumentation+Other Forum                          |                    0.000255363 |
# Value counts for: CORE_main + CORE_sub
# |                                                                       |   CORE_main + CORE_sub |
# |:----------------------------------------------------------------------|-----------------------:|
# | Informational Description/Explanation+Description of a Thing          |            0.216755    |
# | Narrative+News Report/Blog                                            |            0.148841    |
# | Informational Persuasion+Description with Intent to Sell              |            0.0424969   |
# | Opinion+Opinion Blog                                                  |            0.0414803   |
# | Narrative+Sports Report                                               |            0.0408703   |
# | Narrative+Personal Blog                                               |            0.0345669   |
# | Interactive Discussion+Discussion Forum                               |            0.0335502   |
# | Informational Description/Explanation+Legal terms                     |            0.0325336   |
# | Informational Description/Explanation+Information Blog                |            0.0302969   |
# | How-To/Instructional+How-to                                           |            0.0274502   |
# | Informational Description/Explanation+Research Article                |            0.0270435   |
# | Informational Description/Explanation+Encyclopedia Article            |            0.0256202   |
# | Informational Description/Explanation+News Report/Blog                |            0.0244002   |
# | Opinion+Reviews                                                       |            0.0223668   |
# | Spoken+Interview                                                      |            0.0205368   |
# | Narrative+Short Story                                                 |            0.0183001   |
# | Informational Description/Explanation+Description with Intent to Sell |            0.0142334   |
# | Interactive Discussion+Question/Answer Forum                          |            0.0113867   |
# | Informational Description/Explanation+Description of a Person         |            0.0111834   |
# | Opinion+Religious Blogs/Sermons                                       |            0.0109801   |
# | Informational Description/Explanation+FAQ about Information           |            0.0093534   |
# | Opinion+Advice                                                        |            0.00915006  |
# | Informational Description/Explanation+Question/Answer Forum           |            0.00671004  |
# | Informational Persuasion+Description of a Thing                       |            0.00630338  |
# | Narrative+Historical Article                                          |            0.00610004  |
# | Lyrical+Song Lyrics                                                   |            0.00569337  |
# | Informational Description/Explanation+Interview                       |            0.00508337  |
# | How-To/Instructional+Recipe                                           |            0.00447336  |
# | Narrative+Description of a Thing                                      |            0.00427003  |
# | Opinion+Information Blog                                              |            0.00406669  |
# | Informational Description/Explanation+Opinion Blog                    |            0.00386336  |
# | Narrative+Description of a Person                                     |            0.00386336  |
# | Informational Description/Explanation+How-to                          |            0.00345669  |
# | Narrative+Discussion Forum                                            |            0.00345669  |
# | Spoken+Description of a Thing                                         |            0.00345669  |
# | Spoken+Discussion Forum                                               |            0.00325336  |
# | Narrative+Opinion Blog                                                |            0.00284669  |
# | Informational Description/Explanation+Discussion Forum                |            0.00264335  |
# | NA IN+News Report/Blog                                                |            0.00264335  |
# | Spoken+Personal Blog                                                  |            0.00244002  |
# | Spoken+News Report/Blog                                               |            0.00244002  |
# | Informational Description/Explanation+Reviews                         |            0.00244002  |
# | Narrative+Travel Blog                                                 |            0.00223668  |
# | Informational Description/Explanation+Personal Blog                   |            0.00203335  |
# | Opinion+News Report/Blog                                              |            0.00203335  |
# | Opinion+Description with Intent to Sell                               |            0.00183001  |
# | Informational Description/Explanation+Historical Article              |            0.00183001  |
# | Interactive Discussion+Personal Blog                                  |            0.00183001  |
# | Lyrical+Short Story                                                   |            0.00162668  |
# | Spoken+Question/Answer Forum                                          |            0.00162668  |
# | Narrative+Religious Blogs/Sermons                                     |            0.00162668  |
# | How-To/Instructional+Description of a Thing                           |            0.00162668  |
# | Spoken+Description of a Person                                        |            0.00142334  |
# | Narrative+Interview                                                   |            0.00142334  |
# | Interactive Discussion+Description of a Thing                         |            0.00142334  |
# | NA OP+Opinion Blog                                                    |            0.00142334  |
# | NA IN+Description of a Thing                                          |            0.00142334  |
# | Opinion+Description of a Thing                                        |            0.00122001  |
# | Informational Description/Explanation+Sports Report                   |            0.00122001  |
# | Informational Description/Explanation+Other Information               |            0.00101667  |
# | Spoken+Short Story                                                    |            0.00101667  |
# | Informational Description/Explanation+Short Story                     |            0.00101667  |
# | Informational Persuasion+Reviews                                      |            0.00101667  |
# | NA IN+Personal Blog                                                   |            0.00101667  |
# | Informational Description/Explanation+Religious Blogs/Sermons         |            0.00101667  |
# | Spoken+Reviews                                                        |            0.00101667  |
# | Informational Persuasion+Persuasive Article or Essay                  |            0.000813339 |
# | Informational Description/Explanation+Course Materials                |            0.000813339 |
# | IN HI+How-to                                                          |            0.000813339 |
# | How-To/Instructional+Information Blog                                 |            0.000813339 |
# | NA IN+Description of a Person                                         |            0.000813339 |
# | Spoken+FAQ about Information                                          |            0.000813339 |
# | IN OP+Opinion Blog                                                    |            0.000813339 |
# | Spoken+Encyclopedia Article                                           |            0.000610004 |
# | Spoken+Opinion Blog                                                   |            0.000610004 |
# | Narrative+Encyclopedia Article                                        |            0.000610004 |
# | Spoken+Religious Blogs/Sermons                                        |            0.000610004 |
# | Informational Description/Explanation+Advice                          |            0.000610004 |
# | How-To/Instructional+Description with Intent to Sell                  |            0.000610004 |
# | Narrative+Magazine Article                                            |            0.000610004 |
# | How-To/Instructional+Advice                                           |            0.000610004 |
# | Opinion+Personal Blog                                                 |            0.000610004 |
# | NA OP+News Report/Blog                                                |            0.000610004 |
# | How-To/Instructional+FAQ about Information                            |            0.000610004 |
# | Opinion+Question/Answer Forum                                         |            0.000610004 |
# | Opinion+Historical Article                                            |            0.000610004 |
# | IN OP+Information Blog                                                |            0.000406669 |
# | Lyrical+Poem                                                          |            0.000406669 |
# | IN OP+Religious Blogs/Sermons                                         |            0.000406669 |
# | How-To/Instructional+FAQ about How-to                                 |            0.000406669 |
# | Interactive Discussion+Reader/Viewer Responses                        |            0.000406669 |
# | IN ID+Question/Answer Forum                                           |            0.000406669 |
# | IN IP+Description with Intent to Sell                                 |            0.000406669 |
# | IN OP+Reviews                                                         |            0.000406669 |
# | Spoken+Transcript of Video/Audio                                      |            0.000406669 |
# | NA IN+Historical Article                                              |            0.000406669 |
# | Informational Persuasion+Editorial                                    |            0.000406669 |
# | Narrative+Reviews                                                     |            0.000406669 |
# | Opinion+Short Story                                                   |            0.000406669 |
# | Lyrical+Personal Blog                                                 |            0.000406669 |
# | Opinion+Interview                                                     |            0.000406669 |
# | Narrative+Information Blog                                            |            0.000406669 |
# | Informational Persuasion+Question/Answer Forum                        |            0.000406669 |
# | Spoken+Formal Speech                                                  |            0.000406669 |
# | Opinion+Discussion Forum                                              |            0.000406669 |
# | Interactive Discussion+Interview                                      |            0.000406669 |
# | IN HI+Information Blog                                                |            0.000203335 |
# | NA SP+Interview                                                       |            0.000203335 |
# | NA IP+Description with Intent to Sell                                 |            0.000203335 |
# | Opinion+Other Opinion                                                 |            0.000203335 |
# | IN SP+Description of a Thing                                          |            0.000203335 |
# | IN LY+Poem                                                            |            0.000203335 |
# | OP ID+Question/Answer Forum                                           |            0.000203335 |
# | IN HI+FAQ about Information                                           |            0.000203335 |
# | NA IN+Sports Report                                                   |            0.000203335 |
# | NA OP+Advice                                                          |            0.000203335 |
# | NA IP+Persuasive Article or Essay                                     |            0.000203335 |
# | IN OP+Description of a Person                                         |            0.000203335 |
# | How-To/Instructional+Technical Support                                |            0.000203335 |
# | NA IN+Information Blog                                                |            0.000203335 |
# | Informational Description/Explanation+Technical Report                |            0.000203335 |
# | OP ID+Reviews                                                         |            0.000203335 |
# | NA OP+Personal Blog                                                   |            0.000203335 |
# | Spoken+TV/Movie Script                                                |            0.000203335 |
# | OP HI+How-to                                                          |            0.000203335 |
# | Spoken+Other Spoken                                                   |            0.000203335 |
# | Lyrical+Prayer                                                        |            0.000203335 |
# | Interactive Discussion+Description with Intent to Sell                |            0.000203335 |
# | Opinion+Advertisement                                                 |            0.000203335 |
# | Informational Persuasion+How-to                                       |            0.000203335 |
# | Informational Persuasion+Personal Blog                                |            0.000203335 |
# | How-To/Instructional+Religious Blogs/Sermons                          |            0.000203335 |
# | How-To/Instructional+Legal terms                                      |            0.000203335 |
# | Lyrical+Description with Intent to Sell                               |            0.000203335 |
# | Opinion+Song Lyrics                                                   |            0.000203335 |
# | Narrative+Research Article                                            |            0.000203335 |
# | Opinion+How-to                                                        |            0.000203335 |
# | Spoken+Sports Report                                                  |            0.000203335 |
# | Informational Persuasion+Interview                                    |            0.000203335 |
# | Interactive Discussion+News Report/Blog                               |            0.000203335 |
# | Informational Description/Explanation+Song Lyrics                     |            0.000203335 |
# | Informational Persuasion+Information Blog                             |            0.000203335 |
# | Informational Persuasion+Religious Blogs/Sermons                      |            0.000203335 |
# | Opinion+Letter to Editor                                              |            0.000203335 |
# | Interactive Discussion+FAQ about Information                          |            0.000203335 |
# | Lyrical+Description of a Thing                                        |            0.000203335 |
# | Informational Description/Explanation+Recipe                          |            0.000203335 |
# | Spoken+Advice                                                         |            0.000203335 |
# | Interactive Discussion+How-to                                         |            0.000203335 |
# | Informational Persuasion+Advice                                       |            0.000203335 |
# | Interactive Discussion+Information Blog                               |            0.000203335 |
# | How-To/Instructional+Encyclopedia Article                             |            0.000203335 |
# | IN OP+Description of a Thing                                          |            0.000203335 |
# | IN OP+Research Article                                                |            0.000203335 |
# | IN HI+Description of a Thing                                          |            0.000203335 |
# | NA OP+Reviews                                                         |            0.000203335 |
# | Interactive Discussion+Other Forum                                    |            0.000203335 |

# %% [markdown]
# ## Finding the best mapping using the association rules

# %%
# Open the dataset
merged_df = pd.read_csv("data-sheets-with-all-info/Merged-datasets-with-all-predictions.csv", sep="\t", index_col = 0)
merged_df.head(1)
# Out:
#    index original_label                                               text  \
# 0      0            FTD  BMW's and Chinese Justice * * * * * In most pl...
#
#                   FTD  GINCO_downcast MT-GINCO_downcast  CORE_main  \
# 0  A1 (argumentative)  News/Reporting    News/Reporting  Narrative
#
#            CORE_sub    X-GENRE
# 0  News Report/Blog  discarded

# %%
# Use only relevant columns
merged_df = merged_df[['FTD', 'GINCO_downcast', 'CORE_main', 'CORE_sub']]
merged_df.head(1)
# Out:
#                   FTD  GINCO_downcast  CORE_main          CORE_sub
# 0  A1 (argumentative)  News/Reporting  Narrative  News Report/Blog

# %%
# Remove nan values - they occurred in the GINCO_downcast column because we added MT-GINCO downcast without this values to the dataframe, and we don't use this column here.
merged_df.dropna(subset=["GINCO_downcast"], inplace=True)

# %%
# Check if there are any NaNs left
merged_df[merged_df.isnull().values]
# Out:
# Empty DataFrame
# Columns: [FTD, GINCO_downcast, CORE_main, CORE_sub]
# Index: []

# %%
# Reset index
merged_df = merged_df.reset_index()

# %%
# Add information about columns to the label names
merged_df["FTD"] = "FTD: " + merged_df["FTD"].astype(str)
merged_df["FTD"].head(5)
# Out:
# 0    FTD: A1 (argumentative)
# 1    FTD: A1 (argumentative)
# 2    FTD: A1 (argumentative)
# 3    FTD: A1 (argumentative)
# 4    FTD: A1 (argumentative)
# Name: FTD, dtype: object

# %%
merged_df.columns
# Out:
# Index(['index', 'FTD', 'GINCO_downcast', 'CORE_main', 'CORE_sub'], dtype='object')

# %%
merged_df["GINCO_downcast"] = "GINCO: " + merged_df["GINCO_downcast"].astype(str)
merged_df["CORE_main"] = "CORE_main: " + merged_df["CORE_main"].astype(str)
merged_df["CORE_sub"] = "CORE_sub: " + merged_df["CORE_sub"].astype(str)
merged_df.head(3)
# Out:
#    index                      FTD                  GINCO_downcast  \
# 0      0  FTD: A1 (argumentative)           GINCO: News/Reporting
# 1      1  FTD: A1 (argumentative)  GINCO: Information/Explanation
# 2      2  FTD: A1 (argumentative)    GINCO: Opinion/Argumentation
#
#               CORE_main                    CORE_sub
# 0  CORE_main: Narrative  CORE_sub: News Report/Blog
# 1    CORE_main: Opinion      CORE_sub: Opinion Blog
# 2    CORE_main: Opinion      CORE_sub: Opinion Blog

# %%
merged_df.shape
# Out:
# (3916, 5)

# %%
# Save the dataset

merged_df.to_csv("data-sheets-with-all-info/Merged-datasets-with-all-predictions.csv", sep="\t")

# %%
# Let's created the required ouput - a list of all values per instance - I will create a list of pairs from each schemata instead of lists of 4 values from the schema
apriori_list = []

for i in range(0,3915):
	apriori_list.append([str(merged_df.values[i,j]) for j in range(1,5)])


apriori_list[:10]
# Out:
# [['FTD: A1 (argumentative)',
#   'GINCO: News/Reporting',
#   'CORE_main: Narrative',
#   'CORE_sub: News Report/Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: Information/Explanation',
#   'CORE_main: Opinion',
#   'CORE_sub: Opinion Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: Opinion/Argumentation',
#   'CORE_main: Opinion',
#   'CORE_sub: Opinion Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: Opinion/Argumentation',
#   'CORE_main: Narrative',
#   'CORE_sub: Historical Article'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: News/Reporting',
#   'CORE_main: Narrative',
#   'CORE_sub: News Report/Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: List of Summaries/Excerpts',
#   'CORE_main: Narrative',
#   'CORE_sub: News Report/Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: News/Reporting',
#   'CORE_main: Narrative',
#   'CORE_sub: News Report/Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: Opinion/Argumentation',
#   'CORE_main: Informational Description/Explanation',
#   'CORE_sub: Description of a Thing'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: News/Reporting',
#   'CORE_main: Narrative',
#   'CORE_sub: News Report/Blog'],
#  ['FTD: A1 (argumentative)',
#   'GINCO: News/Reporting',
#   'CORE_main: Narrative',
#   'CORE_sub: News Report/Blog']]

# %%
# Training the model
from apyori import apriori

results = list(apriori(apriori_list,
             min_support=0.01,
             min_confidence=0.80,
             min_lift=1.0,
             max_length=None))

# %%
#Transform the results into pandas dataframe
output = list(results) # returns a non-tabular output

# putting output into a pandas dataframe
def inspect(output):
    lhs         = [tuple(result[2][0][0])[0] for result in output]
    rhs         = [tuple(result[2][0][1])[0] for result in output]
    support    = [result[1] for result in output]
    confidence = [result[2][0][2] for result in output]
    lift       = [result[2][0][3] for result in output]
    entire_item = [list(result) for result in output]
    return list(zip(lhs, rhs, support, confidence, lift, entire_item))
output_df = pd.DataFrame(inspect(output), columns = ['Left_Hand_Side', 'Right_Hand_Side', 'Support', 'Confidence', 'Lift','Full_result'])

# Display results based on lift
output_df.sort_values(by="Lift", ascending=False).head()

# %%
output_DataFrame.iloc[102]["Full_result"]
# Out:
# [frozenset({'CORE_main: Narrative',
#             'CORE_sub: Short Story',
#             'FTD: A4 (fiction)',
#             'GINCO: Other'}),
#  0.013282247765006385,
#  [OrderedStatistic(items_base=frozenset({'CORE_sub: Short Story', 'GINCO: Other'}), items_add=frozenset({'CORE_main: Narrative', 'FTD: A4 (fiction)'}), confidence=0.8666666666666667, lift=37.285714285714285),
#   OrderedStatistic(items_base=frozenset({'CORE_sub: Short Story', 'CORE_main: Narrative', 'GINCO: Other'}), items_add=frozenset({'FTD: A4 (fiction)'}), confidence=1.0, lift=30.826771653543307),
#   OrderedStatistic(items_base=frozenset({'GINCO: Other', 'CORE_main: Narrative', 'FTD: A4 (fiction)'}), items_add=frozenset({'CORE_sub: Short Story'}), confidence=0.9811320754716981, lift=38.79931389365352),
#   OrderedStatistic(items_base=frozenset({'CORE_sub: Short Story', 'FTD: A4 (fiction)', 'GINCO: Other'}), items_add=frozenset({'CORE_main: Narrative'}), confidence=0.8965517241379309, lift=3.1564748201438846)]]

# %%
output_DataFrame.iloc[67]["Full_result"]
# Out:
# [frozenset({'CORE_main: Narrative',
#             'CORE_sub: Short Story',
#             'FTD: A4 (fiction)'}),
#  0.020945083014048533,
#  [OrderedStatistic(items_base=frozenset({'CORE_sub: Short Story'}), items_add=frozenset({'CORE_main: Narrative', 'FTD: A4 (fiction)'}), confidence=0.8282828282828284, lift=35.634365634365636),
#   OrderedStatistic(items_base=frozenset({'CORE_sub: Short Story', 'CORE_main: Narrative'}), items_add=frozenset({'FTD: A4 (fiction)'}), confidence=0.9647058823529412, lift=29.738767948124135),
#   OrderedStatistic(items_base=frozenset({'CORE_main: Narrative', 'FTD: A4 (fiction)'}), items_add=frozenset({'CORE_sub: Short Story'}), confidence=0.9010989010989011, lift=35.634365634365636),
#   OrderedStatistic(items_base=frozenset({'CORE_sub: Short Story', 'FTD: A4 (fiction)'}), items_add=frozenset({'CORE_main: Narrative'}), confidence=0.9010989010989011, lift=3.1724839908293148)]]

# %% [markdown]
# Support: It measures the number of times a particular item or combination of items occur in a dataset out of the number of all instances.
# `Support(I) = \frac{transaction containing(I)}{total.transactions}`
#
# Confidence: It measures how the left value is likely to consume to be predicted for this instance given they the right value has been predicted.
# `Confidence(I_1\rightarrow I_2) = \frac{transaction cointaing(I_1and I_2)}{transactions containing(I_1)}
#
# Lift: A lift is a metric that determines the strength of association between the best rules. It is obtained by taking confidence and diving it with support.
# `Lift(I_1\rightarrow I_2) = \frac{Confidence(I_1\rightarrow I_2)}{Support(I_2)}`

# %%
# Let's also try the same, but comparing schemata only in pairs

def compare_with_apriori(dataframe, column1, column2):
	apriori_list =  list(list(zip(list(dataframe[column1]), list(dataframe[column2]))))

	results = list(apriori(apriori_list,
             min_support=0.01,
             min_confidence=0.50,
             min_lift=1.0,
             max_length=None))

	output_df = pd.DataFrame(inspect(list(results)), columns = ['Left_Hand_Side', 'Right_Hand_Side', 'Support', 'Confidence', 'Lift','Full_result'])

	output_df = output_df.sort_values(by="Lift", ascending=False)

	return output_df

# %%
FTD_GINCO_df = compare_with_apriori(merged_df, "FTD", "GINCO_downcast")

FTD_GINCO_df
# Out:
#            Left_Hand_Side                 Right_Hand_Side   Support  \
# 7         FTD: A9 (legal)         GINCO: Legal/Regulation  0.017620
# 5   FTD: A7 (instruction)              GINCO: Instruction  0.052860
# 4       FTD: A4 (fiction)                    GINCO: Other  0.016599
# 2     FTD: A14 (academic)  GINCO: Information/Explanation  0.022472
# 1    FTD: A12 (promotion)                GINCO: Promotion  0.104188
# 3  FTD: A16 (information)  GINCO: Information/Explanation  0.077630
# 0     FTD: A11 (personal)    GINCO: Opinion/Argumentation  0.049030
# 6          FTD: A8 (news)           GINCO: News/Reporting  0.129213
#
#    Confidence       Lift                                        Full_result
# 7    0.627273  32.321053  [(GINCO: Legal/Regulation, FTD: A9 (legal)), 0...
# 5    0.565574   9.629508  [(FTD: A7 (instruction), GINCO: Instruction), ...
# 4    0.511811   7.679126  [(GINCO: Other, FTD: A4 (fiction)), 0.01659856...
# 2    0.814815   4.323597  [(GINCO: Information/Explanation, FTD: A14 (ac...
# 1    0.563536   4.140350  [(GINCO: Promotion, FTD: A12 (promotion)), 0.1...
# 3    0.722090   3.831579  [(FTD: A16 (information), GINCO: Information/E...
# 0    0.666667   3.729524  [(GINCO: Opinion/Argumentation, FTD: A11 (pers...
# 6    0.840532   3.527890  [(FTD: A8 (news), GINCO: News/Reporting), 0.12...

# %%
FTD_CORE_main_df = compare_with_apriori(merged_df, "FTD", "CORE_main")

FTD_CORE_main_df
# Out:
#                         Left_Hand_Side  \
# 0      CORE_main: How-To/Instructional
# 5  CORE_main: Informational Persuasion
# 7                       FTD: A8 (news)
# 6                    FTD: A4 (fiction)
# 4                      FTD: A9 (legal)
# 2                  FTD: A14 (academic)
# 3               FTD: A16 (information)
# 1                 FTD: A12 (promotion)
#
#                                     Right_Hand_Side   Support  Confidence  \
# 0                             FTD: A7 (instruction)  0.035240    0.890323
# 5                              FTD: A12 (promotion)  0.036006    0.758065
# 7                              CORE_main: Narrative  0.124617    0.810631
# 6                              CORE_main: Narrative  0.023238    0.716535
# 4  CORE_main: Informational Description/Explanation  0.027068    0.963636
# 2  CORE_main: Informational Description/Explanation  0.024770    0.898148
# 3  CORE_main: Informational Description/Explanation  0.089632    0.833729
# 1  CORE_main: Informational Description/Explanation  0.118744    0.642265
#
#        Lift                                        Full_result
# 0  9.525965  [(CORE_main: How-To/Instructional, FTD: A7 (in...
# 5  4.100250  [(FTD: A12 (promotion), CORE_main: Information...
# 7  2.852140  [(FTD: A8 (news), CORE_main: Narrative), 0.124...
# 6  2.521072  [(CORE_main: Narrative, FTD: A4 (fiction)), 0....
# 4  2.376322  [(CORE_main: Informational Description/Explana...
# 2  2.214829  [(CORE_main: Informational Description/Explana...
# 3  2.055972  [(FTD: A16 (information), CORE_main: Informati...
# 1  1.583823  [(FTD: A12 (promotion), CORE_main: Information...

# %%
FTD_core_sub_df = compare_with_apriori(merged_df, "FTD", "CORE_sub")
FTD_core_sub_df
# Out:
#                                Left_Hand_Side  \
# 10                      CORE_sub: Short Story
# 4                       CORE_sub: Legal terms
# 8                  CORE_sub: Research Article
# 3                            CORE_sub: How-to
# 9                           CORE_sub: Reviews
# 7                     CORE_sub: Personal Blog
# 2              CORE_sub: Encyclopedia Article
# 11                    CORE_sub: Sports Report
# 1   CORE_sub: Description with Intent to Sell
# 6                      CORE_sub: Opinion Blog
# 5                  CORE_sub: News Report/Blog
# 0                        FTD: A12 (promotion)
#
#                      Right_Hand_Side   Support  Confidence       Lift  \
# 10                 FTD: A4 (fiction)  0.023238    0.919192  28.342957
# 4                    FTD: A9 (legal)  0.021706    0.643939  22.924242
# 8                FTD: A14 (academic)  0.017109    0.563025  20.414877
# 3              FTD: A7 (instruction)  0.031920    0.905797   9.691534
# 9                  FTD: A17 (review)  0.025281    0.798387   9.222666
# 7                FTD: A11 (personal)  0.030899    0.675978   9.191418
# 2             FTD: A16 (information)  0.016088    0.656250   6.104216
# 11                    FTD: A8 (news)  0.034219    0.807229   5.251011
# 1               FTD: A12 (promotion)  0.042135    0.793269   4.290666
# 6            FTD: A1 (argumentative)  0.044178    0.742489   3.498903
# 5                     FTD: A8 (news)  0.096782    0.522759   3.400536
# 0   CORE_sub: Description of a Thing  0.096782    0.523481   2.411706
#
#                                           Full_result
# 10  [(CORE_sub: Short Story, FTD: A4 (fiction)), 0...
# 4   [(CORE_sub: Legal terms, FTD: A9 (legal)), 0.0...
# 8   [(CORE_sub: Research Article, FTD: A14 (academ...
# 3   [(CORE_sub: How-to, FTD: A7 (instruction)), 0....
# 9   [(CORE_sub: Reviews, FTD: A17 (review)), 0.025...
# 7   [(CORE_sub: Personal Blog, FTD: A11 (personal)...
# 2   [(FTD: A16 (information), CORE_sub: Encycloped...
# 11  [(FTD: A8 (news), CORE_sub: Sports Report), 0....
# 1   [(FTD: A12 (promotion), CORE_sub: Description ...
# 6   [(CORE_sub: Opinion Blog, FTD: A1 (argumentati...
# 5   [(FTD: A8 (news), CORE_sub: News Report/Blog),...
# 0   [(FTD: A12 (promotion), CORE_sub: Description ...

# %%
GINCO_CORE_main_df = compare_with_apriori(merged_df, "GINCO_downcast", "CORE_main")
GINCO_CORE_main_df
# Out:
#                         Left_Hand_Side  \
# 5    CORE_main: Interactive Discussion
# 0      CORE_main: How-To/Instructional
# 4  CORE_main: Informational Persuasion
# 7                   CORE_main: Opinion
# 2              GINCO: Legal/Regulation
# 6                 CORE_main: Narrative
# 1       GINCO: Information/Explanation
# 3                     GINCO: Promotion
#
#                                     Right_Hand_Side   Support  Confidence  \
# 5                                      GINCO: Forum  0.027579    0.537313
# 0                                GINCO: Instruction  0.032176    0.812903
# 4                                  GINCO: Promotion  0.033197    0.698925
# 7                      GINCO: Opinion/Argumentation  0.057201    0.501119
# 2  CORE_main: Informational Description/Explanation  0.019152    0.986842
# 6                             GINCO: News/Reporting  0.163432    0.575022
# 1  CORE_main: Informational Description/Explanation  0.155260    0.823848
# 3  CORE_main: Informational Description/Explanation  0.079162    0.581614
#
#         Lift                                        Full_result
# 5  14.027463  [(CORE_main: Interactive Discussion, GINCO: Fo...
# 0  13.840561  [(CORE_main: How-To/Instructional, GINCO: Inst...
# 4   5.135064  [(GINCO: Promotion, CORE_main: Informational P...
# 7   2.803400  [(GINCO: Opinion/Argumentation, CORE_main: Opi...
# 2   2.433548  [(GINCO: Legal/Regulation, CORE_main: Informat...
# 6   2.413492  [(CORE_main: Narrative, GINCO: News/Reporting)...
# 1   2.031606  [(GINCO: Information/Explanation, CORE_main: I...
# 3   1.434256  [(GINCO: Promotion, CORE_main: Informational D...

# %%
GINCO_CORE_sub_df = compare_with_apriori(merged_df, "GINCO_downcast", "CORE_sub")
GINCO_CORE_sub_df
# Out:
#                                Left_Hand_Side                 Right_Hand_Side  \
# 4                       CORE_sub: Legal terms         GINCO: Legal/Regulation
# 1                  CORE_sub: Discussion Forum                    GINCO: Forum
# 3                            CORE_sub: How-to              GINCO: Instruction
# 9                       CORE_sub: Short Story                    GINCO: Other
# 0   CORE_sub: Description with Intent to Sell                GINCO: Promotion
# 7                     CORE_sub: Personal Blog    GINCO: Opinion/Argumentation
# 8                  CORE_sub: Research Article  GINCO: Information/Explanation
# 2              CORE_sub: Encyclopedia Article  GINCO: Information/Explanation
# 6                      CORE_sub: Opinion Blog    GINCO: Opinion/Argumentation
# 5                  CORE_sub: News Report/Blog           GINCO: News/Reporting
# 10                    CORE_sub: Sports Report           GINCO: News/Reporting
#
#      Support  Confidence       Lift  \
# 4   0.017365    0.515152  26.543860
# 1   0.024259    0.593750  15.500833
# 3   0.027324    0.775362  13.201386
# 9   0.015322    0.606061   9.093231
# 0   0.039326    0.740385   5.439674
# 7   0.036517    0.798883   4.469178
# 8   0.025026    0.823529   4.369839
# 2   0.018131    0.739583   3.924402
# 6   0.039837    0.669528   3.745530
# 5   0.140960    0.761379   3.195671
# 10  0.031920    0.753012   3.160552
#
#                                           Full_result
# 4   [(GINCO: Legal/Regulation, CORE_sub: Legal ter...
# 1   [(GINCO: Forum, CORE_sub: Discussion Forum), 0...
# 3   [(CORE_sub: How-to, GINCO: Instruction), 0.027...
# 9   [(CORE_sub: Short Story, GINCO: Other), 0.0153...
# 0   [(GINCO: Promotion, CORE_sub: Description with...
# 7   [(GINCO: Opinion/Argumentation, CORE_sub: Pers...
# 8   [(GINCO: Information/Explanation, CORE_sub: Re...
# 2   [(GINCO: Information/Explanation, CORE_sub: En...
# 6   [(CORE_sub: Opinion Blog, GINCO: Opinion/Argum...
# 5   [(CORE_sub: News Report/Blog, GINCO: News/Repo...
# 10  [(CORE_sub: Sports Report, GINCO: News/Reporti...

# %%
CORE_sub_CORE_main_df = compare_with_apriori(merged_df, "CORE_main", "CORE_sub")
CORE_sub_CORE_main_df
# Out:
#                          Left_Hand_Side  \
# 18                    CORE_main: Spoken
# 0       CORE_main: How-To/Instructional
# 8     CORE_main: Interactive Discussion
# 7   CORE_main: Informational Persuasion
# 9       CORE_sub: Question/Answer Forum
# 14                     CORE_sub: Advice
# 15               CORE_sub: Opinion Blog
# 17                    CORE_sub: Reviews
# 16    CORE_sub: Religious Blogs/Sermons
# 13              CORE_sub: Sports Report
# 12                CORE_sub: Short Story
# 10                 CORE_main: Narrative
# 11              CORE_sub: Personal Blog
# 5                 CORE_sub: Legal terms
# 6            CORE_sub: Research Article
# 3        CORE_sub: Encyclopedia Article
# 2      CORE_sub: Description of a Thing
# 4            CORE_sub: Information Blog
# 1     CORE_sub: Description of a Person
#
#                                      Right_Hand_Side   Support  Confidence  \
# 18                               CORE_sub: Interview  0.016854    0.594595
# 0                                   CORE_sub: How-to  0.029877    0.754839
# 8                         CORE_sub: Discussion Forum  0.033963    0.661692
# 7          CORE_sub: Description with Intent to Sell  0.038304    0.806452
# 9                  CORE_main: Interactive Discussion  0.012513    0.662162
# 14                                CORE_main: Opinion  0.011491    0.882353
# 15                                CORE_main: Opinion  0.050051    0.841202
# 17                                CORE_main: Opinion  0.026302    0.830645
# 16                                CORE_main: Opinion  0.012513    0.777778
# 13                              CORE_main: Narrative  0.040858    0.963855
# 12                              CORE_main: Narrative  0.021706    0.858586
# 10                        CORE_sub: News Report/Blog  0.157303    0.553459
# 11                              CORE_main: Narrative  0.037538    0.821229
# 5   CORE_main: Informational Description/Explanation  0.033453    0.992424
# 6   CORE_main: Informational Description/Explanation  0.029877    0.983193
# 3   CORE_main: Informational Description/Explanation  0.023493    0.958333
# 2   CORE_main: Informational Description/Explanation  0.200715    0.924706
# 4   CORE_main: Informational Description/Explanation  0.034729    0.829268
# 1   CORE_main: Informational Description/Explanation  0.012257    0.676056
#
#          Lift                                        Full_result
# 18  24.509815  [(CORE_sub: Interview, CORE_main: Spoken), 0.0...
# 0   21.419916  [(CORE_main: How-To/Instructional, CORE_sub: H...
# 8   16.194900  [(CORE_main: Interactive Discussion, CORE_sub:...
# 7   15.183002  [(CORE_main: Informational Persuasion, CORE_su...
# 9   12.900632  [(CORE_sub: Question/Answer Forum, CORE_main: ...
# 14   7.729964  [(CORE_sub: Advice, CORE_main: Opinion), 0.011...
# 15   7.369454  [(CORE_sub: Opinion Blog, CORE_main: Opinion),...
# 17   7.276972  [(CORE_sub: Reviews, CORE_main: Opinion), 0.02...
# 16   6.813821  [(CORE_sub: Religious Blogs/Sermons, CORE_main...
# 13   3.391247  [(CORE_sub: Sports Report, CORE_main: Narrativ...
# 12   3.020865  [(CORE_sub: Short Story, CORE_main: Narrative)...
# 10   2.989443  [(CORE_main: Narrative, CORE_sub: News Report/...
# 11   2.889428  [(CORE_sub: Personal Blog, CORE_main: Narrativ...
# 5    2.447313  [(CORE_main: Informational Description/Explana...
# 6    2.424550  [(CORE_main: Informational Description/Explana...
# 3    2.363245  [(CORE_main: Informational Description/Explana...
# 2    2.280320  [(CORE_main: Informational Description/Explana...
# 4    2.044971  [(CORE_main: Informational Description/Explana...
# 1    1.667152  [(CORE_main: Informational Description/Explana...

# %% [markdown]
# # Analysing the correlation of labels with the chi-square test

# %% [markdown]
# The Chi-square test is one of the statistical tests we can use to decide whether there is a correlation between the categorical variables by analysing the relationship between the observed and expected values.
#
# Pearson’s chi-squared test is a hypothesis test that is used to determine whether there is a significant association between two categorical variables in the data. The test involves two hypotheses (H0 & H1):
# - H0 : The two categorical variables have no relationship (independent)
# - H1 : There is a relationship (dependent) between two categorical variables
#
# So as a null hypothesis, we keep the positive aspect of the test and in the alternate hypothesis, we keep the negative aspect. The positive aspect of chi-square is that there should not be any correlation because correlation can result in overfitting of the machine learning algorithm. The negative is that there is a correlation between the two categorical columns.

# %%
merged_df.head(2)
# Out:
#    index                      FTD                  GINCO_downcast  \
# 0      0  FTD: A1 (argumentative)           GINCO: News/Reporting
# 1      1  FTD: A1 (argumentative)  GINCO: Information/Explanation
#
#               CORE_main                    CORE_sub
# 0  CORE_main: Narrative  CORE_sub: News Report/Blog
# 1    CORE_main: Opinion      CORE_sub: Opinion Blog

# %%
# Create a constingency table for two schemata (two columns)
FTD_GINCO_comparison = pd.crosstab(merged_df["FTD"], merged_df["GINCO_downcast"])

FTD_GINCO_comparison
# Out:
# GINCO_downcast           GINCO: Forum  GINCO: Information/Explanation  \
# FTD
# FTD: A1 (argumentative)            58                             132
# FTD: A11 (personal)                41                               6
# FTD: A12 (promotion)               11                              91
# FTD: A14 (academic)                 1                              88
# FTD: A16 (information)              4                             304
# FTD: A17 (review)                  18                              20
# FTD: A4 (fiction)                   0                              20
# FTD: A7 (instruction)              17                              37
# FTD: A8 (news)                      0                              16
# FTD: A9 (legal)                     0                              24
#
# GINCO_downcast           GINCO: Instruction  GINCO: Legal/Regulation  \
# FTD
# FTD: A1 (argumentative)                   1                        3
# FTD: A11 (personal)                       3                        0
# FTD: A12 (promotion)                     17                        0
# FTD: A14 (academic)                       0                        1
# FTD: A16 (information)                    1                        1
# FTD: A17 (review)                         0                        0
# FTD: A4 (fiction)                         0                        0
# FTD: A7 (instruction)                   207                        0
# FTD: A8 (news)                            0                        2
# FTD: A9 (legal)                           1                       69
#
# GINCO_downcast           GINCO: List of Summaries/Excerpts  \
# FTD
# FTD: A1 (argumentative)                                 57
# FTD: A11 (personal)                                     15
# FTD: A12 (promotion)                                    58
# FTD: A14 (academic)                                      2
# FTD: A16 (information)                                  26
# FTD: A17 (review)                                       53
# FTD: A4 (fiction)                                        3
# FTD: A7 (instruction)                                   26
# FTD: A8 (news)                                          54
# FTD: A9 (legal)                                          1
#
# GINCO_downcast           GINCO: News/Reporting  GINCO: Opinion/Argumentation  \
# FTD
# FTD: A1 (argumentative)                    225                           284
# FTD: A11 (personal)                          6                           192
# FTD: A12 (promotion)                        66                            29
# FTD: A14 (academic)                          6                             7
# FTD: A16 (information)                      37                            23
# FTD: A17 (review)                           71                            97
# FTD: A4 (fiction)                            2                            37
# FTD: A7 (instruction)                       10                            17
# FTD: A8 (news)                             506                            14
# FTD: A9 (legal)                              4                             0
#
# GINCO_downcast           GINCO: Other  GINCO: Promotion
# FTD
# FTD: A1 (argumentative)            54                17
# FTD: A11 (personal)                25                 0
# FTD: A12 (promotion)               44               408
# FTD: A14 (academic)                 3                 0
# FTD: A16 (information)             10                15
# FTD: A17 (review)                  16                64
# FTD: A4 (fiction)                  65                 0
# FTD: A7 (instruction)              26                26
# FTD: A8 (news)                      7                 3
# FTD: A9 (legal)                    11                 0

# %%
# Add sum of values in the row
FTD_GINCO_comparison['Row_total'] = FTD_GINCO_comparison.apply(np.sum, axis=1)

FTD_GINCO_comparison
# Out:
# GINCO_downcast           GINCO: Forum  GINCO: Information/Explanation  \
# FTD
# FTD: A1 (argumentative)            58                             132
# FTD: A11 (personal)                41                               6
# FTD: A12 (promotion)               11                              91
# FTD: A14 (academic)                 1                              88
# FTD: A16 (information)              4                             304
# FTD: A17 (review)                  18                              20
# FTD: A4 (fiction)                   0                              20
# FTD: A7 (instruction)              17                              37
# FTD: A8 (news)                      0                              16
# FTD: A9 (legal)                     0                              24
#
# GINCO_downcast           GINCO: Instruction  GINCO: Legal/Regulation  \
# FTD
# FTD: A1 (argumentative)                   1                        3
# FTD: A11 (personal)                       3                        0
# FTD: A12 (promotion)                     17                        0
# FTD: A14 (academic)                       0                        1
# FTD: A16 (information)                    1                        1
# FTD: A17 (review)                         0                        0
# FTD: A4 (fiction)                         0                        0
# FTD: A7 (instruction)                   207                        0
# FTD: A8 (news)                            0                        2
# FTD: A9 (legal)                           1                       69
#
# GINCO_downcast           GINCO: List of Summaries/Excerpts  \
# FTD
# FTD: A1 (argumentative)                                 57
# FTD: A11 (personal)                                     15
# FTD: A12 (promotion)                                    58
# FTD: A14 (academic)                                      2
# FTD: A16 (information)                                  26
# FTD: A17 (review)                                       53
# FTD: A4 (fiction)                                        3
# FTD: A7 (instruction)                                   26
# FTD: A8 (news)                                          54
# FTD: A9 (legal)                                          1
#
# GINCO_downcast           GINCO: News/Reporting  GINCO: Opinion/Argumentation  \
# FTD
# FTD: A1 (argumentative)                    225                           284
# FTD: A11 (personal)                          6                           192
# FTD: A12 (promotion)                        66                            29
# FTD: A14 (academic)                          6                             7
# FTD: A16 (information)                      37                            23
# FTD: A17 (review)                           71                            97
# FTD: A4 (fiction)                            2                            37
# FTD: A7 (instruction)                       10                            17
# FTD: A8 (news)                             506                            14
# FTD: A9 (legal)                              4                             0
#
# GINCO_downcast           GINCO: Other  GINCO: Promotion  Row_total
# FTD
# FTD: A1 (argumentative)            54                17        831
# FTD: A11 (personal)                25                 0        288
# FTD: A12 (promotion)               44               408        724
# FTD: A14 (academic)                 3                 0        108
# FTD: A16 (information)             10                15        421
# FTD: A17 (review)                  16                64        339
# FTD: A4 (fiction)                  65                 0        127
# FTD: A7 (instruction)              26                26        366
# FTD: A8 (news)                      7                 3        602
# FTD: A9 (legal)                    11                 0        110

# %%
# Add sum of columns
FTD_GINCO_comparison.loc['Column_total']= FTD_GINCO_comparison.sum()

FTD_GINCO_comparison
# Out:
# GINCO_downcast           GINCO: Forum  GINCO: Information/Explanation  \
# FTD
# FTD: A1 (argumentative)            58                             132
# FTD: A11 (personal)                41                               6
# FTD: A12 (promotion)               11                              91
# FTD: A14 (academic)                 1                              88
# FTD: A16 (information)              4                             304
# FTD: A17 (review)                  18                              20
# FTD: A4 (fiction)                   0                              20
# FTD: A7 (instruction)              17                              37
# FTD: A8 (news)                      0                              16
# FTD: A9 (legal)                     0                              24
# Column_total                      150                             738
#
# GINCO_downcast           GINCO: Instruction  GINCO: Legal/Regulation  \
# FTD
# FTD: A1 (argumentative)                   1                        3
# FTD: A11 (personal)                       3                        0
# FTD: A12 (promotion)                     17                        0
# FTD: A14 (academic)                       0                        1
# FTD: A16 (information)                    1                        1
# FTD: A17 (review)                         0                        0
# FTD: A4 (fiction)                         0                        0
# FTD: A7 (instruction)                   207                        0
# FTD: A8 (news)                            0                        2
# FTD: A9 (legal)                           1                       69
# Column_total                            230                       76
#
# GINCO_downcast           GINCO: List of Summaries/Excerpts  \
# FTD
# FTD: A1 (argumentative)                                 57
# FTD: A11 (personal)                                     15
# FTD: A12 (promotion)                                    58
# FTD: A14 (academic)                                      2
# FTD: A16 (information)                                  26
# FTD: A17 (review)                                       53
# FTD: A4 (fiction)                                        3
# FTD: A7 (instruction)                                   26
# FTD: A8 (news)                                          54
# FTD: A9 (legal)                                          1
# Column_total                                           295
#
# GINCO_downcast           GINCO: News/Reporting  GINCO: Opinion/Argumentation  \
# FTD
# FTD: A1 (argumentative)                    225                           284
# FTD: A11 (personal)                          6                           192
# FTD: A12 (promotion)                        66                            29
# FTD: A14 (academic)                          6                             7
# FTD: A16 (information)                      37                            23
# FTD: A17 (review)                           71                            97
# FTD: A4 (fiction)                            2                            37
# FTD: A7 (instruction)                       10                            17
# FTD: A8 (news)                             506                            14
# FTD: A9 (legal)                              4                             0
# Column_total                               933                           700
#
# GINCO_downcast           GINCO: Other  GINCO: Promotion  Row_total
# FTD
# FTD: A1 (argumentative)            54                17        831
# FTD: A11 (personal)                25                 0        288
# FTD: A12 (promotion)               44               408        724
# FTD: A14 (academic)                 3                 0        108
# FTD: A16 (information)             10                15        421
# FTD: A17 (review)                  16                64        339
# FTD: A4 (fiction)                  65                 0        127
# FTD: A7 (instruction)              26                26        366
# FTD: A8 (news)                      7                 3        602
# FTD: A9 (legal)                    11                 0        110
# Column_total                      261               533       3916

# %%
pairs = FTD_GINCO_comparison.iloc[].stack().index.values
pairs
# Out:
# array([('FTD: A1 (argumentative)', 'GINCO: Forum'),
#        ('FTD: A1 (argumentative)', 'GINCO: Information/Explanation'),
#        ('FTD: A1 (argumentative)', 'GINCO: Instruction'),
#        ('FTD: A1 (argumentative)', 'GINCO: Legal/Regulation'),
#        ('FTD: A1 (argumentative)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A1 (argumentative)', 'GINCO: News/Reporting'),
#        ('FTD: A1 (argumentative)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A1 (argumentative)', 'GINCO: Other'),
#        ('FTD: A1 (argumentative)', 'GINCO: Promotion'),
#        ('FTD: A1 (argumentative)', 'Row_total'),
#        ('FTD: A11 (personal)', 'GINCO: Forum'),
#        ('FTD: A11 (personal)', 'GINCO: Information/Explanation'),
#        ('FTD: A11 (personal)', 'GINCO: Instruction'),
#        ('FTD: A11 (personal)', 'GINCO: Legal/Regulation'),
#        ('FTD: A11 (personal)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A11 (personal)', 'GINCO: News/Reporting'),
#        ('FTD: A11 (personal)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A11 (personal)', 'GINCO: Other'),
#        ('FTD: A11 (personal)', 'GINCO: Promotion'),
#        ('FTD: A11 (personal)', 'Row_total'),
#        ('FTD: A12 (promotion)', 'GINCO: Forum'),
#        ('FTD: A12 (promotion)', 'GINCO: Information/Explanation'),
#        ('FTD: A12 (promotion)', 'GINCO: Instruction'),
#        ('FTD: A12 (promotion)', 'GINCO: Legal/Regulation'),
#        ('FTD: A12 (promotion)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A12 (promotion)', 'GINCO: News/Reporting'),
#        ('FTD: A12 (promotion)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A12 (promotion)', 'GINCO: Other'),
#        ('FTD: A12 (promotion)', 'GINCO: Promotion'),
#        ('FTD: A12 (promotion)', 'Row_total'),
#        ('FTD: A14 (academic)', 'GINCO: Forum'),
#        ('FTD: A14 (academic)', 'GINCO: Information/Explanation'),
#        ('FTD: A14 (academic)', 'GINCO: Instruction'),
#        ('FTD: A14 (academic)', 'GINCO: Legal/Regulation'),
#        ('FTD: A14 (academic)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A14 (academic)', 'GINCO: News/Reporting'),
#        ('FTD: A14 (academic)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A14 (academic)', 'GINCO: Other'),
#        ('FTD: A14 (academic)', 'GINCO: Promotion'),
#        ('FTD: A14 (academic)', 'Row_total'),
#        ('FTD: A16 (information)', 'GINCO: Forum'),
#        ('FTD: A16 (information)', 'GINCO: Information/Explanation'),
#        ('FTD: A16 (information)', 'GINCO: Instruction'),
#        ('FTD: A16 (information)', 'GINCO: Legal/Regulation'),
#        ('FTD: A16 (information)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A16 (information)', 'GINCO: News/Reporting'),
#        ('FTD: A16 (information)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A16 (information)', 'GINCO: Other'),
#        ('FTD: A16 (information)', 'GINCO: Promotion'),
#        ('FTD: A16 (information)', 'Row_total'),
#        ('FTD: A17 (review)', 'GINCO: Forum'),
#        ('FTD: A17 (review)', 'GINCO: Information/Explanation'),
#        ('FTD: A17 (review)', 'GINCO: Instruction'),
#        ('FTD: A17 (review)', 'GINCO: Legal/Regulation'),
#        ('FTD: A17 (review)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A17 (review)', 'GINCO: News/Reporting'),
#        ('FTD: A17 (review)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A17 (review)', 'GINCO: Other'),
#        ('FTD: A17 (review)', 'GINCO: Promotion'),
#        ('FTD: A17 (review)', 'Row_total'),
#        ('FTD: A4 (fiction)', 'GINCO: Forum'),
#        ('FTD: A4 (fiction)', 'GINCO: Information/Explanation'),
#        ('FTD: A4 (fiction)', 'GINCO: Instruction'),
#        ('FTD: A4 (fiction)', 'GINCO: Legal/Regulation'),
#        ('FTD: A4 (fiction)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A4 (fiction)', 'GINCO: News/Reporting'),
#        ('FTD: A4 (fiction)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A4 (fiction)', 'GINCO: Other'),
#        ('FTD: A4 (fiction)', 'GINCO: Promotion'),
#        ('FTD: A4 (fiction)', 'Row_total'),
#        ('FTD: A7 (instruction)', 'GINCO: Forum'),
#        ('FTD: A7 (instruction)', 'GINCO: Information/Explanation'),
#        ('FTD: A7 (instruction)', 'GINCO: Instruction'),
#        ('FTD: A7 (instruction)', 'GINCO: Legal/Regulation'),
#        ('FTD: A7 (instruction)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A7 (instruction)', 'GINCO: News/Reporting'),
#        ('FTD: A7 (instruction)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A7 (instruction)', 'GINCO: Other'),
#        ('FTD: A7 (instruction)', 'GINCO: Promotion'),
#        ('FTD: A7 (instruction)', 'Row_total'),
#        ('FTD: A8 (news)', 'GINCO: Forum'),
#        ('FTD: A8 (news)', 'GINCO: Information/Explanation'),
#        ('FTD: A8 (news)', 'GINCO: Instruction'),
#        ('FTD: A8 (news)', 'GINCO: Legal/Regulation'),
#        ('FTD: A8 (news)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A8 (news)', 'GINCO: News/Reporting'),
#        ('FTD: A8 (news)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A8 (news)', 'GINCO: Other'),
#        ('FTD: A8 (news)', 'GINCO: Promotion'),
#        ('FTD: A8 (news)', 'Row_total'),
#        ('FTD: A9 (legal)', 'GINCO: Forum'),
#        ('FTD: A9 (legal)', 'GINCO: Information/Explanation'),
#        ('FTD: A9 (legal)', 'GINCO: Instruction'),
#        ('FTD: A9 (legal)', 'GINCO: Legal/Regulation'),
#        ('FTD: A9 (legal)', 'GINCO: List of Summaries/Excerpts'),
#        ('FTD: A9 (legal)', 'GINCO: News/Reporting'),
#        ('FTD: A9 (legal)', 'GINCO: Opinion/Argumentation'),
#        ('FTD: A9 (legal)', 'GINCO: Other'),
#        ('FTD: A9 (legal)', 'GINCO: Promotion'),
#        ('FTD: A9 (legal)', 'Row_total'), ('Column_total', 'GINCO: Forum'),
#        ('Column_total', 'GINCO: Information/Explanation'),
#        ('Column_total', 'GINCO: Instruction'),
#        ('Column_total', 'GINCO: Legal/Regulation'),
#        ('Column_total', 'GINCO: List of Summaries/Excerpts'),
#        ('Column_total', 'GINCO: News/Reporting'),
#        ('Column_total', 'GINCO: Opinion/Argumentation'),
#        ('Column_total', 'GINCO: Other'),
#        ('Column_total', 'GINCO: Promotion'),
#        ('Column_total', 'Row_total')], dtype=object)

# %%
# Remove "Column total"

# %%
# To calculate dependency of each label pair, you need to create a table, as seen in https://link.springer.com/article/10.1007/s10994-012-5312-9/tables/1

# Example for dependency of Forum and FTD Argumentative

# Calculate a - labels occured together
a = FTD_GINCO_comparison.loc["FTD: A1 (argumentative)", "GINCO: Forum"]
print(a)

# Calculate b - number of the FTD label that did not occured in combination with the GINCO label
b = FTD_GINCO_comparison.loc["FTD: A1 (argumentative)", "Row_total"]-a
print(b)

# Calculate c - number of the GINCO label that did not occured in combination with the FTD label
c = FTD_GINCO_comparison.loc["Column_total", "GINCO: Forum"]-a
print(c)

# Calculate d - number of instances without these two labels
d = FTD_GINCO_comparison.loc["Column_total", "Row_total"]-a-b-c
print(d)
# Out:
# 58
# 773
# 92
# 2993

# %%
# Calculate dependency based on the formula in https://link.springer.com/article/10.1007/s10994-012-5312-9
x = ((((a*d)-(b*c))**2)*(a+b+c+d))/((a+b)*(c+d)*(b+d)*(a+c))
x
# Out:
# 28.397244332005908

# %%
pair_list = []
value_list = []

for pair in pairs:
	# Calculate a - labels occured together
	a = FTD_GINCO_comparison.loc[pair[0], pair[1]]

	# Calculate b - number of the FTD label that did not occured in combination with the GINCO label
	b = FTD_GINCO_comparison.loc[pair[0], "Row_total"]-a

	# Calculate c - number of the GINCO label that did not occured in combination with the FTD label
	c = FTD_GINCO_comparison.loc["Column_total", pair[1]]-a

	# Calculate d - number of instances without these two labels
	d = FTD_GINCO_comparison.loc["Column_total", "Row_total"]-a-b-c

	x = ((((a*d)-(b*c))**2)*(a+b+c+d))/((a+b)*(c+d)*(b+d)*(a+c))

	pair_list.append(f"{pair[0]}, {pair[1]}")
	value_list.append(x)

# Create a df with results
FTD_GINCO_results = pd.DataFrame({"pair": pair_list, "dependency_value": value_list}).sort_values("dependency_value", ascending= False)

FTD_GINCO_results
# Out:
# /tmp/ipykernel_31253/399712551.py:17: RuntimeWarning: invalid value encountered in long_scalars
#   x = ((((a*d)-(b*c))**2)*(a+b+c+d))/((a+b)*(c+d)*(b+d)*(a+c))
#                                                   pair  dependency_value
# 93            FTD: A9 (legal), GINCO: Legal/Regulation       2197.463402
# 72           FTD: A7 (instruction), GINCO: Instruction       1876.031006
# 85               FTD: A8 (news), GINCO: News/Reporting       1421.777009
# 28              FTD: A12 (promotion), GINCO: Promotion       1380.065589
# 41   FTD: A16 (information), GINCO: Information/Exp...        878.289115
# ..                                                 ...               ...
# 105                Column_total, GINCO: News/Reporting               NaN
# 106         Column_total, GINCO: Opinion/Argumentation               NaN
# 107                         Column_total, GINCO: Other               NaN
# 108                     Column_total, GINCO: Promotion               NaN
# 109                            Column_total, Row_total               NaN
#
# [110 rows x 2 columns]

# %%
# Show top 30
FTD_GINCO_results.head(30)
# Out:
#                                                  pair  dependency_value
# 93           FTD: A9 (legal), GINCO: Legal/Regulation       2197.463402
# 72          FTD: A7 (instruction), GINCO: Instruction       1876.031006
# 85              FTD: A8 (news), GINCO: News/Reporting       1421.777009
# 28             FTD: A12 (promotion), GINCO: Promotion       1380.065589
# 41  FTD: A16 (information), GINCO: Information/Exp...        878.289115
# 16  FTD: A11 (personal), GINCO: Opinion/Argumentation        504.108089
# 67                    FTD: A4 (fiction), GINCO: Other        418.132802
# 31  FTD: A14 (academic), GINCO: Information/Explan...        284.897583
# 6   FTD: A1 (argumentative), GINCO: Opinion/Argume...        190.920030
# 81     FTD: A8 (news), GINCO: Information/Explanation        121.883716
# 8           FTD: A1 (argumentative), GINCO: Promotion        119.989552
# 86       FTD: A8 (news), GINCO: Opinion/Argumentation        117.167635
# 26  FTD: A12 (promotion), GINCO: Opinion/Argumenta...        116.394831
# 25        FTD: A12 (promotion), GINCO: News/Reporting        105.889630
# 88                   FTD: A8 (news), GINCO: Promotion        104.019095
# 75       FTD: A7 (instruction), GINCO: News/Reporting         98.975193
# 10                  FTD: A11 (personal), GINCO: Forum         91.373853
# 15         FTD: A11 (personal), GINCO: News/Reporting         80.968723
# 2         FTD: A1 (argumentative), GINCO: Instruction         63.150962
# 45      FTD: A16 (information), GINCO: News/Reporting         58.767209
# 11  FTD: A11 (personal), GINCO: Information/Explan...         57.110615
# 46  FTD: A16 (information), GINCO: Opinion/Argumen...         49.504699
# 18              FTD: A11 (personal), GINCO: Promotion         48.977104
# 76  FTD: A7 (instruction), GINCO: Opinion/Argument...         48.141996
# 82                 FTD: A8 (news), GINCO: Instruction         44.387346
# 51  FTD: A17 (review), GINCO: Information/Explanation         40.669938
# 48           FTD: A16 (information), GINCO: Promotion         40.502591
# 65           FTD: A4 (fiction), GINCO: News/Reporting         35.805764
# 54  FTD: A17 (review), GINCO: List of Summaries/Ex...         34.965343
# 87                       FTD: A8 (news), GINCO: Other         34.618856

# %%
# Remove NaN
FTD_GINCO_results = FTD_GINCO_results.dropna()
FTD_GINCO_results
# Out:
#                                                  pair  dependency_value
# 93           FTD: A9 (legal), GINCO: Legal/Regulation       2197.463402
# 72          FTD: A7 (instruction), GINCO: Instruction       1876.031006
# 85              FTD: A8 (news), GINCO: News/Reporting       1421.777009
# 28             FTD: A12 (promotion), GINCO: Promotion       1380.065589
# 41  FTD: A16 (information), GINCO: Information/Exp...        878.289115
# ..                                                ...               ...
# 27                 FTD: A12 (promotion), GINCO: Other          0.493019
# 24  FTD: A12 (promotion), GINCO: List of Summaries...          0.291166
# 77                FTD: A7 (instruction), GINCO: Other          0.124999
# 74  FTD: A7 (instruction), GINCO: List of Summarie...          0.106856
# 7               FTD: A1 (argumentative), GINCO: Other          0.047160
#
# [90 rows x 2 columns]

# %%
GINCO_labels = list(merged_df["GINCO_downcast"].unique())
FTD_labels = list(merged_df["FTD"].unique())
# Out:
# [('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('N', ' '),
#  ('e', '('),
#  ('w', 'a'),
#  ('s', 'r'),
#  ('/', 'g'),
#  ('R', 'u'),
#  ('e', 'm'),
#  ('p', 'e'),
#  ('o', 'n'),
#  ('r', 't'),
#  ('t', 'a'),
#  ('i', 't'),
#  ('n', 'i'),
#  ('g', 'v'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '4'),
#  ('N', ' '),
#  ('e', '('),
#  ('w', 'f'),
#  ('s', 'i'),
#  ('/', 'c'),
#  ('R', 't'),
#  ('e', 'i'),
#  ('p', 'o'),
#  ('o', 'n'),
#  ('r', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('N', '2'),
#  ('e', ' '),
#  ('w', '('),
#  ('s', 'p'),
#  ('/', 'r'),
#  ('R', 'o'),
#  ('e', 'm'),
#  ('p', 'o'),
#  ('o', 't'),
#  ('r', 'i'),
#  ('t', 'o'),
#  ('i', 'n'),
#  ('n', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '8'),
#  ('N', ' '),
#  ('e', '('),
#  ('w', 'n'),
#  ('s', 'e'),
#  ('/', 'w'),
#  ('R', 's'),
#  ('e', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('N', '1'),
#  ('e', ' '),
#  ('w', '('),
#  ('s', 'p'),
#  ('/', 'e'),
#  ('R', 'r'),
#  ('e', 's'),
#  ('p', 'o'),
#  ('o', 'n'),
#  ('r', 'a'),
#  ('t', 'l'),
#  ('i', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '7'),
#  ('N', ' '),
#  ('e', '('),
#  ('w', 'i'),
#  ('s', 'n'),
#  ('/', 's'),
#  ('R', 't'),
#  ('e', 'r'),
#  ('p', 'u'),
#  ('o', 'c'),
#  ('r', 't'),
#  ('t', 'i'),
#  ('i', 'o'),
#  ('n', 'n'),
#  ('g', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '9'),
#  ('N', ' '),
#  ('e', '('),
#  ('w', 'l'),
#  ('s', 'e'),
#  ('/', 'g'),
#  ('R', 'a'),
#  ('e', 'l'),
#  ('p', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('N', '4'),
#  ('e', ' '),
#  ('w', '('),
#  ('s', 'a'),
#  ('/', 'c'),
#  ('R', 'a'),
#  ('e', 'd'),
#  ('p', 'e'),
#  ('o', 'm'),
#  ('r', 'i'),
#  ('t', 'c'),
#  ('i', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('N', '6'),
#  ('e', ' '),
#  ('w', '('),
#  ('s', 'i'),
#  ('/', 'n'),
#  ('R', 'f'),
#  ('e', 'o'),
#  ('p', 'r'),
#  ('o', 'm'),
#  ('r', 'a'),
#  ('t', 't'),
#  ('i', 'i'),
#  ('n', 'o'),
#  ('g', 'n'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('N', '7'),
#  ('e', ' '),
#  ('w', '('),
#  ('s', 'r'),
#  ('/', 'e'),
#  ('R', 'v'),
#  ('e', 'i'),
#  ('p', 'e'),
#  ('o', 'w'),
#  ('r', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('I', ' '),
#  ('n', '('),
#  ('f', 'a'),
#  ('o', 'r'),
#  ('r', 'g'),
#  ('m', 'u'),
#  ('a', 'm'),
#  ('t', 'e'),
#  ('i', 'n'),
#  ('o', 't'),
#  ('n', 'a'),
#  ('/', 't'),
#  ('E', 'i'),
#  ('x', 'v'),
#  ('p', 'e'),
#  ('l', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '4'),
#  ('I', ' '),
#  ('n', '('),
#  ('f', 'f'),
#  ('o', 'i'),
#  ('r', 'c'),
#  ('m', 't'),
#  ('a', 'i'),
#  ('t', 'o'),
#  ('i', 'n'),
#  ('o', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('I', '2'),
#  ('n', ' '),
#  ('f', '('),
#  ('o', 'p'),
#  ('r', 'r'),
#  ('m', 'o'),
#  ('a', 'm'),
#  ('t', 'o'),
#  ('i', 't'),
#  ('o', 'i'),
#  ('n', 'o'),
#  ('/', 'n'),
#  ('E', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '8'),
#  ('I', ' '),
#  ('n', '('),
#  ('f', 'n'),
#  ('o', 'e'),
#  ('r', 'w'),
#  ('m', 's'),
#  ('a', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('I', '1'),
#  ('n', ' '),
#  ('f', '('),
#  ('o', 'p'),
#  ('r', 'e'),
#  ('m', 'r'),
#  ('a', 's'),
#  ('t', 'o'),
#  ('i', 'n'),
#  ('o', 'a'),
#  ('n', 'l'),
#  ('/', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '7'),
#  ('I', ' '),
#  ('n', '('),
#  ('f', 'i'),
#  ('o', 'n'),
#  ('r', 's'),
#  ('m', 't'),
#  ('a', 'r'),
#  ('t', 'u'),
#  ('i', 'c'),
#  ('o', 't'),
#  ('n', 'i'),
#  ('/', 'o'),
#  ('E', 'n'),
#  ('x', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '9'),
#  ('I', ' '),
#  ('n', '('),
#  ('f', 'l'),
#  ('o', 'e'),
#  ('r', 'g'),
#  ('m', 'a'),
#  ('a', 'l'),
#  ('t', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('I', '4'),
#  ('n', ' '),
#  ('f', '('),
#  ('o', 'a'),
#  ('r', 'c'),
#  ('m', 'a'),
#  ('a', 'd'),
#  ('t', 'e'),
#  ('i', 'm'),
#  ('o', 'i'),
#  ('n', 'c'),
#  ('/', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('I', '6'),
#  ('n', ' '),
#  ('f', '('),
#  ('o', 'i'),
#  ('r', 'n'),
#  ('m', 'f'),
#  ('a', 'o'),
#  ('t', 'r'),
#  ('i', 'm'),
#  ('o', 'a'),
#  ('n', 't'),
#  ('/', 'i'),
#  ('E', 'o'),
#  ('x', 'n'),
#  ('p', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('I', '7'),
#  ('n', ' '),
#  ('f', '('),
#  ('o', 'r'),
#  ('r', 'e'),
#  ('m', 'v'),
#  ('a', 'i'),
#  ('t', 'e'),
#  ('i', 'w'),
#  ('o', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', ' '),
#  ('p', '('),
#  ('i', 'a'),
#  ('n', 'r'),
#  ('i', 'g'),
#  ('o', 'u'),
#  ('n', 'm'),
#  ('/', 'e'),
#  ('A', 'n'),
#  ('r', 't'),
#  ('g', 'a'),
#  ('u', 't'),
#  ('m', 'i'),
#  ('e', 'v'),
#  ('n', 'e'),
#  ('t', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '4'),
#  ('O', ' '),
#  ('p', '('),
#  ('i', 'f'),
#  ('n', 'i'),
#  ('i', 'c'),
#  ('o', 't'),
#  ('n', 'i'),
#  ('/', 'o'),
#  ('A', 'n'),
#  ('r', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '2'),
#  ('p', ' '),
#  ('i', '('),
#  ('n', 'p'),
#  ('i', 'r'),
#  ('o', 'o'),
#  ('n', 'm'),
#  ('/', 'o'),
#  ('A', 't'),
#  ('r', 'i'),
#  ('g', 'o'),
#  ('u', 'n'),
#  ('m', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '8'),
#  ('O', ' '),
#  ('p', '('),
#  ('i', 'n'),
#  ('n', 'e'),
#  ('i', 'w'),
#  ('o', 's'),
#  ('n', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '1'),
#  ('p', ' '),
#  ('i', '('),
#  ('n', 'p'),
#  ('i', 'e'),
#  ('o', 'r'),
#  ('n', 's'),
#  ('/', 'o'),
#  ('A', 'n'),
#  ('r', 'a'),
#  ('g', 'l'),
#  ('u', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '7'),
#  ('O', ' '),
#  ('p', '('),
#  ('i', 'i'),
#  ('n', 'n'),
#  ('i', 's'),
#  ('o', 't'),
#  ('n', 'r'),
#  ('/', 'u'),
#  ('A', 'c'),
#  ('r', 't'),
#  ('g', 'i'),
#  ('u', 'o'),
#  ('m', 'n'),
#  ('e', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '9'),
#  ('O', ' '),
#  ('p', '('),
#  ('i', 'l'),
#  ('n', 'e'),
#  ('i', 'g'),
#  ('o', 'a'),
#  ('n', 'l'),
#  ('/', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '4'),
#  ('p', ' '),
#  ('i', '('),
#  ('n', 'a'),
#  ('i', 'c'),
#  ('o', 'a'),
#  ('n', 'd'),
#  ('/', 'e'),
#  ('A', 'm'),
#  ('r', 'i'),
#  ('g', 'c'),
#  ('u', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '6'),
#  ('p', ' '),
#  ('i', '('),
#  ('n', 'i'),
#  ('i', 'n'),
#  ('o', 'f'),
#  ('n', 'o'),
#  ('/', 'r'),
#  ('A', 'm'),
#  ('r', 'a'),
#  ('g', 't'),
#  ('u', 'i'),
#  ('m', 'o'),
#  ('e', 'n'),
#  ('n', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '7'),
#  ('p', ' '),
#  ('i', '('),
#  ('n', 'r'),
#  ('i', 'e'),
#  ('o', 'v'),
#  ('n', 'i'),
#  ('/', 'e'),
#  ('A', 'w'),
#  ('r', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('L', ' '),
#  ('i', '('),
#  ('s', 'a'),
#  ('t', 'r'),
#  (' ', 'g'),
#  ('o', 'u'),
#  ('f', 'm'),
#  (' ', 'e'),
#  ('S', 'n'),
#  ('u', 't'),
#  ('m', 'a'),
#  ('m', 't'),
#  ('a', 'i'),
#  ('r', 'v'),
#  ('i', 'e'),
#  ('e', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '4'),
#  ('L', ' '),
#  ('i', '('),
#  ('s', 'f'),
#  ('t', 'i'),
#  (' ', 'c'),
#  ('o', 't'),
#  ('f', 'i'),
#  (' ', 'o'),
#  ('S', 'n'),
#  ('u', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('L', '2'),
#  ('i', ' '),
#  ('s', '('),
#  ('t', 'p'),
#  (' ', 'r'),
#  ('o', 'o'),
#  ('f', 'm'),
#  (' ', 'o'),
#  ('S', 't'),
#  ('u', 'i'),
#  ('m', 'o'),
#  ('m', 'n'),
#  ('a', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '8'),
#  ('L', ' '),
#  ('i', '('),
#  ('s', 'n'),
#  ('t', 'e'),
#  (' ', 'w'),
#  ('o', 's'),
#  ('f', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('L', '1'),
#  ('i', ' '),
#  ('s', '('),
#  ('t', 'p'),
#  (' ', 'e'),
#  ('o', 'r'),
#  ('f', 's'),
#  (' ', 'o'),
#  ('S', 'n'),
#  ('u', 'a'),
#  ('m', 'l'),
#  ('m', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '7'),
#  ('L', ' '),
#  ('i', '('),
#  ('s', 'i'),
#  ('t', 'n'),
#  (' ', 's'),
#  ('o', 't'),
#  ('f', 'r'),
#  (' ', 'u'),
#  ('S', 'c'),
#  ('u', 't'),
#  ('m', 'i'),
#  ('m', 'o'),
#  ('a', 'n'),
#  ('r', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '9'),
#  ('L', ' '),
#  ('i', '('),
#  ('s', 'l'),
#  ('t', 'e'),
#  (' ', 'g'),
#  ('o', 'a'),
#  ('f', 'l'),
#  (' ', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('L', '4'),
#  ('i', ' '),
#  ('s', '('),
#  ('t', 'a'),
#  (' ', 'c'),
#  ('o', 'a'),
#  ('f', 'd'),
#  (' ', 'e'),
#  ('S', 'm'),
#  ('u', 'i'),
#  ('m', 'c'),
#  ('m', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('L', '6'),
#  ('i', ' '),
#  ('s', '('),
#  ('t', 'i'),
#  (' ', 'n'),
#  ('o', 'f'),
#  ('f', 'o'),
#  (' ', 'r'),
#  ('S', 'm'),
#  ('u', 'a'),
#  ('m', 't'),
#  ('m', 'i'),
#  ('a', 'o'),
#  ('r', 'n'),
#  ('i', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('L', '7'),
#  ('i', ' '),
#  ('s', '('),
#  ('t', 'r'),
#  (' ', 'e'),
#  ('o', 'v'),
#  ('f', 'i'),
#  (' ', 'e'),
#  ('S', 'w'),
#  ('u', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', ' '),
#  ('t', '('),
#  ('h', 'a'),
#  ('e', 'r'),
#  ('r', 'g'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '4'),
#  ('O', ' '),
#  ('t', '('),
#  ('h', 'f'),
#  ('e', 'i'),
#  ('r', 'c'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '2'),
#  ('t', ' '),
#  ('h', '('),
#  ('e', 'p'),
#  ('r', 'r'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '8'),
#  ('O', ' '),
#  ('t', '('),
#  ('h', 'n'),
#  ('e', 'e'),
#  ('r', 'w'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '1'),
#  ('t', ' '),
#  ('h', '('),
#  ('e', 'p'),
#  ('r', 'e'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '7'),
#  ('O', ' '),
#  ('t', '('),
#  ('h', 'i'),
#  ('e', 'n'),
#  ('r', 's'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '9'),
#  ('O', ' '),
#  ('t', '('),
#  ('h', 'l'),
#  ('e', 'e'),
#  ('r', 'g'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '4'),
#  ('t', ' '),
#  ('h', '('),
#  ('e', 'a'),
#  ('r', 'c'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '6'),
#  ('t', ' '),
#  ('h', '('),
#  ('e', 'i'),
#  ('r', 'n'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('O', '7'),
#  ('t', ' '),
#  ('h', '('),
#  ('e', 'r'),
#  ('r', 'e'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('P', ' '),
#  ('r', '('),
#  ('o', 'a'),
#  ('m', 'r'),
#  ('o', 'g'),
#  ('t', 'u'),
#  ('i', 'm'),
#  ('o', 'e'),
#  ('n', 'n'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '4'),
#  ('P', ' '),
#  ('r', '('),
#  ('o', 'f'),
#  ('m', 'i'),
#  ('o', 'c'),
#  ('t', 't'),
#  ('i', 'i'),
#  ('o', 'o'),
#  ('n', 'n'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('P', '2'),
#  ('r', ' '),
#  ('o', '('),
#  ('m', 'p'),
#  ('o', 'r'),
#  ('t', 'o'),
#  ('i', 'm'),
#  ('o', 'o'),
#  ('n', 't'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '8'),
#  ('P', ' '),
#  ('r', '('),
#  ('o', 'n'),
#  ('m', 'e'),
#  ('o', 'w'),
#  ('t', 's'),
#  ('i', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('P', '1'),
#  ('r', ' '),
#  ('o', '('),
#  ('m', 'p'),
#  ('o', 'e'),
#  ('t', 'r'),
#  ('i', 's'),
#  ('o', 'o'),
#  ('n', 'n'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '7'),
#  ('P', ' '),
#  ('r', '('),
#  ('o', 'i'),
#  ('m', 'n'),
#  ('o', 's'),
#  ('t', 't'),
#  ('i', 'r'),
#  ('o', 'u'),
#  ('n', 'c'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '9'),
#  ('P', ' '),
#  ('r', '('),
#  ('o', 'l'),
#  ('m', 'e'),
#  ('o', 'g'),
#  ('t', 'a'),
#  ('i', 'l'),
#  ('o', ')'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('P', '4'),
#  ('r', ' '),
#  ('o', '('),
#  ('m', 'a'),
#  ('o', 'c'),
#  ('t', 'a'),
#  ('i', 'd'),
#  ('o', 'e'),
#  ('n', 'm'),
#  ('G', 'F'),
#  ('I', 'T'),
#  ('N', 'D'),
#  ('C', ':'),
#  ('O', ' '),
#  (':', 'A'),
#  (' ', '1'),
#  ('P', '6'),
#  ('r', ' '),
#  ('o', '('),
#  ...]

# %%
# Do this for all label pairs
for pair in
