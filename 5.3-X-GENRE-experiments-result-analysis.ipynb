# %%
import pandas as pd
import numpy as np

# %%
# Import the file with results
results = pd.read_csv("results/X-GENRE-Experiments-Results.csv", sep = "\t", index_col = 0)

results
# Out:
#                                      experiment   microF1   macroF1  \
# 0          testing-FTD-X-GENRE-on-SL-GINCO-test  0.569832  0.498112
# 1          testing-FTD-X-GENRE-on-MT-GINCO-test  0.569832  0.457568
# 2              testing-FTD-X-GENRE-on-CORE-test  0.477833  0.397299
# 3                    testing-FTD-X-GENRE-on-dev  0.814286  0.827740
# 4                   testing-FTD-X-GENRE-on-test  0.842857  0.851374
# 5           testing-FTD-X-GENRE-on-X-GENRE-test  0.635135  0.532467
# 6   MT-GINCO-classifier-tested-on-MT-GINCO-test  0.743017  0.722785
# 7   MT-GINCO-classifier-tested-on-SI-GINCO-test  0.731844  0.655184
# 8       MT-GINCO-classifier-tested-on-CORE-test  0.660099  0.552608
# 9        MT-GINCO-classifier-tested-on-FTD-test  0.736318  0.718093
# 10   MT-GINCO-classifier-tested-on-X-GENRE-test  0.697635  0.666822
# 11   MT-GINCO-classifier-tested-on-MT-GINCO-dev  0.765363  0.759041
# 12   SI-GINCO-classifier-tested-on-SI-GINCO-dev  0.670391  0.581713
# 13  SI-GINCO-classifier-tested-on-SI-GINCO-test  0.754190  0.750090
# 14  SI-GINCO-classifier-tested-on-MT-GINCO-test  0.675978  0.596419
# 15      SI-GINCO-classifier-tested-on-CORE-test  0.591133  0.521128
# 16       SI-GINCO-classifier-tested-on-FTD-test  0.725888  0.654365
# 17   SI-GINCO-classifier-tested-on-X-GENRE-test  0.672297  0.616866
# 18           CORE-classifier-tested-on-CORE-dev  0.763547  0.609151
# 19          CORE-classifier-tested-on-CORE-test  0.778325  0.626549
# 20      CORE-classifier-tested-on-SI-GINCO-test  0.374302  0.347626
# 21      CORE-classifier-tested-on-MT-GINCO-test  0.385475  0.393512
# 22           CORE-classifier-tested-on-FTD-test  0.495098  0.419347
# 23       CORE-classifier-tested-on-X-GENRE-test  0.550676  0.480781
#
#                                                y_true  \
# 0   {228: 'News', 12: 'Opinion/Argumentation', 617...
# 1   {2: 'Promotion', 3: 'News', 12: 'Opinion/Argum...
# 2   {216: 'Forum', 41678: 'Forum', 7171: 'News', 9...
# 3   {409: 'Instruction', 1051: 'Legal', 1473: 'Pro...
# 4   {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...
# 5   {0: 'Forum', 1: 'Forum', 2: 'News', 3: 'Prose/...
# 6   {2: 'Promotion', 3: 'News', 12: 'Opinion/Argum...
# 7   {228: 'News', 12: 'Opinion/Argumentation', 617...
# 8   {216: 'Forum', 41678: 'Forum', 7171: 'News', 9...
# 9   {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...
# 10  {0: 'Forum', 1: 'Forum', 2: 'News', 3: 'Prose/...
# 11  {1: 'Information/Explanation', 6: 'Promotion',...
# 12  {71: 'Promotion', 827: 'Promotion', 427: 'News...
# 13  {228: 'News', 12: 'Opinion/Argumentation', 617...
# 14  {2: 'Promotion', 3: 'News', 12: 'Opinion/Argum...
# 15  {216: 'Forum', 41678: 'Forum', 7171: 'News', 9...
# 16  {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...
# 17  {0: 'Forum', 1: 'Forum', 2: 'News', 3: 'Prose/...
# 18  {23139: 'Opinion/Argumentation', 630: 'Instruc...
# 19  {216: 'Forum', 41678: 'Forum', 7171: 'News', 9...
# 20  {228: 'News', 12: 'Opinion/Argumentation', 617...
# 21  {2: 'Promotion', 3: 'News', 12: 'Opinion/Argum...
# 22  {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...
# 23  {0: 'Forum', 1: 'Forum', 2: 'News', 3: 'Prose/...
#
#                                                y_pred trained_on  \
# 0   {228: 'Instruction', 12: 'Information/Explanat...        FTD
# 1   {2: 'Promotion', 3: 'News', 12: 'Information/E...        FTD
# 2   {216: 'Opinion/Argumentation', 41678: 'Instruc...        FTD
# 3   {409: 'Information/Explanation', 1051: 'Legal'...        FTD
# 4   {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...        FTD
# 5   {0: 'Opinion/Argumentation', 1: 'Instruction',...        FTD
# 6   {2: 'News', 3: 'News', 12: 'Other', 15: 'News'...   MT-GINCO
# 7   {228: 'News', 12: 'Other', 617: 'Promotion', 2...   MT-GINCO
# 8   {216: 'Forum', 41678: 'Instruction', 7171: 'Ne...   MT-GINCO
# 9   {439: 'Other', 1576: 'Promotion', 913: 'Prose/...   MT-GINCO
# 10  {0: 'Forum', 1: 'Instruction', 2: 'News', 3: '...   MT-GINCO
# 11  {1: 'News', 6: 'Promotion', 8: 'Promotion', 9:...   MT-GINCO
# 12  {71: 'Promotion', 827: 'Instruction', 427: 'Ne...   SI-GINCO
# 13  {228: 'News', 12: 'Other', 617: 'Promotion', 2...   SI-GINCO
# 14  {2: 'News', 3: 'News', 12: 'Other', 15: 'News'...   SI-GINCO
# 15  {216: 'Forum', 41678: 'Instruction', 7171: 'Ne...   SI-GINCO
# 16  {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...   SI-GINCO
# 17  {0: 'Forum', 1: 'Instruction', 2: 'News', 3: '...   SI-GINCO
# 18  {23139: 'Forum', 630: 'Instruction', 29214: 'I...       CORE
# 19  {216: 'Forum', 41678: 'Instruction', 7171: 'Ne...       CORE
# 20  {228: 'Information/Explanation', 12: 'Other', ...       CORE
# 21  {2: 'Information/Explanation', 3: 'News', 12: ...       CORE
# 22  {439: 'Instruction', 1576: 'Information/Explan...       CORE
# 23  {0: 'Forum', 1: 'Instruction', 2: 'News', 3: '...       CORE
#
#         tested_on
# 0        SL-GINCO
# 1        MT-GINCO
# 2            CORE
# 3         FTD-dev
# 4        FTD-test
# 5    X-GENRE-test
# 6   MT-GINCO-test
# 7   SI-GINCO-test
# 8       CORE-test
# 9        FTD-test
# 10   X-GENRE-test
# 11   MT-GINCO-dev
# 12   SI-GINCO-dev
# 13  SI-GINCO-test
# 14  MT-GINCO-test
# 15      CORE-test
# 16       FTD-test
# 17   X-GENRE-test
# 18       CORE-dev
# 19      CORE-test
# 20  SI-GINCO-test
# 21  MT-GINCO-test
# 22       FTD-test
# 23   X-GENRE-test

# %%
results.tested_on.unique()
# Out:
# array(['SL-GINCO', 'MT-GINCO', 'CORE', 'FTD-dev', 'FTD-test',
#        'X-GENRE-test', 'MT-GINCO-test', 'SI-GINCO-test', 'CORE-test',
#        'MT-GINCO-dev', 'SI-GINCO-dev', 'CORE-dev'], dtype=object)

# %%
results.trained_on.unique()
# Out:
# array(['FTD', 'MT-GINCO', 'SI-GINCO', 'CORE'], dtype=object)

# %%
# Edit the "tested_on" values so that they are the same as trained_on values.
# If the name does not include "-dev", the file is a "test" file
results["tested_on"] = [x.replace("-test", "") for x in results["tested_on"]]
results["tested_on"] = [x.replace("SL-GINCO", "SI-GINCO") for x in results["tested_on"]]

results.tested_on.unique()
# Out:
# array(['SI-GINCO', 'MT-GINCO', 'CORE', 'FTD-dev', 'FTD', 'X-GENRE',
#        'MT-GINCO-dev', 'SI-GINCO-dev', 'CORE-dev'], dtype=object)

# %% [markdown]
# ## Baseline results (In-dataset experiments results)

# %%
# Add a column with information whether the experiment is in-dataset
results["in-dataset"] = np.where(results["trained_on"] == results["tested_on"], "y", "n")

results.head()
# Out:
#                              experiment   microF1   macroF1  \
# 0  testing-FTD-X-GENRE-on-SL-GINCO-test  0.569832  0.498112
# 1  testing-FTD-X-GENRE-on-MT-GINCO-test  0.569832  0.457568
# 2      testing-FTD-X-GENRE-on-CORE-test  0.477833  0.397299
# 3            testing-FTD-X-GENRE-on-dev  0.814286  0.827740
# 4           testing-FTD-X-GENRE-on-test  0.842857  0.851374
#
#                                               y_true  \
# 0  {228: 'News', 12: 'Opinion/Argumentation', 617...
# 1  {2: 'Promotion', 3: 'News', 12: 'Opinion/Argum...
# 2  {216: 'Forum', 41678: 'Forum', 7171: 'News', 9...
# 3  {409: 'Instruction', 1051: 'Legal', 1473: 'Pro...
# 4  {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...
#
#                                               y_pred trained_on tested_on  \
# 0  {228: 'Instruction', 12: 'Information/Explanat...        FTD  SI-GINCO
# 1  {2: 'Promotion', 3: 'News', 12: 'Information/E...        FTD  MT-GINCO
# 2  {216: 'Opinion/Argumentation', 41678: 'Instruc...        FTD      CORE
# 3  {409: 'Information/Explanation', 1051: 'Legal'...        FTD   FTD-dev
# 4  {439: 'Promotion', 1576: 'Promotion', 913: 'Pr...        FTD       FTD
#
#   in-dataset
# 0          n
# 1          n
# 2          n
# 3          n
# 4          y

# %%
def markdown_table(dataframe, in_dataset):
    """
    Prints out a markdown table from the dataframe with results.

    Args:
    - dataframe: the dataframe with results
    - in_dataset (boolean): True or False - whether the experiments are in-dataset
    """
    table = pd.DataFrame({"Trained on": dataframe["trained_on"], "Tested on": dataframe["tested_on"], "Micro F1": round(dataframe["microF1"],3), "Macro F1": round(dataframe["macroF1"],3)})

    if in_dataset == True:
        table.drop(columns = ["Tested on"], inplace = True)

    table = table.sort_values(by= ["Micro F1", "Macro F1"], ascending = False)
    
    print(table.to_markdown(index = False))

# %%
markdown_table(results[results["in-dataset"] == "y"], True)
# Out:
# | Trained on   |   Micro F1 |   Macro F1 |
# |:-------------|-----------:|-----------:|
# | FTD          |      0.843 |      0.851 |
# | CORE         |      0.778 |      0.627 |
# | SI-GINCO     |      0.754 |      0.75  |
# | MT-GINCO     |      0.743 |      0.723 |

# %% [markdown]
# ## In-dataset experiments by a classifier

# %%
for i in list(results.trained_on.unique()):
    print(f"Results for the {i}-X-GENRE classifier - trained on {i}.\n")

    markdown_table(results[results["trained_on"] == i], False)

    print("\n")
# Out:
# Results for the FTD-X-GENRE classifier - trained on FTD.
#
# | Trained on   | Tested on   |   Micro F1 |   Macro F1 |
# |:-------------|:------------|-----------:|-----------:|
# | FTD          | FTD         |      0.843 |      0.851 |
# | FTD          | FTD-dev     |      0.814 |      0.828 |
# | FTD          | X-GENRE     |      0.635 |      0.532 |
# | FTD          | SI-GINCO    |      0.57  |      0.498 |
# | FTD          | MT-GINCO    |      0.57  |      0.458 |
# | FTD          | CORE        |      0.478 |      0.397 |
#
#
# Results for the MT-GINCO-X-GENRE classifier - trained on MT-GINCO.
#
# | Trained on   | Tested on    |   Micro F1 |   Macro F1 |
# |:-------------|:-------------|-----------:|-----------:|
# | MT-GINCO     | MT-GINCO-dev |      0.765 |      0.759 |
# | MT-GINCO     | MT-GINCO     |      0.743 |      0.723 |
# | MT-GINCO     | FTD          |      0.736 |      0.718 |
# | MT-GINCO     | SI-GINCO     |      0.732 |      0.655 |
# | MT-GINCO     | X-GENRE      |      0.698 |      0.667 |
# | MT-GINCO     | CORE         |      0.66  |      0.553 |
#
#
# Results for the SI-GINCO-X-GENRE classifier - trained on SI-GINCO.
#
# | Trained on   | Tested on    |   Micro F1 |   Macro F1 |
# |:-------------|:-------------|-----------:|-----------:|
# | SI-GINCO     | SI-GINCO     |      0.754 |      0.75  |
# | SI-GINCO     | FTD          |      0.726 |      0.654 |
# | SI-GINCO     | MT-GINCO     |      0.676 |      0.596 |
# | SI-GINCO     | X-GENRE      |      0.672 |      0.617 |
# | SI-GINCO     | SI-GINCO-dev |      0.67  |      0.582 |
# | SI-GINCO     | CORE         |      0.591 |      0.521 |
#
#
# Results for the CORE-X-GENRE classifier - trained on CORE.
#
# | Trained on   | Tested on   |   Micro F1 |   Macro F1 |
# |:-------------|:------------|-----------:|-----------:|
# | CORE         | CORE        |      0.778 |      0.627 |
# | CORE         | CORE-dev    |      0.764 |      0.609 |
# | CORE         | X-GENRE     |      0.551 |      0.481 |
# | CORE         | FTD         |      0.495 |      0.419 |
# | CORE         | MT-GINCO    |      0.385 |      0.394 |
# | CORE         | SI-GINCO    |      0.374 |      0.348 |

# %% [markdown]
# ## Results on X-GENRE

# %%
markdown_table(results[results["tested_on"] == "X-GENRE"], False)
# Out:
# | Trained on   | Tested on   |   Micro F1 |   Macro F1 |
# |:-------------|:------------|-----------:|-----------:|
# | MT-GINCO     | X-GENRE     |      0.698 |      0.667 |
# | SI-GINCO     | X-GENRE     |      0.672 |      0.617 |
# | FTD          | X-GENRE     |      0.635 |      0.532 |
# | CORE         | X-GENRE     |      0.551 |      0.481 |

# %% [markdown]
# ## All results

# %%
markdown_table(results, False)
# Out:
# | Trained on   | Tested on    |   Micro F1 |   Macro F1 |
# |:-------------|:-------------|-----------:|-----------:|
# | FTD          | FTD          |      0.843 |      0.851 |
# | FTD          | FTD-dev      |      0.814 |      0.828 |
# | CORE         | CORE         |      0.778 |      0.627 |
# | MT-GINCO     | MT-GINCO-dev |      0.765 |      0.759 |
# | CORE         | CORE-dev     |      0.764 |      0.609 |
# | SI-GINCO     | SI-GINCO     |      0.754 |      0.75  |
# | MT-GINCO     | MT-GINCO     |      0.743 |      0.723 |
# | MT-GINCO     | FTD          |      0.736 |      0.718 |
# | MT-GINCO     | SI-GINCO     |      0.732 |      0.655 |
# | SI-GINCO     | FTD          |      0.726 |      0.654 |
# | MT-GINCO     | X-GENRE      |      0.698 |      0.667 |
# | SI-GINCO     | MT-GINCO     |      0.676 |      0.596 |
# | SI-GINCO     | X-GENRE      |      0.672 |      0.617 |
# | SI-GINCO     | SI-GINCO-dev |      0.67  |      0.582 |
# | MT-GINCO     | CORE         |      0.66  |      0.553 |
# | FTD          | X-GENRE      |      0.635 |      0.532 |
# | SI-GINCO     | CORE         |      0.591 |      0.521 |
# | FTD          | SI-GINCO     |      0.57  |      0.498 |
# | FTD          | MT-GINCO     |      0.57  |      0.458 |
# | CORE         | X-GENRE      |      0.551 |      0.481 |
# | CORE         | FTD          |      0.495 |      0.419 |
# | FTD          | CORE         |      0.478 |      0.397 |
# | CORE         | MT-GINCO     |      0.385 |      0.394 |
# | CORE         | SI-GINCO     |      0.374 |      0.348 |
