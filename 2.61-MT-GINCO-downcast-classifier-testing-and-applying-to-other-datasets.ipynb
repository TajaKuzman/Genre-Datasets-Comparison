# %% [markdown]
# Import all necessary libraries and install everything you need for training:

# %%
# install the libraries necessary for data wrangling, prediction and result analysis
import json
import numpy as np
import pandas as pd
import logging
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, f1_score,precision_score, recall_score
import torch
from numba import cuda
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

# %%
# Install transformers
# (this needs to be done on Kaggle each time you start the session)
#!pip install -q transformers

# %%
# Install the simpletransformers
#!pip install -q simpletransformers
from simpletransformers.classification import ClassificationModel

# %%
# Install wandb
#!pip install -q wandb

# %%
import wandb

# %%
# Login to wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tajak (use `wandb login --relogin` to force relogin)
# True

# %%
# Clean the GPU cache

cuda.select_device(0)
cuda.close()
cuda.select_device(0)
torch.cuda.empty_cache()

# %% [markdown]
# ### Import the data

# %%
# MT-GINCO downcast set
train_df = pd.read_csv("data-splits/MT-GINCO-downcast-train.csv", index_col = 0)
dev_df = pd.read_csv("data-splits/MT-GINCO-downcast-dev.csv", index_col = 0)
test_df = pd.read_csv("data-splits/MT-GINCO-downcast-test.csv", index_col = 0)

print("GINCO train shape: {}, Dev shape: {}, Test shape: {}.".format(train_df.shape, dev_df.shape, test_df.shape))
# Out:
# GINCO train shape: (601, 3), Dev shape: (201, 3), Test shape: (200, 3).

# %%
# Use only the first 2 columns
train_df = train_df.drop(columns=["split"])
test_df = test_df.drop(columns=["split"])
dev_df = dev_df.drop(columns=["split"])

# %%
train_df.head()
# Out:
#                                                 text            labels
# 3  In November, the month of addiction prevention...    News/Reporting
# 4  Selena Gomez launches new album <p/> 16.07.201...    News/Reporting
# 5  Miscellaneous <p/> This year, for the 30th tim...         Promotion
# 7  JUDGMENT: The rule in Article 216 of the CCP a...  Legal/Regulation
# 8  Exhibition, "White sport along the green river...         Promotion

# %% [markdown]
# ## Testing

# %% [markdown]
# We will use the multilingual XLM-RoBERTa model
# https://huggingface.co/xlm-roberta-base

# %%
# Create a file to save results into (you can find it under Data: Output). Be careful, run this step only once to not overwrite the results file.
#results = []

#with open("results/FTD-Experiments-Results.json", "w") as results_file:
#    json.dump(results,results_file, indent= "")

# %%
# Open the main results file:

previous_results_file = open("results/GINCO-Experiments-Results.json")
previous_results = json.load(previous_results_file)
len(previous_results)
# Out:
# 16

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Create a list of labels
LABELS = train_df.labels.unique().tolist()
LABELS
# Out:
# ['News/Reporting',
#  'Promotion',
#  'Legal/Regulation',
#  'Forum',
#  'Opinion/Argumentation',
#  'Other',
#  'Information/Explanation',
#  'List of Summaries/Excerpts',
#  'Instruction']

# %%
# Initialize Wandb
run = wandb.init(project="GINCO-hyperparameter-search", entity="tajak", name="testing-trained-model")
# Out:
# wandb version 0.12.21 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20220803_140225-jvz5yo2d</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/GINCO-hyperparameter-search/runs/jvz5yo2d" target="_blank">testing-trained-model</a></strong> to <a href="https://wandb.ai/tajak/GINCO-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# Load the saved model
artifact = run.use_artifact('tajak/GINCO-hyperparameter-search/MT-GINCO-downcast-classifier:v0', type='model')
artifact_dir = artifact.download()

# Loading a local save
model = ClassificationModel(
    "xlmroberta", artifact_dir)
# Out:
# wandb: Downloading large artifact MT-GINCO-downcast-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
def testing(test_df, test_name):
    """
    This function takes the test dataset and applies the trained model on it to infer predictions.
    It also prints and saves a confusion matrix, calculates the F1 scores and saves the results in a list of results.

    Args:
    - test_df (pandas DataFrame)
    - test_name
    """
    # Get the true labels
    y_true = test_df.labels
    
    # Calculate the model's predictions on test
    def make_prediction(input_string):
        return model.predict([input_string])[0][0]

    y_pred = test_df.text.apply(make_prediction)
    test_df["y_pred_MT-GINCO_downcast"] = y_pred

    # Calculate the scores
    macro = f1_score(y_true, y_pred, labels=LABELS, average="macro")
    micro = f1_score(y_true, y_pred, labels=LABELS,  average="micro")
    print(f"Macro f1: {macro:0.3}, Micro f1: {micro:0.3}")

    # Plot the confusion matrix:
    cm = confusion_matrix(y_true, y_pred, labels=LABELS)
    plt.figure(figsize=(9, 9))
    plt.imshow(cm, cmap="Oranges")
    for (i, j), z in np.ndenumerate(cm):
        plt.text(j, i, '{:d}'.format(z), ha='center', va='center')
    classNames = LABELS
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    tick_marks = np.arange(len(classNames))
    plt.xticks(tick_marks, classNames, rotation=90)
    plt.yticks(tick_marks, classNames)
    plt.title(f"{test_name}")

    plt.tight_layout()
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    fig1.savefig(f"figures/Confusion-matrix-{test_name}.png",dpi=100)

    # Save the results:
    rezdict = {
        "experiment": test_name,
        "num_train_epochs": 15,
        "train_batch_size":8,
        "learning_rate": 1e-5,
        "microF1": micro,
        "macroF1": macro,
        "y_true": y_true.to_dict(),
        "y_pred": y_pred.to_dict(),
        }
    previous_results.append(rezdict)

    #Save intermediate results (just in case)
    backup = []
    backup.append(rezdict)
    with open(f"backup-results-{test_name}.json", "w") as backup_file:
        json.dump(backup,backup_file, indent= "")

    # Save the new dataframe which contains the y_pred values as well
    test_df.to_csv(f"results/{test_name}-sheet-with-predictions.csv", sep="\t")

# %%
testing(dev_df, "testing-MT-GINCO-downcast-on-dev")

print("\nTesting finished.")
# Out:
# Macro f1: 0.806, Micro f1: 0.781
# Testing finished.

# %%
testing(test_df, "testing-MT-GINCO-downcast-on-test")
print("\nTesting finished.")
# Out:
# Macro f1: 0.723, Micro f1: 0.72
# Testing finished.

# %%
# Compare the results by creating a dataframe from the previous_results dictionary:
results_df = pd.DataFrame(previous_results)

results_df
# Out:
#                                        experiment  num_train_epochs  \
# 0                              Dev-epoch-search:1                 1
# 1                             Dev-epoch-search:12                12
# 2                             Dev-epoch-search:15                15
# 3                             Dev-epoch-search:20                20
# 4                             Dev-epoch-search:25                25
# 5             testing-GINCO-full-set-model-on-dev                20
# 6              FTD-classifier-predictions-on-test                20
# 7   GINCO-full-set-classifier-predictions-on-test                20
# 8               GINCO-downcast-dev-epoch-search:8                 8
# 9              GINCO-downcast-dev-epoch-search:10                10
# 10             GINCO-downcast-dev-epoch-search:15                15
# 11             GINCO-downcast-dev-epoch-search:20                20
# 12             GINCO-downcast-dev-epoch-search:25                25
# 13             GINCO-downcast-dev-epoch-search:30                30
# 14                  testing-GINCO-downcast-on-dev                15
# 15                 testing-GINCO-downcast-on-test                15
# 16               testing-MT-GINCO-downcast-on-dev                15
# 17              testing-MT-GINCO-downcast-on-test                15
#
#     train_batch_size  learning_rate   microF1   macroF1  \
# 0                  8        0.00001  0.238342  0.085359
# 1                  8        0.00001  0.585492  0.417602
# 2                  8        0.00001  0.658031  0.504828
# 3                  8        0.00001  0.637306  0.530084
# 4                  8        0.00001  0.626943  0.497636
# 5                  8        0.00001  0.668394  0.539277
# 6                  8        0.00001  0.590674  0.465714
# 7                  8        0.00001  0.590674  0.465714
# 8                  8        0.00001  0.527363  0.267149
# 9                  8        0.00001  0.721393  0.719435
# 10                 8        0.00001  0.776119  0.818806
# 11                 8        0.00001  0.756219  0.791577
# 12                 8        0.00001  0.766169  0.800081
# 13                 8        0.00001  0.736318  0.764189
# 14                 8        0.00001  0.701493  0.740766
# 15                 8        0.00001  0.715000  0.729721
# 16                 8        0.00001  0.781095  0.805693
# 17                 8        0.00001  0.720000  0.723423
#
#                                                y_true  \
# 0   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 1   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 2   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 3   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 4   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 5   {'245': 'Call', '143': 'Invitation', '146': 'N...
# 6   {'574': 'Opinionated News', '636': 'Informatio...
# 7   {'574': 'Opinionated News', '636': 'Informatio...
# 8   {'648': 'Other', '992': 'Instruction', '51': '...
# 9   {'648': 'Other', '992': 'Instruction', '51': '...
# 10  {'648': 'Other', '992': 'Instruction', '51': '...
# 11  {'648': 'Other', '992': 'Instruction', '51': '...
# 12  {'648': 'Other', '992': 'Instruction', '51': '...
# 13  {'648': 'Other', '992': 'Instruction', '51': '...
# 14  {'648': 'Other', '992': 'Instruction', '51': '...
# 15  {'677': 'List of Summaries/Excerpts', '355': '...
# 16  {1: 'Information/Explanation', 6: 'Promotion',...
# 17  {0: 'News/Reporting', 2: 'Promotion', 14: 'Oth...
#
#                                                y_pred
# 0   {'245': 'News/Reporting', '143': 'Information/...
# 1   {'245': 'News/Reporting', '143': 'Invitation',...
# 2   {'245': 'News/Reporting', '143': 'Promotion of...
# 3   {'245': 'News/Reporting', '143': 'Promotion', ...
# 4   {'245': 'News/Reporting', '143': 'Promotion of...
# 5   {'245': 'News/Reporting', '143': 'Invitation',...
# 6   {'574': 'News/Reporting', '636': 'Information/...
# 7   {'574': 'News/Reporting', '636': 'Information/...
# 8   {'648': 'Opinion/Argumentation', '992': 'Promo...
# 9   {'648': 'Forum', '992': 'Instruction', '51': '...
# 10  {'648': 'Forum', '992': 'Instruction', '51': '...
# 11  {'648': 'Forum', '992': 'Instruction', '51': '...
# 12  {'648': 'Forum', '992': 'Instruction', '51': '...
# 13  {'648': 'Forum', '992': 'Instruction', '51': '...
# 14  {'648': 'Forum', '992': 'Instruction', '51': '...
# 15  {'677': 'List of Summaries/Excerpts', '355': '...
# 16  {1: 'Information/Explanation', 6: 'Promotion',...
# 17  {0: 'News/Reporting', 2: 'News/Reporting', 14:...

# %%
# Save the file with updated results.
with open("results/GINCO-Experiments-Results.json", "w") as results_file:
    json.dump(previous_results,results_file, indent= "")

# %% [markdown]
# ## Predict GINCO labels to other datasets

# %%
# Create a function to predict
def predict_GINCO(df, new_file_name):
    """
    This function takes a dataset and applies the trained model on it to infer predictions.
	It returns and saves the resulting df with added columns with GINCO predictions.

    Args:
    - df: dataframe on which we want to apply prediction. The text should be in a column "text".
    - new_file_name: define the name of the new file
    """
    # Predict on the df
    def make_prediction(input_string):
        return model.predict([input_string])[0][0]

    y_pred = df.text.apply(make_prediction)

    df["MT-GINCO_downcast_pred"] = y_pred

    # Save the new dataframe which contains the y_pred values as well
    df.to_csv(f"{new_file_name}", sep="\t")

    return df

# %% [markdown]
# Prediction takes around 22 minutes per 1000 instances.

# %% [markdown]
# ### Predict MT-GINCO to CORE

# %%
# Import data about CORE
core_df = pd.read_csv("data-sheets-with-all-info/CORE-all-information.csv", index_col=0, sep="\t")

core_df
# Out:
#              label                                               text  split  \
# 0      NA OP SR OB  The Top TEN 'Whiniest Sets of Fans' in English...  train
# 1            NA NE  Ferry consultation needs deeper questions, say...  train
# 2            ID DF  I'v been recording and mixing music for about ...  train
# 3            NA SR  The 25-year-old did have chances at Anfield. B...  train
# 4         NA IN HA  Elizabethan Science and Technology Elizabethan...  train
# ...            ...                                                ...    ...
# 48444        NA NE  Lollapalooza heading to the Middle East in 201...    dev
# 48445        OP AV  How to: Improve Brand Engagement on Twitter Ea...    dev
# 48446        OP OB  The Last Post. A shameful reflection on Canada...    dev
# 48447        NA NE  Related Stories Students at a Sherwood Park hi...    dev
# 48448        IN OP  2009 September 14th The folks over at VGBlogge...    dev
#
#       main_labels sublabels  Len  main_len  sub_len                GINCORE  \
# 0           NA OP     SR OB    4         2        2            NA OP SR OB
# 1             NaN        NE    2         1        1                   News
# 2              ID        DF    2         1        1                  Forum
# 3             NaN        SR    2         1        1                   News
# 4           NA IN        HA    3         2        1               NA IN HA
# ...           ...       ...  ...       ...      ...                    ...
# 48444         NaN        NE    2         1        1                   News
# 48445          OP        AV    2         1        1  Opinion/Argumentation
# 48446          OP        OB    2         1        1  Opinion/Argumentation
# 48447         NaN        NE    2         1        1                   News
# 48448       IN OP       NaN    2         2        1                discard
#
#                full_names  main_labels_full_names            FTD_pred  \
# 0                   SR OB                   NA OP                 NaN
# 1        News Report/Blog               Narrative                 NaN
# 2        Discussion Forum  Interactive Discussion                 NaN
# 3           Sports Report               Narrative                 NaN
# 4      Historical Article                   NA IN                 NaN
# ...                   ...                     ...                 ...
# 48444    News Report/Blog               Narrative                 NaN
# 48445              Advice                 Opinion                 NaN
# 48446        Opinion Blog                 Opinion  A1 (argumentative)
# 48447    News Report/Blog               Narrative                 NaN
# 48448                 NaN                   IN OP                 NaN
#
#       GINCO_downcast_pred
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 48444                 NaN
# 48445                 NaN
# 48446                 NaN
# 48447                 NaN
# 48448                 NaN
#
# [48420 rows x 13 columns]

# %% [markdown]
# As prediction takes a lot of time, we will use a smaller sample of the dataset - I will use a stratified split of the test split (data-splits/CORE-sub-test-sample.csv) which is a stratified based on the subcategories) sample of the whole dataset where we:
#
# * removed instances with more than one subcategory and instances with no subcategories (with main category only)
# * removed instances of categories with less than 10 instances
#
# The sample has 1500 instances, like the FTD dataset.

# %%
# Import
core_sample = pd.read_csv("data-splits/CORE-sub-test-sample.csv", index_col=0)

core_sample
# Out:
#                                                     text  \
# 10379  The table below shows UK prices for the iPad M...
# 36572  You can protect your kids for every possibly h...
# 2751   Pages 19 September 2012 Murder in East Timor t...
# 1804   Hadean Era Abstract A brief description of the...
# 12696  28 and he was returning and sitting in his cha...
# ...                                                  ...
# 15611  What was Australia's 1967 Referendum about? Th...
# 25484  related stories Cox happy ahead of Middle Park...
# 16340  Blog Wells-Next-The-Sea -- "Keep in Front of t...
# 12311  Do you need to complete a tax return? If you h...
# 9648   Story Tools DARRYL Forday's rapid-fire marshma...
#
#                         labels
# 10379         News Report/Blog
# 36572         News Report/Blog
# 2751          News Report/Blog
# 1804      Encyclopedia Article
# 12696  Religious Blogs/Sermons
# ...                        ...
# 15611       Historical Article
# 25484            Sports Report
# 16340                  Reviews
# 12311         FAQ about How-to
# 9648                   Reviews
#
# [1500 rows x 2 columns]

# %%
# Apply MT-GINCO-downcast classifier to samples
predicted_sample = predict_GINCO(core_sample, "CORE-test-sample-MT-GINCO-predicted.csv")

predicted_sample.head()
# Out:
#                                                     text  \
# 10379  The table below shows UK prices for the iPad M...
# 36572  You can protect your kids for every possibly h...
# 2751   Pages 19 September 2012 Murder in East Timor t...
# 1804   Hadean Era Abstract A brief description of the...
# 12696  28 and he was returning and sitting in his cha...
#
#                         labels   MT-GINCO_downcast_pred
# 10379         News Report/Blog           News/Reporting
# 36572         News Report/Blog           News/Reporting
# 2751          News Report/Blog           News/Reporting
# 1804      Encyclopedia Article  Information/Explanation
# 12696  Religious Blogs/Sermons    Opinion/Argumentation

# %%
# Add to the main sheet - core_df
core_df["MT-GINCO_downcast_pred"] = predicted_sample["MT-GINCO_downcast_pred"]

core_df
# Out:
#              label                                               text  split  \
# 0      NA OP SR OB  The Top TEN 'Whiniest Sets of Fans' in English...  train
# 1            NA NE  Ferry consultation needs deeper questions, say...  train
# 2            ID DF  I'v been recording and mixing music for about ...  train
# 3            NA SR  The 25-year-old did have chances at Anfield. B...  train
# 4         NA IN HA  Elizabethan Science and Technology Elizabethan...  train
# ...            ...                                                ...    ...
# 48444        NA NE  Lollapalooza heading to the Middle East in 201...    dev
# 48445        OP AV  How to: Improve Brand Engagement on Twitter Ea...    dev
# 48446        OP OB  The Last Post. A shameful reflection on Canada...    dev
# 48447        NA NE  Related Stories Students at a Sherwood Park hi...    dev
# 48448        IN OP  2009 September 14th The folks over at VGBlogge...    dev
#
#       main_labels sublabels  Len  main_len  sub_len                GINCORE  \
# 0           NA OP     SR OB    4         2        2            NA OP SR OB
# 1             NaN        NE    2         1        1                   News
# 2              ID        DF    2         1        1                  Forum
# 3             NaN        SR    2         1        1                   News
# 4           NA IN        HA    3         2        1               NA IN HA
# ...           ...       ...  ...       ...      ...                    ...
# 48444         NaN        NE    2         1        1                   News
# 48445          OP        AV    2         1        1  Opinion/Argumentation
# 48446          OP        OB    2         1        1  Opinion/Argumentation
# 48447         NaN        NE    2         1        1                   News
# 48448       IN OP       NaN    2         2        1                discard
#
#                full_names  main_labels_full_names            FTD_pred  \
# 0                   SR OB                   NA OP                 NaN
# 1        News Report/Blog               Narrative                 NaN
# 2        Discussion Forum  Interactive Discussion                 NaN
# 3           Sports Report               Narrative                 NaN
# 4      Historical Article                   NA IN                 NaN
# ...                   ...                     ...                 ...
# 48444    News Report/Blog               Narrative                 NaN
# 48445              Advice                 Opinion                 NaN
# 48446        Opinion Blog                 Opinion  A1 (argumentative)
# 48447    News Report/Blog               Narrative                 NaN
# 48448                 NaN                   IN OP                 NaN
#
#       GINCO_downcast_pred MT-GINCO_downcast_pred
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
# ...                   ...                    ...
# 48444                 NaN                    NaN
# 48445                 NaN                    NaN
# 48446                 NaN                    NaN
# 48447                 NaN                    NaN
# 48448                 NaN                    NaN
#
# [48420 rows x 14 columns]

# %%
core_df["MT-GINCO_downcast_pred"].value_counts()
# Out:
# News/Reporting                481
# Opinion/Argumentation         443
# Information/Explanation       146
# Promotion                     123
# Forum                         107
# Instruction                    90
# Other                          60
# List of Summaries/Excerpts     47
# Legal/Regulation                3
# Name: MT-GINCO_downcast_pred, dtype: int64

# %%
# Save the new dataframe
core_df.to_csv("data-sheets-with-all-info/CORE-all-information.csv", sep="\t")

# %% [markdown]
# ## Predict GINCO to FTD

# %%
# Import data
ftd = pd.read_csv("data-sheets-with-all-info/FTD-dataset-with-all-information.csv", sep="\t", index_col = 0)

ftd
# Out:
#                          ID              labels Multiple labels  \
# 0         __id__1-syndicate  A1 (argumentative)             NaN
# 1         __id__2-syndicate  A1 (argumentative)             NaN
# 2         __id__3-syndicate  A1 (argumentative)             NaN
# 3         __id__4-syndicate  A1 (argumentative)             NaN
# 4         __id__5-syndicate  A1 (argumentative)             NaN
# ...                     ...                 ...             ...
# 1681  __id__1682-britannica  A1 (argumentative)             NaN
# 1682  __id__1683-britannica   A16 (information)             NaN
# 1683  __id__1684-britannica  A1 (argumentative)             NaN
# 1684  __id__1685-britannica     A12 (promotion)             NaN
# 1685  __id__1686-britannica   A16 (information)             NaN
#
#                                                    text  length  \
# 0     BMW's and Chinese Justice * * * * * In most pl...     975
# 1     China and a New Balance of Power SHANGHAI – Th...     956
# 2     China and Russia in the New World Disorder Can...     978
# 3     The Roots of Chinese / Japanese Rivalry BOSTON...     957
# 4     China's Cyber-Warriors NEW DELHI – The world n...    1034
# ...                                                 ...     ...
# 1681  In Eichmann in Jerusalem , Hannah Arendt descr...     610
# 1682  The vast expanse of the African continent span...     381
# 1683  Lance Corporal Samantha L. Jones , USMC Politi...    2482
# 1684  Courtesy of the Victoria and Albert Museum , L...     390
# 1685  In their quest for survival , plants have evol...    1027
#
#           GINCO_downcast_pred
# 0              News/Reporting
# 1     Information/Explanation
# 2       Opinion/Argumentation
# 3       Opinion/Argumentation
# 4              News/Reporting
# ...                       ...
# 1681  Information/Explanation
# 1682  Information/Explanation
# 1683  Information/Explanation
# 1684  Information/Explanation
# 1685  Information/Explanation
#
# [1553 rows x 6 columns]

# %%
ftd_predicted = predict_GINCO(ftd, "FTD-dataset-with-all-information.csv")

ftd_predicted
# Out:
#                          ID              labels Multiple labels  \
# 0         __id__1-syndicate  A1 (argumentative)             NaN
# 1         __id__2-syndicate  A1 (argumentative)             NaN
# 2         __id__3-syndicate  A1 (argumentative)             NaN
# 3         __id__4-syndicate  A1 (argumentative)             NaN
# 4         __id__5-syndicate  A1 (argumentative)             NaN
# ...                     ...                 ...             ...
# 1681  __id__1682-britannica  A1 (argumentative)             NaN
# 1682  __id__1683-britannica   A16 (information)             NaN
# 1683  __id__1684-britannica  A1 (argumentative)             NaN
# 1684  __id__1685-britannica     A12 (promotion)             NaN
# 1685  __id__1686-britannica   A16 (information)             NaN
#
#                                                    text  length  \
# 0     BMW's and Chinese Justice * * * * * In most pl...     975
# 1     China and a New Balance of Power SHANGHAI – Th...     956
# 2     China and Russia in the New World Disorder Can...     978
# 3     The Roots of Chinese / Japanese Rivalry BOSTON...     957
# 4     China's Cyber-Warriors NEW DELHI – The world n...    1034
# ...                                                 ...     ...
# 1681  In Eichmann in Jerusalem , Hannah Arendt descr...     610
# 1682  The vast expanse of the African continent span...     381
# 1683  Lance Corporal Samantha L. Jones , USMC Politi...    2482
# 1684  Courtesy of the Victoria and Albert Museum , L...     390
# 1685  In their quest for survival , plants have evol...    1027
#
#           GINCO_downcast_pred   MT-GINCO_downcast_pred
# 0              News/Reporting           News/Reporting
# 1     Information/Explanation    Opinion/Argumentation
# 2       Opinion/Argumentation    Opinion/Argumentation
# 3       Opinion/Argumentation    Opinion/Argumentation
# 4              News/Reporting           News/Reporting
# ...                       ...                      ...
# 1681  Information/Explanation  Information/Explanation
# 1682  Information/Explanation  Information/Explanation
# 1683  Information/Explanation  Information/Explanation
# 1684  Information/Explanation  Information/Explanation
# 1685  Information/Explanation  Information/Explanation
#
# [1553 rows x 7 columns]
