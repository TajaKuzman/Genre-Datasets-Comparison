# %% [markdown]
# Import all necessary libraries and install everything you need for training:

# %%
# install the libraries necessary for data wrangling, prediction and result analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from numba import cuda
from itertools import islice
import time
from tqdm import tqdm

# %%
# Install transformers
# (this needs to be done on Kaggle each time you start the session)
#!pip install -q transformers

# Install the simpletransformers
#!pip install -q simpletransformers
from simpletransformers.classification import ClassificationModel

# Install wandb
#!pip install -q wandb
import wandb

# Login to wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tajak (use `wandb login --relogin` to force relogin)
# True

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Import the MaCoCu sample

dataset = pd.read_csv("MaCoCu-sl-manual-checkup-sample.csv", sep="\t", index_col = 0)
dataset.head(2)
# Out:
#        domain                       url  \
# 0  solemio.si       https://solemio.si/
# 1    bimbo.si  https://www.bimbo.si/cam
#
#                                                 text  length
# 0  Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...     468
# 1  Cam\nGledati na svet z otroškimi očmi, da bi r...     230

# %%
# Include information on the manually assigned genre (based on manual checkup)

manual_an_df = pd.read_csv("genres-in-Slovene-domains.csv")

manual_an_df.head(1)
# Out:
#        Web domain             Genre
# 0  sodnapraksa.si  legal/regulation

# %%
# Change the name of column to "domain"
manual_an_df = manual_an_df.rename(columns={"Web domain": "domain", "Genre": "manually-assigned-genre"})
manual_an_df.head(1)
# Out:
#            domain manually-assigned-genre
# 0  sodnapraksa.si        legal/regulation

# %%
# merge the datasets
dataset = pd.merge(manual_an_df, dataset, how = "outer", on= "domain")

dataset.head()
# Out:
#            domain manually-assigned-genre  \
# 0  sodnapraksa.si        legal/regulation
# 1  sodnapraksa.si        legal/regulation
# 2  sodnapraksa.si        legal/regulation
# 3  sodnapraksa.si        legal/regulation
# 4  sodnapraksa.si        legal/regulation
#
#                                                  url  \
# 0  http://sodnapraksa.si/?q=ViiiIps193/2010&amp;d...
# 1  http://www.sodnapraksa.si/search.php?q=G35/12&...
# 2  http://www.sodnapraksa.si/search.php?q=G35/12&...
# 3  http://sodnapraksa.si/?q=285%20&amp;database%5...
# 4  http://www.sodnapraksa.si/?q=id:20150811114380...
#
#                                                 text  length
# 0  predlog za dopustitev revizije - nepopoln pred...   444.0
# 1  Jedro\nČe tožnik nima ustreznega dovoljenja za...   571.0
# 2  Pravna podlaga za toženkino odškodninsko odgov...  2317.0
# 3  predložitev pooblastila odvetniku– zavrženje p...  2546.0
# 4  Izrek\n2. Zoper sklep se po pooblaščencu pravo...   407.0

# %%
dataset.describe(include="all")
# Out:
#             domain                                             url  \
# count         3000                                            3000
# unique         300                                            2986
# top     solemio.si  http://www.telex.si/index.php?s=143&amp;page=2
# freq            10                                               3
# mean           NaN                                             NaN
# std            NaN                                             NaN
# min            NaN                                             NaN
# 25%            NaN                                             NaN
# 50%            NaN                                             NaN
# 75%            NaN                                             NaN
# max            NaN                                             NaN
#
#                                                      text        length
# count                                                3000   3000.000000
# unique                                               3000           NaN
# top     Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    503.810333
# std                                                   NaN   1330.962600
# min                                                   NaN     76.000000
# 25%                                                   NaN    125.000000
# 50%                                                   NaN    227.500000
# 75%                                                   NaN    452.250000
# max                                                   NaN  30308.000000

# %% [markdown]
# ## Apply classifier

# %% [markdown]
# Models used:
# - FTD classifier - original FTD data (except multi-labeled texts and non-text texts) - 10 categories, 849 instances in training data
# - GINCO-downcast classifier - used primary_level_4 downcasted GINCO labels - 9 labels. It was trained on 601 texts.
# - CORE-main classifier - main categories only - 9 instances. All texts with multiple labels were discarded. It was trained on 10256 instances.
# - GINCO X-GENRE classifier - 9 X-GENRE labels. It was trained on 535 texts (10% texts discarded - belonging to "discarded" labels)
# - FTD X-GENRE classifier - 7 X-GENRE labels. It was trained on 630 texts (23% texts were discarded).
# - CORE X-GENRE classifier - 9 X-GENRE labels. It was trained on 607 texts - large changes to the dataset were performed (change of distribution, taking only a sample to have a similar size as FTD and GINCO).
# - X-GENRE classifier - 9 X-GENRE labels. Trained on the training splits of all of the X-GENRE datasets mentioned above: 1772 instances in the training dataset.

# %% [markdown]
# ### Functions

# %%
def define_model(model_name):
	"""
	Define which model you want to use and download it.
	Args:
	- model_name: choose from "FTD", "GINCO", "CORE", "GINCO-X-GENRE", "FTD-X-GENRE", "CORE-X-GENRE", "X-GENRE"
	"""
	if model_name == "FTD":
		# Initialize Wandb: 
		run = wandb.init(project="FTD-learning-manual-hyperparameter-search", entity="tajak", name="applying-predictions-on-MaCoCu")

		# Load the FTD model from Wandb:
		artifact = run.use_artifact('tajak/FTD-learning-manual-hyperparameter-search/FTD-classifier:v1', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)

	elif model_name == "GINCO":
		# Initialize Wandb: 
		run = wandb.init(project="GINCO-hyperparameter-search", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the GINCO-downcast model from Wandb:
		artifact = run.use_artifact('tajak/GINCO-hyperparameter-search/GINCO-downcast-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "CORE":
		# Initialize Wandb: 
		run = wandb.init(project="CORE-hyperparameter-search", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the CORE-main model from Wandb:
		artifact = run.use_artifact('tajak/CORE-hyperparameter-search/CORE-main-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "GINCO-X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the GINCO-X-GENRE model from Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/SI-GINCO-X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "FTD-X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the FTD-X-GENRE model from Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/FTD-X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "CORE-X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		# To access the model from the Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/CORE-X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		# To access the model from the Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)

	return model

# %%
def predict(dataset, model, model_name):
	"""
	This function takes the dataset and applies the trained model on it to infer predictions.
	It saves the results to a new csv file.

	Args:
	- dataset (pandas DataFrame): dataset to apply prediction on. The text we want to predict should be in the column "text".
	- model: the model to use
	- model_name: the name of the classifier
	"""
	# Silence the model
	model.args.silent = True

	labels = model.args.labels_list

	# Split the dataframe into batches

	def chunk(arr_range, arr_size):
		arr_range = iter(arr_range)
		return iter(lambda: tuple(islice(arr_range, arr_size)), ())

	batches_list = list(chunk(dataset.text, 8))

	batches_list_new = []

	for i in batches_list:
		batches_list_new.append(list(i))

	print("The dataset is split into {} batches of {} texts.".format(len(batches_list_new),len(batches_list_new[0])))

	# Apply softmax to the raw outputs
	def softmax(x):
		#Compute softmax values for each sets of scores in x.
		return np.exp(x) / np.sum(np.exp(x), axis=0)

	y_pred = []
	y_distr = []
	most_probable = []
	batch_counter = 0

	print(f"Prediction with model {model_name} started.")
	start_time = time.time()

	for i in tqdm(batches_list_new):
		output = model.predict(i)
		current_y_pred = output[0]
		current_y_distr = output[1]
		current_y_distr_softmax = []
		current_y_distr_most_probable = []
		for i in current_y_distr:
			distr = softmax(i)
			distr_dict = {labels[i]: round(distr[i],4) for i in range(len(labels))}
			current_y_distr_softmax.append(distr_dict)
			# Also add the information for the softmax of the most probable category ("certainty")
			distr_sorted = np.sort(distr)
			current_y_distr_most_probable.append(distr_sorted[-1])

		for i in current_y_pred:
			y_pred.append(i)

		for i in current_y_distr_softmax:
			y_distr.append(i)

		for i in current_y_distr_most_probable:
			most_probable.append(i)

		batch_counter += 1
		#print("Batch {} predicted.".format(batch_counter))

	prediction_time = round((time.time() - start_time)/60,2)

	print("Prediction with model {} completed. It took {} minutes for {} instances - {} minutes per one instance.".format(model_name, prediction_time, dataset.shape[0], prediction_time/dataset.shape[0]))

	dataset[f"{model_name}"] = y_pred
	dataset[f"{model_name}_label_distribution"] = y_distr
	dataset[f"{model_name}_confidence"] = most_probable

	# Save the new dataframe which contains the y_pred values as well
	dataset.to_csv("MaCoCu-sl-sample-prediction-{}".format(model_name), sep="\t")

	return dataset

# %% [markdown]
# ### Prediction

# %% [markdown]
# #### FTD

# %%
FTD = define_model("FTD")

# Define labels
FTD_labels = [7, 8, 0, 1, 6, 5, 2, 4, 3, 9]

ftd_mapping = {'A1 (argumentative)': 0, 'A11 (personal)': 1, 'A12 (promotion)': 2, 'A14 (academic)': 3, 'A16 (information)': 4, 'A17 (review)': 5, 'A4 (fiction)': 6, 'A7 (instruction)': 7, 'A8 (news)': 8, 'A9 (legal)': 9}

ftd_mapping_reverse = {list(ftd_mapping.values())[i]: list(ftd_mapping.keys())[i] for i in range(len(list(ftd_mapping.values())))}
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-data/Comparison-based-on-manual-checkup-MaCoCu-sl/wandb/run-20230105_125113-3emmjlla</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/FTD-learning-manual-hyperparameter-search/runs/3emmjlla" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/FTD-learning-manual-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact FTD-classifier:v1, 1081.90MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
# Predict FTD to the dataset
dataset = predict(dataset, FTD, "FTD")
# Out:
# The dataset is split into 375 batches of 8 texts.
# Prediction with model FTD started.
# 100%|██████████| 375/375 [07:15<00:00,  1.16s/it]
# Prediction with model FTD completed. It took 7.27 minutes for 3000 instances - 0.0024233333333333333 minutes per one instance.

# %%
dataset.head(3)
# Out:
#        domain                        url  \
# 0  solemio.si        https://solemio.si/
# 1    bimbo.si   https://www.bimbo.si/cam
# 3     kwon.si  https://www.kwon.si/acerr
#
#                                                 text  length  FTD  \
# 0  Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...     468    2
# 1  Cam\nGledati na svet z otroškimi očmi, da bi r...     230    2
# 3  Ne glede na to, ali gledate filme, igrate igre...     246    2
#
#                               FTD_label_distribution  FTD_confidence
# 0  {7: 0.0088, 8: 0.0079, 0: 0.0132, 1: 0.0049, 6...        0.930402
# 1  {7: 0.0065, 8: 0.0048, 0: 0.0079, 1: 0.0025, 6...        0.952343
# 3  {7: 0.0439, 8: 0.0103, 0: 0.0162, 1: 0.0069, 6...        0.804932

# %%
# Map the FTD labels to names
dataset["FTD"] = [ftd_mapping_reverse[x] for x in dataset["FTD"]]

dataset.head(3)
# Out:
#        domain                        url  \
# 0  solemio.si        https://solemio.si/
# 1    bimbo.si   https://www.bimbo.si/cam
# 3     kwon.si  https://www.kwon.si/acerr
#
#                                                 text  length              FTD  \
# 0  Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...     468  A12 (promotion)
# 1  Cam\nGledati na svet z otroškimi očmi, da bi r...     230  A12 (promotion)
# 3  Ne glede na to, ali gledate filme, igrate igre...     246  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence
# 0  {7: 0.0088, 8: 0.0079, 0: 0.0132, 1: 0.0049, 6...        0.930402
# 1  {7: 0.0065, 8: 0.0048, 0: 0.0079, 1: 0.0025, 6...        0.952343
# 3  {7: 0.0439, 8: 0.0103, 0: 0.0162, 1: 0.0069, 6...        0.804932

# %%
# At the end of each prediction and before downloading the next model, delete the previous one from the folder to release space.

# Remove previous classifier
# %rm -rf wandb
# %rm -rf artifacts

# %%
# Save the dataset with results
dataset.to_csv("MaCoCu-sl_manual_checkup_with_predictions.csv", sep="\t")

# %% [markdown]
# #### Loop through other classifiers

# %%
# Open the dataset
dataset = pd.read_csv("MaCoCu-sl_manual_checkup_with_predictions.csv", sep="\t", index_col = 0)
dataset.head(2)
# Out:
#        domain                       url  \
# 0  solemio.si       https://solemio.si/
# 1    bimbo.si  https://www.bimbo.si/cam
#
#                                                 text  length              FTD  \
# 0  Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...     468  A12 (promotion)
# 1  Cam\nGledati na svet z otroškimi očmi, da bi r...     230  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence
# 0  {7: 0.0088, 8: 0.0079, 0: 0.0132, 1: 0.0049, 6...        0.930402
# 1  {7: 0.0065, 8: 0.0048, 0: 0.0079, 1: 0.0025, 6...        0.952343

# %%
def prediction_pipeline(model_name, dataset):
	"""Choose from ["GINCO", "CORE", "GINCO-X-GENRE", "FTD-X-GENRE", "CORE-X-GENRE", "X-GENRE"]"""

	# Define the model
	model = define_model(model_name)

	# Predict genre labels to the dataset
	dataset = predict(dataset, model, model_name)

	# Before downloading the next model, delete the previous one to release space.
	# %rm -rf wandb
	# %rm -rf artifacts

# %%
prediction_pipeline("GINCO", dataset)
# Out:
# Finishing last run (ID:3emmjlla) before initializing another...
# Successfully finished last run (ID:3emmjlla). Initializing new run:<br/>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-data/Comparison-based-on-manual-checkup-MaCoCu-sl/wandb/run-20230105_132447-1au9xeop</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/GINCO-hyperparameter-search/runs/1au9xeop" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/GINCO-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact GINCO-downcast-classifier:v0, 1081.89MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 375 batches of 8 texts.
# Prediction with model GINCO started.
# 100%|██████████| 375/375 [08:03<00:00,  1.29s/it]
# Prediction with model GINCO completed. It took 8.06 minutes for 3000 instances - 0.0026866666666666666 minutes per one instance.

# %%
dataset.head(2)
# Out:
#        domain                       url  \
# 0  solemio.si       https://solemio.si/
# 1    bimbo.si  https://www.bimbo.si/cam
#
#                                                 text  length              FTD  \
# 0  Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...     468  A12 (promotion)
# 1  Cam\nGledati na svet z otroškimi očmi, da bi r...     230  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0088, 8: 0.0079, 0: 0.0132, 1: 0.0049, 6...        0.930402
# 1  {7: 0.0065, 8: 0.0048, 0: 0.0079, 1: 0.0025, 6...        0.952343
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence
# 0  {'Forum': 0.0015, 'News/Reporting': 0.0018, 'O...          0.951623
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0115, 'O...          0.801395

# %%
dataset["GINCO"].value_counts()
# Out:
# Promotion                     949
# News/Reporting                661
# Forum                         445
# Opinion/Argumentation         319
# List of Summaries/Excerpts    203
# Information/Explanation       186
# Instruction                   100
# Legal/Regulation               77
# Other                          60
# Name: GINCO, dtype: int64

# %%
prediction_pipeline("CORE", dataset)
# Out:
# Finishing last run (ID:1au9xeop) before initializing another...
# Successfully finished last run (ID:1au9xeop). Initializing new run:<br/>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-data/Comparison-based-on-manual-checkup-MaCoCu-sl/wandb/run-20230105_133521-1e15igtw</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/CORE-hyperparameter-search/runs/1e15igtw" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/CORE-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact CORE-main-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 375 batches of 8 texts.
# Prediction with model CORE started.
# 100%|██████████| 375/375 [06:41<00:00,  1.07s/it]
# Prediction with model CORE completed. It took 6.7 minutes for 3000 instances - 0.0022333333333333333 minutes per one instance.

# %%
dataset.head(2)
# Out:
#        domain                       url  \
# 0  solemio.si       https://solemio.si/
# 1    bimbo.si  https://www.bimbo.si/cam
#
#                                                 text  length              FTD  \
# 0  Ker nam ni vseeno\nTočke zvestobe\nZvestobo na...     468  A12 (promotion)
# 1  Cam\nGledati na svet z otroškimi očmi, da bi r...     230  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0088, 8: 0.0079, 0: 0.0132, 1: 0.0049, 6...        0.930402
# 1  {7: 0.0065, 8: 0.0048, 0: 0.0079, 1: 0.0025, 6...        0.952343
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0015, 'News/Reporting': 0.0018, 'O...          0.951623
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0115, 'O...          0.801395
#
#                        CORE  \
# 0  Informational Persuasion
# 1  Informational Persuasion
#
#                              CORE_label_distribution  CORE_confidence
# 0  {'Interactive Discussion': 0.0029, 'Narrative'...         0.535811
# 1  {'Interactive Discussion': 0.0022, 'Narrative'...         0.784336

# %%
dataset["CORE"].value_counts()
# Out:
# Informational Description/Explanation    941
# Narrative                                696
# Informational Persuasion                 562
# Interactive Discussion                   476
# Opinion                                  170
# How-To/Instructional                     109
# Spoken                                    26
# Lyrical                                   20
# Name: CORE, dtype: int64

# %%
prediction_pipeline("GINCO-X-GENRE", dataset)
# Out:
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-sl-sample2/wandb/run-20221125_094512-1q707l6l</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/1q707l6l" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact SI-GINCO-X-GENRE-classifier:v0, 1081.88MB. 44 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1250 batches of 8 texts.
# Prediction with model GINCO-X-GENRE started.
# 100%|██████████| 1250/1250 [19:43<00:00,  1.06it/s]
# Prediction with model GINCO-X-GENRE completed. It took 19.73 minutes for 10000 instances - 0.001973 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  zsc.si   http://www.zsc.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Nacionalna varnost je preresna stvar, da bi jo...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.283" title="ZSC - Zveza slo...     200        A8 (news)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0329, 8: 0.285, 0: 0.1495, 1: 0.0462, 6:...        0.285015
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0  List of Summaries/Excerpts
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0038, 'News/Reporting': 0.0289, 'O...          0.921079
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...          0.919409
#
#                                     CORE  \
# 0                              Narrative
# 1  Informational Description/Explanation
#
#                              CORE_label_distribution  CORE_confidence  \
# 0  {'Interactive Discussion': 0.003, 'Narrative':...         0.617481
# 1  {'Interactive Discussion': 0.0251, 'Narrative'...         0.650196
#
#   GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0          News  {'Information/Explanation': 0.0008, 'Opinion/A...
# 1     Promotion  {'Information/Explanation': 0.0029, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence
# 0                  0.990630
# 1                  0.984429

# %%
dataset["GINCO-X-GENRE"].value_counts(normalize=True)
# Out:
# Promotion                  0.4467
# Information/Explanation    0.1467
# News                       0.1352
# Opinion/Argumentation      0.0993
# Instruction                0.0816
# Other                      0.0615
# Forum                      0.0199
# Legal                      0.0078
# Prose/Lyrical              0.0013
# Name: GINCO-X-GENRE, dtype: float64

# %%
prediction_pipeline("FTD-X-GENRE", dataset)
# Out:
# Finishing last run (ID:1q707l6l) before initializing another...
# Successfully finished last run (ID:1q707l6l). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-sl-sample2/wandb/run-20221125_100632-2l7s2r8o</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/2l7s2r8o" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact FTD-X-GENRE-classifier:v0, 1081.88MB. 44 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1250 batches of 8 texts.
# Prediction with model FTD-X-GENRE started.
# 100%|██████████| 1250/1250 [22:34<00:00,  1.08s/it]
# Prediction with model FTD-X-GENRE completed. It took 22.57 minutes for 10000 instances - 0.002257 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  zsc.si   http://www.zsc.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Nacionalna varnost je preresna stvar, da bi jo...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.283" title="ZSC - Zveza slo...     200        A8 (news)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0329, 8: 0.285, 0: 0.1495, 1: 0.0462, 6:...        0.285015
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0  List of Summaries/Excerpts
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0038, 'News/Reporting': 0.0289, 'O...          0.921079
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...          0.919409
#
#                                     CORE  \
# 0                              Narrative
# 1  Informational Description/Explanation
#
#                              CORE_label_distribution  CORE_confidence  \
# 0  {'Interactive Discussion': 0.003, 'Narrative':...         0.617481
# 1  {'Interactive Discussion': 0.0251, 'Narrative'...         0.650196
#
#   GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0          News  {'Information/Explanation': 0.0008, 'Opinion/A...
# 1     Promotion  {'Information/Explanation': 0.0029, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence FTD-X-GENRE  \
# 0                  0.990630        News
# 1                  0.984429   Promotion
#
#                       FTD-X-GENRE_label_distribution  FTD-X-GENRE_confidence
# 0  {'Promotion': 0.2129, 'Opinion/Argumentation':...                0.551021
# 1  {'Promotion': 0.4754, 'Opinion/Argumentation':...                0.475421

# %%
dataset["FTD-X-GENRE"].value_counts(normalize=True)
# Out:
# Promotion                  0.6282
# Information/Explanation    0.1693
# News                       0.0789
# Instruction                0.0605
# Opinion/Argumentation      0.0320
# Legal                      0.0227
# Prose/Lyrical              0.0084
# Name: FTD-X-GENRE, dtype: float64

# %%
prediction_pipeline("CORE-X-GENRE", dataset)
# Out:
# Finishing last run (ID:2l7s2r8o) before initializing another...
# Successfully finished last run (ID:2l7s2r8o). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-sl-sample2/wandb/run-20221125_103610-3fsaijbh</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/3fsaijbh" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact CORE-X-GENRE-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1250 batches of 8 texts.
# Prediction with model CORE-X-GENRE started.
# 100%|██████████| 1250/1250 [22:37<00:00,  1.09s/it]
# Prediction with model CORE-X-GENRE completed. It took 22.62 minutes for 10000 instances - 0.002262 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  zsc.si   http://www.zsc.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Nacionalna varnost je preresna stvar, da bi jo...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.283" title="ZSC - Zveza slo...     200        A8 (news)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0329, 8: 0.285, 0: 0.1495, 1: 0.0462, 6:...        0.285015
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0  List of Summaries/Excerpts
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  ...  CORE_confidence  \
# 0  {'Forum': 0.0038, 'News/Reporting': 0.0289, 'O...  ...         0.617481
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...  ...         0.650196
#
#   GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0          News  {'Information/Explanation': 0.0008, 'Opinion/A...
# 1     Promotion  {'Information/Explanation': 0.0029, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence FTD-X-GENRE  \
# 0                  0.990630        News
# 1                  0.984429   Promotion
#
#                       FTD-X-GENRE_label_distribution  FTD-X-GENRE_confidence  \
# 0  {'Promotion': 0.2129, 'Opinion/Argumentation':...                0.551021
# 1  {'Promotion': 0.4754, 'Opinion/Argumentation':...                0.475421
#
#             CORE-X-GENRE                    CORE-X-GENRE_label_distribution  \
# 0                   News  {'Other': 0.0365, 'Information/Explanation': 0...
# 1  Opinion/Argumentation  {'Other': 0.0831, 'Information/Explanation': 0...
#
#    CORE-X-GENRE_confidence
# 0                 0.680891
# 1                 0.521125
#
# [2 rows x 23 columns]

# %%
dataset["CORE-X-GENRE"].value_counts(normalize=True)
# Out:
# Information/Explanation    0.4085
# Instruction                0.2019
# Opinion/Argumentation      0.1444
# News                       0.1343
# Forum                      0.0698
# Prose/Lyrical              0.0237
# Other                      0.0174
# Name: CORE-X-GENRE, dtype: float64

# %%
prediction_pipeline("X-GENRE", dataset)
# Out:
# Finishing last run (ID:1e15igtw) before initializing another...
# Successfully finished last run (ID:1e15igtw). Initializing new run:<br/>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-data/Comparison-based-on-manual-checkup-MaCoCu-sl/wandb/run-20230105_140343-33hvilmi</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/33hvilmi" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact X-GENRE-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 375 batches of 8 texts.
# Prediction with model X-GENRE started.
# 100%|██████████| 375/375 [06:42<00:00,  1.07s/it]
# Prediction with model X-GENRE completed. It took 6.71 minutes for 3000 instances - 0.0022366666666666668 minutes per one instance.

# %%
# View the final dataset
dataset.describe(include="all")
# Out:
#         domain                 url  \
# count    10000               10000
# unique    1000                9974
# top     zsc.si  http://www.zsc.si/
# freq        10                   3
# mean       NaN                 NaN
# std        NaN                 NaN
# min        NaN                 NaN
# 25%        NaN                 NaN
# 50%        NaN                 NaN
# 75%        NaN                 NaN
# max        NaN                 NaN
#
#                                                      text  \
# count                                               10000
# unique                                              10000
# top     Nacionalna varnost je preresna stvar, da bi jo...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       doc        length  \
# count                                               10000  10000.000000
# unique                                              10000           NaN
# top     <doc id="macocu.si.283" title="ZSC - Zveza slo...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    431.505500
# std                                                   NaN   1188.840319
# min                                                   NaN     76.000000
# 25%                                                   NaN    126.000000
# 50%                                                   NaN    221.000000
# 75%                                                   NaN    424.000000
# max                                                   NaN  56091.000000
#
#                     FTD                             FTD_label_distribution  \
# count             10000                                              10000
# unique               10                                              10000
# top     A12 (promotion)  {7: 0.0329, 8: 0.285, 0: 0.1495, 1: 0.0462, 6:...
# freq               5891                                                  1
# mean                NaN                                                NaN
# std                 NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
#
#         FTD_confidence      GINCO  \
# count     10000.000000      10000
# unique             NaN          9
# top                NaN  Promotion
# freq               NaN       4044
# mean          0.698041        NaN
# std           0.234183        NaN
# min           0.156952        NaN
# 25%           0.486665        NaN
# 50%           0.776443        NaN
# 75%           0.916415        NaN
# max           0.963047        NaN
#
#                                  GINCO_label_distribution  ...  \
# count                                               10000  ...
# unique                                              10000  ...
# top     {'Forum': 0.0038, 'News/Reporting': 0.0289, 'O...  ...
# freq                                                    1  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#         GINCO-X-GENRE_confidence FTD-X-GENRE  \
# count               10000.000000       10000
# unique                       NaN           7
# top                          NaN   Promotion
# freq                         NaN        6282
# mean                    0.938409         NaN
# std                     0.117327         NaN
# min                     0.255282         NaN
# 25%                     0.959605         NaN
# 50%                     0.988922         NaN
# 75%                     0.992147         NaN
# max                     0.994778         NaN
#
#                            FTD-X-GENRE_label_distribution  \
# count                                               10000
# unique                                              10000
# top     {'Promotion': 0.2129, 'Opinion/Argumentation':...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         FTD-X-GENRE_confidence             CORE-X-GENRE  \
# count             10000.000000                    10000
# unique                     NaN                        7
# top                        NaN  Information/Explanation
# freq                       NaN                     4085
# mean                  0.773492                      NaN
# std                   0.191455                      NaN
# min                   0.188668                      NaN
# 25%                   0.634583                      NaN
# 50%                   0.863190                      NaN
# 75%                   0.928335                      NaN
# max                   0.973481                      NaN
#
#                           CORE-X-GENRE_label_distribution  \
# count                                               10000
# unique                                              10000
# top     {'Other': 0.0365, 'Information/Explanation': 0...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         CORE-X-GENRE_confidence    X-GENRE  \
# count              10000.000000      10000
# unique                      NaN          9
# top                         NaN  Promotion
# freq                        NaN       3875
# mean                   0.560823        NaN
# std                    0.234900        NaN
# min                    0.149268        NaN
# 25%                    0.347263        NaN
# 50%                    0.537455        NaN
# 75%                    0.783557        NaN
# max                    0.948538        NaN
#
#                                X-GENRE_label_distribution  X-GENRE_confidence
# count                                               10000        10000.000000
# unique                                               5121                 NaN
# top     {'Other': 0.0002, 'Information/Explanation': 0...                 NaN
# freq                                                  762                 NaN
# mean                                                  NaN            0.969197
# std                                                   NaN            0.091506
# min                                                   NaN            0.332393
# 25%                                                   NaN            0.995489
# 50%                                                   NaN            0.998672
# 75%                                                   NaN            0.998982
# max                                                   NaN            0.999148
#
# [11 rows x 26 columns]

# %%
dataset["X-GENRE"].value_counts()
# Out:
# Promotion                  3875
# Information/Explanation    1810
# News                       1474
# Opinion/Argumentation      1185
# Instruction                 860
# Other                       327
# Forum                       246
# Legal                       165
# Prose/Lyrical                58
# Name: X-GENRE, dtype: int64

# %%
dataset.columns
# Out:
# Index(['domain', 'url', 'text', 'doc', 'length', 'FTD',
#        'FTD_label_distribution', 'FTD_confidence', 'GINCO',
#        'GINCO_label_distribution', 'GINCO_confidence', 'CORE',
#        'CORE_label_distribution', 'CORE_confidence', 'GINCO-X-GENRE',
#        'GINCO-X-GENRE_label_distribution', 'GINCO-X-GENRE_confidence',
#        'FTD-X-GENRE', 'FTD-X-GENRE_label_distribution',
#        'FTD-X-GENRE_confidence', 'CORE-X-GENRE',
#        'CORE-X-GENRE_label_distribution', 'CORE-X-GENRE_confidence', 'X-GENRE',
#        'X-GENRE_label_distribution', 'X-GENRE_confidence'],
#       dtype='object')

# %%
# Save the final dataset with results
dataset.to_csv("MaCoCu-sl_sample2_with_predictions.csv", sep="\t")
