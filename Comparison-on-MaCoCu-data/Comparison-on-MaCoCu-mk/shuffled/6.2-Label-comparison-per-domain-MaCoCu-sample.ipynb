# %% [markdown]
# ## Beginning

# %%
import pandas as pd
import numpy as np
import regex as re
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, f1_score,precision_score, recall_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from statistics import multimode
from apyori import apriori
import utils

classifiers = ["FTD", "GINCO", "CORE", "GINCO-X-GENRE", "FTD-X-GENRE", "CORE-X-GENRE", "X-GENRE"]

# Open the file

# Show all columns
pd.set_option('display.max_columns', None)

corpus_name = "MaCoCu-mk-shuffled"

corpus = pd.read_csv("MaCoCu-mk_with_predictions.csv",index_col=0, sep="\t")

# Define the extended corpus and domain-level corpus if you already created them
extended_corpus = pd.read_csv(f"MaCoCu-mk-shuffled_with_predictions-domain-info-added.csv", sep="\t", index_col = 0)
genre_distribution = pd.read_csv(f"MaCoCu-mk-shuffled-domain-level.csv", sep="\t", index_col = 0)

# %%
corpus.head(3)
# Out:
#    domain                 url  \
# 0   gg.mk      https://gg.mk/
# 1   qs.mk  https://www.qs.mk/
# 2  in2.mk      http://in2.mk/
#
#                                                 text  \
# 0  Тоа е тоа, екипа. Претпоследната епизода ја на...
# 1  Парадата на гордоста се враќа под слоганот "Во...
# 2  Од крајот на месец Ноември 2009 година, своето...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.mk.4" title="GG.MK - е-спорт &...     864     A17 (review)
# 1  <doc id="macocu.mk.5" title="КВИР СКВЕР Скопје...    1054  A12 (promotion)
# 2  <doc id="macocu.mk.25" title="IN2 - ПOЧЕTHA CT...     162  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0152, 8: 0.1352, 0: 0.0334, 1: 0.0402, 6...        0.643622
# 1  {7: 0.0056, 8: 0.0162, 0: 0.0263, 1: 0.0047, 6...        0.904037
# 2  {7: 0.0102, 8: 0.0147, 0: 0.0178, 1: 0.0055, 6...        0.902866
#
#                         GINCO  \
# 0  List of Summaries/Excerpts
# 1  List of Summaries/Excerpts
# 2                   Promotion
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0036, 'News/Reporting': 0.0147, 'O...          0.919893
# 1  {'Forum': 0.0037, 'News/Reporting': 0.0111, 'O...          0.780482
# 2  {'Forum': 0.0014, 'News/Reporting': 0.0022, 'O...          0.957065
#
#                                     CORE  \
# 0                                Opinion
# 1  Informational Description/Explanation
# 2  Informational Description/Explanation
#
#                              CORE_label_distribution  CORE_confidence  \
# 0  {'Interactive Discussion': 0.0085, 'Narrative'...         0.541413
# 1  {'Interactive Discussion': 0.001, 'Narrative':...         0.950632
# 2  {'Interactive Discussion': 0.0011, 'Narrative'...         0.976693
#
#            GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0  Opinion/Argumentation  {'Information/Explanation': 0.0055, 'Opinion/A...
# 1              Promotion  {'Information/Explanation': 0.0014, 'Opinion/A...
# 2              Promotion  {'Information/Explanation': 0.0014, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence FTD-X-GENRE  \
# 0                  0.861316   Promotion
# 1                  0.990890   Promotion
# 2                  0.989641   Promotion
#
#                       FTD-X-GENRE_label_distribution  FTD-X-GENRE_confidence  \
# 0  {'Promotion': 0.526, 'Opinion/Argumentation': ...                0.525988
# 1  {'Promotion': 0.9479, 'Opinion/Argumentation':...                0.947886
# 2  {'Promotion': 0.9251, 'Opinion/Argumentation':...                0.925099
#
#               CORE-X-GENRE                    CORE-X-GENRE_label_distribution  \
# 0    Opinion/Argumentation  {'Other': 0.0953, 'Information/Explanation': 0...
# 1                     News  {'Other': 0.1212, 'Information/Explanation': 0...
# 2  Information/Explanation  {'Other': 0.0706, 'Information/Explanation': 0...
#
#    CORE-X-GENRE_confidence                X-GENRE  \
# 0                 0.419943  Opinion/Argumentation
# 1                 0.533915              Promotion
# 2                 0.317117              Promotion
#
#                           X-GENRE_label_distribution  X-GENRE_confidence  \
# 0  {'Other': 0.0002, 'Information/Explanation': 0...            0.998700
# 1  {'Other': 0.0004, 'Information/Explanation': 0...            0.998806
# 2  {'Other': 0.0003, 'Information/Explanation': 0...            0.998599
#
#   X-GENRE-majority-label X-GENRE-majority-label-tie
# 0  Opinion/Argumentation                         no
# 1              Promotion                         no
# 2              Promotion                         no

# %%
# Keep only relevant columns
corpus = corpus[['domain', 'url', 'text', 'doc', 'length', 'FTD',
       'GINCO', 'CORE', 'GINCO-X-GENRE',
       'FTD-X-GENRE', 'CORE-X-GENRE','X-GENRE']]

# %%
corpus["FTD"].head()
# Out:
# 0          A17 (review)
# 1       A12 (promotion)
# 2       A12 (promotion)
# 3    A1 (argumentative)
# 4    A1 (argumentative)
# Name: FTD, dtype: object

# %%
corpus["FTD"].head()
# Out:
# 0    A14 (academic)
# 1         A8 (news)
# 2         A8 (news)
# 3         A8 (news)
# 4      A17 (review)
# Name: FTD, dtype: object

# %%
# Now, let's shuffle the predictions of all classifiers
for i in classifiers:
	label_list = list(corpus[i])
	random.shuffle(label_list)
	corpus[i] = label_list

corpus.head(5)
# Out:
#    domain                 url  \
# 0   gg.mk      https://gg.mk/
# 1   qs.mk  https://www.qs.mk/
# 2  in2.mk      http://in2.mk/
# 3  ldp.mk     https://ldp.mk/
# 4  iep.mk     https://iep.mk/
#
#                                                 text  \
# 0  Тоа е тоа, екипа. Претпоследната епизода ја на...
# 1  Парадата на гордоста се враќа под слоганот "Во...
# 2  Од крајот на месец Ноември 2009 година, своето...
# 3  Што не прави либрали?\nЕманципација од стравов...
# 4  ИНИЦИЈАТИВА ЗА ЕВРОПСКА ПЕРСПЕКТИВА\nЗдружение...
#
#                                                  doc  length             FTD  \
# 0  <doc id="macocu.mk.4" title="GG.MK - е-спорт &...     864  A14 (academic)
# 1  <doc id="macocu.mk.5" title="КВИР СКВЕР Скопје...    1054       A8 (news)
# 2  <doc id="macocu.mk.25" title="IN2 - ПOЧЕTHA CT...     162       A8 (news)
# 3  <doc id="macocu.mk.35" title="Либерално демокр...     343       A8 (news)
# 4  <doc id="macocu.mk.37" title="Иницијатива за Е...     182    A17 (review)
#
#                      GINCO                                   CORE  \
# 0    Opinion/Argumentation                              Narrative
# 1  Information/Explanation                              Narrative
# 2           News/Reporting  Informational Description/Explanation
# 3  Information/Explanation  Informational Description/Explanation
# 4           News/Reporting                              Narrative
#
#              GINCO-X-GENRE  FTD-X-GENRE             CORE-X-GENRE  \
# 0                     News    Promotion    Opinion/Argumentation
# 1  Information/Explanation    Promotion                     News
# 2  Information/Explanation    Promotion  Information/Explanation
# 3  Information/Explanation    Promotion  Information/Explanation
# 4  Information/Explanation  Instruction                     News
#
#                  X-GENRE
# 0  Opinion/Argumentation
# 1            Instruction
# 2                  Other
# 3                   News
# 4                   News

# %% [markdown]
# ## General analysis

# %% [markdown]
# ### Label confidence per classifier

# %%
# Print the label confidence for each classifier
utils.label_confidence(corpus, classifiers)

# %% [markdown]
# ### Most frequent values per classifier

# %%
utils.most_frequent_values(corpus, classifiers)

# %% [markdown]
# ### Label distribution per classifier

# %%
# Create a dataframe with label distribution per classifier
utils.label_distribution(corpus, classifiers)
# Out:
# | label_distribution_FTD       | label_distribution_GINCO             | label_distribution_CORE                         | label_distribution_GINCO-X-GENRE   | label_distribution_FTD-X-GENRE    | label_distribution_CORE-X-GENRE   | label_distribution_X-GENRE        |
# |:-----------------------------|:-------------------------------------|:------------------------------------------------|:-----------------------------------|:----------------------------------|:----------------------------------|:----------------------------------|
# | ('A12 (promotion)', 0.42)    | ('News/Reporting', 0.31)             | ('Informational Description/Explanation', 0.58) | ('News', 0.31)                     | ('Promotion', 0.44)               | ('Information/Explanation', 0.36) | ('News', 0.34)                    |
# | ('A8 (news)', 0.2)           | ('Promotion', 0.24)                  | ('Narrative', 0.24)                             | ('Promotion', 0.29)                | ('News', 0.26)                    | ('News', 0.31)                    | ('Promotion', 0.27)               |
# | ('A1 (argumentative)', 0.13) | ('Information/Explanation', 0.18)    | ('Informational Persuasion', 0.07)              | ('Information/Explanation', 0.19)  | ('Information/Explanation', 0.19) | ('Instruction', 0.13)             | ('Information/Explanation', 0.18) |
# | ('A16 (information)', 0.12)  | ('List of Summaries/Excerpts', 0.08) | ('Opinion', 0.04)                               | ('Other', 0.08)                    | ('Instruction', 0.05)             | ('Opinion/Argumentation', 0.13)   | ('Opinion/Argumentation', 0.08)   |
# | ('A7 (instruction)', 0.04)   | ('Opinion/Argumentation', 0.08)      | ('How-To/Instructional', 0.04)                  | ('Opinion/Argumentation', 0.06)    | ('Legal', 0.03)                   | ('Forum', 0.04)                   | ('Instruction', 0.07)             |
# | ('A17 (review)', 0.04)       | ('Instruction', 0.05)                | ('Interactive Discussion', 0.01)                | ('Instruction', 0.06)              | ('Opinion/Argumentation', 0.02)   | ('Prose/Lyrical', 0.02)           | ('Other', 0.03)                   |
# | ('A9 (legal)', 0.02)         | ('Other', 0.03)                      | ('Spoken', 0.01)                                | ('Legal', 0.01)                    | ('Prose/Lyrical', 0.01)           | ('Other', 0.01)                   | ('Legal', 0.02)                   |
# | ('A11 (personal)', 0.01)     | ('Forum', 0.01)                      | ('Lyrical', 0.0)                                | ('Forum', 0.01)                    |                                   |                                   | ('Forum', 0.01)                   |
# | ('A14 (academic)', 0.01)     | ('Legal/Regulation', 0.01)           |                                                 | ('Prose/Lyrical', 0.0)             |                                   |                                   | ('Prose/Lyrical', 0.01)           |
# | ('A4 (fiction)', 0.0)        |                                      |                                                 |                                    |                                   |                                   |                                   |
# |                              |                                      |                                                 |                                    |                                   |                                   |                                   |
# |                              |                                      |                                                 |                                    |                                   |                                   |                                   |

# %% [markdown]
# ## Analysis based on domains

# %% [markdown]
# ### Create a domain level corpus and the extended corpus

# %%
# Create a corpus where instances are grouped into domains, and with additional information on the most common labels per domains
genre_distribution = utils.calculate_label_per_domain(corpus, classifiers)

genre_distribution.head(3)
# Out:
#       domain_id                               genres-in-domain-FTD  \
# 0    101foot.mk  {'A9 (legal)': 1, 'A16 (information)': 3, 'A12...
# 1  2020.iffs.mk  {'A16 (information)': 1, 'A12 (promotion)': 7,...
# 2   24apteka.mk  {'A12 (promotion)': 3, 'A8 (news)': 2, 'A16 (i...
#
#                               genres-in-domain-GINCO  \
# 0  {'Information/Explanation': 3, 'News/Reporting...
# 1  {'Information/Explanation': 1, 'Instruction': ...
# 2  {'News/Reporting': 5, 'Promotion': 4, 'Instruc...
#
#                                genres-in-domain-CORE  \
# 0  {'Informational Description/Explanation': 9, '...
# 1  {'Informational Description/Explanation': 6, '...
# 2  {'Informational Description/Explanation': 7, '...
#
#                       genres-in-domain-GINCO-X-GENRE  \
# 0  {'Promotion': 1, 'Opinion/Argumentation': 1, '...
# 1  {'Opinion/Argumentation': 2, 'Promotion': 3, '...
# 2                        {'Promotion': 5, 'News': 5}
#
#                         genres-in-domain-FTD-X-GENRE  \
# 0  {'Promotion': 4, 'News': 4, 'Legal': 1, 'Instr...
# 1                        {'News': 5, 'Promotion': 5}
# 2  {'News': 3, 'Promotion': 1, 'Information/Expla...
#
#                        genres-in-domain-CORE-X-GENRE  \
# 0  {'News': 4, 'Forum': 1, 'Information/Explanati...
# 1  {'News': 4, 'Other': 1, 'Information/Explanati...
# 2  {'News': 3, 'Information/Explanation': 5, 'Opi...
#
#                             genres-in-domain-X-GENRE  \
# 0  {'Opinion/Argumentation': 1, 'Instruction': 2,...
# 1  {'Information/Explanation': 6, 'News': 3, 'Opi...
# 2  {'News': 5, 'Promotion': 3, 'Instruction': 1, ...
#
#    biggest-label-frequency-FTD  biggest-label-frequency-GINCO  \
# 0                            3                              6
# 1                            7                              3
# 2                            3                              5
#
#    biggest-label-frequency-CORE  biggest-label-frequency-GINCO-X-GENRE  \
# 0                             9                                      4
# 1                             6                                      3
# 2                             7                                      5
#
#    biggest-label-frequency-FTD-X-GENRE  biggest-label-frequency-CORE-X-GENRE  \
# 0                                    4                                     4
# 1                                    5                                     4
# 2                                    5                                     5
#
#    biggest-label-frequency-X-GENRE most_frequent_label_FTD tie-FTD  \
# 0                                5       A16 (information)     yes
# 1                                6         A12 (promotion)      no
# 2                                5         A12 (promotion)      no
#
#   most_frequent_label_GINCO tie-GINCO               most_frequent_label_CORE  \
# 0            News/Reporting        no  Informational Description/Explanation
# 1            News/Reporting        no  Informational Description/Explanation
# 2            News/Reporting        no  Informational Description/Explanation
#
#   tie-CORE most_frequent_label_GINCO-X-GENRE tie-GINCO-X-GENRE  \
# 0       no           Information/Explanation                no
# 1       no                              News               yes
# 2       no                         Promotion               yes
#
#   most_frequent_label_FTD-X-GENRE tie-FTD-X-GENRE  \
# 0                       Promotion             yes
# 1                            News             yes
# 2         Information/Explanation              no
#
#   most_frequent_label_CORE-X-GENRE tie-CORE-X-GENRE  \
# 0                             News               no
# 1          Information/Explanation              yes
# 2          Information/Explanation               no
#
#   most_frequent_label_X-GENRE tie-X-GENRE
# 0                        News          no
# 1     Information/Explanation          no
# 2                        News          no

# %%
# Save the domain-level corpus
genre_distribution.to_csv(f"{corpus_name}-domain-level.csv", sep="\t")

# %%
# Then merge the domain-level df with the initial corpus so that all the domain information will be added to each instance from the domain
extended_corpus = pd.merge(left = corpus, right = genre_distribution, how = "left", left_on= "domain", right_on= "domain_id", suffixes=["",""])

extended_corpus.head(2)
# Out:
#   domain                 url  \
# 0  gg.mk      https://gg.mk/
# 1  qs.mk  https://www.qs.mk/
#
#                                                 text  \
# 0  Тоа е тоа, екипа. Претпоследната епизода ја на...
# 1  Парадата на гордоста се враќа под слоганот "Во...
#
#                                                  doc  length             FTD  \
# 0  <doc id="macocu.mk.4" title="GG.MK - е-спорт &...     864  A14 (academic)
# 1  <doc id="macocu.mk.5" title="КВИР СКВЕР Скопје...    1054       A8 (news)
#
#                      GINCO       CORE            GINCO-X-GENRE FTD-X-GENRE  \
# 0    Opinion/Argumentation  Narrative                     News   Promotion
# 1  Information/Explanation  Narrative  Information/Explanation   Promotion
#
#             CORE-X-GENRE                X-GENRE domain_id  \
# 0  Opinion/Argumentation  Opinion/Argumentation     gg.mk
# 1                   News            Instruction     qs.mk
#
#                                 genres-in-domain-FTD  \
# 0  {'A14 (academic)': 1, 'A1 (argumentative)': 3,...
# 1  {'A8 (news)': 1, 'A12 (promotion)': 4, 'A1 (ar...
#
#                               genres-in-domain-GINCO  \
# 0  {'Opinion/Argumentation': 2, 'Promotion': 1, '...
# 1  {'Information/Explanation': 3, 'News/Reporting...
#
#                                genres-in-domain-CORE  \
# 0  {'Narrative': 1, 'Informational Description/Ex...
# 1  {'Narrative': 4, 'Opinion': 1, 'Informational ...
#
#                       genres-in-domain-GINCO-X-GENRE  \
# 0  {'News': 4, 'Information/Explanation': 4, 'Oth...
# 1  {'Information/Explanation': 2, 'News': 2, 'Pro...
#
#                         genres-in-domain-FTD-X-GENRE  \
# 0  {'Promotion': 4, 'Information/Explanation': 2,...
# 1  {'Promotion': 5, 'News': 3, 'Information/Expla...
#
#                        genres-in-domain-CORE-X-GENRE  \
# 0  {'Opinion/Argumentation': 1, 'News': 3, 'Forum...
# 1  {'News': 4, 'Information/Explanation': 4, 'For...
#
#                             genres-in-domain-X-GENRE  \
# 0  {'Opinion/Argumentation': 2, 'Promotion': 2, '...
# 1  {'Instruction': 2, 'Promotion': 2, 'Informatio...
#
#    biggest-label-frequency-FTD  biggest-label-frequency-GINCO  \
# 0                            3                              4
# 1                            4                              6
#
#    biggest-label-frequency-CORE  biggest-label-frequency-GINCO-X-GENRE  \
# 0                             8                                      4
# 1                             5                                      4
#
#    biggest-label-frequency-FTD-X-GENRE  biggest-label-frequency-CORE-X-GENRE  \
# 0                                    4                                     4
# 1                                    5                                     4
#
#    biggest-label-frequency-X-GENRE most_frequent_label_FTD tie-FTD  \
# 0                                3      A1 (argumentative)     yes
# 1                                3         A12 (promotion)      no
#
#   most_frequent_label_GINCO tie-GINCO               most_frequent_label_CORE  \
# 0            News/Reporting        no  Informational Description/Explanation
# 1            News/Reporting        no  Informational Description/Explanation
#
#   tie-CORE most_frequent_label_GINCO-X-GENRE tie-GINCO-X-GENRE  \
# 0       no           Information/Explanation               yes
# 1       no                         Promotion                no
#
#   most_frequent_label_FTD-X-GENRE tie-FTD-X-GENRE  \
# 0                       Promotion              no
# 1                       Promotion              no
#
#   most_frequent_label_CORE-X-GENRE tie-CORE-X-GENRE  \
# 0          Information/Explanation               no
# 1                             News              yes
#
#   most_frequent_label_X-GENRE tie-X-GENRE
# 0                        News          no
# 1     Information/Explanation         yes

# %%
# Save the extended corpus
extended_corpus.to_csv(f"{corpus_name}_with_predictions-domain-info-added.csv", sep="\t")

# %% [markdown]
# ### Graphs based on frequency of most frequent label in the domains

# %%
utils.create_graphs(genre_distribution, classifiers, corpus_name)

# %% [markdown]
# ### Most frequent labels per domain
# We will look into how many times each specific category was most frequent on a domain. For this, I will use the domain-level corpus (genre_distribution dataframe). I will group the texts into domains and calculate for each label in each schema in how many domains it is the most frequent.

# %%
utils.label_distribution_per_domain(genre_distribution, classifiers)
# Out:
# | label_distribution_FTD       | label_distribution_GINCO             | label_distribution_CORE                         | label_distribution_GINCO-X-GENRE   | label_distribution_FTD-X-GENRE    | label_distribution_CORE-X-GENRE   | label_distribution_X-GENRE        |
# |:-----------------------------|:-------------------------------------|:------------------------------------------------|:-----------------------------------|:----------------------------------|:----------------------------------|:----------------------------------|
# | ('A12 (promotion)', 0.73)    | ('News/Reporting', 0.51)             | ('Informational Description/Explanation', 0.88) | ('Promotion', 0.41)                | ('Promotion', 0.67)               | ('Information/Explanation', 0.52) | ('News', 0.54)                    |
# | ('A8 (news)', 0.15)          | ('Promotion', 0.29)                  | ('Narrative', 0.11)                             | ('News', 0.4)                      | ('News', 0.21)                    | ('News', 0.39)                    | ('Promotion', 0.3)                |
# | ('A1 (argumentative)', 0.06) | ('Information/Explanation', 0.14)    | ('Informational Persuasion', 0.0)               | ('Information/Explanation', 0.15)  | ('Information/Explanation', 0.12) | ('Instruction', 0.05)             | ('Information/Explanation', 0.13) |
# | ('A16 (information)', 0.04)  | ('Opinion/Argumentation', 0.03)      | ('Opinion', 0.0)                                | ('Other', 0.02)                    | ('Instruction', 0.0)              | ('Opinion/Argumentation', 0.04)   | ('Opinion/Argumentation', 0.01)   |
# | ('A7 (instruction)', 0.0)    | ('List of Summaries/Excerpts', 0.02) | ('How-To/Instructional', 0.0)                   | ('Opinion/Argumentation', 0.01)    |                                   | ('Prose/Lyrical', 0.0)            | ('Instruction', 0.01)             |
# | ('A17 (review)', 0.0)        | ('Instruction', 0.01)                |                                                 | ('Instruction', 0.01)              |                                   | ('Forum', 0.0)                    | ('Other', 0.0)                    |
# | ('A9 (legal)', 0.0)          | ('Other', 0.0)                       |                                                 |                                    |                                   |                                   | ('Legal', 0.0)                    |
# |                              | ('Forum', 0.0)                       |                                                 |                                    |                                   |                                   |                                   |
# |                              | ('Legal/Regulation', 0.0)            |                                                 |                                    |                                   |                                   |                                   |
# |                              |                                      |                                                 |                                    |                                   |                                   |                                   |
# |                              |                                      |                                                 |                                    |                                   |                                   |                                   |
# |                              |                                      |                                                 |                                    |                                   |                                   |                                   |

# %% [markdown]
# ### Calculating scores assuming domains are uni-genre
# Calculating F1, precision, recall assuming that domains are uni-genre. To calculate this, I will take the predicted labels as y_pred and the most_frequent_label (most frequent label in domain) labels as y_true.
#
# For this, I will use the extended corpus (which is instance-level, but contains the information on domains).

# %%
results_scores_based_on_domain = utils.scores_based_on_domains(extended_corpus, classifiers)
# Out:
# Classifier: FTD
# Macro F1: 0.15, Micro F1: 0.45, Accuracy: 0.45
# Krippendorfs Alpha: 0.12
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#     A14 (academic)       0.00      0.00      0.00         0
#          A8 (news)       0.29      0.38      0.33      1500
#       A17 (review)       0.02      0.27      0.04        30
# A1 (argumentative)       0.16      0.36      0.22       610
#  A16 (information)       0.13      0.36      0.20       450
#    A12 (promotion)       0.84      0.49      0.62      7350
#     A11 (personal)       0.00      0.00      0.00         0
#   A7 (instruction)       0.02      0.28      0.05        40
#       A4 (fiction)       0.00      0.00      0.00         0
#         A9 (legal)       0.02      0.20      0.04        20
#
#           accuracy                           0.45     10000
#          macro avg       0.15      0.23      0.15     10000
#       weighted avg       0.68      0.45      0.53     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classifier: GINCO
# Macro F1: 0.2, Micro F1: 0.4, Accuracy: 0.4
# Krippendorfs Alpha: 0.17
#                             precision    recall  f1-score   support
#
#      Opinion/Argumentation       0.10      0.30      0.15       260
#    Information/Explanation       0.29      0.35      0.32      1450
#             News/Reporting       0.68      0.42      0.52      5060
# List of Summaries/Excerpts       0.09      0.33      0.14       220
#                      Other       0.04      0.33      0.07        40
#                  Promotion       0.46      0.39      0.42      2870
#                Instruction       0.04      0.26      0.07        80
#                      Forum       0.02      0.20      0.03        10
#           Legal/Regulation       0.03      0.20      0.05        10
#
#                   accuracy                           0.40     10000
#                  macro avg       0.19      0.31      0.20     10000
#               weighted avg       0.52      0.40      0.44     10000
# Classifier: CORE
# Macro F1: 0.14, Micro F1: 0.6, Accuracy: 0.6
# Krippendorfs Alpha: 0.07
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                        precision    recall  f1-score   support
#
#                             Narrative       0.22      0.47      0.30      1130
# Informational Description/Explanation       0.93      0.62      0.74      8790
#                               Opinion       0.02      0.27      0.03        30
#                  How-To/Instructional       0.01      0.30      0.03        20
#              Informational Persuasion       0.02      0.40      0.03        30
#                                Spoken       0.00      0.00      0.00         0
#                Interactive Discussion       0.00      0.00      0.00         0
#                               Lyrical       0.00      0.00      0.00         0
#
#                              accuracy                           0.60     10000
#                             macro avg       0.15      0.26      0.14     10000
#                          weighted avg       0.84      0.60      0.69     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classifier: GINCO-X-GENRE
# Macro F1: 0.18, Micro F1: 0.41, Accuracy: 0.41
# Krippendorfs Alpha: 0.19
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#                    News       0.57      0.43      0.49      4040
# Information/Explanation       0.31      0.38      0.34      1490
#               Promotion       0.59      0.42      0.49      4070
#   Opinion/Argumentation       0.06      0.28      0.09       130
#                   Other       0.07      0.31      0.11       170
#             Instruction       0.05      0.28      0.08       100
#                   Forum       0.00      0.00      0.00         0
#                   Legal       0.00      0.00      0.00         0
#           Prose/Lyrical       0.00      0.00      0.00         0
#
#                accuracy                           0.41     10000
#               macro avg       0.18      0.23      0.18     10000
#            weighted avg       0.52      0.41      0.45     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classifier: FTD-X-GENRE
# Macro F1: 0.2, Micro F1: 0.49, Accuracy: 0.49
# Krippendorfs Alpha: 0.17
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#               Promotion       0.80      0.52      0.63      6700
#             Instruction       0.03      0.33      0.05        40
# Information/Explanation       0.25      0.42      0.31      1150
#                    News       0.35      0.44      0.39      2110
#           Prose/Lyrical       0.00      0.00      0.00         0
#                   Legal       0.00      0.00      0.00         0
#   Opinion/Argumentation       0.00      0.00      0.00         0
#
#                accuracy                           0.49     10000
#               macro avg       0.20      0.24      0.20     10000
#            weighted avg       0.64      0.49      0.54     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classifier: CORE-X-GENRE
# Macro F1: 0.21, Micro F1: 0.45, Accuracy: 0.45
# Krippendorfs Alpha: 0.18
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#   Opinion/Argumentation       0.13      0.36      0.19       450
#                    News       0.56      0.45      0.50      3890
# Information/Explanation       0.66      0.46      0.55      5150
#             Instruction       0.14      0.37      0.20       490
#                   Forum       0.01      0.40      0.02        10
#           Prose/Lyrical       0.02      0.30      0.04        10
#                   Other       0.00      0.00      0.00         0
#
#                accuracy                           0.45     10000
#               macro avg       0.22      0.33      0.21     10000
#            weighted avg       0.57      0.45      0.49     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classifier: X-GENRE
# Macro F1: 0.17, Micro F1: 0.42, Accuracy: 0.42
# Krippendorfs Alpha: 0.17
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#   Opinion/Argumentation       0.06      0.32      0.10       140
#             Instruction       0.06      0.31      0.10       120
#                   Other       0.01      0.20      0.01        10
#                    News       0.69      0.44      0.54      5350
#               Promotion       0.47      0.41      0.44      3040
# Information/Explanation       0.28      0.37      0.32      1330
#                   Legal       0.01      0.30      0.02        10
#                   Forum       0.00      0.00      0.00         0
#           Prose/Lyrical       0.00      0.00      0.00         0
#
#                accuracy                           0.42     10000
#               macro avg       0.17      0.26      0.17     10000
#            weighted avg       0.55      0.42      0.47     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# | Classifier    |   Accuracy |   Krippendorfs Alpha |   Macro F1 |   Micro F1 |   Macro precision |   Macro recall |
# |:--------------|-----------:|---------------------:|-----------:|-----------:|------------------:|---------------:|
# | CORE-X-GENRE  |       0.45 |                 0.18 |       0.21 |       0.45 |              0.22 |           0.33 |
# | GINCO         |       0.4  |                 0.17 |       0.2  |       0.4  |              0.19 |           0.31 |
# | FTD-X-GENRE   |       0.49 |                 0.17 |       0.2  |       0.49 |              0.2  |           0.24 |
# | GINCO-X-GENRE |       0.41 |                 0.19 |       0.18 |       0.41 |              0.18 |           0.23 |
# | X-GENRE       |       0.42 |                 0.17 |       0.17 |       0.42 |              0.17 |           0.26 |
# | FTD           |       0.45 |                 0.12 |       0.15 |       0.45 |              0.15 |           0.23 |
# | CORE          |       0.6  |                 0.07 |       0.14 |       0.6  |              0.15 |           0.26 |

# %% [markdown]
# ### Scores based on agreement of labels inside domains

# %%
utils.calculate_hits(extended_corpus, genre_distribution, classifiers)
# Out:
# | Classifier    |   Hits |   Hits percentage |
# |:--------------|-------:|------------------:|
# | CORE          |  18274 |              0.41 |
# | CORE-X-GENRE  |  11794 |              0.26 |
# | FTD           |  11380 |              0.25 |
# | FTD-X-GENRE   |  13679 |              0.3  |
# | GINCO         |   9246 |              0.21 |
# | GINCO-X-GENRE |  10109 |              0.22 |
# | X-GENRE       |  10358 |              0.23 |

# %% [markdown]
# ## Comparison of X-GENRE predictions based on the majority prediction
# Focus only on X-genre and assume the domain label to be the one that has been chosen most by ALL classifiers, calculate F1, (microF1, macroF1). For this, we will use the extended corpus.

# %%
x_genre_majority_results = utils.scores_based_on_xgenre_majority(extended_corpus, "MaCoCu-is")
# Out:
# Number of ties when defining the majority label:
# |     |   X-GENRE-majority-label-tie |
# |:----|-----------------------------:|
# | no  |                       0.6947 |
# | yes |                       0.3053 |
# Majority label distribution:
# |                         |   X-GENRE-majority-label |
# |:------------------------|-------------------------:|
# | Promotion               |                   0.4862 |
# | Information/Explanation |                   0.2257 |
# | News                    |                   0.0986 |
# | Instruction             |                   0.0779 |
# | Opinion/Argumentation   |                   0.0713 |
# | Forum                   |                   0.0153 |
# | Other                   |                   0.0145 |
# | Legal                   |                   0.0073 |
# | Prose/Lyrical           |                   0.0032 |
# Classifier: GINCO-X-GENRE
# Macro F1: 0.33, Micro F1: 0.54, Accuracy: 0.54
#                          precision    recall  f1-score   support
#
# Information/Explanation       0.59      0.38      0.46      2257
#             Instruction       0.35      0.37      0.36       779
#               Promotion       0.73      0.68      0.70      4862
#   Opinion/Argumentation       0.32      0.45      0.38       713
#                   Forum       0.20      0.26      0.23       153
#                    News       0.36      0.49      0.41       986
#                   Other       0.17      0.72      0.28       145
#                   Legal       0.12      0.12      0.12        73
#           Prose/Lyrical       0.00      0.00      0.00        32
#
#                accuracy                           0.54     10000
#               macro avg       0.32      0.39      0.33     10000
#            weighted avg       0.58      0.54      0.55     10000
# Classifier: FTD-X-GENRE
# Macro F1: 0.38, Micro F1: 0.59, Accuracy: 0.58
#                          precision    recall  f1-score   support
#
#               Promotion       0.64      0.83      0.73      4862
# Information/Explanation       0.58      0.44      0.50      2257
#             Instruction       0.38      0.29      0.33       779
#                    News       0.40      0.32      0.36       986
#   Opinion/Argumentation       0.43      0.19      0.27       713
#           Prose/Lyrical       0.17      0.44      0.24        32
#                   Legal       0.18      0.56      0.27        73
#
#               micro avg       0.58      0.59      0.59      9702
#               macro avg       0.40      0.44      0.38      9702
#            weighted avg       0.56      0.59      0.56      9702
# Classifier: CORE-X-GENRE
# Macro F1: 0.29, Micro F1: 0.4, Accuracy: 0.3
#                          precision    recall  f1-score   support
#
# Information/Explanation       0.39      0.71      0.51      2257
#   Opinion/Argumentation       0.26      0.52      0.35       713
#                    News       0.30      0.41      0.35       986
#           Prose/Lyrical       0.05      0.38      0.09        32
#             Instruction       0.24      0.62      0.35       779
#                   Forum       0.14      0.64      0.23       153
#                   Other       0.13      0.16      0.14       145
#
#               micro avg       0.30      0.59      0.40      5065
#               macro avg       0.22      0.49      0.29      5065
#            weighted avg       0.32      0.59      0.41      5065
# Classifier: X-GENRE
# Macro F1: 0.36, Micro F1: 0.53, Accuracy: 0.53
#                          precision    recall  f1-score   support
#
#               Promotion       0.76      0.60      0.67      4862
#   Opinion/Argumentation       0.30      0.50      0.38       713
#                   Other       0.17      0.38      0.23       145
#                    News       0.35      0.52      0.41       986
# Information/Explanation       0.56      0.45      0.50      2257
#             Instruction       0.35      0.39      0.37       779
#                   Legal       0.18      0.41      0.25        73
#                   Forum       0.19      0.31      0.24       153
#           Prose/Lyrical       0.16      0.28      0.20        32
#
#                accuracy                           0.53     10000
#               macro avg       0.33      0.43      0.36     10000
#            weighted avg       0.58      0.53      0.54     10000
# | Classifier    |   Accuracy |   Macro F1 |   Micro F1 |   Macro precision |   Macro recall |
# |:--------------|-----------:|-----------:|-----------:|------------------:|---------------:|
# | FTD-X-GENRE   |       0.58 |       0.38 |       0.59 |              0.4  |           0.44 |
# | X-GENRE       |       0.53 |       0.36 |       0.53 |              0.33 |           0.43 |
# | GINCO-X-GENRE |       0.54 |       0.33 |       0.54 |              0.32 |           0.39 |
# | CORE-X-GENRE  |       0.3  |       0.29 |       0.4  |              0.22 |           0.49 |

# %% [markdown]
# ## Agreement between X-GENRE classifiers
# For X-genre classifiers, calculate agreement between them via F1, macroF1, microF1 (one classifier y_pred, another y_true - confusion matrix).

# %%
utils.x_genre_classifier_agreement(extended_corpus)
# Out:
# Comparison of classifiers: GINCO-X-GENRE as y_true, FTD-X-GENRE as y_pred
# Macro F1: 0.13, Micro F1: 0.33
#                          precision    recall  f1-score   support
#
#               Promotion       0.44      0.61      0.51      4467
# Information/Explanation       0.14      0.17      0.15      1467
#             Instruction       0.08      0.06      0.07       816
#                    News       0.14      0.08      0.10      1352
#   Opinion/Argumentation       0.09      0.03      0.04       993
#           Prose/Lyrical       0.00      0.00      0.00        13
#                   Legal       0.01      0.03      0.01        78
#
#               micro avg       0.32      0.35      0.33      9186
#               macro avg       0.13      0.14      0.13      9186
#            weighted avg       0.27      0.35      0.30      9186
# Comparison of classifiers: GINCO-X-GENRE as y_true, CORE-X-GENRE as y_pred
# Macro F1: 0.1, Micro F1: 0.15
#                          precision    recall  f1-score   support
#
# Information/Explanation       0.15      0.41      0.22      1467
#   Opinion/Argumentation       0.11      0.15      0.13       993
#                    News       0.14      0.13      0.14      1352
#           Prose/Lyrical       0.00      0.00      0.00        13
#             Instruction       0.09      0.22      0.13       816
#                   Forum       0.03      0.09      0.04       199
#                   Other       0.07      0.02      0.03       615
#
#               micro avg       0.12      0.21      0.15      5455
#               macro avg       0.08      0.15      0.10      5455
#            weighted avg       0.12      0.21      0.14      5455
# Comparison of classifiers: GINCO-X-GENRE as y_true, X-GENRE as y_pred
# Macro F1: 0.11, Micro F1: 0.24
#                          precision    recall  f1-score   support
#
#               Promotion       0.44      0.38      0.41      4467
#   Opinion/Argumentation       0.10      0.12      0.11       993
#                   Other       0.07      0.04      0.05       615
#                    News       0.14      0.15      0.14      1352
# Information/Explanation       0.15      0.18      0.16      1467
#             Instruction       0.08      0.09      0.08       816
#                   Legal       0.01      0.01      0.01        78
#                   Forum       0.02      0.03      0.03       199
#           Prose/Lyrical       0.00      0.00      0.00        13
#
#                accuracy                           0.24     10000
#               macro avg       0.11      0.11      0.11     10000
#            weighted avg       0.26      0.24      0.25     10000
# Comparison of classifiers: FTD-X-GENRE as y_true, GINCO-X-GENRE as y_pred
# Macro F1: 0.13, Micro F1: 0.33
#                          precision    recall  f1-score   support
#
#               Promotion       0.61      0.44      0.51      6282
# Information/Explanation       0.17      0.14      0.15      1693
#             Instruction       0.06      0.08      0.07       605
#                    News       0.08      0.14      0.10       789
#   Opinion/Argumentation       0.03      0.09      0.04       320
#           Prose/Lyrical       0.00      0.00      0.00        84
#                   Legal       0.03      0.01      0.01       227
#
#               micro avg       0.35      0.32      0.33     10000
#               macro avg       0.14      0.13      0.13     10000
#            weighted avg       0.43      0.32      0.36     10000
# Comparison of classifiers: FTD-X-GENRE as y_true, CORE-X-GENRE as y_pred
# Macro F1: 0.07, Micro F1: 0.1
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#               Promotion       0.00      0.00      0.00      6282
# Information/Explanation       0.17      0.41      0.24      1693
#             Instruction       0.06      0.20      0.09       605
#                    News       0.07      0.12      0.09       789
#   Opinion/Argumentation       0.04      0.18      0.07       320
#           Prose/Lyrical       0.01      0.04      0.02        84
#                   Legal       0.00      0.00      0.00       227
#
#               micro avg       0.11      0.10      0.10     10000
#               macro avg       0.05      0.13      0.07     10000
#            weighted avg       0.04      0.10      0.06     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Comparison of classifiers: FTD-X-GENRE as y_true, X-GENRE as y_pred
# Macro F1: 0.13, Micro F1: 0.3
#                          precision    recall  f1-score   support
#
#               Promotion       0.62      0.38      0.47      6282
# Information/Explanation       0.16      0.17      0.17      1693
#             Instruction       0.05      0.07      0.06       605
#                    News       0.07      0.14      0.09       789
#   Opinion/Argumentation       0.04      0.15      0.06       320
#           Prose/Lyrical       0.00      0.00      0.00        84
#                   Legal       0.03      0.02      0.03       227
#
#               micro avg       0.31      0.29      0.30     10000
#               macro avg       0.14      0.13      0.13     10000
#            weighted avg       0.43      0.29      0.34     10000
# Comparison of classifiers: CORE-X-GENRE as y_true, GINCO-X-GENRE as y_pred
# Macro F1: 0.08, Micro F1: 0.12
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
# Information/Explanation       0.41      0.15      0.22      4085
#             Instruction       0.22      0.09      0.13      2019
#               Promotion       0.00      0.00      0.00         0
#   Opinion/Argumentation       0.15      0.11      0.13      1444
#                   Forum       0.09      0.03      0.04       698
#                    News       0.13      0.14      0.14      1343
#                   Other       0.02      0.07      0.03       174
#                   Legal       0.00      0.00      0.00         0
#           Prose/Lyrical       0.00      0.00      0.00       237
#
#                accuracy                           0.12     10000
#               macro avg       0.11      0.06      0.08     10000
#            weighted avg       0.26      0.12      0.15     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Comparison of classifiers: CORE-X-GENRE as y_true, FTD-X-GENRE as y_pred
# Macro F1: 0.07, Micro F1: 0.1
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#               Promotion       0.00      0.00      0.00         0
# Information/Explanation       0.41      0.17      0.24      4085
#             Instruction       0.20      0.06      0.09      2019
#                    News       0.12      0.07      0.09      1343
#   Opinion/Argumentation       0.18      0.04      0.07      1444
#           Prose/Lyrical       0.04      0.01      0.02       237
#                   Legal       0.00      0.00      0.00         0
#
#               micro avg       0.10      0.11      0.10      9128
#               macro avg       0.13      0.05      0.07      9128
#            weighted avg       0.27      0.11      0.15      9128
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Comparison of classifiers: CORE-X-GENRE as y_true, X-GENRE as y_pred
# Macro F1: 0.08, Micro F1: 0.13
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
#               Promotion       0.00      0.00      0.00         0
#   Opinion/Argumentation       0.15      0.12      0.13      1444
#                   Other       0.02      0.03      0.02       174
#                    News       0.13      0.14      0.13      1343
# Information/Explanation       0.41      0.18      0.25      4085
#             Instruction       0.23      0.10      0.14      2019
#                   Legal       0.00      0.00      0.00         0
#                   Forum       0.07      0.02      0.03       698
#           Prose/Lyrical       0.00      0.00      0.00       237
#
#                accuracy                           0.13     10000
#               macro avg       0.11      0.07      0.08     10000
#            weighted avg       0.26      0.13      0.17     10000
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/tajak/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Comparison of classifiers: X-GENRE as y_true, GINCO-X-GENRE as y_pred
# Macro F1: 0.11, Micro F1: 0.24
#                          precision    recall  f1-score   support
#
# Information/Explanation       0.18      0.15      0.16      1810
#             Instruction       0.09      0.08      0.08       860
#               Promotion       0.38      0.44      0.41      3875
#   Opinion/Argumentation       0.12      0.10      0.11      1185
#                   Forum       0.03      0.02      0.03       246
#                    News       0.15      0.14      0.14      1474
#                   Other       0.04      0.07      0.05       327
#                   Legal       0.01      0.01      0.01       165
#           Prose/Lyrical       0.00      0.00      0.00        58
#
#                accuracy                           0.24     10000
#               macro avg       0.11      0.11      0.11     10000
#            weighted avg       0.23      0.24      0.23     10000
# Comparison of classifiers: X-GENRE as y_true, FTD-X-GENRE as y_pred
# Macro F1: 0.13, Micro F1: 0.3
#                          precision    recall  f1-score   support
#
#               Promotion       0.38      0.62      0.47      3875
# Information/Explanation       0.17      0.16      0.17      1810
#             Instruction       0.07      0.05      0.06       860
#                    News       0.14      0.07      0.09      1474
#   Opinion/Argumentation       0.15      0.04      0.06      1185
#           Prose/Lyrical       0.00      0.00      0.00        58
#                   Legal       0.02      0.03      0.03       165
#
#               micro avg       0.29      0.31      0.30      9427
#               macro avg       0.13      0.14      0.13      9427
#            weighted avg       0.24      0.31      0.25      9427
# Comparison of classifiers: X-GENRE as y_true, CORE-X-GENRE as y_pred
# Macro F1: 0.1, Micro F1: 0.17
#                          precision    recall  f1-score   support
#
# Information/Explanation       0.18      0.41      0.25      1810
#   Opinion/Argumentation       0.12      0.15      0.13      1185
#                    News       0.14      0.13      0.13      1474
#           Prose/Lyrical       0.00      0.00      0.00        58
#             Instruction       0.10      0.23      0.14       860
#                   Forum       0.02      0.07      0.03       246
#                   Other       0.03      0.02      0.02       327
#
#               micro avg       0.13      0.22      0.17      5960
#               macro avg       0.08      0.14      0.10      5960
#            weighted avg       0.13      0.22      0.16      5960
# | Classifier as y_true   | Classifier as y_pred   |   Macro F1 |   Micro F1 |   Macro precision |   Macro recall |
# |:-----------------------|:-----------------------|-----------:|-----------:|------------------:|---------------:|
# | GINCO-X-GENRE          | FTD-X-GENRE            |       0.13 |       0.33 |              0.13 |           0.14 |
# | FTD-X-GENRE            | GINCO-X-GENRE          |       0.13 |       0.33 |              0.14 |           0.13 |
# | FTD-X-GENRE            | X-GENRE                |       0.13 |       0.3  |              0.14 |           0.13 |
# | X-GENRE                | FTD-X-GENRE            |       0.13 |       0.3  |              0.13 |           0.14 |
# | GINCO-X-GENRE          | X-GENRE                |       0.11 |       0.24 |              0.11 |           0.11 |
# | X-GENRE                | GINCO-X-GENRE          |       0.11 |       0.24 |              0.11 |           0.11 |
# | GINCO-X-GENRE          | CORE-X-GENRE           |       0.1  |       0.15 |              0.08 |           0.15 |
# | X-GENRE                | CORE-X-GENRE           |       0.1  |       0.17 |              0.08 |           0.14 |
# | CORE-X-GENRE           | GINCO-X-GENRE          |       0.08 |       0.12 |              0.11 |           0.06 |
# | CORE-X-GENRE           | X-GENRE                |       0.08 |       0.13 |              0.11 |           0.07 |
# | FTD-X-GENRE            | CORE-X-GENRE           |       0.07 |       0.1  |              0.05 |           0.13 |
# | CORE-X-GENRE           | FTD-X-GENRE            |       0.07 |       0.1  |              0.13 |           0.05 |

# %% [markdown]
# # Analysis of which labels often occur together

# %% [markdown]
# I had another idea that we could analyse which labels occur together using the apriori algorithm which is used in association rule learning.
#
# Main concepts:
#
# - Support: It measures the number of times a particular item or combination of items occur in a dataset out of the number of all instances.
# `Support(pair) = frequency_of_pair/no_of_instances`
#
# - Confidence: It measures how likely the pair will occur given they the left value has been predicted - number of times both have been predicted together divided by a number of time the left value has been predicted (-> if the left value occurs very often, the confidence will be smaller)
# `Confidence(pair (based of occurrence of left value)) = frequency_of_pair/frequency of left value`
#
# - Lift: A lift is a metric that determines the strength of association between the best rules. It is obtained by taking confidence (based on the frequency of the left value and right value) dand diving it with support (for right value).
# `Lift(pair (based on occurrence of left value)) = Confidence(based on occurrence of left value)/Support(right value)}`
#
# This means that if left value is very frequent -> confidence is smaller, if the pair does not occur together very often, it won't reach the confidence limit. The frequency of right value does not impact the confidence, but it does impact the lift. For the same number of occurences of the pair, the lift is higher if one of them is infrequent than if both were frequent. The bigger support (frequency of the pair occuring together), the bigger is lift.

# %% [markdown]
# two most frequent values, always occurring together:
# left = 7
# right = 7
#
# occur = 7/10
# total = 10
#
# confidence = 7/10 / 7/10 = 1
#
# support = 7/10
#
# lift = 1 / 0.7 = 1.42
#
# -----------
# two not so frequent values always occurring together:
#
# left = 4
# right = 4
#
# occur = 4/10
#
# confidence = 1
#
# support = 0.4
#
# lift = 1/0.4 = 2.5

# %%
utils.calculate_apriori(extended_corpus, classifiers)
# Out:
# /home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/Comparison-on-MaCoCu-data/Comparison-on-MaCoCu-sl-sample2/utils.py:521: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpus_small[i] = "{}: ".format(i) + corpus_small[i].astype(str)
# Comparison: FTD with GINCO
# | Left_Hand_Side         | Right_Hand_Side                |   Support |   Confidence |    Lift |
# |:-----------------------|:-------------------------------|----------:|-------------:|--------:|
# | FTD: A7 (instruction)  | GINCO: Instruction             |    0.0383 |     0.728137 | 9.76055 |
# | FTD: A8 (news)         | GINCO: News/Reporting          |    0.0434 |     0.82197  | 6.83835 |
# | FTD: A11 (personal)    | GINCO: Opinion/Argumentation   |    0.0224 |     0.724919 | 6.03094 |
# | FTD: A16 (information) | GINCO: Information/Explanation |    0.0842 |     0.651199 | 4.56022 |
# | FTD: A12 (promotion)   | GINCO: Promotion               |    0.3854 |     0.654218 | 1.61775 |
# Labels not matched: ['FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A9 (legal)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)', 'GINCO: List of Summaries/Excerpts', 'GINCO: Other', 'GINCO: Legal/Regulation', 'GINCO: Forum']
# Comparison: FTD with CORE
# | Left_Hand_Side                              | Right_Hand_Side                             |   Support |   Confidence |    Lift |
# |:--------------------------------------------|:--------------------------------------------|----------:|-------------:|--------:|
# | CORE: How-To/Instructional                  | FTD: A7 (instruction)                       |    0.0275 |     0.514019 | 9.77222 |
# | FTD: A8 (news)                              | CORE: Narrative                             |    0.0402 |     0.761364 | 6.87151 |
# | FTD: A11 (personal)                         | CORE: Narrative                             |    0.0181 |     0.585761 | 5.28665 |
# | CORE: Informational Persuasion              | FTD: A12 (promotion)                        |    0.1112 |     0.959448 | 1.62867 |
# | FTD: A9 (legal)                             | CORE: Informational Description/Explanation |    0.0158 |     0.993711 | 1.53445 |
# | FTD: A16 (information)                      | CORE: Informational Description/Explanation |    0.1151 |     0.890178 | 1.37458 |
# | CORE: Informational Description/Explanation | FTD: A12 (promotion)                        |    0.4244 |     0.655343 | 1.11245 |
# Labels not matched: ['FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)', 'CORE: Opinion', 'CORE: Spoken', 'CORE: Lyrical', 'CORE: Interactive Discussion']
# Comparison: FTD with GINCO-X-GENRE
# | Left_Hand_Side         | Right_Hand_Side                        |   Support |   Confidence |    Lift |
# |:-----------------------|:---------------------------------------|----------:|-------------:|--------:|
# | FTD: A7 (instruction)  | GINCO-X-GENRE: Instruction             |    0.0398 |     0.756654 | 9.27272 |
# | FTD: A11 (personal)    | GINCO-X-GENRE: Opinion/Argumentation   |    0.0227 |     0.734628 | 7.39806 |
# | FTD: A8 (news)         | GINCO-X-GENRE: News                    |    0.0501 |     0.948864 | 7.01822 |
# | FTD: A16 (information) | GINCO-X-GENRE: Information/Explanation |    0.0862 |     0.666667 | 4.54442 |
# | FTD: A12 (promotion)   | GINCO-X-GENRE: Promotion               |    0.4174 |     0.708538 | 1.58616 |
# Labels not matched: ['FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A9 (legal)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)', 'GINCO-X-GENRE: Other', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Forum', 'GINCO-X-GENRE: Prose/Lyrical']
# Comparison: FTD with FTD-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side        |   Support |   Confidence |     Lift |
# |:-------------------------------------|:-----------------------|----------:|-------------:|---------:|
# | FTD-X-GENRE: Legal                   | FTD: A9 (legal)        |    0.0155 |     0.682819 | 42.9446  |
# | FTD-X-GENRE: Opinion/Argumentation   | FTD: A11 (personal)    |    0.0215 |     0.671875 | 21.7435  |
# | FTD-X-GENRE: Instruction             | FTD: A7 (instruction)  |    0.0447 |     0.738843 | 14.0464  |
# | FTD-X-GENRE: News                    | FTD: A8 (news)         |    0.0493 |     0.624842 | 11.8341  |
# | FTD-X-GENRE: Information/Explanation | FTD: A16 (information) |    0.1065 |     0.629061 |  4.86513 |
# Labels not matched: ['FTD: A12 (promotion)', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)', 'FTD-X-GENRE: Promotion', 'FTD-X-GENRE: Prose/Lyrical']
# Comparison: FTD with CORE-X-GENRE
# | Left_Hand_Side                        | Right_Hand_Side                       |   Support |   Confidence |    Lift |
# |:--------------------------------------|:--------------------------------------|----------:|-------------:|--------:|
# | FTD: A8 (news)                        | CORE-X-GENRE: News                    |    0.0498 |     0.943182 | 7.02295 |
# | FTD: A7 (instruction)                 | CORE-X-GENRE: Instruction             |    0.0383 |     0.728137 | 3.60642 |
# | FTD: A9 (legal)                       | CORE-X-GENRE: Information/Explanation |    0.0154 |     0.968553 | 2.371   |
# | FTD: A16 (information)                | CORE-X-GENRE: Information/Explanation |    0.1031 |     0.79737  | 1.95195 |
# | CORE-X-GENRE: Instruction             | FTD: A12 (promotion)                  |    0.1517 |     0.751362 | 1.27544 |
# | CORE-X-GENRE: Opinion/Argumentation   | FTD: A12 (promotion)                  |    0.0937 |     0.648892 | 1.1015  |
# | CORE-X-GENRE: Forum                   | FTD: A12 (promotion)                  |    0.0426 |     0.610315 | 1.03601 |
# | CORE-X-GENRE: Information/Explanation | FTD: A12 (promotion)                  |    0.2426 |     0.59388  | 1.00811 |
# | CORE-X-GENRE: Other                   | FTD: A12 (promotion)                  |    0.0103 |     0.591954 | 1.00484 |
# Labels not matched: ['FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A11 (personal)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)', 'CORE-X-GENRE: Prose/Lyrical']
# Comparison: FTD with X-GENRE
# | Left_Hand_Side         | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:-----------------------|:---------------------------------|----------:|-------------:|---------:|
# | FTD: A9 (legal)        | X-GENRE: Legal                   |    0.0124 |     0.779874 | 47.2651  |
# | FTD: A7 (instruction)  | X-GENRE: Instruction             |    0.0417 |     0.792776 |  9.21832 |
# | FTD: A8 (news)         | X-GENRE: News                    |    0.0513 |     0.971591 |  6.59153 |
# | FTD: A11 (personal)    | X-GENRE: Opinion/Argumentation   |    0.0239 |     0.773463 |  6.52711 |
# | FTD: A16 (information) | X-GENRE: Information/Explanation |    0.0907 |     0.701469 |  3.87552 |
# | FTD: A12 (promotion)   | X-GENRE: Promotion               |    0.3718 |     0.631132 |  1.62873 |
# | X-GENRE: Other         | FTD: A12 (promotion)             |    0.0203 |     0.620795 |  1.0538  |
# Labels not matched: ['FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)', 'X-GENRE: Prose/Lyrical', 'X-GENRE: Forum']
# Comparison: GINCO with FTD
# | Left_Hand_Side         | Right_Hand_Side                |   Support |   Confidence |    Lift |
# |:-----------------------|:-------------------------------|----------:|-------------:|--------:|
# | FTD: A7 (instruction)  | GINCO: Instruction             |    0.0383 |     0.728137 | 9.76055 |
# | FTD: A8 (news)         | GINCO: News/Reporting          |    0.0434 |     0.82197  | 6.83835 |
# | FTD: A11 (personal)    | GINCO: Opinion/Argumentation   |    0.0224 |     0.724919 | 6.03094 |
# | FTD: A16 (information) | GINCO: Information/Explanation |    0.0842 |     0.651199 | 4.56022 |
# | FTD: A12 (promotion)   | GINCO: Promotion               |    0.3854 |     0.654218 | 1.61775 |
# Labels not matched: ['GINCO: List of Summaries/Excerpts', 'GINCO: Other', 'GINCO: Legal/Regulation', 'GINCO: Forum', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A9 (legal)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)']
# Comparison: GINCO with CORE
# | Left_Hand_Side                    | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:----------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion      | GINCO: Forum                                |    0.0171 |     0.715481 | 32.0844  |
# | CORE: How-To/Instructional        | GINCO: Instruction                          |    0.0365 |     0.682243 |  9.14535 |
# | CORE: Opinion                     | GINCO: Opinion/Argumentation                |    0.0248 |     0.649215 |  5.40112 |
# | CORE: Informational Persuasion    | GINCO: Promotion                            |    0.1052 |     0.907679 |  2.24451 |
# | GINCO: Information/Explanation    | CORE: Informational Description/Explanation |    0.1361 |     0.953081 |  1.47171 |
# | GINCO: List of Summaries/Excerpts | CORE: Informational Description/Explanation |    0.0581 |     0.721739 |  1.11448 |
# | GINCO: Other                      | CORE: Informational Description/Explanation |    0.019  |     0.703704 |  1.08663 |
# | GINCO: Promotion                  | CORE: Informational Description/Explanation |    0.2822 |     0.697824 |  1.07755 |
# Labels not matched: ['GINCO: Legal/Regulation', 'GINCO: News/Reporting', 'CORE: Narrative', 'CORE: Spoken', 'CORE: Lyrical']
# Comparison: GINCO with GINCO-X-GENRE
# | Left_Hand_Side                         | Right_Hand_Side                |   Support |   Confidence |     Lift |
# |:---------------------------------------|:-------------------------------|----------:|-------------:|---------:|
# | GINCO-X-GENRE: Forum                   | GINCO: Forum                   |    0.0176 |     0.884422 | 39.6602  |
# | GINCO: Other                           | GINCO-X-GENRE: Other           |    0.0163 |     0.603704 |  9.81632 |
# | GINCO-X-GENRE: Instruction             | GINCO: Instruction             |    0.0584 |     0.715686 |  9.59365 |
# | GINCO-X-GENRE: Opinion/Argumentation   | GINCO: Opinion/Argumentation   |    0.0814 |     0.819738 |  6.81979 |
# | GINCO-X-GENRE: News                    | GINCO: News/Reporting          |    0.091  |     0.673077 |  5.59964 |
# | GINCO-X-GENRE: Information/Explanation | GINCO: Information/Explanation |    0.1156 |     0.788003 |  5.51823 |
# | GINCO-X-GENRE: Promotion               | GINCO: Promotion               |    0.3722 |     0.833221 |  2.06039 |
# Labels not matched: ['GINCO: List of Summaries/Excerpts', 'GINCO: Legal/Regulation', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical']
# Comparison: GINCO with FTD-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                |   Support |   Confidence |    Lift |
# |:-------------------------------------|:-------------------------------|----------:|-------------:|--------:|
# | FTD-X-GENRE: Instruction             | GINCO: Instruction             |    0.0416 |     0.687603 | 9.2172  |
# | FTD-X-GENRE: News                    | GINCO: News/Reporting          |    0.0605 |     0.766793 | 6.37931 |
# | FTD-X-GENRE: Opinion/Argumentation   | GINCO: Opinion/Argumentation   |    0.0212 |     0.6625   | 5.51165 |
# | FTD-X-GENRE: Information/Explanation | GINCO: Information/Explanation |    0.094  |     0.555227 | 3.88815 |
# | FTD-X-GENRE: Promotion               | GINCO: Promotion               |    0.3869 |     0.615887 | 1.52296 |
# | GINCO: List of Summaries/Excerpts    | FTD-X-GENRE: Promotion         |    0.0561 |     0.696894 | 1.10935 |
# Labels not matched: ['GINCO: Other', 'GINCO: Legal/Regulation', 'GINCO: Forum', 'FTD-X-GENRE: Legal', 'FTD-X-GENRE: Prose/Lyrical']
# Comparison: GINCO with CORE-X-GENRE
# | Left_Hand_Side                 | Right_Hand_Side                       |   Support |   Confidence |     Lift |
# |:-------------------------------|:--------------------------------------|----------:|-------------:|---------:|
# | GINCO: Forum                   | CORE-X-GENRE: Forum                   |    0.0207 |     0.928251 | 13.2987  |
# | CORE-X-GENRE: Prose/Lyrical    | GINCO: Opinion/Argumentation          |    0.015  |     0.632911 |  5.26549 |
# | CORE-X-GENRE: News             | GINCO: News/Reporting                 |    0.0756 |     0.562919 |  4.68319 |
# | GINCO: Instruction             | CORE-X-GENRE: Instruction             |    0.0584 |     0.782842 |  3.87737 |
# | GINCO: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.1273 |     0.891457 |  2.18227 |
# | CORE-X-GENRE: Instruction      | GINCO: Promotion                      |    0.1175 |     0.581971 |  1.4391  |
# Labels not matched: ['GINCO: List of Summaries/Excerpts', 'GINCO: Other', 'GINCO: Legal/Regulation', 'CORE-X-GENRE: Opinion/Argumentation', 'CORE-X-GENRE: Other']
# Comparison: GINCO with X-GENRE
# | Left_Hand_Side                 | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:-------------------------------|:---------------------------------|----------:|-------------:|---------:|
# | GINCO: Forum                   | X-GENRE: Forum                   |    0.0195 |     0.874439 | 35.5463  |
# | GINCO: Instruction             | X-GENRE: Instruction             |    0.0591 |     0.792225 |  9.21192 |
# | GINCO: Opinion/Argumentation   | X-GENRE: Opinion/Argumentation   |    0.0917 |     0.762895 |  6.43793 |
# | GINCO: News/Reporting          | X-GENRE: News                    |    0.0945 |     0.78619  |  5.33372 |
# | GINCO: Information/Explanation | X-GENRE: Information/Explanation |    0.121  |     0.847339 |  4.68143 |
# | GINCO: Promotion               | X-GENRE: Promotion               |    0.3439 |     0.850396 |  2.19457 |
# Labels not matched: ['GINCO: List of Summaries/Excerpts', 'GINCO: Other', 'GINCO: Legal/Regulation', 'X-GENRE: Other', 'X-GENRE: Legal', 'X-GENRE: Prose/Lyrical']
# Comparison: CORE with FTD
# | Left_Hand_Side                              | Right_Hand_Side                             |   Support |   Confidence |    Lift |
# |:--------------------------------------------|:--------------------------------------------|----------:|-------------:|--------:|
# | CORE: How-To/Instructional                  | FTD: A7 (instruction)                       |    0.0275 |     0.514019 | 9.77222 |
# | FTD: A8 (news)                              | CORE: Narrative                             |    0.0402 |     0.761364 | 6.87151 |
# | FTD: A11 (personal)                         | CORE: Narrative                             |    0.0181 |     0.585761 | 5.28665 |
# | CORE: Informational Persuasion              | FTD: A12 (promotion)                        |    0.1112 |     0.959448 | 1.62867 |
# | FTD: A9 (legal)                             | CORE: Informational Description/Explanation |    0.0158 |     0.993711 | 1.53445 |
# | FTD: A16 (information)                      | CORE: Informational Description/Explanation |    0.1151 |     0.890178 | 1.37458 |
# | CORE: Informational Description/Explanation | FTD: A12 (promotion)                        |    0.4244 |     0.655343 | 1.11245 |
# Labels not matched: ['CORE: Opinion', 'CORE: Spoken', 'CORE: Lyrical', 'CORE: Interactive Discussion', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)']
# Comparison: CORE with GINCO
# | Left_Hand_Side                    | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:----------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion      | GINCO: Forum                                |    0.0171 |     0.715481 | 32.0844  |
# | CORE: How-To/Instructional        | GINCO: Instruction                          |    0.0365 |     0.682243 |  9.14535 |
# | CORE: Opinion                     | GINCO: Opinion/Argumentation                |    0.0248 |     0.649215 |  5.40112 |
# | CORE: Informational Persuasion    | GINCO: Promotion                            |    0.1052 |     0.907679 |  2.24451 |
# | GINCO: Information/Explanation    | CORE: Informational Description/Explanation |    0.1361 |     0.953081 |  1.47171 |
# | GINCO: List of Summaries/Excerpts | CORE: Informational Description/Explanation |    0.0581 |     0.721739 |  1.11448 |
# | GINCO: Other                      | CORE: Informational Description/Explanation |    0.019  |     0.703704 |  1.08663 |
# | GINCO: Promotion                  | CORE: Informational Description/Explanation |    0.2822 |     0.697824 |  1.07755 |
# Labels not matched: ['CORE: Narrative', 'CORE: Spoken', 'CORE: Lyrical', 'GINCO: Legal/Regulation', 'GINCO: News/Reporting']
# Comparison: CORE with GINCO-X-GENRE
# | Left_Hand_Side                         | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:---------------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion           | GINCO-X-GENRE: Forum                        |    0.0148 |     0.619247 | 31.1179  |
# | CORE: How-To/Instructional             | GINCO-X-GENRE: Instruction                  |    0.0412 |     0.770093 |  9.43742 |
# | CORE: Opinion                          | GINCO-X-GENRE: Opinion/Argumentation        |    0.022  |     0.575916 |  5.79976 |
# | CORE: Narrative                        | GINCO-X-GENRE: News                         |    0.0606 |     0.546931 |  4.04535 |
# | CORE: Informational Persuasion         | GINCO-X-GENRE: Promotion                    |    0.1046 |     0.902502 |  2.02038 |
# | GINCO-X-GENRE: Information/Explanation | CORE: Informational Description/Explanation |    0.1368 |     0.932515 |  1.43996 |
# | GINCO-X-GENRE: Promotion               | CORE: Informational Description/Explanation |    0.3215 |     0.719722 |  1.11137 |
# | GINCO-X-GENRE: Other                   | CORE: Informational Description/Explanation |    0.0427 |     0.694309 |  1.07213 |
# Labels not matched: ['CORE: Spoken', 'CORE: Lyrical', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical']
# Comparison: CORE with FTD-X-GENRE
# | Left_Hand_Side                              | Right_Hand_Side                             |   Support |   Confidence |    Lift |
# |:--------------------------------------------|:--------------------------------------------|----------:|-------------:|--------:|
# | CORE: How-To/Instructional                  | FTD-X-GENRE: Instruction                    |    0.0294 |     0.549533 | 9.08319 |
# | FTD-X-GENRE: News                           | CORE: Narrative                             |    0.0521 |     0.66033  | 5.95965 |
# | FTD-X-GENRE: Opinion/Argumentation          | CORE: Narrative                             |    0.0171 |     0.534375 | 4.82288 |
# | CORE: Informational Persuasion              | FTD-X-GENRE: Promotion                      |    0.1139 |     0.982744 | 1.56438 |
# | FTD-X-GENRE: Legal                          | CORE: Informational Description/Explanation |    0.0223 |     0.982379 | 1.51695 |
# | FTD-X-GENRE: Information/Explanation        | CORE: Informational Description/Explanation |    0.1387 |     0.819256 | 1.26506 |
# | CORE: Informational Description/Explanation | FTD-X-GENRE: Promotion                      |    0.4392 |     0.678196 | 1.07959 |
# Labels not matched: ['CORE: Opinion', 'CORE: Spoken', 'CORE: Lyrical', 'CORE: Interactive Discussion', 'FTD-X-GENRE: Prose/Lyrical']
# Comparison: CORE with CORE-X-GENRE
# | Left_Hand_Side                        | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:--------------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion          | CORE-X-GENRE: Forum                         |    0.0222 |     0.92887  | 13.3076  |
# | CORE: Narrative                       | CORE-X-GENRE: News                          |    0.064  |     0.577617 |  4.30095 |
# | CORE: How-To/Instructional            | CORE-X-GENRE: Instruction                   |    0.045  |     0.841121 |  4.16603 |
# | CORE-X-GENRE: Information/Explanation | CORE: Informational Description/Explanation |    0.3486 |     0.853366 |  1.31774 |
# Labels not matched: ['CORE: Informational Persuasion', 'CORE: Opinion', 'CORE: Spoken', 'CORE: Lyrical', 'CORE-X-GENRE: Opinion/Argumentation', 'CORE-X-GENRE: Other', 'CORE-X-GENRE: Prose/Lyrical']
# Comparison: CORE with X-GENRE
# | Left_Hand_Side                   | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:---------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion     | X-GENRE: Forum                              |    0.0187 |     0.782427 | 31.806   |
# | CORE: How-To/Instructional       | X-GENRE: Instruction                        |    0.0444 |     0.829907 |  9.65008 |
# | CORE: Opinion                    | X-GENRE: Opinion/Argumentation              |    0.025  |     0.65445  |  5.52279 |
# | CORE: Narrative                  | X-GENRE: News                               |    0.0606 |     0.546931 |  3.71053 |
# | CORE: Informational Persuasion   | X-GENRE: Promotion                          |    0.104  |     0.897325 |  2.31568 |
# | X-GENRE: Legal                   | CORE: Informational Description/Explanation |    0.0165 |     1        |  1.54416 |
# | X-GENRE: Information/Explanation | CORE: Informational Description/Explanation |    0.1701 |     0.939779 |  1.45117 |
# | X-GENRE: Promotion               | CORE: Informational Description/Explanation |    0.2713 |     0.700129 |  1.08111 |
# | X-GENRE: Other                   | CORE: Informational Description/Explanation |    0.0227 |     0.69419  |  1.07194 |
# Labels not matched: ['CORE: Spoken', 'CORE: Lyrical', 'X-GENRE: Prose/Lyrical']
# Comparison: GINCO-X-GENRE with FTD
# | Left_Hand_Side         | Right_Hand_Side                        |   Support |   Confidence |    Lift |
# |:-----------------------|:---------------------------------------|----------:|-------------:|--------:|
# | FTD: A7 (instruction)  | GINCO-X-GENRE: Instruction             |    0.0398 |     0.756654 | 9.27272 |
# | FTD: A11 (personal)    | GINCO-X-GENRE: Opinion/Argumentation   |    0.0227 |     0.734628 | 7.39806 |
# | FTD: A8 (news)         | GINCO-X-GENRE: News                    |    0.0501 |     0.948864 | 7.01822 |
# | FTD: A16 (information) | GINCO-X-GENRE: Information/Explanation |    0.0862 |     0.666667 | 4.54442 |
# | FTD: A12 (promotion)   | GINCO-X-GENRE: Promotion               |    0.4174 |     0.708538 | 1.58616 |
# Labels not matched: ['GINCO-X-GENRE: Other', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Forum', 'GINCO-X-GENRE: Prose/Lyrical', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A9 (legal)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)']
# Comparison: GINCO-X-GENRE with GINCO
# | Left_Hand_Side                         | Right_Hand_Side                |   Support |   Confidence |     Lift |
# |:---------------------------------------|:-------------------------------|----------:|-------------:|---------:|
# | GINCO-X-GENRE: Forum                   | GINCO: Forum                   |    0.0176 |     0.884422 | 39.6602  |
# | GINCO: Other                           | GINCO-X-GENRE: Other           |    0.0163 |     0.603704 |  9.81632 |
# | GINCO-X-GENRE: Instruction             | GINCO: Instruction             |    0.0584 |     0.715686 |  9.59365 |
# | GINCO-X-GENRE: Opinion/Argumentation   | GINCO: Opinion/Argumentation   |    0.0814 |     0.819738 |  6.81979 |
# | GINCO-X-GENRE: News                    | GINCO: News/Reporting          |    0.091  |     0.673077 |  5.59964 |
# | GINCO-X-GENRE: Information/Explanation | GINCO: Information/Explanation |    0.1156 |     0.788003 |  5.51823 |
# | GINCO-X-GENRE: Promotion               | GINCO: Promotion               |    0.3722 |     0.833221 |  2.06039 |
# Labels not matched: ['GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical', 'GINCO: List of Summaries/Excerpts', 'GINCO: Legal/Regulation']
# Comparison: GINCO-X-GENRE with CORE
# | Left_Hand_Side                         | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:---------------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion           | GINCO-X-GENRE: Forum                        |    0.0148 |     0.619247 | 31.1179  |
# | CORE: How-To/Instructional             | GINCO-X-GENRE: Instruction                  |    0.0412 |     0.770093 |  9.43742 |
# | CORE: Opinion                          | GINCO-X-GENRE: Opinion/Argumentation        |    0.022  |     0.575916 |  5.79976 |
# | CORE: Narrative                        | GINCO-X-GENRE: News                         |    0.0606 |     0.546931 |  4.04535 |
# | CORE: Informational Persuasion         | GINCO-X-GENRE: Promotion                    |    0.1046 |     0.902502 |  2.02038 |
# | GINCO-X-GENRE: Information/Explanation | CORE: Informational Description/Explanation |    0.1368 |     0.932515 |  1.43996 |
# | GINCO-X-GENRE: Promotion               | CORE: Informational Description/Explanation |    0.3215 |     0.719722 |  1.11137 |
# | GINCO-X-GENRE: Other                   | CORE: Informational Description/Explanation |    0.0427 |     0.694309 |  1.07213 |
# Labels not matched: ['GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical', 'CORE: Spoken', 'CORE: Lyrical']
# Comparison: GINCO-X-GENRE with FTD-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                        |   Support |   Confidence |    Lift |
# |:-------------------------------------|:---------------------------------------|----------:|-------------:|--------:|
# | FTD-X-GENRE: Instruction             | GINCO-X-GENRE: Instruction             |    0.0413 |     0.682645 | 8.36574 |
# | FTD-X-GENRE: News                    | GINCO-X-GENRE: News                    |    0.0692 |     0.87706  | 6.48713 |
# | FTD-X-GENRE: Opinion/Argumentation   | GINCO-X-GENRE: Opinion/Argumentation   |    0.0198 |     0.61875  | 6.23112 |
# | FTD-X-GENRE: Information/Explanation | GINCO-X-GENRE: Information/Explanation |    0.0957 |     0.565269 | 3.85323 |
# | FTD-X-GENRE: Promotion               | GINCO-X-GENRE: Promotion               |    0.4197 |     0.668099 | 1.49563 |
# Labels not matched: ['GINCO-X-GENRE: Other', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Forum', 'GINCO-X-GENRE: Prose/Lyrical', 'FTD-X-GENRE: Legal', 'FTD-X-GENRE: Prose/Lyrical']
# Comparison: GINCO-X-GENRE with CORE-X-GENRE
# | Left_Hand_Side                         | Right_Hand_Side                       |   Support |   Confidence |     Lift |
# |:---------------------------------------|:--------------------------------------|----------:|-------------:|---------:|
# | GINCO-X-GENRE: Forum                   | CORE-X-GENRE: Forum                   |    0.0187 |     0.939698 | 13.4627  |
# | CORE-X-GENRE: Prose/Lyrical            | GINCO-X-GENRE: Opinion/Argumentation  |    0.0154 |     0.649789 |  6.5437  |
# | CORE-X-GENRE: News                     | GINCO-X-GENRE: News                   |    0.0903 |     0.672375 |  4.97319 |
# | GINCO-X-GENRE: Instruction             | CORE-X-GENRE: Instruction             |    0.0589 |     0.721814 |  3.57511 |
# | GINCO-X-GENRE: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.1292 |     0.880709 |  2.15596 |
# | CORE-X-GENRE: Instruction              | GINCO-X-GENRE: Promotion              |    0.1276 |     0.631996 |  1.41481 |
# | CORE-X-GENRE: Opinion/Argumentation    | GINCO-X-GENRE: Promotion              |    0.0737 |     0.510388 |  1.14257 |
# Labels not matched: ['GINCO-X-GENRE: Other', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical', 'CORE-X-GENRE: Other']
# Comparison: GINCO-X-GENRE with X-GENRE
# | Left_Hand_Side                         | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:---------------------------------------|:---------------------------------|----------:|-------------:|---------:|
# | GINCO-X-GENRE: Forum                   | X-GENRE: Forum                   |    0.0178 |     0.894472 | 36.3607  |
# | X-GENRE: Other                         | GINCO-X-GENRE: Other             |    0.0187 |     0.571865 |  9.29863 |
# | GINCO-X-GENRE: Instruction             | X-GENRE: Instruction             |    0.0607 |     0.743873 |  8.64968 |
# | GINCO-X-GENRE: Opinion/Argumentation   | X-GENRE: Opinion/Argumentation   |    0.0829 |     0.834844 |  7.0451  |
# | GINCO-X-GENRE: News                    | X-GENRE: News                    |    0.1166 |     0.862426 |  5.85092 |
# | GINCO-X-GENRE: Information/Explanation | X-GENRE: Information/Explanation |    0.1223 |     0.833674 |  4.60593 |
# | GINCO-X-GENRE: Promotion               | X-GENRE: Promotion               |    0.3617 |     0.809716 |  2.08959 |
# Labels not matched: ['GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical', 'X-GENRE: Legal', 'X-GENRE: Prose/Lyrical']
# Comparison: FTD-X-GENRE with FTD
# | Left_Hand_Side                       | Right_Hand_Side        |   Support |   Confidence |     Lift |
# |:-------------------------------------|:-----------------------|----------:|-------------:|---------:|
# | FTD-X-GENRE: Legal                   | FTD: A9 (legal)        |    0.0155 |     0.682819 | 42.9446  |
# | FTD-X-GENRE: Opinion/Argumentation   | FTD: A11 (personal)    |    0.0215 |     0.671875 | 21.7435  |
# | FTD-X-GENRE: Instruction             | FTD: A7 (instruction)  |    0.0447 |     0.738843 | 14.0464  |
# | FTD-X-GENRE: News                    | FTD: A8 (news)         |    0.0493 |     0.624842 | 11.8341  |
# | FTD-X-GENRE: Information/Explanation | FTD: A16 (information) |    0.1065 |     0.629061 |  4.86513 |
# Labels not matched: ['FTD-X-GENRE: Promotion', 'FTD-X-GENRE: Prose/Lyrical', 'FTD: A12 (promotion)', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)']
# Comparison: FTD-X-GENRE with GINCO
# | Left_Hand_Side                       | Right_Hand_Side                |   Support |   Confidence |    Lift |
# |:-------------------------------------|:-------------------------------|----------:|-------------:|--------:|
# | FTD-X-GENRE: Instruction             | GINCO: Instruction             |    0.0416 |     0.687603 | 9.2172  |
# | FTD-X-GENRE: News                    | GINCO: News/Reporting          |    0.0605 |     0.766793 | 6.37931 |
# | FTD-X-GENRE: Opinion/Argumentation   | GINCO: Opinion/Argumentation   |    0.0212 |     0.6625   | 5.51165 |
# | FTD-X-GENRE: Information/Explanation | GINCO: Information/Explanation |    0.094  |     0.555227 | 3.88815 |
# | FTD-X-GENRE: Promotion               | GINCO: Promotion               |    0.3869 |     0.615887 | 1.52296 |
# | GINCO: List of Summaries/Excerpts    | FTD-X-GENRE: Promotion         |    0.0561 |     0.696894 | 1.10935 |
# Labels not matched: ['FTD-X-GENRE: Legal', 'FTD-X-GENRE: Prose/Lyrical', 'GINCO: Other', 'GINCO: Legal/Regulation', 'GINCO: Forum']
# Comparison: FTD-X-GENRE with CORE
# | Left_Hand_Side                              | Right_Hand_Side                             |   Support |   Confidence |    Lift |
# |:--------------------------------------------|:--------------------------------------------|----------:|-------------:|--------:|
# | CORE: How-To/Instructional                  | FTD-X-GENRE: Instruction                    |    0.0294 |     0.549533 | 9.08319 |
# | FTD-X-GENRE: News                           | CORE: Narrative                             |    0.0521 |     0.66033  | 5.95965 |
# | FTD-X-GENRE: Opinion/Argumentation          | CORE: Narrative                             |    0.0171 |     0.534375 | 4.82288 |
# | CORE: Informational Persuasion              | FTD-X-GENRE: Promotion                      |    0.1139 |     0.982744 | 1.56438 |
# | FTD-X-GENRE: Legal                          | CORE: Informational Description/Explanation |    0.0223 |     0.982379 | 1.51695 |
# | FTD-X-GENRE: Information/Explanation        | CORE: Informational Description/Explanation |    0.1387 |     0.819256 | 1.26506 |
# | CORE: Informational Description/Explanation | FTD-X-GENRE: Promotion                      |    0.4392 |     0.678196 | 1.07959 |
# Labels not matched: ['FTD-X-GENRE: Prose/Lyrical', 'CORE: Opinion', 'CORE: Spoken', 'CORE: Lyrical', 'CORE: Interactive Discussion']
# Comparison: FTD-X-GENRE with GINCO-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                        |   Support |   Confidence |    Lift |
# |:-------------------------------------|:---------------------------------------|----------:|-------------:|--------:|
# | FTD-X-GENRE: Instruction             | GINCO-X-GENRE: Instruction             |    0.0413 |     0.682645 | 8.36574 |
# | FTD-X-GENRE: News                    | GINCO-X-GENRE: News                    |    0.0692 |     0.87706  | 6.48713 |
# | FTD-X-GENRE: Opinion/Argumentation   | GINCO-X-GENRE: Opinion/Argumentation   |    0.0198 |     0.61875  | 6.23112 |
# | FTD-X-GENRE: Information/Explanation | GINCO-X-GENRE: Information/Explanation |    0.0957 |     0.565269 | 3.85323 |
# | FTD-X-GENRE: Promotion               | GINCO-X-GENRE: Promotion               |    0.4197 |     0.668099 | 1.49563 |
# Labels not matched: ['FTD-X-GENRE: Legal', 'FTD-X-GENRE: Prose/Lyrical', 'GINCO-X-GENRE: Other', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Forum', 'GINCO-X-GENRE: Prose/Lyrical']
# Comparison: FTD-X-GENRE with CORE-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                       |   Support |   Confidence |    Lift |
# |:-------------------------------------|:--------------------------------------|----------:|-------------:|--------:|
# | CORE-X-GENRE: News                   | FTD-X-GENRE: News                     |    0.0679 |     0.505585 | 6.40792 |
# | FTD-X-GENRE: Instruction             | CORE-X-GENRE: Instruction             |    0.0445 |     0.735537 | 3.64308 |
# | FTD-X-GENRE: Legal                   | CORE-X-GENRE: Information/Explanation |    0.0217 |     0.955947 | 2.34014 |
# | FTD-X-GENRE: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.1266 |     0.747785 | 1.83056 |
# | CORE-X-GENRE: Opinion/Argumentation  | FTD-X-GENRE: Promotion                |    0.1151 |     0.797091 | 1.26885 |
# | CORE-X-GENRE: Instruction            | FTD-X-GENRE: Promotion                |    0.1471 |     0.728579 | 1.15979 |
# | CORE-X-GENRE: Other                  | FTD-X-GENRE: Promotion                |    0.0121 |     0.695402 | 1.10698 |
# | CORE-X-GENRE: Forum                  | FTD-X-GENRE: Promotion                |    0.0452 |     0.647564 | 1.03083 |
# Labels not matched: ['FTD-X-GENRE: Opinion/Argumentation', 'FTD-X-GENRE: Prose/Lyrical', 'CORE-X-GENRE: Prose/Lyrical']
# Comparison: FTD-X-GENRE with X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:-------------------------------------|:---------------------------------|----------:|-------------:|---------:|
# | FTD-X-GENRE: Legal                   | X-GENRE: Legal                   |    0.0139 |     0.612335 | 37.1112  |
# | FTD-X-GENRE: Instruction             | X-GENRE: Instruction             |    0.0465 |     0.768595 |  8.93715 |
# | FTD-X-GENRE: News                    | X-GENRE: News                    |    0.0702 |     0.889734 |  6.03619 |
# | FTD-X-GENRE: Opinion/Argumentation   | X-GENRE: Opinion/Argumentation   |    0.0218 |     0.68125  |  5.74895 |
# | FTD-X-GENRE: Information/Explanation | X-GENRE: Information/Explanation |    0.1037 |     0.612522 |  3.3841  |
# | FTD-X-GENRE: Promotion               | X-GENRE: Promotion               |    0.376  |     0.598535 |  1.54461 |
# | X-GENRE: Other                       | FTD-X-GENRE: Promotion           |    0.0243 |     0.743119 |  1.18293 |
# Labels not matched: ['FTD-X-GENRE: Prose/Lyrical', 'X-GENRE: Prose/Lyrical', 'X-GENRE: Forum']
# Comparison: CORE-X-GENRE with FTD
# | Left_Hand_Side                        | Right_Hand_Side                       |   Support |   Confidence |    Lift |
# |:--------------------------------------|:--------------------------------------|----------:|-------------:|--------:|
# | FTD: A8 (news)                        | CORE-X-GENRE: News                    |    0.0498 |     0.943182 | 7.02295 |
# | FTD: A7 (instruction)                 | CORE-X-GENRE: Instruction             |    0.0383 |     0.728137 | 3.60642 |
# | FTD: A9 (legal)                       | CORE-X-GENRE: Information/Explanation |    0.0154 |     0.968553 | 2.371   |
# | FTD: A16 (information)                | CORE-X-GENRE: Information/Explanation |    0.1031 |     0.79737  | 1.95195 |
# | CORE-X-GENRE: Instruction             | FTD: A12 (promotion)                  |    0.1517 |     0.751362 | 1.27544 |
# | CORE-X-GENRE: Opinion/Argumentation   | FTD: A12 (promotion)                  |    0.0937 |     0.648892 | 1.1015  |
# | CORE-X-GENRE: Forum                   | FTD: A12 (promotion)                  |    0.0426 |     0.610315 | 1.03601 |
# | CORE-X-GENRE: Information/Explanation | FTD: A12 (promotion)                  |    0.2426 |     0.59388  | 1.00811 |
# | CORE-X-GENRE: Other                   | FTD: A12 (promotion)                  |    0.0103 |     0.591954 | 1.00484 |
# Labels not matched: ['CORE-X-GENRE: Prose/Lyrical', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A11 (personal)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)']
# Comparison: CORE-X-GENRE with GINCO
# | Left_Hand_Side                 | Right_Hand_Side                       |   Support |   Confidence |     Lift |
# |:-------------------------------|:--------------------------------------|----------:|-------------:|---------:|
# | GINCO: Forum                   | CORE-X-GENRE: Forum                   |    0.0207 |     0.928251 | 13.2987  |
# | CORE-X-GENRE: Prose/Lyrical    | GINCO: Opinion/Argumentation          |    0.015  |     0.632911 |  5.26549 |
# | CORE-X-GENRE: News             | GINCO: News/Reporting                 |    0.0756 |     0.562919 |  4.68319 |
# | GINCO: Instruction             | CORE-X-GENRE: Instruction             |    0.0584 |     0.782842 |  3.87737 |
# | GINCO: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.1273 |     0.891457 |  2.18227 |
# | CORE-X-GENRE: Instruction      | GINCO: Promotion                      |    0.1175 |     0.581971 |  1.4391  |
# Labels not matched: ['CORE-X-GENRE: Opinion/Argumentation', 'CORE-X-GENRE: Other', 'GINCO: List of Summaries/Excerpts', 'GINCO: Other', 'GINCO: Legal/Regulation']
# Comparison: CORE-X-GENRE with CORE
# | Left_Hand_Side                        | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:--------------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion          | CORE-X-GENRE: Forum                         |    0.0222 |     0.92887  | 13.3076  |
# | CORE: Narrative                       | CORE-X-GENRE: News                          |    0.064  |     0.577617 |  4.30095 |
# | CORE: How-To/Instructional            | CORE-X-GENRE: Instruction                   |    0.045  |     0.841121 |  4.16603 |
# | CORE-X-GENRE: Information/Explanation | CORE: Informational Description/Explanation |    0.3486 |     0.853366 |  1.31774 |
# Labels not matched: ['CORE-X-GENRE: Opinion/Argumentation', 'CORE-X-GENRE: Other', 'CORE-X-GENRE: Prose/Lyrical', 'CORE: Informational Persuasion', 'CORE: Opinion', 'CORE: Spoken', 'CORE: Lyrical']
# Comparison: CORE-X-GENRE with GINCO-X-GENRE
# | Left_Hand_Side                         | Right_Hand_Side                       |   Support |   Confidence |     Lift |
# |:---------------------------------------|:--------------------------------------|----------:|-------------:|---------:|
# | GINCO-X-GENRE: Forum                   | CORE-X-GENRE: Forum                   |    0.0187 |     0.939698 | 13.4627  |
# | CORE-X-GENRE: Prose/Lyrical            | GINCO-X-GENRE: Opinion/Argumentation  |    0.0154 |     0.649789 |  6.5437  |
# | CORE-X-GENRE: News                     | GINCO-X-GENRE: News                   |    0.0903 |     0.672375 |  4.97319 |
# | GINCO-X-GENRE: Instruction             | CORE-X-GENRE: Instruction             |    0.0589 |     0.721814 |  3.57511 |
# | GINCO-X-GENRE: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.1292 |     0.880709 |  2.15596 |
# | CORE-X-GENRE: Instruction              | GINCO-X-GENRE: Promotion              |    0.1276 |     0.631996 |  1.41481 |
# | CORE-X-GENRE: Opinion/Argumentation    | GINCO-X-GENRE: Promotion              |    0.0737 |     0.510388 |  1.14257 |
# Labels not matched: ['CORE-X-GENRE: Other', 'GINCO-X-GENRE: Other', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical']
# Comparison: CORE-X-GENRE with FTD-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                       |   Support |   Confidence |    Lift |
# |:-------------------------------------|:--------------------------------------|----------:|-------------:|--------:|
# | CORE-X-GENRE: News                   | FTD-X-GENRE: News                     |    0.0679 |     0.505585 | 6.40792 |
# | FTD-X-GENRE: Instruction             | CORE-X-GENRE: Instruction             |    0.0445 |     0.735537 | 3.64308 |
# | FTD-X-GENRE: Legal                   | CORE-X-GENRE: Information/Explanation |    0.0217 |     0.955947 | 2.34014 |
# | FTD-X-GENRE: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.1266 |     0.747785 | 1.83056 |
# | CORE-X-GENRE: Opinion/Argumentation  | FTD-X-GENRE: Promotion                |    0.1151 |     0.797091 | 1.26885 |
# | CORE-X-GENRE: Instruction            | FTD-X-GENRE: Promotion                |    0.1471 |     0.728579 | 1.15979 |
# | CORE-X-GENRE: Other                  | FTD-X-GENRE: Promotion                |    0.0121 |     0.695402 | 1.10698 |
# | CORE-X-GENRE: Forum                  | FTD-X-GENRE: Promotion                |    0.0452 |     0.647564 | 1.03083 |
# Labels not matched: ['CORE-X-GENRE: Prose/Lyrical', 'FTD-X-GENRE: Opinion/Argumentation', 'FTD-X-GENRE: Prose/Lyrical']
# Comparison: CORE-X-GENRE with X-GENRE
# | Left_Hand_Side                   | Right_Hand_Side                       |   Support |   Confidence |     Lift |
# |:---------------------------------|:--------------------------------------|----------:|-------------:|---------:|
# | X-GENRE: Forum                   | CORE-X-GENRE: Forum                   |    0.0238 |     0.96748  | 13.8607  |
# | CORE-X-GENRE: News               | X-GENRE: News                         |    0.0959 |     0.714073 |  4.84446 |
# | CORE-X-GENRE: Prose/Lyrical      | X-GENRE: Opinion/Argumentation        |    0.012  |     0.506329 |  4.27282 |
# | X-GENRE: Instruction             | CORE-X-GENRE: Instruction             |    0.07   |     0.813953 |  4.03147 |
# | X-GENRE: Legal                   | CORE-X-GENRE: Information/Explanation |    0.016  |     0.969697 |  2.3738  |
# | X-GENRE: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.155  |     0.856354 |  2.09634 |
# | CORE-X-GENRE: Instruction        | X-GENRE: Promotion                    |    0.1077 |     0.533432 |  1.3766  |
# Labels not matched: ['CORE-X-GENRE: Opinion/Argumentation', 'CORE-X-GENRE: Other', 'X-GENRE: Other', 'X-GENRE: Prose/Lyrical']
# Comparison: X-GENRE with FTD
# | Left_Hand_Side         | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:-----------------------|:---------------------------------|----------:|-------------:|---------:|
# | FTD: A9 (legal)        | X-GENRE: Legal                   |    0.0124 |     0.779874 | 47.2651  |
# | FTD: A7 (instruction)  | X-GENRE: Instruction             |    0.0417 |     0.792776 |  9.21832 |
# | FTD: A8 (news)         | X-GENRE: News                    |    0.0513 |     0.971591 |  6.59153 |
# | FTD: A11 (personal)    | X-GENRE: Opinion/Argumentation   |    0.0239 |     0.773463 |  6.52711 |
# | FTD: A16 (information) | X-GENRE: Information/Explanation |    0.0907 |     0.701469 |  3.87552 |
# | FTD: A12 (promotion)   | X-GENRE: Promotion               |    0.3718 |     0.631132 |  1.62873 |
# | X-GENRE: Other         | FTD: A12 (promotion)             |    0.0203 |     0.620795 |  1.0538  |
# Labels not matched: ['X-GENRE: Prose/Lyrical', 'X-GENRE: Forum', 'FTD: A1 (argumentative)', 'FTD: A17 (review)', 'FTD: A4 (fiction)', 'FTD: A14 (academic)']
# Comparison: X-GENRE with GINCO
# | Left_Hand_Side                 | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:-------------------------------|:---------------------------------|----------:|-------------:|---------:|
# | GINCO: Forum                   | X-GENRE: Forum                   |    0.0195 |     0.874439 | 35.5463  |
# | GINCO: Instruction             | X-GENRE: Instruction             |    0.0591 |     0.792225 |  9.21192 |
# | GINCO: Opinion/Argumentation   | X-GENRE: Opinion/Argumentation   |    0.0917 |     0.762895 |  6.43793 |
# | GINCO: News/Reporting          | X-GENRE: News                    |    0.0945 |     0.78619  |  5.33372 |
# | GINCO: Information/Explanation | X-GENRE: Information/Explanation |    0.121  |     0.847339 |  4.68143 |
# | GINCO: Promotion               | X-GENRE: Promotion               |    0.3439 |     0.850396 |  2.19457 |
# Labels not matched: ['X-GENRE: Other', 'X-GENRE: Legal', 'X-GENRE: Prose/Lyrical', 'GINCO: List of Summaries/Excerpts', 'GINCO: Other', 'GINCO: Legal/Regulation']
# Comparison: X-GENRE with CORE
# | Left_Hand_Side                   | Right_Hand_Side                             |   Support |   Confidence |     Lift |
# |:---------------------------------|:--------------------------------------------|----------:|-------------:|---------:|
# | CORE: Interactive Discussion     | X-GENRE: Forum                              |    0.0187 |     0.782427 | 31.806   |
# | CORE: How-To/Instructional       | X-GENRE: Instruction                        |    0.0444 |     0.829907 |  9.65008 |
# | CORE: Opinion                    | X-GENRE: Opinion/Argumentation              |    0.025  |     0.65445  |  5.52279 |
# | CORE: Narrative                  | X-GENRE: News                               |    0.0606 |     0.546931 |  3.71053 |
# | CORE: Informational Persuasion   | X-GENRE: Promotion                          |    0.104  |     0.897325 |  2.31568 |
# | X-GENRE: Legal                   | CORE: Informational Description/Explanation |    0.0165 |     1        |  1.54416 |
# | X-GENRE: Information/Explanation | CORE: Informational Description/Explanation |    0.1701 |     0.939779 |  1.45117 |
# | X-GENRE: Promotion               | CORE: Informational Description/Explanation |    0.2713 |     0.700129 |  1.08111 |
# | X-GENRE: Other                   | CORE: Informational Description/Explanation |    0.0227 |     0.69419  |  1.07194 |
# Labels not matched: ['X-GENRE: Prose/Lyrical', 'CORE: Spoken', 'CORE: Lyrical']
# Comparison: X-GENRE with GINCO-X-GENRE
# | Left_Hand_Side                         | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:---------------------------------------|:---------------------------------|----------:|-------------:|---------:|
# | GINCO-X-GENRE: Forum                   | X-GENRE: Forum                   |    0.0178 |     0.894472 | 36.3607  |
# | X-GENRE: Other                         | GINCO-X-GENRE: Other             |    0.0187 |     0.571865 |  9.29863 |
# | GINCO-X-GENRE: Instruction             | X-GENRE: Instruction             |    0.0607 |     0.743873 |  8.64968 |
# | GINCO-X-GENRE: Opinion/Argumentation   | X-GENRE: Opinion/Argumentation   |    0.0829 |     0.834844 |  7.0451  |
# | GINCO-X-GENRE: News                    | X-GENRE: News                    |    0.1166 |     0.862426 |  5.85092 |
# | GINCO-X-GENRE: Information/Explanation | X-GENRE: Information/Explanation |    0.1223 |     0.833674 |  4.60593 |
# | GINCO-X-GENRE: Promotion               | X-GENRE: Promotion               |    0.3617 |     0.809716 |  2.08959 |
# Labels not matched: ['X-GENRE: Legal', 'X-GENRE: Prose/Lyrical', 'GINCO-X-GENRE: Legal', 'GINCO-X-GENRE: Prose/Lyrical']
# Comparison: X-GENRE with FTD-X-GENRE
# | Left_Hand_Side                       | Right_Hand_Side                  |   Support |   Confidence |     Lift |
# |:-------------------------------------|:---------------------------------|----------:|-------------:|---------:|
# | FTD-X-GENRE: Legal                   | X-GENRE: Legal                   |    0.0139 |     0.612335 | 37.1112  |
# | FTD-X-GENRE: Instruction             | X-GENRE: Instruction             |    0.0465 |     0.768595 |  8.93715 |
# | FTD-X-GENRE: News                    | X-GENRE: News                    |    0.0702 |     0.889734 |  6.03619 |
# | FTD-X-GENRE: Opinion/Argumentation   | X-GENRE: Opinion/Argumentation   |    0.0218 |     0.68125  |  5.74895 |
# | FTD-X-GENRE: Information/Explanation | X-GENRE: Information/Explanation |    0.1037 |     0.612522 |  3.3841  |
# | FTD-X-GENRE: Promotion               | X-GENRE: Promotion               |    0.376  |     0.598535 |  1.54461 |
# | X-GENRE: Other                       | FTD-X-GENRE: Promotion           |    0.0243 |     0.743119 |  1.18293 |
# Labels not matched: ['X-GENRE: Prose/Lyrical', 'X-GENRE: Forum', 'FTD-X-GENRE: Prose/Lyrical']
# Comparison: X-GENRE with CORE-X-GENRE
# | Left_Hand_Side                   | Right_Hand_Side                       |   Support |   Confidence |     Lift |
# |:---------------------------------|:--------------------------------------|----------:|-------------:|---------:|
# | X-GENRE: Forum                   | CORE-X-GENRE: Forum                   |    0.0238 |     0.96748  | 13.8607  |
# | CORE-X-GENRE: News               | X-GENRE: News                         |    0.0959 |     0.714073 |  4.84446 |
# | CORE-X-GENRE: Prose/Lyrical      | X-GENRE: Opinion/Argumentation        |    0.012  |     0.506329 |  4.27282 |
# | X-GENRE: Instruction             | CORE-X-GENRE: Instruction             |    0.07   |     0.813953 |  4.03147 |
# | X-GENRE: Legal                   | CORE-X-GENRE: Information/Explanation |    0.016  |     0.969697 |  2.3738  |
# | X-GENRE: Information/Explanation | CORE-X-GENRE: Information/Explanation |    0.155  |     0.856354 |  2.09634 |
# | CORE-X-GENRE: Instruction        | X-GENRE: Promotion                    |    0.1077 |     0.533432 |  1.3766  |
# Labels not matched: ['X-GENRE: Other', 'X-GENRE: Prose/Lyrical', 'CORE-X-GENRE: Opinion/Argumentation', 'CORE-X-GENRE: Other']
