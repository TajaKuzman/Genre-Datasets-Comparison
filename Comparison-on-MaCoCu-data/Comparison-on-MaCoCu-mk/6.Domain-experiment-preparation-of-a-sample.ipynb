# %% [markdown]
# Here, we prepare a sample from MaCoCu-hr, on which we use the genre classifiers. To prepare the sample, we first need to discard all texts with text length smaller than 75 - I created a dictionary of all domains and urls of texts that are long enough. Then I calculated the frequency of the domains. I discarded domains that have less than 10 instances (if I wouldn't, the median would be 6 texts per domain). Then I calculated the median and took random 500 domains above the median and 500 domains below the median.

# %%
import gzip
import wget
import regex as re
import pandas as pd
import numpy as np
import json
import random
from tqdm import tqdm

# %%
# Compile regex for url and domain
url_re = re.compile('url="(.*?)"')
domain_re = re.compile('domain="(.*?)"')

# %% [markdown]
# ## Download and open the XLM file

# %%
# Download the corpus
# Download the file

#Defining the zip file URL
url = "https://www.clarin.si/repository/xmlui/bitstream/handle/11356/1512/MaCoCu-mk.xml.gz"

# Downloading the file by sending the request to the URL
corpus_file = wget.download(url)
print('Downloading Completed')
# Out:
# Downloading Completed

# %%
file = gzip.open('MaCoCu-mk.xml.gz', 'rt', encoding='utf-8')

# %% [markdown]
# ## Create a dataframe with the most frequent domains and a sample of 10 URLs from each domain

# %% [markdown]
# First, get a list of all domains and urls of texts that have are more than 75 words long.

# %%
text_counter = 0

texts = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_length = 0
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
	elif line.startswith("<p"):
		continue
	elif line.startswith("</p"):
		continue
	elif line.startswith("</doc"):
		text_length = len(pure_text.split())
		if text_length > 75:
			current_text = [current_domain, current_url]
			texts.append(current_text)
			text_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		pure_text += line
# Out:
# 47208386it [02:36, 302411.61it/s]

# %%
# Create a dataframe
df = pd.DataFrame({"domain": [x[0] for x in texts], "url": [x[1] for x in texts]})

df.head()
# Out:
#   domain                 url
# 0  ia.mk  https://www.ia.mk/
# 1  dd.mk  https://www.dd.mk/
# 2  gg.mk      https://gg.mk/
# 3  qs.mk  https://www.qs.mk/
# 4  fn.mk      https://fn.mk/

# %%
# Sort the df based on the domain
df = df.sort_values("domain")

df.head()
# Out:
#                       domain                                              url
# 300689  1000knigi.mon.gov.mk      http://1000knigi.mon.gov.mk/book.php?id=252
# 316176  1000knigi.mon.gov.mk     http://1000knigi.mon.gov.mk/book.php?id=1522
# 311898  1000knigi.mon.gov.mk     http://1000knigi.mon.gov.mk/book.php?id=1000
# 311899  1000knigi.mon.gov.mk     http://1000knigi.mon.gov.mk/book.php?id=1001
# 302153  1000knigi.mon.gov.mk  http://www.1000knigi.mon.gov.mk/book.php?id=107

# %%
df.describe(include="all")
# Out:
#          domain                                                url
# count   1475266                                            1475266
# unique     6257                                            1475261
# top      gol.mk  https://forum.kajgana.com/threads/%D0%93%D0%BB...
# freq      65658                                                  4

# %% [markdown]
# We got 1,475,261 texts in 6,257 domains.

# %%
df.domain.value_counts().to_dict()
# Out:
# {'gol.mk': 65658,
#  'denar.mk': 34908,
#  'kafepauza.mk': 34305,
#  'press24.mk': 33496,
#  'sitel.com.mk': 32750,
#  'off.net.mk': 26432,
#  'plusinfo.mk': 26229,
#  'slobodnaevropa.mk': 25271,
#  'daily.mk': 25080,
#  'forum.carclub.mk': 21873,
#  'ekran.mk': 21340,
#  'sdk.mk': 20331,
#  'okno.mk': 19441,
#  'novatv.mk': 19390,
#  'fashionel.mk': 19198,
#  'utrinski.com.mk': 18518,
#  'it.mk': 18360,
#  '365.com.mk': 17775,
#  'vardarfans.mk': 17252,
#  'tvm.mk': 16547,
#  'usb.mk': 16155,
#  'moirecepti.mk': 14786,
#  'ringeraja.mk': 13522,
#  'mkd.mk': 11824,
#  'forum.idividi.com.mk': 11802,
#  'skopjeinfo.mk': 11590,
#  'katolici.mk': 10512,
#  'mn.mk': 10211,
#  'lokalno.mk': 9757,
#  'radar.mk': 9732,
#  'arhiva.sdsm.org.mk': 9585,
#  'forum.it.mk': 9517,
#  'puls24.mk': 9463,
#  'civilmedia.mk': 9396,
#  'pravdiko.mk': 9347,
#  'arhiva.sportmedia.mk': 9175,
#  'telefoni.mk': 8928,
#  'kukuriku.com.mk': 8604,
#  'zdravstvo.mk': 8398,
#  'dubai-portal.com.mk': 8209,
#  'reporter.mk': 8156,
#  'publicitet.mk': 8136,
#  'forum.femina.mk': 8042,
#  'g-sport.mk': 7964,
#  'time.mk': 7870,
#  'preminportal.mk': 7856,
#  'ulica.mk': 7570,
#  'infomax.mk': 7253,
#  'femina.mk': 6997,
#  'demo13.clip.mk': 6980,
#  'sportm.mk': 6784,
#  'ustavensud.mk': 6712,
#  'sportmanija.mk': 6292,
#  'popularno.mk': 6132,
#  'inovativnost.mk': 6129,
#  'stylist.mk': 5996,
#  'build.mk': 5987,
#  'avtoplus.mk': 5707,
#  'mtm.mk': 5640,
#  'emiter.com.mk': 5443,
#  'gotvi.mk': 5425,
#  'apla.mk': 5413,
#  'slobodenpecat.mk': 5388,
#  'tvpaket.com.mk': 5248,
#  'eprints.ugd.edu.mk': 5234,
#  'bitolskivesnik.mk': 5162,
#  'kanal8.mk': 5043,
#  'meta.mk': 5037,
#  'info.mk': 5022,
#  'svest.mk': 4966,
#  'denesmagazin.mk': 4869,
#  'smart.sdk.mk': 4809,
#  'mia.mk': 4771,
#  'duma.mk': 4581,
#  '24rakomet.mk': 4487,
#  'mkvesti.mk': 4439,
#  'forum.kajgana.com': 4367,
#  'lider.com.mk': 4340,
#  'ubavinaizdravje.mk': 4326,
#  'crnobelo.com': 4268,
#  'vesti24.mk': 4193,
#  'porta3.mk': 3843,
#  'proverkanafakti.mk': 3838,
#  'ktv.mk': 3792,
#  'publikum.mk': 3672,
#  'brif.mk': 3469,
#  'sekojden.net': 3463,
#  'ipon.mk': 3388,
#  'narodenglas.com': 3309,
#  'ubavo.mk': 3287,
#  'standard.mk': 3232,
#  'vistinomer.mk': 3196,
#  'carclub.mk': 3178,
#  'fokus.mk': 3166,
#  'kurir.mk': 3125,
#  'moemeni.mk': 3092,
#  'smartportal.mk': 3040,
#  'religija.mk': 2993,
#  'sobranie.mk': 2913,
#  'radiomof.mk': 2882,
#  'novalek.mk': 2841,
#  'biznisvesti.mk': 2831,
#  'a1on.mk': 2822,
#  '24.mk': 2814,
#  'vrabotuvanje.com.mk': 2805,
#  'pharmanews.mk': 2800,
#  'mpc.org.mk': 2761,
#  'vecer.press': 2745,
#  'prizma.mk': 2725,
#  'krajbrezje.mk': 2709,
#  'aktuelno.mk': 2661,
#  'bankarstvo.mk': 2634,
#  'motori.mk': 2575,
#  'supersport.mk': 2529,
#  'emagazin.mk': 2524,
#  'arhiva.ugd.edu.mk': 2483,
#  'maktel.mk': 2463,
#  'skopjeid.mk': 2447,
#  'interesno.mk': 2420,
#  'kladenje.mk': 2365,
#  'ilike.mk': 2354,
#  'kanal5.com.mk': 2332,
#  'reklama5.mk': 2315,
#  'forum.gsm.mk': 2314,
#  'makfax.com.mk': 2274,
#  'dosie.mk': 2265,
#  'mk.globalvoices.org': 2262,
#  'milenicinja.mk': 2217,
#  'roditeliideca.com.mk': 2196,
#  'cooltura.mk': 2186,
#  'faktor.mk': 2179,
#  'bigorski.org.mk': 2168,
#  'mojportal.mk': 2164,
#  'forum.crnobelo.com': 2128,
#  'volanskopje.blogspot.com': 2106,
#  'makpress.mk': 2101,
#  'naslovna.mk': 2069,
#  'rtk.mk': 2039,
#  'vlada.mk': 2032,
#  'mmagazin.mk': 2031,
#  'ohridnews.com': 2023,
#  'babambitola.mk': 1992,
#  'mcms.mk': 1971,
#  'idividi.com.mk': 1967,
#  'mkd-news.com': 1950,
#  'gragjanskisvet.org.mk': 1949,
#  'sezadomot.com.mk': 1862,
#  'kajgana.com': 1846,
#  'sezahrana.mk': 1840,
#  'netpress.com.mk': 1836,
#  'babyshop.mk': 1798,
#  'divianarts.com': 1724,
#  'rabotnik.com.mk': 1689,
#  'strumica.gov.mk': 1680,
#  'autofocus.mk': 1642,
#  'marketkonekt.com': 1642,
#  'akademik.mk': 1617,
#  'kicevo.mk': 1604,
#  'rkmetalurg.mk': 1574,
#  'migusto.mk': 1570,
#  'kiselavoda.gov.mk': 1570,
#  'radiostip.mk': 1555,
#  'enauka.mk': 1492,
#  'kajmakot.softver.org.mk': 1480,
#  'republika.mk': 1476,
#  'zabava.mk': 1473,
#  'mbh.mk': 1456,
#  'stat.gov.mk': 1440,
#  'sony.com.mk': 1434,
#  'kariera.mk': 1433,
#  'romanticni.mk': 1419,
#  'vinotika.mk': 1379,
#  'aktuelno24.com.mk': 1347,
#  'life.ugd.edu.mk': 1341,
#  'webohrid.com': 1339,
#  'samozdravje.mk': 1316,
#  'ssm.org.mk': 1304,
#  'entrepreneur.mk': 1297,
#  'zenitprilep.com.mk': 1278,
#  'conrad.mk': 1274,
#  'marketing365.mk': 1257,
#  'finance.gov.mk': 1244,
#  'lider.mk': 1243,
#  'hitportal.com.mk': 1242,
#  'studenti.mk': 1225,
#  'rkvardar.mk': 1224,
#  'opstinakiselavoda.gov.mk': 1217,
#  'clp.mk': 1210,
#  'slikarskipribor.mk': 1205,
#  'loging.mk': 1177,
#  'wp.mpc.org.mk': 1145,
#  'zdravjeihrana.mk': 1144,
#  'seeu.edu.mk': 1142,
#  'radiokocani.mk': 1138,
#  'pedijatar.mk': 1124,
#  'muabet.mk': 1122,
#  'kanalvis.com': 1120,
#  'gazibaba.gov.mk': 1087,
#  'ekonomijaibiznis.mk': 1087,
#  'runway.mk': 1084,
#  'agrotim.mk': 1081,
#  'panacea.mk': 1080,
#  'ams.gov.mk': 1059,
#  'igeografija.mk': 1056,
#  'srekja.mk': 1051,
#  'glasnik.mk': 1048,
#  '24press.mk': 1029,
#  'denovi.mk': 1014,
#  'ujp.gov.mk': 1014,
#  'onestopshop.mk': 1012,
#  'novamakedonija.com.mk': 1010,
#  'gostivarpress.mk': 1006,
#  'ekologist.mk': 1000,
#  'vipmarket5.mk': 998,
#  '360stepeni.mk': 994,
#  'canon.com.mk': 993,
#  'gradina.mk': 982,
#  'dke.org.mk': 967,
#  'service.aerodrom.gov.mk': 957,
#  'mk.warbletoncouncil.org': 953,
#  'sportski.mk': 939,
#  'kultura.mk': 933,
#  'tribuna.mk': 926,
#  'dodajgas.mk': 923,
#  'panoptikum.mk': 908,
#  'krusevo.gov.mk': 901,
#  'kulart.mk': 894,
#  'sportmedia.mk': 879,
#  'radioholidej.com.mk': 865,
#  'mztskopjeaerodrom.mk': 865,
#  'instore.mk': 863,
#  'klaster.mk': 859,
#  'pretpriemac.com': 849,
#  'vesnik-ilinden.com': 836,
#  'mojaopstina.mk': 821,
#  'radiofortuna.com.mk': 816,
#  'popara.mk': 809,
#  'biznisinfo.mk': 799,
#  'mk.approby.com': 799,
#  'crapwerk.blogspot.com': 798,
#  'kineziologija.mk': 796,
#  'veles.gov.mk': 790,
#  'zazabava.com': 777,
#  'transparency.mk': 770,
#  'tocka.com.mk': 768,
#  'modamoda.mk': 768,
#  'autoinfo.mk': 767,
#  'dw.com': 766,
#  'pazar3.mk': 764,
#  'svedok.org.mk': 763,
#  'index24.mk': 762,
#  'drmitov.mk': 732,
#  'adtodate.mk': 731,
#  'vistina.com.mk': 722,
#  'nuub.mk': 718,
#  'dormeo.com.mk': 711,
#  'zurnal.mk': 708,
#  'greencivil.mk': 703,
#  'erizaov.mk': 702,
#  'mk.unistica.com': 690,
#  'zk.mk': 689,
#  'negotino.gov.mk': 676,
#  'respublica.edu.mk': 676,
#  'futv.media': 673,
#  'caa.gov.mk': 669,
#  'stip.gov.mk': 665,
#  'kupinapopust.mk': 656,
#  'viralno.mk': 655,
#  'blesok.mk': 649,
#  'sportvision.mk': 643,
#  'zemjodelie.mk': 633,
#  'iph.mk': 632,
#  'e-elixir.mk': 632,
#  'ibiz.mk': 628,
#  '24apteka.mk': 614,
#  'zenskimagazin.mk': 613,
#  'shop.kniga.mk': 611,
#  'zrk.rkmetalurg.mk': 608,
#  'customs.gov.mk': 607,
#  'denesen.mk': 602,
#  'pulsradio.mk': 600,
#  'porta.mk': 599,
#  'frontline.mk': 597,
#  'old.ekipa.mk': 597,
#  'svedok.mk': 594,
#  'gamer.mk': 591,
#  'mail.demirhisar.gov.mk': 590,
#  'jasnesumjas.blogspot.com': 590,
#  'povardarska-eparhija.org.mk': 589,
#  'demirhisar.gov.mk': 584,
#  'hbogo.mk': 566,
#  'topshop.com.mk': 565,
#  'feit.ukim.edu.mk': 563,
#  'arhiva.kultura.gov.mk': 552,
#  'arhiva.republika.mk': 548,
#  'fakulteti.mk': 547,
#  'pretpriemac.mk': 539,
#  'nfic.ff.ukim.edu.mk': 537,
#  'lisca.mk': 531,
#  'jorm.gov.mk': 528,
#  'mojtrener.mk': 528,
#  '1000knigi.mon.gov.mk': 528,
#  'glas.mk': 527,
#  'mail.mn.mk': 527,
#  'archive.jugoinfo.mk': 523,
#  'majkatiitatkoti.com': 522,
#  'vic.mk': 514,
#  'idscs.org.mk': 514,
#  'ckrm.org.mk': 510,
#  'agri.mk': 506,
#  'radovisnews.mk': 505,
#  'lekarinfo.mk': 500,
#  'crithink.mk': 498,
#  'arheo.com.mk': 498,
#  'aberdzija.com': 496,
#  'levica.mk': 496,
#  'rakupen.mk': 493,
#  'skopskoeho.mk': 493,
#  'artoftravel.mk': 492,
#  'preminportal.com.mk': 490,
#  'economist.mk': 488,
#  'nama.mk': 483,
#  'muzika24.mk': 481,
#  'alsat.mk': 480,
#  'vakataka.mk': 479,
#  'izvoz.mk': 477,
#  'vocentar.com': 476,
#  'zase.mk': 475,
#  'kulpop.mk': 475,
#  'pogled.mk': 474,
#  'demokratskisojuz.org.mk': 468,
#  'pozitiv.mk': 468,
#  'forum.avijacija.mk': 466,
#  'sajtotnadedo.mk': 466,
#  'kanal77.mk': 461,
#  'radiobravo.com.mk': 461,
#  'sd.fzf.ukim.edu.mk': 458,
#  'ednakvi.mk': 457,
#  'gsm.mk': 454,
#  'mim.org.mk': 453,
#  'skopje.global': 451,
#  'pelagon.mk': 449,
#  'vecer.mk': 448,
#  'ssnm.org.mk': 442,
#  'ecommerce.mk': 441,
#  'mms.mk': 441,
#  'ekipa.mk': 440,
#  'makedonskijazik.mk': 440,
#  'bujinkan.koryu.mk': 440,
#  'krugmk.com': 439,
#  'acibademsistina.mk': 439,
#  'mkn.koshachek.com': 438,
#  'coffeetime.mk': 437,
#  'bregalnicki.mk': 437,
#  'economy.gov.mk': 435,
#  'mail.ekologist.mk': 433,
#  'finki.ukim.mk': 422,
#  'kvota.mk': 422,
#  'polleosport.mk': 421,
#  'motori.com.mk': 421,
#  'maccinema.com': 417,
#  'radiobum.com.mk': 414,
#  'vicoteka.mk': 410,
#  'mtftennis.mk': 409,
#  'tetovoinfo.mk': 408,
#  'hitkujna.com.mk': 408,
#  'rsbsp.org.mk': 407,
#  'encimenci.com.mk': 405,
#  'grouper.mk': 404,
#  'emigriko.mk': 403,
#  'dzlp.mk': 400,
#  'kares.mk': 395,
#  'adora.com.mk': 395,
#  'jademe.mk': 387,
#  'antiko.org.mk': 373,
#  'mtsp.gov.mk': 367,
#  'nvosorabotka.gov.mk': 367,
#  'majkaidete.mk': 367,
#  'espreso.mk': 367,
#  'acibademsistinababy.mk': 365,
#  'sport1.mk': 363,
#  'probistip.mk': 362,
#  'skopje24.mk': 359,
#  'spektra.com.mk': 357,
#  'macedonium.org': 356,
#  'galama.club': 354,
#  'hops.org.mk': 351,
#  'scoutveles.org.mk': 350,
#  'kic.com.mk': 350,
#  'password.mk': 349,
#  'rdc.mk': 348,
#  'mavrovoirostuse.gov.mk': 347,
#  'meduza.mk': 346,
#  'gevgelija.gov.mk': 343,
#  'acmilan.mk': 340,
#  'atamacedonia.org.mk': 339,
#  'bukovo36.com': 336,
#  '420macedonia.blogspot.com': 335,
#  'mobilnost.mk': 330,
#  'jser.fzf.ukim.edu.mk': 327,
#  'mk.rbth.com': 326,
#  'strumicadenes.mk': 324,
#  'makpetrol.com.mk': 322,
#  'vlada.gov.mk': 321,
#  'gimprilep.edu.mk': 320,
#  '24auto.mk': 320,
#  'arhiva.finance.gov.mk': 319,
#  'antropol.mk': 318,
#  'macedoniahandball.com.mk': 316,
#  'magazin.mk': 315,
#  'rodina.org.mk': 314,
#  'ttk.com.mk': 313,
#  'mchamber.mk': 309,
#  'slowfood.mk': 308,
#  'kiss-menada.mk': 308,
#  'debrca.gov.mk': 305,
#  'wiki.spodeli.org': 304,
#  'zdravjeizivot.mk': 304,
#  'sdsmprilep.org.mk': 303,
#  'gevgelijanet.com': 301,
#  'delightoffice.mk': 300,
#  'blog.everest.mk': 295,
#  'javisejuzna.mk': 295,
#  'pehcevo.gov.mk': 295,
#  'licevlice.mk': 294,
#  'megjashi.org.mk': 292,
#  'komunikacii.net': 290,
#  '24fudbal.mk': 289,
#  'globusmagazin.mk': 289,
#  'scoop.mk': 289,
#  'nationalgallery.mk': 288,
#  'timeout.mk': 288,
#  'fitr.mk': 288,
#  'cup.org.mk': 286,
#  'brzkrug.com': 286,
#  'prohor.org': 285,
#  'samoprasaj.mk': 284,
#  'arhiva.womsvetinikole.org.mk': 280,
#  'pcelar.mk': 278,
#  'bregalnickaeparhija.org.mk': 278,
#  'bregalnica-ncp.mk': 276,
#  'mk.orthodoxwiki.org': 275,
#  'clubeconomy.com.mk': 274,
#  'fitlife.com.mk': 273,
#  'kinoteka.mk': 273,
#  'relaxirano.mk': 273,
#  'eccf.ukim.edu.mk': 272,
#  'outleton.com': 268,
#  'vesnik.com': 267,
#  'dribling.mk': 267,
#  'forumi.sdc.com.mk': 267,
#  'alkaloid.com.mk': 267,
#  'selotejp.com': 265,
#  'shop.depileve.mk': 265,
#  'sporty.mk': 264,
#  'destinationdelcevo.mk': 264,
#  'tiveriopol.mk': 263,
#  'lady.mk': 260,
#  'feniks.net.mk': 260,
#  'childrensembassy.org.mk': 260,
#  'ffm.mk': 260,
#  'arhiva.mvr.gov.mk': 259,
#  'semosedu.com.mk': 257,
#  'mitra.mk': 252,
#  'deso.mk': 250,
#  'samsung.com': 249,
#  'komoraoai.mk': 248,
#  'istyle.mk': 248,
#  'citylife.mk': 247,
#  'vicepremier-ekonomija.gov.mk': 247,
#  'mhc.org.mk': 246,
#  'dokazm.mk': 244,
#  'avtomagazin.com.mk': 244,
#  'derbi.mk': 243,
#  'health.acibademsistina.mk': 242,
#  'amsm.mk': 241,
#  'bigshop.mk': 240,
#  'upoz.org.mk': 240,
#  'arhiva.eastregion.mk': 239,
#  'ohridpress.com.mk': 239,
#  'prilep.gov.mk': 238,
#  'heratours.mk': 238,
#  'sakamknigi.mk': 237,
#  'e-tinex.mk': 236,
#  'marxists.org': 235,
#  'opendata.mk': 235,
#  'mkmap.eu.mk': 234,
#  'alfa.mk': 234,
#  'romaversitas.org.mk': 234,
#  'navalica.com': 233,
#  'bellina.mk': 232,
#  'mes.org.mk': 231,
#  'rezultat.mk': 231,
#  'clubeconomy.mk': 230,
#  'antolog.mk': 229,
#  'seinet.com.mk': 229,
#  'govornaomraza.mk': 228,
#  'macedonism.org': 227,
#  'tvoebebe.com': 226,
#  'cefe.mk': 225,
#  'eshop.wurth.com.mk': 225,
#  'krusel.mk': 224,
#  'nea.mk': 224,
#  'isos.com.mk': 223,
#  'jk.com.mk': 222,
#  'aek.mk': 222,
#  'koronavirus.gov.mk': 221,
#  'reagiraj.mk': 218,
#  'medium.edu.mk': 216,
#  'smsporaki.com': 215,
#  'glasprotivnasilstvo.org.mk': 214,
#  'mk.pmio.mk': 214,
#  'prosvetnodelo.com.mk': 213,
#  'oldprilep.com': 213,
#  'zonel.com.mk': 213,
#  'kavadareckiglas.blogspot.com': 212,
#  'pina.mk': 211,
#  'doktori.mk': 211,
#  'tiandemk.mk': 210,
#  'balkan.mk': 210,
#  'mail.opstinavinica.gov.mk': 209,
#  'utrinskivesnik.mk': 209,
#  'razvigormk.blogspot.com': 209,
#  'cineplexx.mk': 207,
#  'balansplus.mk': 207,
#  'nzs.mk': 207,
#  'gledaj.mkc.mk': 204,
#  'kolozeg.info': 204,
#  'hortikultura.mk': 204,
#  'utms.edu.mk': 204,
#  'narconon-balkan.org': 203,
#  'boza.mk': 203,
#  'esem.org.mk': 203,
#  'youthcan.org.mk': 202,
#  'ayurveda.mk': 202,
#  'zoom.mk': 202,
#  'napravisam.mk': 202,
#  'marh.mk': 201,
#  'mail.makedonikalitera.mk': 201,
#  'ugostitelstvo.mk': 201,
#  'cair.gov.mk': 200,
#  'portret.digital': 199,
#  'opserver.mk': 199,
#  'nff.org.mk': 199,
#  'evn.mk': 198,
#  'centar.mk': 198,
#  'imoti247.com': 196,
#  'mmb.org.mk': 196,
#  'mail.adtodate.mk': 196,
#  'medicushelp.com.mk': 196,
#  'znm.org.mk': 195,
#  'pressingtv.mk': 194,
#  'nubsk.edu.mk': 194,
#  'direktno.mk': 194,
#  'biznisregulativa.mk': 193,
#  'mba.org.mk': 192,
#  'dezen.mk': 192,
#  'mk.mcgo.org.mk': 192,
#  'termin.mk': 192,
#  'ohrid24.mk': 190,
#  'marjan.mk': 189,
#  'zelenaberza.com.mk': 189,
#  'dieta.mk': 189,
#  'pari.com.mk': 188,
#  'makemigration.org': 187,
#  'cinemax.mk': 187,
#  'rkprolet.mk': 186,
#  'conservative.mk': 185,
#  'eprints.uklo.edu.mk': 185,
#  'lgbti.mk': 184,
#  'zdruzenska.org.mk': 183,
#  'bulevar.mk': 183,
#  'skopjecasual.mk': 183,
#  'sakampivo.mk': 179,
#  'telma.com.mk': 179,
#  'opm.org.mk': 179,
#  'news1.mk': 178,
#  'credissimo.mk': 178,
#  'fotosojuz.mk': 175,
#  'dbki.gov.mk': 175,
#  'cesinovo-oblesevo.gov.mk': 175,
#  'holocaustfund.org.mk': 175,
#  'pppe.mk': 175,
#  'onlineshopping.mk': 173,
#  'sportskoradio903.com.mk': 173,
#  'dudinka.org': 172,
#  'samaholiday.com.mk': 171,
#  'forum-csrd.org.mk': 171,
#  'pbc.mk': 171,
#  'setaliste.com.mk': 171,
#  'sovremenozemjodelstvo.mk': 170,
#  'kumanovskimuabeti.mk': 169,
#  'mister.com.mk': 169,
#  'kirm.mk': 169,
#  'sistinaoftalmologija.mk': 168,
#  'aktiv.mk': 168,
#  'beta.mafia.mk': 166,
#  'korica.mk': 166,
#  'telekom.mk': 166,
#  'zazu.mk': 166,
#  'fmu.ukim.edu.mk': 164,
#  'yves-rocher.mk': 164,
#  'europeanmovement.org.mk': 164,
#  'libertabebecentar.mk': 164,
#  'dafkocani.com': 162,
#  'fkkitgo.mk': 162,
#  'outdoor.mk': 162,
#  'mkdsumi.com.mk': 162,
#  'wellneo.com.mk': 162,
#  'posta.com.mk': 160,
#  'somelikeitraw.mk': 160,
#  'ikona.mk': 159,
#  'radiobubamara.mk': 159,
#  'astronomija.mk': 158,
#  'iutecredit.mk': 158,
#  'slobodensoftver.org.mk': 158,
#  'mk.voanews.com': 157,
#  'velesbiking.mk': 156,
#  'mrfp.mk': 156,
#  'vinica.gov.mk': 156,
#  'termosistem.com.mk': 156,
#  'usje.com.mk': 155,
#  'herald.mk': 155,
#  'yes-network.org': 155,
#  'kfsm.mk': 154,
#  '112.mk': 154,
#  'ftu.uklo.edu.mk': 154,
#  'datalab.com.mk': 154,
#  'flesh.mk': 154,
#  'epilepsijamakedonija.mk': 153,
#  'kb.com.mk': 153,
#  'kooperacija.mk': 153,
#  'metamorphosis.org.mk': 153,
#  'urma.mk': 153,
#  'ihr.org.mk': 152,
#  'daikin.mk': 151,
#  'medno.mk': 151,
#  'oer.mk': 151,
#  'm-p-c.org': 150,
#  'grid.mk': 150,
#  'fzo.org.mk': 150,
#  'blog.literatura.mk': 150,
#  'probistip.gov.mk': 150,
#  'uklo.edu.mk': 149,
#  'comics.mk': 149,
#  'diversitymedia.mk': 149,
#  'chamber.mk': 149,
#  'pablisher.nicer2.com': 149,
#  'ajvandoktor.blogspot.com': 148,
#  'platform.mk': 147,
#  'volvotrucks.mk': 147,
#  'radovis.gov.mk': 147,
#  'glamur.mk': 146,
#  'web.archive.org': 145,
#  'maticanaiselenici.com': 145,
#  'autolux.mk': 144,
#  'msi.gov.mk': 144,
#  'makedonikalitera.mk': 144,
#  'herojnaedenden.mk': 143,
#  'bubamaraigracki.mk': 142,
#  'gs1mk.org.mk': 142,
#  'makedoniaese.com': 142,
#  'creative.arheo.com.mk': 142,
#  'romainfo.mk': 142,
#  'arhiva.berovo.gov.mk': 140,
#  'smartus.mk': 139,
#  'ribar.com.mk': 138,
#  'libertas.mk': 138,
#  'fn.mk': 138,
#  'tvplus.mk': 138,
#  'lenka.mk': 138,
#  'stb.mk': 138,
#  'makstrip.com.mk': 137,
#  'a1.mk': 137,
#  'literatura.mk': 137,
#  'skopje2014.prizma.birn.eu.com': 137,
#  'lakes.mk': 136,
#  'isshs.edu.mk': 136,
#  'patem.mk': 136,
#  'surovoivkusno.com': 136,
#  'bitola.info': 136,
#  'skopjelab.mk': 136,
#  'ipardpa.gov.mk': 136,
#  'jivi.mk': 135,
#  'msu.edu.mk': 135,
#  'kavadarci.gov.mk': 135,
#  'geograf.mk': 135,
#  'marketonline.mk': 134,
#  'epi.org.mk': 134,
#  'remedika.com.mk': 132,
#  'iskonmakedonija.blogspot.com': 131,
#  'tfb.edu.mk': 131,
#  'pmf.ukim.edu.mk': 131,
#  'jub.com.mk': 131,
#  'georeport.mk': 131,
#  'kocani.gov.mk': 131,
#  'inpress.mk': 130,
#  'struze.mk': 130,
#  'creativehub.mk': 130,
#  'avmu.mk': 129,
#  '1tv.mk': 129,
#  'sdsm.org.mk': 129,
#  'artkujna.mk': 128,
#  'nuubgdst.mk': 128,
#  'makstore.mk': 128,
#  'snestorovska.com': 128,
#  'casinobonus.mk': 128,
#  'vesti.mk': 127,
#  'schatze.mk': 127,
#  'volkswagen.com.mk': 127,
#  'natochak.blogspot.com': 126,
#  'astroscopia.com': 126,
#  'pretsedatel.mk': 126,
#  'drnka.mk': 125,
#  'fitkit.app': 125,
#  'mvr.gov.mk': 125,
#  'nmd.mk': 125,
#  'mse.mk': 125,
#  'automedia.mk': 124,
#  'begemot.mk': 124,
#  'audi.mk': 124,
#  'vbb.mk': 124,
#  'idsbiolozi.com': 124,
#  'domato.mk': 123,
#  'torba.mk': 123,
#  'flp.bg': 123,
#  'civicamobilitas.mk': 123,
#  'lazaropolee.blogspot.com': 123,
#  'skopje1.mk': 122,
#  'makedonija.rastko.net': 122,
#  'stb.com.mk': 122,
#  'wellnessmk.com': 122,
#  'kulturnamapa.mk': 121,
#  'ckbelimugri.mk': 121,
#  'buzzsneakers.com': 121,
#  'onlinenewspapers24.com': 121,
#  'duvlo.mk': 121,
#  'mja.org.mk': 121,
#  'alfaromeo.mk': 120,
#  'superradio.com.mk': 120,
#  'avtoklub.mk': 120,
#  'sitnoseckano.com': 119,
#  'oougocedelcev.edu.mk': 119,
#  'archived.feit.ukim.edu.mk': 119,
#  'akcent.mk': 119,
#  'nutrivita.mk': 119,
#  'umbrellashop.mk': 119,
#  'ekobalans.mk': 118,
#  'pandorashop.mk': 118,
#  'blog.grouper.mk': 118,
#  'ex.mk': 117,
#  'stanica.mk': 117,
#  'mojbiznis.mk': 117,
#  'konekt.org.mk': 116,
#  'media.mk': 116,
#  'lush.com.mk': 116,
#  'tera.mk': 116,
#  'pravda.gov.mk': 116,
#  'agencija.gov.mk': 116,
#  'mojagarderoba.mk': 115,
#  'dzs.gov.mk': 115,
#  'gavro.com.mk': 115,
#  'sei.gov.mk': 115,
#  'setec.mk': 115,
#  'euroimpex.com.mk': 115,
#  'aurora.mk': 114,
#  'ippo.gov.mk': 114,
#  'odnaszanas.com': 114,
#  'toniavramov.wordpress.com': 114,
#  'vmro-dpmne.org.mk': 114,
#  'klever.com.mk': 114,
#  'eatalian.mk': 113,
#  'kupialat.mk': 113,
#  'robertkrstevski.blogspot.com': 113,
#  'arno.mk': 113,
#  'iml.edu.mk': 113,
#  'cea.org.mk': 112,
#  'istokpress.mk': 111,
#  'liqui-moly.mk': 111,
#  'hairshop.mk': 110,
#  'economy.strumica.gov.mk': 110,
#  'skopjecitymall.mk': 110,
#  'investicii.prizma.mk': 110,
#  'galama.website': 109,
#  'prekrasensvet.mk': 109,
#  'izlezi.mk': 109,
#  'borka.org.mk': 109,
#  'arh.ukim.edu.mk': 108,
#  'knauf.mk': 108,
#  'mojotgrad.com': 108,
#  'topsport.mk': 107,
#  'irl.mk': 107,
#  'carwash.mk': 107,
#  'neuromedica.com.mk': 106,
#  'krivogastani.com': 106,
#  'lococroco.com': 106,
#  'mail.apla.mk': 105,
#  'rcgo.mk': 105,
#  'pf.ugd.edu.mk': 105,
#  'semm.mk': 104,
#  'objektivno24.mk': 104,
#  'proektsreka.mk': 104,
#  'janakiznae.mk': 104,
#  'healthrights.mk': 103,
#  'nlb.mk': 103,
#  'zdravaishrana.mk': 103,
#  'novaiskra.mk': 103,
#  'naglednisredstva.mk': 103,
#  'muzejbitola.mk': 103,
#  'represent.mk': 103,
#  'cms.mtsp.gov.mk': 102,
#  'adsdp.com.mk': 102,
#  '4news.mk': 102,
#  '24info.mk': 102,
#  'elenalukahome.com': 102,
#  'ohridinfo.mk': 101,
#  'elektromobilnost.mk': 101,
#  'statija.mk': 101,
#  'mba.mk': 101,
#  'silkroadbank.com.mk': 101,
#  'publisher.mk': 101,
#  'stopgmo.mk': 101,
#  'vrabotuvanje.usje.mk': 101,
#  'halkbank.mk': 100,
#  'ff.ukim.edu.mk': 100,
#  'telegraph.mk': 99,
#  'alpinizam.org': 99,
#  'topsi.mk': 99,
#  'vistinatakeveoslobodi.wordpress.com': 98,
#  'bubamara.mk': 98,
#  'fiat.mk': 98,
#  'esi.mk': 98,
#  'simpozion.mk': 97,
#  'tirekovmirece.com': 97,
#  'novakonsalting.mk': 97,
#  'geokomora.mk': 97,
#  'maskimagazin.faktor.mk': 96,
#  'sosuilinden.edu.mk': 96,
#  'ekonomski.mk': 96,
#  'tiiiitinc.com': 96,
#  'abortusne.org.mk': 94,
#  'fkvardar.mk': 94,
#  'mpps.org.mk': 94,
#  'sezafitnes.mk': 94,
#  'iks.edu.mk': 94,
#  'popis.mk': 94,
#  'kultura.com.mk': 93,
#  'opel.mk': 93,
#  'valentinolaucoski.com': 93,
#  'hajdpark.mk': 93,
#  'webstrian.mk': 93,
#  'mir.org.mk': 92,
#  'healthaid.mk': 92,
#  'natusana.mk': 92,
#  'habitat.org.mk': 92,
#  'vermilion-books.info': 92,
#  'skoda.com.mk': 92,
#  'babinlek.com': 92,
#  'pressclipping.com.mk': 91,
#  'bkk-pisateli.mk': 91,
#  'master-sport.com.mk': 91,
#  'nekrolog.info': 91,
#  'vasaptekar.mk': 91,
#  'champion.mk': 91,
#  'cmus.ugd.edu.mk': 90,
#  'zim.mk': 90,
#  'justall24news.com': 90,
#  'automakedonija.com.mk': 90,
#  'mod.gov.mk': 89,
#  'tehnolab.com.mk': 89,
#  'm.alfa.mk': 89,
#  'hemija.net': 89,
#  'berin.mk': 89,
#  'crvenkrst-veles.org.mk': 88,
#  'ftbl.ugd.edu.mk': 88,
#  'bebehome.mk': 88,
#  'bbschool.mk': 88,
#  'tvoezdravje.mk': 88,
#  'replek.com.mk': 87,
#  'tesoridimare.mk': 87,
#  'cgimk.org.mk': 87,
#  'superortho.com.mk': 87,
#  'sika.com.mk': 87,
#  'sportclub.mk': 87,
#  'scjanesandanski.mk': 87,
#  'prodavnici.mk': 87,
#  'fbe.edu.mk': 86,
#  'ccc.org.mk': 86,
#  'autopro.mk': 86,
#  'jeep.mk': 86,
#  'papa.mk': 86,
#  'svadbainfo.mk': 86,
#  'kkvardar.mk': 86,
#  'shop.smart-idea.mk': 86,
#  'zanas.mk': 85,
#  'biokom-trend.com': 85,
#  'ff.ugd.edu.mk': 85,
#  'sadu.mk': 85,
#  'mon.gov.mk': 85,
#  '101hair.mk': 85,
#  'zrkvardar.mk': 85,
#  'next-em.com.mk': 84,
#  'matica.com.mk': 84,
#  'mojzbor.com': 84,
#  'cancertreatment.mk': 84,
#  'a5.arh.ukim.edu.mk': 84,
#  'nssrm.org.mk': 84,
#  'delimano.com.mk': 83,
#  'daves-kitchen.com': 83,
#  'libido.com.mk': 83,
#  'makedonskakamenica.gov.mk': 83,
#  'markukule.mk': 83,
#  'vodovod-ohrid.com.mk': 83,
#  'cuk.gov.mk': 83,
#  'aitonix.mk': 83,
#  'managersacademy.mk': 82,
#  'dnevninovosti.mk': 82,
#  'osten.mk': 82,
#  'popup.mk': 82,
#  'nemrazi.mk': 82,
#  'midb.mk': 82,
#  'meridijani.blogspot.com': 82,
#  'bkks.org': 81,
#  'insumak.mk': 81,
#  'uzkn.gov.mk': 81,
#  'oemvp.org': 81,
#  'bilnaapteka.com.mk': 81,
#  'viafarm.mk': 81,
#  'slikomania.mk': 80,
#  '4k.mk': 80,
#  'fva.gov.mk': 80,
#  'kfm.com.mk': 80,
#  'eurovia.mk': 80,
#  'biocosmos.mk': 80,
#  'merc.org.mk': 80,
#  'mf.ukim.edu.mk': 80,
#  'antena5.mk': 80,
#  'eu.edu.mk': 79,
#  'blog.bananakick.mk': 79,
#  'storybox.mk': 79,
#  'sluh.com.mk': 79,
#  'bran.com.mk': 79,
#  'continental.mk': 78,
#  'bitolanews.mk': 78,
#  'euro-stil.mk': 78,
#  'gdu.org.mk': 78,
#  'java.com.mk': 78,
#  'biblegateway.com': 78,
#  'mail.interesno.mk': 78,
#  'sunilens.com.mk': 77,
#  'mrfp.org.mk': 77,
#  'm.makpress.mk': 77,
#  'zf.ugd.edu.mk': 77,
#  'maktrek.blogspot.com': 77,
#  'bilboard.mk': 77,
#  '24mall.mk': 77,
#  'nacebugjoni.mk': 76,
#  'footballmacedonia.blogspot.com': 76,
#  'print.mk': 76,
#  'zenica.mk': 76,
#  'aopz.gov.mk': 76,
#  'calivita.mk': 76,
#  'firmi.gazibaba.gov.mk': 75,
#  'bramac.mk': 75,
#  'sier.org.mk': 75,
#  'avijacija.com.mk': 75,
#  'cdhv.mk': 75,
#  'wine.mk': 75,
#  'gorginaumov.edu.mk': 74,
#  'rodovreactor.mk': 74,
#  'restorani.com.mk': 74,
#  'fmn.ugd.edu.mk': 74,
#  'officeplus.mk': 74,
#  'cedi.mk': 74,
#  'ramstoredodoma.com.mk': 74,
#  'supermen.tocka.com.mk': 74,
#  'ef.utms.edu.mk': 73,
#  'balkanturist.mk': 73,
#  'decibel.mk': 73,
#  'infokompas.com.mk': 73,
#  'sud.mk': 73,
#  'stepbystep.org.mk': 73,
#  'jungletribe.mk': 72,
#  'meta2.webfactional.com': 72,
#  'commonsensehate.blogspot.com': 72,
#  'skopskimaraton.com.mk': 72,
#  'prf.org.mk': 72,
#  'bmw.com.mk': 72,
#  'investinpelagoniaregion.mk': 72,
#  'mail.mztskopjeaerodrom.mk': 72,
#  'staronagoricane.blogspot.com': 72,
#  'duna.mk': 72,
#  'krivapalanka.gov.mk': 72,
#  'idealno.mk': 72,
#  '7dena.mk': 72,
#  'novinarskapatka.mk': 71,
#  'sicommunication.mk': 71,
#  'av.gov.mk': 71,
#  'times.com.mk': 71,
#  'tigo.mk': 71,
#  ...}

# %%
# Calculate domain distribution
domain_distribution = pd.DataFrame({"domain": list(df.domain.value_counts().to_dict().keys()), "frequency":list(df.domain.value_counts().to_dict().values())})
domain_distribution
# Out:
#                    domain  frequency
# 0                  gol.mk      65658
# 1                denar.mk      34908
# 2            kafepauza.mk      34305
# 3              press24.mk      33496
# 4            sitel.com.mk      32750
# ...                   ...        ...
# 6252  elektrobojan.com.mk          1
# 6253           myprint.mk          1
# 6254   elektroluks.com.mk          1
# 6255          semering.mk          1
# 6256        m.reklama5.mk          1
#
# [6257 rows x 2 columns]

# %%
# Discard instances with frequency less than 10
domain_distribution = domain_distribution[domain_distribution["frequency"] > 9]

domain_distribution.shape
# Out:
# (2606, 2)

# %% [markdown]
# I first discarded domains with less than 10 texts, then calculated the median. The remaining number of domains was 2,606.

# %%
# Find the median
domain_distribution.frequency.describe()
# Out:
# count     2606.000000
# mean       561.796239
# std       2715.305274
# min         10.000000
# 25%         18.000000
# 50%         43.000000
# 75%        146.750000
# max      65658.000000
# Name: frequency, dtype: float64

# %% [markdown]
# The median number of texts per domain is 43. Now, I'll take 500 domains with frequency below this number and 500 domains with frequency above this number. I'll split the dataset into two based on the median.

# %%
domain_distribution.head()
# Out:
#          domain  frequency
# 0        gol.mk      65658
# 1      denar.mk      34908
# 2  kafepauza.mk      34305
# 3    press24.mk      33496
# 4  sitel.com.mk      32750

# %%
top_domain_distribution = domain_distribution[domain_distribution["frequency"] > 43]
top_domain_distribution.shape
# Out:
# (1288, 2)

# %%
bottom_domain_distribution = domain_distribution[domain_distribution["frequency"] < 43]
bottom_domain_distribution.shape
# Out:
# (1300, 2)

# %%
# Take a random sample from top and random sample from bottom
top_domain_distribution = top_domain_distribution.sample(n=500)
top_domain_distribution.shape
# Out:
# (500, 2)

# %%
top_domain_distribution["frequency"].describe()
# Out:
# count      500.00000
# mean       995.12600
# std       2733.36359
# min         44.00000
# 25%         72.00000
# 50%        156.50000
# 75%        527.25000
# max      21340.00000
# Name: frequency, dtype: float64

# %%
bottom_domain_distribution = bottom_domain_distribution.sample(n=500)
bottom_domain_distribution.head()
# Out:
#                 domain  frequency
# 1470            msu.mk         33
# 1507       povrzani.mk         31
# 1671  fmmm.utms.edu.mk         26
# 1461       mbdp.com.mk         33
# 1518       adriamed.mk         31

# %%
# Join the dataframes
domain_sample = pd.concat([top_domain_distribution, bottom_domain_distribution])
domain_sample.describe(include="all")
# Out:
#                           domain    frequency
# count                       1000   1000.00000
# unique                      1000          NaN
# top     newbalkanpolitics.org.mk          NaN
# freq                           1          NaN
# mean                         NaN    507.91100
# std                          NaN   1992.37393
# min                          NaN     10.00000
# 25%                          NaN     18.00000
# 50%                          NaN     43.00000
# 75%                          NaN    156.25000
# max                          NaN  21340.00000

# %%
# Create a list of domains
domain_sample_list = domain_sample.domain.to_list()
domain_sample_list[:10]
# Out:
# ['newbalkanpolitics.org.mk',
#  'mk.voanews.com',
#  'denesen.mk',
#  'krivogastani.com',
#  'kfsm.mk',
#  'marxists.org',
#  'suteren.mk',
#  'aitonix.mk',
#  'kulturnariznica.mk',
#  'forum.gsm.mk']

# %%
# For each domain, sample out 10 texts from the initial dataframe

# First create the initial df to which all others in the loop will be added
final_sample = df[df["domain"] == domain_sample_list[0]].sample(n=10)

final_sample
# Out:
#                            domain  \
# 476371   newbalkanpolitics.org.mk
# 583732   newbalkanpolitics.org.mk
# 1284056  newbalkanpolitics.org.mk
# 1297315  newbalkanpolitics.org.mk
# 1215721  newbalkanpolitics.org.mk
# 539857   newbalkanpolitics.org.mk
# 1071795  newbalkanpolitics.org.mk
# 605494   newbalkanpolitics.org.mk
# 578966   newbalkanpolitics.org.mk
# 1028097  newbalkanpolitics.org.mk
#
#                                                        url
# 476371   http://newbalkanpolitics.org.mk/item/Fear-and-...
# 583732   http://newbalkanpolitics.org.mk/item/THE-BORDE...
# 1284056  http://www.newbalkanpolitics.org.mk/item/Oднос...
# 1297315  http://www.newbalkanpolitics.org.mk/item/Recur...
# 1215721  http://newbalkanpolitics.org.mk/item/SHAMEFUL-...
# 539857   http://www.newbalkanpolitics.org.mk/item/Inter...
# 1071795  http://newbalkanpolitics.org.mk/item/The%20Ody...
# 605494   http://www.newbalkanpolitics.org.mk/item/Кога-...
# 578966   http://www.newbalkanpolitics.org.mk/item/Каков...
# 1028097  http://newbalkanpolitics.org.mk/item/The-Posit...

# %%
# Add all other domains
remaining_list = domain_sample_list[1:]

for i in remaining_list:
	added_instances = df[df["domain"] == i].sample(n=10)
	final_sample = pd.concat([final_sample, added_instances])

final_sample.shape
# Out:
# (10000, 2)

# %%
final_sample.describe()
# Out:
#                           domain  \
# count                      10000
# unique                      1000
# top     newbalkanpolitics.org.mk
# freq                          10
#
#                                                       url
# count                                               10000
# unique                                              10000
# top     http://newbalkanpolitics.org.mk/item/Fear-and-...
# freq                                                    1

# %% [markdown]
# The final sample has 10.000 instances from 1000 domains.

# %%
# Save the df
final_sample.to_csv("MaCoCu-mk-sample-domains-and-urls.csv", sep="\t")

# %% [markdown]
# ## Extract the text from the TMX based on the URL list

# %%
# Open the df with domains and urls for the sample
final_sample = pd.read_csv("MaCoCu-mk-sample-domains-and-urls.csv", sep="\t", index_col = 0)

final_sample.head(2)
# Out:
#                           domain  \
# 476371  newbalkanpolitics.org.mk
# 583732  newbalkanpolitics.org.mk
#
#                                                       url
# 476371  http://newbalkanpolitics.org.mk/item/Fear-and-...
# 583732  http://newbalkanpolitics.org.mk/item/THE-BORDE...

# %%
final_sample.shape
# Out:
# (10000, 2)

# %%
# Create a list of urls in the sample
url_list = list(final_sample["url"].unique())
url_list[:10]
# Out:
# ['http://newbalkanpolitics.org.mk/item/Fear-and-Politics/mk',
#  'http://newbalkanpolitics.org.mk/item/THE-BORDERS-OF-OUR-MINDS/mk',
#  'http://www.newbalkanpolitics.org.mk/item/Oдносите-меѓу-црквата-и-државата,-националниот-идентитет-и-безбедноста-во-Грција-по-студената-војна/mk',
#  'http://www.newbalkanpolitics.org.mk/item/Recurrent-Challenges-to-the-Implementation-of-Intrastate-Peace-Agreements:The-Resistance-of-State-Authorities/mk',
#  'http://newbalkanpolitics.org.mk/item/SHAMEFUL-BEHAVIOR-OF-THE-OFFICIALS-OF-THE-EUROPEAN-AGENCY-FOR-RECONSTRUCTION/mk',
#  'http://www.newbalkanpolitics.org.mk/item/International-politics/mk',
#  'http://newbalkanpolitics.org.mk/item/The%20Odyssey%20of%20the%20Roma%20Refugees%20from%20Kosovo/mk',
#  'http://www.newbalkanpolitics.org.mk/item/Кога-ништо-друго-не-успева/mk',
#  'http://www.newbalkanpolitics.org.mk/item/Каков-однос-кон-минатото/mk',
#  'http://newbalkanpolitics.org.mk/item/The-Position-of-the-Turks-in-the-Republic-of-Macedonia/mk']

# %%
len(url_list)
# Out:
# 10000

# %%
# Now that I have the URL list, I will extract texts from the MaCoCu-mk.xml.gz for the sample based on the URL list.

text_all_counter = 0

texts_all = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_string = ""
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
		text_string += line
	elif line.startswith("<p"):
		text_string += line
	elif line.startswith("</p"):
		text_string += line
	elif line.startswith("</doc"):
		text_string += line
		if current_url in url_list:
			current_text = [current_domain, current_url, pure_text, text_string]
			texts_all.append(current_text)
			text_all_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		text_string += line
		pure_text += line
# Out:
# 47208386it [05:54, 133165.23it/s]

# %%
text_all_counter
# Out:
# 10000

# %%
# Create a dataframe out of the text file

df_long_texts = pd.DataFrame({"domain": [x[0] for x in texts_all], "url": [x[1] for x in texts_all], "text": [x[2] for x in texts_all],"doc": [x[3] for x in texts_all]})

df_long_texts.head()
# Out:
#    domain                 url  \
# 0   gg.mk      https://gg.mk/
# 1   qs.mk  https://www.qs.mk/
# 2  in2.mk      http://in2.mk/
# 3  ldp.mk     https://ldp.mk/
# 4  iep.mk     https://iep.mk/
#
#                                                 text  \
# 0  Тоа е тоа, екипа. Претпоследната епизода ја на...
# 1  Парадата на гордоста се враќа под слоганот "Во...
# 2  Од крајот на месец Ноември 2009 година, своето...
# 3  Што не прави либрали?\nЕманципација од стравов...
# 4  ИНИЦИЈАТИВА ЗА ЕВРОПСКА ПЕРСПЕКТИВА\nЗдружение...
#
#                                                  doc
# 0  <doc id="macocu.mk.4" title="GG.MK - е-спорт &...
# 1  <doc id="macocu.mk.5" title="КВИР СКВЕР Скопје...
# 2  <doc id="macocu.mk.25" title="IN2 - ПOЧЕTHA CT...
# 3  <doc id="macocu.mk.35" title="Либерално демокр...
# 4  <doc id="macocu.mk.37" title="Иницијатива за Е...

# %%
df_long_texts.describe(include="all")
# Out:
#        domain             url  \
# count   10000           10000
# unique   1000           10000
# top     gg.mk  https://gg.mk/
# freq       10               1
#
#                                                      text  \
# count                                               10000
# unique                                              10000
# top     Тоа е тоа, екипа. Претпоследната епизода ја на...
# freq                                                    1
#
#                                                       doc
# count                                               10000
# unique                                              10000
# top     <doc id="macocu.mk.4" title="GG.MK - е-спорт &...
# freq                                                    1

# %%
df_long_texts.domain.value_counts()
# Out:
# gg.mk                         10
# respublica.edu.mk             10
# vinodonia.mk                  10
# dekra.mk                      10
# investinpelagoniaregion.mk    10
#                               ..
# zenica.mk                     10
# tesoridimare.mk               10
# grafopres.mk                  10
# insumak.mk                    10
# sud.mk                        10
# Name: domain, Length: 1000, dtype: int64

# %%
# Add information on length
df_long_texts["length"] = df_long_texts["text"].str.split().str.len()

df_long_texts.head()
# Out:
#    domain                 url  \
# 0   gg.mk      https://gg.mk/
# 1   qs.mk  https://www.qs.mk/
# 2  in2.mk      http://in2.mk/
# 3  ldp.mk     https://ldp.mk/
# 4  iep.mk     https://iep.mk/
#
#                                                 text  \
# 0  Тоа е тоа, екипа. Претпоследната епизода ја на...
# 1  Парадата на гордоста се враќа под слоганот "Во...
# 2  Од крајот на месец Ноември 2009 година, своето...
# 3  Што не прави либрали?\nЕманципација од стравов...
# 4  ИНИЦИЈАТИВА ЗА ЕВРОПСКА ПЕРСПЕКТИВА\nЗдружение...
#
#                                                  doc  length
# 0  <doc id="macocu.mk.4" title="GG.MK - е-спорт &...     864
# 1  <doc id="macocu.mk.5" title="КВИР СКВЕР Скопје...    1054
# 2  <doc id="macocu.mk.25" title="IN2 - ПOЧЕTHA CT...     162
# 3  <doc id="macocu.mk.35" title="Либерално демокр...     343
# 4  <doc id="macocu.mk.37" title="Иницијатива за Е...     182

# %%
df_long_texts["length"].describe()
# Out:
# count    10000.000000
# mean       407.222600
# std        867.246509
# min         76.000000
# 25%        128.000000
# 50%        213.000000
# 75%        408.000000
# max      38281.000000
# Name: length, dtype: float64

# %%
# Save the final sample
df_long_texts.to_csv("MaCoCu-mk-sample.csv", sep="\t")
