# %% [markdown]
# Here, we prepare a sample from MaCoCu-sl, on which we use the genre classifiers. To prepare the sample, we first need to discard all texts with text length smaller than 75 - I created a dictionary of all domains and urls of texts that are long enough. Then I calculated the frequency of the domains. I discarded domains that have less than 10 instances (if I wouldn't, the median would be 6 texts per domain). Then I calculated the median and took random 500 domains above the median and 500 domains below the median.

# %%
import gzip
import wget
import regex as re
import pandas as pd
import numpy as np
import json
import random
from tqdm import tqdm

# %%
# Compile regex for url and domain
url_re = re.compile('url="(.*?)"')
domain_re = re.compile('domain="(.*?)"')

# %% [markdown]
# ## Download and open the XLM file

# %%
# Download the corpus
# Download the file

#Defining the zip file URL
url = "https://www.clarin.si/repository/xmlui/bitstream/handle/11356/1517/MaCoCu-sl.xml.gz"

# Downloading the file by sending the request to the URL
corpus_file = wget.download(url)
print('Downloading Completed')
# Out:
# Downloading Completed

# %%
file = gzip.open('MaCoCu-sl.xml.gz', 'rt', encoding='utf-8')

# %% [markdown]
# ## Create a dataframe with the most frequent domains and a sample of 10 URLs from each domain

# %% [markdown]
# First, get a list of all domains and urls of texts that have are more than 75 words long.

# %%
text_counter = 0

texts = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_length = 0
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
	elif line.startswith("<p"):
		continue
	elif line.startswith("</p"):
		continue
	elif line.startswith("</doc"):
		text_length = len(pure_text.split())
		if text_length > 75:
			current_text = [current_domain, current_url]
			texts.append(current_text)
			text_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		pure_text += line
# Out:
# 151967742it [07:43, 327820.79it/s]

# %%
# Create a dataframe
df = pd.DataFrame({"domain": [x[0] for x in texts], "url": [x[1] for x in texts]})

df.head()
# Out:
#   domain                 url
# 0  e3.si  https://www.e3.si/
# 1  x5.si   http://www.x5.si/
# 2  a1.si  https://www.a1.si/
# 3  op.si  https://www.op.si/
# 4  fd.si      https://fd.si/

# %%
# Sort the df based on the domain
df = df.sort_values("domain")

df.head()
# Out:
#                     domain                                         url
# 337411          007.com.hr      http://www.007.com.hr/bugdetector.html
# 177449        090linije.si          http://www.090linije.si/pogoji.htm
# 501444        090linije.si  http://www.090linije.si/simobil/pogoji.htm
# 550412  090vedezevanje.com     https://090vedezevanje.com/tarot-karte/
# 96050   090vedezevanje.com                 https://090vedezevanje.com/

# %%
df.describe(include="all")
# Out:
#           domain                          url
# count    3787272                      3787272
# unique     49096                      3779253
# top     najdi.si  https://www.rtvslo.si/sport
# freq       41255                            8

# %% [markdown]
# We got 3,779,253 texts in 49,096 domains.

# %%
df.domain.value_counts().to_dict()
# Out:
# {'najdi.si': 41255,
#  'rtvslo.si': 39012,
#  'regionalobala.si': 35803,
#  'primorske.si': 31999,
#  'zurnal24.si': 29880,
#  '1zavse.si': 28335,
#  'sodnapraksa.si': 27388,
#  'slo-tech.com': 26412,
#  'mladina.si': 26191,
#  'uradni-list.si': 25820,
#  'radiostudent.si': 24408,
#  'novice.svet24.si': 20773,
#  'govorise.metropolitan.si': 19664,
#  'dk.um.si': 18882,
#  'radio1.si': 18151,
#  'mojmojster.net': 18087,
#  'dnevnik.si': 18001,
#  'muziker.si': 17008,
#  'tax-fin-lex.si': 16593,
#  'siol.net': 16535,
#  'ringaraja.net': 16507,
#  'monitor.si': 16082,
#  'moj-letak.si': 15774,
#  'mojaobcina.si': 15596,
#  'moja-lekarna.com': 14498,
#  'vsi.si': 14387,
#  'instore.si': 14279,
#  'publishwall.si': 14159,
#  'citymagazine.si': 14128,
#  'sloski.si': 12958,
#  'elektronik.si': 12233,
#  'nogomania.com': 12215,
#  'deloindom.delo.si': 11834,
#  'politikis.si': 11517,
#  'viva.si': 11371,
#  'joker.muzej.si': 11280,
#  'nova24tv.si': 10936,
#  'pesem.si': 10301,
#  'gov.si': 10134,
#  'blog.uporabnastran.si': 9510,
#  'sodisce.si': 9321,
#  'mladipodjetnik.si': 9287,
#  'vestnik.si': 8963,
#  'micna.slovenskenovice.si': 8883,
#  'onaplus.delo.si': 8779,
#  'pisrs.si': 8763,
#  'tenisportal.si': 8522,
#  'celje.info': 8094,
#  'radio.ognjisce.si': 8053,
#  'bambino.si': 7907,
#  'lex-localis.info': 7907,
#  'gzs.si': 7693,
#  'maribor24.si': 7658,
#  'predlagam.vladi.si': 7587,
#  'avtomanija.si': 7556,
#  'old.delo.si': 7444,
#  'alter.si': 7436,
#  'kulinarika.net': 7385,
#  'beta.publishwall.si': 7382,
#  'forum.zevs.si': 7375,
#  'bukla.si': 7337,
#  'mojaleta.si': 7303,
#  'fran.si': 7245,
#  'www2.arnes.si': 7156,
#  'vecer.com': 7151,
#  'paranoid.si': 7133,
#  'vzajemnost.si': 7110,
#  'rokometna-zveza.si': 7050,
#  'slovenska-biografija.si': 6905,
#  'kamra.si': 6883,
#  'racunovodja.com': 6797,
#  'pozitivke.net': 6716,
#  'vsikatalogi.si': 6710,
#  'fashion.si': 6565,
#  'policija.si': 6413,
#  'casnik.si': 6368,
#  'kamnik.si': 6303,
#  'tednik.si': 6299,
#  'morel.si': 6156,
#  'dkom.si': 6155,
#  'avto-fokus.si': 6154,
#  'mm-arhiv.si': 6128,
#  'mobile.si': 6068,
#  'rsg.si': 6007,
#  'pzs.si': 5997,
#  'besedilo.si': 5830,
#  'delo.si': 5824,
#  'mimovrste.com': 5821,
#  'openscience.si': 5779,
#  'dj-slovenija.si': 5725,
#  'ekipa.svet24.si': 5714,
#  'www2.gov.si': 5700,
#  'iusinfo.si': 5691,
#  'domzalec.si': 5551,
#  'edusinfo.si': 5546,
#  'druzina.si': 5508,
#  'intimatemedicine.si': 5444,
#  'zvpl.com': 5405,
#  'jabuk.si': 5351,
#  'izvozniki.finance.si': 5341,
#  'megashop.si': 5329,
#  'pefprints.pef.uni-lj.si': 5323,
#  'findinfo.si': 5219,
#  'strelec.si': 5205,
#  'mtb-forum.si': 5061,
#  'obmorju.si': 4996,
#  'avto-magazin.metropolitan.si': 4995,
#  'regionalgoriska.si': 4973,
#  'velenje.com': 4923,
#  'arhiv.gorenjskiglas.si': 4693,
#  'tocnoto.si': 4632,
#  'insolvinfo.si': 4581,
#  'bos.zrc-sazu.si': 4565,
#  'dolenjskilist.si': 4540,
#  'rastline.com': 4460,
#  'elle.metropolitan.si': 4445,
#  'dobreknjige.si': 4437,
#  'mc-celje.si': 4435,
#  'mojtv.si': 4396,
#  'nas-stik.si': 4385,
#  'dobranovica.si': 4376,
#  'forum.modelarji.com': 4343,
#  'svetloba.si': 4222,
#  'avto.finance.si': 4176,
#  'oblizniprste.si': 4160,
#  'gorenjskiglas.si': 4090,
#  'citylife.si': 4056,
#  'tabla.mtb.si': 4054,
#  'efnet.si': 4036,
#  'oglasi.si': 4008,
#  'stirikolesniki.si': 4002,
#  'us-rs.si': 3999,
#  'rocker.si': 3993,
#  'varcevanje-energije.si': 3971,
#  'avtomobilizem.com': 3947,
#  'lokalec.si': 3926,
#  'notranjskoprimorske.si': 3922,
#  'google.si': 3916,
#  'znanjesveta.com': 3916,
#  'ecommerce.sist.si': 3868,
#  'ljubljana.si': 3855,
#  'zelenaslovenija.si': 3814,
#  'cangura.com': 3784,
#  'ricinus2.mf.uni-lj.si': 3778,
#  'dostop.si': 3712,
#  'renault-klub.si': 3605,
#  'pogledi.delo.si': 3597,
#  'primerjam.si': 3582,
#  'sd-sport.si': 3569,
#  'skupaj.si': 3551,
#  'bralnica.com': 3545,
#  'eucbeniki.sio.si': 3538,
#  's5tech.net': 3510,
#  'pesjanar.si': 3467,
#  'koroski-radio.si': 3465,
#  'student.si': 3432,
#  'posavskiobzornik.si': 3395,
#  'slv.acousticbiotech.com': 3367,
#  'locutio.si': 3349,
#  'times.si': 3347,
#  'repozitorij.uni-lj.si': 3340,
#  'mbreport.si': 3330,
#  'teniska-zveza.si': 3310,
#  'vzmd.si': 3288,
#  'zenskisvet.si': 3280,
#  'portalplus.si': 3274,
#  'drugisvet.com': 3273,
#  'pomagamo-zivalim.si': 3273,
#  'povezujemo.si': 3266,
#  'merkur.si': 3240,
#  'edus.iusinfo.si': 3185,
#  'kamnik.info': 3171,
#  'enarocanje.si': 3167,
#  'blizjiknjigi.si': 3154,
#  'arhiv.kzs.si': 3148,
#  'extremevital.com': 3142,
#  'volan.si': 3125,
#  'sta.si': 3123,
#  'ktv-ormoz.si': 3113,
#  'modna.si': 3113,
#  'podjetnik.si': 3111,
#  'ludliteratura.si': 3107,
#  'gurman.eu': 3103,
#  'skuhaj.si': 3101,
#  'realmadrid.si': 3098,
#  'oblacila.si': 3093,
#  'za-misli.si': 3092,
#  'amzs.si': 3085,
#  'ecco-verde.si': 3066,
#  'zarolaj.si': 3057,
#  'paradaplesa.si': 3055,
#  'mojkraj.info': 3050,
#  'radioprvi.rtvslo.si': 3042,
#  'data.si': 3041,
#  'obramba.com': 3039,
#  'nova-gorica.si': 3034,
#  'sls.si': 2970,
#  'cek.ef.uni-lj.si': 2969,
#  'strankasmc.si': 2964,
#  'revija.ognjisce.si': 2963,
#  'maxximum.si': 2950,
#  'had.si': 2922,
#  'music24.si': 2906,
#  'dobrinasveti.si': 2876,
#  'apod.fmf.uni-lj.si': 2861,
#  'igre123.com': 2844,
#  'primorski.eu': 2808,
#  'domzalske-novice.si': 2806,
#  'sigic.si': 2805,
#  'kozjansko.info': 2801,
#  'ceneje.si': 2801,
#  'zofijini.net': 2798,
#  'robin.si': 2787,
#  'info-slovenija.si': 2771,
#  'poslovni-bazar.si': 2767,
#  'mopedist.si': 2731,
#  'zenska.hudo.com': 2715,
#  'nijz.si': 2715,
#  'telex.si': 2697,
#  'igralec.si': 2693,
#  'val202.rtvslo.si': 2685,
#  'vlaki.info': 2683,
#  'sa-agencija.si': 2676,
#  'ubuntu.si': 2671,
#  'vozimvolvo.si': 2663,
#  'bodieko.si': 2639,
#  'matejzalar.si': 2598,
#  'zares.si': 2580,
#  'zdruzenjeobcin.si': 2580,
#  'tehnozvezdje.si': 2573,
#  'lokalne-ajdovscina.si': 2564,
#  'careerjet.si': 2557,
#  'cosmopolitan.metropolitan.si': 2539,
#  'skofija-sobota.si': 2538,
#  'vsinasveti.si': 2537,
#  'bogastvozdravja.si': 2528,
#  'lekarnar.com': 2522,
#  'obrazislovenskihpokrajin.si': 2474,
#  'europarl.europa.eu': 2470,
#  'vitalabo.si': 2457,
#  'mojedelo.com': 2432,
#  'val-navtika.net': 2423,
#  'enavtika.si': 2411,
#  'arhiv.fokuspokus.si': 2407,
#  'tekaskiforum.net': 2397,
#  'katoliska-cerkev.si': 2379,
#  'financnitrgi.com': 2368,
#  'buca.si': 2361,
#  'preberite.si': 2349,
#  'gremovkino.si': 2340,
#  'konoplja.org': 2328,
#  'narobe.si': 2328,
#  'etno-muzej.si': 2282,
#  'primorskival.si': 2277,
#  'kraji.eu': 2271,
#  'omisli.si': 2268,
#  'podarimo.si': 2265,
#  'podskalco.si': 2259,
#  'grazia.si': 2247,
#  'sveterotike.si': 2244,
#  'snportal.si': 2237,
#  'biblos.si': 2233,
#  'nomago.si': 2221,
#  'forum2.arsktrp.gov.si': 2213,
#  'zoohit.si': 2209,
#  'odbojka.si': 2178,
#  'tvsporedi.si': 2167,
#  'skupnostobcin.si': 2150,
#  'rad-dobrojem.si': 2144,
#  'wwwarhiv.ozs.si': 2130,
#  'energetika-portal.si': 2130,
#  'slovenec.org': 2127,
#  'revis.openscience.si': 2126,
#  'tekac.si': 2126,
#  'vest.si': 2122,
#  'jskd.si': 2110,
#  'bajta.si': 2105,
#  'jw.org': 2104,
#  'forum.hamradio.si': 2094,
#  'slonep.net': 2093,
#  'profanity.si': 2092,
#  'uni-lj.si': 2085,
#  'audio-kontakt.com': 2085,
#  'savus.si': 2084,
#  'srce-me-povezuje.si': 2080,
#  'avtofil.si': 2077,
#  'fdv.uni-lj.si': 2073,
#  'stara.odbojka.si': 2054,
#  'velenje.si': 2048,
#  'zps.si': 2048,
#  'kum24.si': 2047,
#  'malinca.si': 2046,
#  'moski.hudo.com': 2041,
#  'smucisca.net': 2036,
#  'slovenskenovice.si': 2030,
#  'namestitev.si': 2012,
#  'nivaoffroadteam.rafter.si': 2011,
#  'up-rs.si': 2006,
#  'nivaoffroadteam.com': 2001,
#  'etransport.si': 1997,
#  'radiotomi.si': 1991,
#  'bmwblog.si': 1988,
#  'horoskop.si': 1984,
#  'nadlani.si': 1974,
#  'sos112.si': 1967,
#  'emundia.si': 1965,
#  'brezice.si': 1952,
#  'saiorg.si': 1945,
#  'fiat-klub.si': 1929,
#  '24kul.si': 1926,
#  'recepti.najdi.si': 1896,
#  'euromobil.si': 1884,
#  'dodogovor.org': 1884,
#  'cvek123.com': 1880,
#  'davkoplacevalci.com': 1873,
#  'viralko.si': 1859,
#  'forum.ssfs.si': 1857,
#  'viri.cjvt.si': 1847,
#  'topshop.si': 1842,
#  'sistory.si': 1820,
#  'mrpet.si': 1818,
#  'lekarna-soca.si': 1815,
#  'ilovejudo.com': 1807,
#  'bicikel.com': 1800,
#  'otroski.rtvslo.si': 1799,
#  'svetovalnica.zrc-sazu.si': 1799,
#  'altstore.si': 1785,
#  'socialnidemokrati.si': 1785,
#  'svet-el.si': 1785,
#  'casoris.si': 1781,
#  'skuponi.si': 1776,
#  'ung.si': 1762,
#  'mtb.si': 1755,
#  'sensa.metropolitan.si': 1755,
#  'astrologija-regulus.si': 1755,
#  'metinalista.si': 1754,
#  'aktivni.metropolitan.si': 1749,
#  'nkdomzale.si': 1748,
#  'mazda-si.net': 1747,
#  'snezak.si': 1742,
#  'sc-nm.si': 1736,
#  'eposavje.com': 1723,
#  'hokej.si': 1719,
#  'mojvideo.com': 1704,
#  'klubgromka.org': 1701,
#  'izola.si': 1699,
#  'sigledal.org': 1698,
#  'nk-bravo.si': 1698,
#  'klip.si': 1691,
#  'dobrakarma.si': 1686,
#  'kinodvor.org': 1678,
#  'e-fotografija.si': 1671,
#  'kresnik.eu': 1670,
#  'svetbesed.si': 1664,
#  'ajdovscina.si': 1630,
#  'drustvo-para-lj.si': 1628,
#  'gasilci.org': 1612,
#  'rks.si': 1610,
#  'racunalniske-novice.com': 1609,
#  'ekosola.uki.si': 1600,
#  '1nadan.si': 1595,
#  'katalogi.ceneje.si': 1578,
#  'primorskestene.com': 1570,
#  'glasdezele.si': 1567,
#  'ach-volley.si': 1565,
#  'slovreme.net': 1562,
#  'usersite.datalab.eu': 1561,
#  'mladinska-knjiga.si': 1559,
#  'arhiv.rlv.si': 1558,
#  'moc.celje.si': 1555,
#  'gore-ljudje.si': 1551,
#  'jesenice.si': 1539,
#  'mojprihranek.si': 1539,
#  'cudovita.si': 1535,
#  'test.times.si': 1531,
#  'slovenska-atletika.si': 1527,
#  'pardon.si': 1521,
#  'meganakupek.si': 1521,
#  'radiomars.si': 1517,
#  'zvvs.si': 1516,
#  'mojpogled.com': 1514,
#  'traktor.mojforum.si': 1509,
#  'bolha.com': 1508,
#  'zdis.si': 1498,
#  'njena.svet24.si': 1492,
#  'bokal-sport.si': 1491,
#  'glitter.si': 1484,
#  'ars.rtvslo.si': 1480,
#  'salonpohistva.si': 1476,
#  'sb.nuk.uni-lj.si': 1476,
#  'wiki.fkkt.uni-lj.si': 1474,
#  'ivancna-gorica.si': 1465,
#  'murska-sobota.si': 1446,
#  'nekdanji-pv.gov.si': 1433,
#  'razvoj.si': 1429,
#  'mestnik.si': 1424,
#  'yoys.si': 1424,
#  'pespoti.si': 1415,
#  'elektron.si': 1412,
#  'forum-lov.org': 1412,
#  'nepremicnine.net': 1411,
#  'sloveniaholidays.com': 1406,
#  'vrhnika.si': 1390,
#  'revije.ff.uni-lj.si': 1385,
#  'oe.finance.si': 1384,
#  'epsihologija.si': 1383,
#  'sl.wikiversity.org': 1377,
#  'nlb.si': 1377,
#  'mladi-sentjur.si': 1377,
#  'gartlc.mojforum.si': 1374,
#  'prvalekarna.com': 1370,
#  'geocacher.si': 1368,
#  'kitarist.si': 1356,
#  'sl.evidentista.org': 1351,
#  'arrs.si': 1347,
#  'telstar.si': 1347,
#  'planinsko-drustvo-ng.si': 1346,
#  'franciskani.si': 1340,
#  'zastarse.si': 1331,
#  'arhiv.mirenski-grad.si': 1322,
#  'klepetobkavi.si': 1320,
#  '1001ideja.si': 1318,
#  'eur-lex.europa.eu': 1311,
#  'enaa.com': 1308,
#  'hyde-park.si': 1307,
#  'solaokusov.si': 1304,
#  'tvsrk-11.si': 1302,
#  'prostovoljstvo.org': 1302,
#  'reporter.si': 1299,
#  'trofeja.si': 1290,
#  'e-apoteka.si': 1286,
#  'tipk.si': 1283,
#  'friko.si': 1282,
#  'srcnotrbovlje.si': 1278,
#  'saop.si': 1276,
#  'peticija.online': 1274,
#  'safe.si': 1273,
#  'e-utrip.si': 1269,
#  'prlekija-on.net': 1264,
#  'cinemania-group.si': 1264,
#  'agromet.mkgp.gov.si': 1253,
#  'punkufer.si': 1250,
#  'dominstil.si': 1248,
#  'e-kurs.si': 1244,
#  'fm-kp.si': 1236,
#  'ooz-ravne.si': 1233,
#  'zsport-jesenice.si': 1232,
#  'gnes.si': 1227,
#  'pef.uni-lj.si': 1225,
#  'mds-drustvo.si': 1222,
#  'shopbuilder.si': 1222,
#  'old.nuk.uni-lj.si': 1221,
#  'sanje.si': 1211,
#  'marmelina.si': 1206,
#  'buildingbody.si': 1206,
#  'ujusansa.si': 1205,
#  'ric-nm.si': 1202,
#  'gfml.si': 1201,
#  'dragocena.si': 1198,
#  'bead.si': 1194,
#  'drogart.org': 1188,
#  'oddaje.ognjisce.si': 1184,
#  'skoberne.si': 1184,
#  'podsvojostreho.net': 1183,
#  'studiofaca.com': 1182,
#  'bigbang.si': 1180,
#  'sony.si': 1179,
#  'forum.finance.si': 1178,
#  'mma.si': 1177,
#  'automobil.si': 1170,
#  'sobotainfo.com': 1165,
#  'gradbenistvo.finance.si': 1164,
#  'startup.si': 1159,
#  'pugi.si': 1156,
#  'planetaudio.si': 1155,
#  'mojpes.net': 1147,
#  'eu2008.si': 1147,
#  'film-center.si': 1142,
#  'cosmeterie.si': 1139,
#  'imedi.si': 1138,
#  'kibla.org': 1135,
#  'cobiss.si': 1135,
#  'sanolabor.si': 1134,
#  'primus.si': 1133,
#  'medikus.hr': 1132,
#  'eetaq.si': 1125,
#  'intersport.si': 1123,
#  'lekarnanaklik.si': 1123,
#  'radeski-utrip.si': 1121,
#  'vandraj.si': 1120,
#  'pd-ljmatica.si': 1119,
#  'btps.si': 1117,
#  'gzdbk.si': 1110,
#  'tehnokrat.si': 1109,
#  'adp.fdv.uni-lj.si': 1109,
#  'tomazflegar.si': 1109,
#  'marcopolo.si': 1109,
#  'rastline.mojforum.si': 1107,
#  'vemkajjem.si': 1106,
#  'videolectures.net': 1105,
#  'arhiv.ds-rs.si': 1104,
#  'forum.alfa-klub.com': 1104,
#  'krtina.com': 1103,
#  'slovenia.info': 1103,
#  'radio-ptuj.si': 1101,
#  'svetevrope.si': 1100,
#  'vitafit.si': 1100,
#  'ljubljanskigrad.si': 1095,
#  'amnesty.si': 1093,
#  'www2.fu.uni-lj.si': 1091,
#  'arhiv.mlad.si': 1090,
#  'evsvet.eu': 1088,
#  'forum.kvarkadabra.net': 1085,
#  'gcc.si': 1083,
#  'pro.finance.si': 1081,
#  'metropolitan.si': 1080,
#  'mucek.si': 1078,
#  'varuh-rs.si': 1077,
#  'harveynorman.si': 1077,
#  'minutka.si': 1077,
#  'spomincica.si': 1074,
#  'delphi.si': 1072,
#  'pozareport.si': 1071,
#  'interismo.si': 1070,
#  'svet-me.si': 1068,
#  'ff.uni-lj.si': 1061,
#  'piccantino.si': 1056,
#  'tosamashop.si': 1055,
#  'smar-team-org.si': 1052,
#  'talentiran.si': 1051,
#  'ess.gov.si': 1049,
#  'agencija-oskar.si': 1043,
#  'nsi.si': 1043,
#  'educa.fmf.uni-lj.si': 1043,
#  'hktriglav.si': 1042,
#  'lunin.net': 1036,
#  'mini-teater.si': 1035,
#  'airbeletrina.si': 1029,
#  'kalcek.si': 1028,
#  'scca-ljubljana.si': 1027,
#  'lokalno.si': 1022,
#  'posrcumlad.si': 1020,
#  'turizem-sevnica.si': 1016,
#  'exodus.si': 1015,
#  'babycenter.si': 1013,
#  'sportnodrustvo-sencur.si': 1006,
#  'ssgt.si': 1003,
#  'vsikuponi.si': 1002,
#  'pravniki.info': 995,
#  'booking.com': 995,
#  'fclitija.si': 995,
#  'kzs.si': 993,
#  'sentjur.net': 991,
#  'gorickilist.si': 989,
#  'pf.uni-lj.si': 984,
#  'mariborinfo.com': 981,
#  'gobe.si': 979,
#  'doria.si': 976,
#  'oglasnik-plus.si': 975,
#  'avdio.ognjisce.si': 975,
#  'ezdravje.com': 975,
#  'med.over.net': 972,
#  'mg-lj.si': 970,
#  'ljudmila.org': 969,
#  'studio12.si': 969,
#  'bsi.si': 969,
#  'duj.si': 967,
#  'canon.si': 965,
#  'operi-avto.si': 962,
#  'prilevcku.si': 959,
#  'svetkapitala.delo.si': 957,
#  'luka-kp.si': 954,
#  'globetrotter.si': 952,
#  'nasvetizavas.si': 951,
#  'koridor-ku.si': 948,
#  'sketa.si': 946,
#  'seonet.ljse.si': 946,
#  'megasvet.si': 945,
#  'odprtakuhinja.delo.si': 944,
#  'consulta.si': 942,
#  'pil.si': 937,
#  'koroskenovice.si': 937,
#  'avtoblog.com': 935,
#  'ijs.si': 933,
#  'os-naklo.si': 933,
#  'arhiv.e-obcina.si': 933,
#  'unicef.si': 929,
#  'zivalskenovice.si': 928,
#  'akravne.si': 926,
#  'polleosport.si': 926,
#  'ciklon.si': 926,
#  'kulturnidom-ng.si': 925,
#  'trgovinayorki.si': 921,
#  'equusvitalis.si': 921,
#  'avogel.si': 919,
#  'forum.sota.si': 916,
#  'literarni-val.slovenianforum.com': 914,
#  'maribor.si': 914,
#  'mohorjeva.org': 913,
#  'stareslike.cerknica.org': 912,
#  'paragliding-slovenia.si': 912,
#  'zvkds.si': 911,
#  'pokukaj.si': 911,
#  'radioekspres.si': 909,
#  'uil-sipo.si': 909,
#  'lek.si': 907,
#  'kataloska-prodaja.si': 907,
#  'alaja.si': 907,
#  'zal.sik.si': 905,
#  'gigafida.net': 904,
#  'vrabecanarhist.eu': 899,
#  'bfcshop.si': 899,
#  'mirovni-institut.si': 897,
#  'zazivali.si': 896,
#  'netokracija.si': 895,
#  'pikapolonica.si': 895,
#  'strankalms.si': 894,
#  'silux.si': 892,
#  'tojeto.info': 891,
#  'natura2000.si': 890,
#  'nrpslo.org': 890,
#  'noviglas.eu': 889,
#  'ten-net.si': 889,
#  'mojmalcek.si': 888,
#  'harb.si': 887,
#  'medrazgl.si': 886,
#  'nazraku.si': 884,
#  'antene-zupancic.si': 884,
#  'tanja-fajon.si': 883,
#  'kosarka.si': 883,
#  'fe.uni-lj.si': 883,
#  'majer.si': 881,
#  'mikec.si': 879,
#  'kgzs.si': 876,
#  'mojefinance.finance.si': 872,
#  'kud.si': 870,
#  'os-bozidarjajakca.si': 869,
#  'sng-mb.si': 868,
#  'revija-tranzit.si': 866,
#  'spanskiborci.si': 860,
#  'hozana.si': 860,
#  'najlepsi-par.si': 859,
#  'gta-neptun.si': 858,
#  'webshop.schachermayer.com': 858,
#  'emajstor.hr': 856,
#  'cityofwomen.org': 856,
#  'slikarski-material.si': 855,
#  'izvoznookno.si': 855,
#  'outlaws.mojforum.si': 854,
#  'osartice.si': 854,
#  'e-kino.si': 853,
#  'zgodovina.si': 849,
#  'spins.si': 848,
#  'informacija.net': 848,
#  'croatia.hr': 847,
#  'nalepse.si': 847,
#  'lekarnaljubljana.si': 847,
#  'moja-dejavnost.si': 846,
#  'norma.si': 846,
#  'ef.uni-lj.si': 844,
#  'proviprlek.si': 843,
#  'cipra.org': 843,
#  'marketingmagazin.si': 842,
#  'kajkupiti.si': 841,
#  'prc.si': 840,
#  'zaps.si': 839,
#  'drustvo-mds.si': 836,
#  'pesmojprijatelj.si': 833,
#  'hbogo.si': 833,
#  'notino.si': 831,
#  'blog69.si': 829,
#  'britev.si': 828,
#  'arhiv.park-goricko.info': 828,
#  'stat.si': 827,
#  'skandal24.si': 826,
#  'm.planet-lepote.com': 822,
#  'eportal.mss.edus.si': 820,
#  'kuzek.si': 820,
#  'instalater.si': 819,
#  'ipop.si': 819,
#  'zemljevid.najdi.si': 817,
#  'zrc-sazu.si': 816,
#  'stajerskival.si': 814,
#  'caranduser.com': 811,
#  'noviceznotranjske.net': 810,
#  'bsf.si': 806,
#  'inst-antonatrstenjaka.si': 806,
#  'ec.europa.eu': 805,
#  'freeapproved.com': 804,
#  'philips.si': 804,
#  'aokranj.com': 802,
#  'avto.info': 797,
#  'podcrto.si': 797,
#  'potnik.si': 797,
#  'kompas.si': 796,
#  'g-sport.si': 795,
#  'trajekt.org': 794,
#  '4d.rtvslo.si': 792,
#  'karizmasport.si': 792,
#  'vsu.ung.si': 789,
#  'mevki55.mojforum.si': 788,
#  'redoljub.si': 787,
#  'um.si': 787,
#  'nib.si': 786,
#  'najnakupi.si': 785,
#  'wiki.potnik.si': 782,
#  'dk.mors.si': 781,
#  'skuterist.mojforum.si': 781,
#  'zdravstveniportal.si': 780,
#  'vesolje.net': 779,
#  'midvakuhava.si': 779,
#  'nkmura.si': 779,
#  'sviz.si': 777,
#  'mojacokolada.si': 775,
#  'lisac.si': 773,
#  'hervardi.com': 771,
#  'nasasuperhrana.si': 769,
#  'gonilniki.si': 768,
#  'sportold.amzs.si': 762,
#  'blog.ognjisce.si': 761,
#  'labelhair.si': 761,
#  'c21.si': 760,
#  'poslovno-mesto.si': 758,
#  'gor-radgona.si': 758,
#  'forum.svet-el.si': 758,
#  'agrooglasi.si': 756,
#  'strojnistvo.com': 756,
#  'agrobiznis.finance.si': 753,
#  'sam.si': 751,
#  'old.radiostudent.si': 750,
#  'ribiskekarte.si': 750,
#  'potovanja.nomago.si': 749,
#  'bimbo.si': 748,
#  'nl.ijs.si': 748,
#  'mizarstvo.si': 747,
#  'sloexport.si': 746,
#  'mgml.si': 744,
#  'szsce.si': 742,
#  'aninakuhinja.si': 741,
#  '3ksport.si': 741,
#  'bmwslo.com': 741,
#  'portal.mss.edus.si': 740,
#  'pobarvanka.gifmania.si': 738,
#  'portalvvesolje.si': 737,
#  'vrtec.os-mostnasoci.si': 736,
#  'avtoforum.net': 735,
#  'ced-slovenia.eu': 732,
#  'czk.si': 732,
#  'skrivnosti.com': 731,
#  'o-ledina.si': 731,
#  'si.openprof.com': 729,
#  'klubrg-narodnidom.si': 728,
#  'symphony.si': 727,
#  'ona-on.com': 727,
#  'kuponko.si': 724,
#  'si.rbth.com': 721,
#  'arhiv.lrf-pomurje.si': 720,
#  'potepuh.si': 719,
#  'onko-i.si': 719,
#  'uo.mojforum.si': 718,
#  'kinoteka.si': 718,
#  'kibuba.com': 717,
#  'ebm.si': 716,
#  'kpss.si': 715,
#  'a1.si': 713,
#  'maltezan.mojforum.si': 713,
#  'makspro.si': 712,
#  'emka.si': 712,
#  'poroka-bo.si': 712,
#  'posel2030.finance.si': 711,
#  'optius.com': 710,
#  'nzs.si': 710,
#  'diamond-realestate.hr': 710,
#  'isjfr.zrc-sazu.si': 710,
#  'starastran.aozeleznicar.org': 706,
#  '3djake.si': 706,
#  'varensvet.si': 704,
#  'outsider.si': 702,
#  'grasca.si': 702,
#  'factorystore.si': 700,
#  'forum.over.net': 696,
#  'matejspehar.si': 696,
#  'pocitnice.si': 695,
#  'kk-hidria.si': 695,
#  'youth-hostel.si': 694,
#  'institutfrance.si': 693,
#  'slo-fishing.si': 693,
#  'skavt.net': 691,
#  'diabetes.si': 690,
#  'kam.si': 688,
#  'helios-suns.si': 687,
#  'pdtolmin.si': 687,
#  'rockonnet.com': 685,
#  'babybook.si': 684,
#  'dmslo.si': 684,
#  'vwcampers.si': 683,
#  'goodlifestyle.si': 681,
#  'molek.si': 679,
#  'mozaik.si': 678,
#  'infomosa.si': 677,
#  'e30.si': 677,
#  'star.www.upr.si': 677,
#  'arhiv.akos-rs.si': 676,
#  'nationalgeographic.si': 676,
#  't-2.rula.net': 676,
#  'ustvarjalneroke.si': 675,
#  'wellnetica.si': 675,
#  'afibel.si': 675,
#  'mojmalipravnik.net': 674,
#  'kclj.si': 674,
#  'vegan.si': 674,
#  'mislec.net': 671,
#  'zdruzenje-sim.si': 669,
#  'mkc.si': 667,
#  'sl.ncmhcso.org': 666,
#  'nikon.si': 666,
#  'nosecka.net': 664,
#  'cd-cc.si': 663,
#  'kamzmulcem.si': 663,
#  'sportnaoprema.si': 662,
#  'sk-pomurje.si': 661,
#  'necenzurirano.si': 656,
#  'iprom.si': 655,
#  'avtofotomarket.si': 652,
#  'lahkihnog-naokrog.si': 651,
#  'loparji.si': 650,
#  'samozapunce.mojforum.si': 650,
#  'zdravniski-nasveti.net': 649,
#  'skofija-novomesto.si': 648,
#  'saleskibiografskileksikon.si': 647,
#  'v8clubforum.mojforum.si': 647,
#  'kroncek.mojforum.si': 646,
#  'cveka.com': 646,
#  'zsc.si': 646,
#  'metuljcica.mojforum.si': 645,
#  'judoklub-duplek.si': 644,
#  'volleyball.si': 643,
#  'vidaxl.si': 642,
#  'nakupek.si': 642,
#  'hrtjisvet.mojforum.si': 640,
#  'rktrimotrebnje.si': 639,
#  'arhiv.izs.si': 637,
#  'posvetu.si': 635,
#  'deloglasnik.si': 634,
#  'pgd-loka.si': 633,
#  'doktor24.si': 629,
#  'rivacic.blogspot.com': 629,
#  'mczos.si': 626,
#  'e-arhiv.org': 625,
#  'piratskastranka.si': 625,
#  'vfokusu.com': 624,
#  'zdravstvena.info': 623,
#  'ntf.uni-lj.si': 623,
#  'eracunovodstvo.org': 623,
#  'mediawatch.mirovni-institut.si': 622,
#  'nina-potuje.com': 620,
#  'biro.si': 620,
#  'o-sta.si': 619,
#  'dulitija.si': 619,
#  'zfm.si': 619,
#  'mixi-caravaning.si': 619,
#  'sodobnost.com': 617,
#  'podblegaske-novice.si': 616,
#  'rk-gorenje.com': 616,
#  'insportline.si': 615,
#  'cdk.si': 613,
#  'varuska-ziva.si': 613,
#  'mundo.si': 611,
#  'maxximum-portal.com': 610,
#  'kr.trma.si': 610,
#  'mojaizbira.si': 610,
#  'cincile.mojforum.si': 609,
#  'razstava.fa.uni-lj.si': 609,
#  'skoda-team.com': 609,
#  'novitednik.si': 609,
#  'sl.toolbox-site.com': 608,
#  'hummel.si': 607,
#  'slo-android.si': 605,
#  'forum.striparna.com': 605,
#  'os-sticna.si': 605,
#  'kakadu.si': 604,
#  'eu-skladi.si': 603,
#  'mojalbum.com': 603,
#  'aips.um.si': 602,
#  'penzionist.info': 601,
#  'nasa-lekarna.si': 601,
#  'lukvel.si': 601,
#  'evo-magazin.si': 600,
#  'telekom.si': 599,
#  'abcnovice.si': 599,
#  'click2chic.si': 598,
#  'tvambienti.si': 598,
#  'epeka.si': 598,
#  'sng-ng.si': 597,
#  'nivea.si': 596,
#  'ims-trgovina.si': 595,
#  'hisavrt.si': 594,
#  'pd-iskra-lj.com': 593,
#  'tomassport2.si': 593,
#  'sl.google-info.org': 592,
#  'zkdl.si': 592,
#  'km-z.si': 591,
#  'torekobpetih.si': 591,
#  'mojezdravje.net': 590,
#  'vezal.si': 589,
#  'zsss.si': 585,
#  'dn.mojforum.si': 585,
#  'marika.mojforum.si': 584,
#  'lovrencan.si': 584,
#  'ro.si': 583,
#  'milnica.si': 582,
#  'mc-jesenice.si': 581,
#  'repozitorij.ung.si': 580,
#  'soup.si': 580,
#  'forum.fiat-klub.si': 578,
#  'nepremagljiva.si': 577,
#  'mesarska.mojforum.si': 577,
#  'emorje.com': 575,
#  'duhovnost.si': 574,
#  'jaz-in-ti.si': 574,
#  'svobodnabeseda.si': 574,
#  'mercator.si': 573,
#  'pef.upr.si': 573,
#  'www2.amzs.si': 572,
#  'pepermint.si': 571,
#  'slovoni.blogspot.com': 571,
#  'cvilimozek.si': 569,
#  'sah-branikmb.si': 569,
#  'printink.si': 568,
#  'forum-tezave-pomagajmosi.mojforum.si': 568,
#  'aao.si': 567,
#  'fmf.uni-lj.si': 566,
#  'tovarnazdravehrane.si': 566,
#  'drustvo-sever-severnaprimorska.si': 566,
#  'crnomelj.si': 565,
#  'milenijski-cilji.si': 565,
#  'yogi.si': 564,
#  'drustvo-sovica.si': 563,
#  'zupnija-lj-zadobrova.rkc.si': 563,
#  'selectbox.si': 561,
#  'zaobljuba.si': 561,
#  'knjiznica-celje.si': 560,
#  'kolesarska-zveza.si': 560,
#  'novice.kulturnik.si': 560,
#  'preprostost.si': 560,
#  'mojbutik.si': 559,
#  'obcina-brda.si': 559,
#  'movit.si': 559,
#  'marianum.si': 556,
#  'pdrustvo-nazarje.si': 556,
#  'pag.si': 554,
#  'sezana.si': 553,
#  'esvet.com': 552,
#  'zdravo.si': 552,
#  'gimnazija-skofjaloka.si': 552,
#  'vezjak.com': 550,
#  'ffa.uni-lj.si': 549,
#  'tehnoplus.si': 549,
#  'frko.si': 548,
#  'arsq.gov.si': 548,
#  'tusdrogerija.si': 547,
#  'slavko.mojforum.si': 546,
#  'avtokampi.si': 546,
#  'barjans.si': 545,
#  'razvezanijezik.org': 544,
#  'odprtehiseslovenije.org': 543,
#  'zupnija-mb-magdalena.rkc.si': 543,
#  'mb-lekarne.si': 542,
#  'aler.si': 542,
#  'izboljsajmo.maribor.si': 541,
#  'mcp.si': 541,
#  'odkrito.svet24.si': 541,
#  'actionmama.com': 539,
#  'mjslocom.mojforum.si': 539,
#  'doggedog.mojforum.si': 538,
#  'novomesto.si': 538,
#  'ds-rs.si': 537,
#  'slo-link.si': 536,
#  'zazdravje.net': 535,
#  'storitev.com': 535,
#  'culinaryjourneybyme.com': 535,
#  'dirros.openscience.si': 535,
#  'montignac.mojforum.si': 535,
#  'rockline.si': 533,
#  'focus.si': 533,
#  'startupmaribor.si': 533,
#  'lukazoja.si': 533,
#  'stripi.si': 531,
#  'sex2.si': 531,
#  'logatec.si': 530,
#  'sportnazvezavelenje.si': 529,
#  'forum.racunovodja.com': 528,
#  'privoscite.si': 528,
#  'tisina.si': 527,
#  'zvezarfr.si': 525,
#  'ndsnumizmatika.mojforum.si': 525,
#  'levica.si': 524,
#  'slovenjgradec.si': 523,
#  'slomedia.si': 522,
#  'inovelmedia.si': 521,
#  ...}

# %%
# Calculate domain distribution
domain_distribution = pd.DataFrame({"domain": list(df.domain.value_counts().to_dict().keys()), "frequency":list(df.domain.value_counts().to_dict().values())})
domain_distribution
# Out:
#                       domain  frequency
# 0                   najdi.si      41255
# 1                  rtvslo.si      39012
# 2           regionalobala.si      35803
# 3               primorske.si      31999
# 4                zurnal24.si      29880
# ...                      ...        ...
# 49091  tapetnistvo-damjan.si          1
# 49092            eurograf.si          1
# 49093   tapetnistvo-kolar.si          1
# 49094   tapetnistvo-kopac.si          1
# 49095             007.com.hr          1
#
# [49096 rows x 2 columns]

# %%
# Discard instances with frequency less than 10
domain_distribution = domain_distribution[domain_distribution["frequency"] > 9]

domain_distribution.shape
# Out:
# (20400, 2)

# %% [markdown]
# If we don't discard domains with less than 10 texts, the median is 6 texts which is not enough. So, I first discarded domains with less than 10 texts, then calculated the median. The remaining number of domains was 20,400.

# %%
# Find the median
domain_distribution.frequency.describe()
# Out:
# count    20400.000000
# mean       181.051225
# std       1044.961694
# min         10.000000
# 25%         16.000000
# 50%         32.000000
# 75%         84.000000
# max      41255.000000
# Name: frequency, dtype: float64

# %% [markdown]
# The median number of texts per domain is 32. Now, I'll take 500 domains with frequency below this number and 500 domains with frequency above this number. I'll split the dataset into two based on the median.

# %%
domain_distribution.head()
# Out:
#              domain  frequency
# 0          najdi.si      41255
# 1         rtvslo.si      39012
# 2  regionalobala.si      35803
# 3      primorske.si      31999
# 4       zurnal24.si      29880

# %%
top_domain_distribution = domain_distribution[domain_distribution["frequency"] > 32]
top_domain_distribution.shape
# Out:
# (9983, 2)

# %%
bottom_domain_distribution = domain_distribution[domain_distribution["frequency"] < 32]
bottom_domain_distribution.shape
# Out:
# (10198, 2)

# %%
# Take a random sample from top and random sample from bottom
top_domain_distribution = top_domain_distribution.sample(n=500)
top_domain_distribution.shape
# Out:
# (500, 2)

# %%
top_domain_distribution["frequency"].describe()
# Out:
# count     500.00000
# mean      262.04000
# std       601.91954
# min        33.00000
# 25%        51.75000
# 50%        85.00000
# 75%       217.00000
# max      5444.00000
# Name: frequency, dtype: float64

# %%
bottom_domain_distribution = bottom_domain_distribution.sample(n=500)
bottom_domain_distribution.head()
# Out:
#                    domain  frequency
# 15516  obcina-krizevci.si         16
# 11700    cotondetulear.si         25
# 16633     modulninja.shop         14
# 12423       migajznami.si         23
# 12247    mladi-gasilec.si         24

# %%
# Join the dataframes
domain_sample = pd.concat([top_domain_distribution, bottom_domain_distribution])
domain_sample.describe(include="all")
# Out:
#                   domain    frequency
# count               1000  1000.000000
# unique              1000          NaN
# top     nepremagljiva.si          NaN
# freq                   1          NaN
# mean                 NaN   139.932000
# std                  NaN   442.624319
# min                  NaN    10.000000
# 25%                  NaN    16.000000
# 50%                  NaN    32.000000
# 75%                  NaN    85.000000
# max                  NaN  5444.000000

# %%
# Create a list of domains
domain_sample_list = domain_sample.domain.to_list()
domain_sample_list[:10]
# Out:
# ['nepremagljiva.si',
#  'althea.si',
#  'odvetnik-kutnjak.si',
#  'kshuje.si',
#  'kmetija.mojforum.si',
#  'slaj-anic.si',
#  'agrarne.si',
#  'yogalishesana.com',
#  'jeziki-stejejo.si',
#  'donaulab.si']

# %%
# For each domain, sample out 10 texts from the initial dataframe

# First create the initial df to which all others in the loop will be added
final_sample = df[df["domain"] == domain_sample_list[0]].sample(n=10)

final_sample
# Out:
#                    domain                                                url
# 375762   nepremagljiva.si               https://nepremagljiva.si/tag/dopust/
# 1682289  nepremagljiva.si  https://nepremagljiva.si/tri-noro-dobre-sladic...
# 1661643  nepremagljiva.si  https://nepremagljiva.si/vse-o-moji-vecni-bitk...
# 2234934  nepremagljiva.si  https://nepremagljiva.si/spoznajte-terapijo-ki...
# 677331   nepremagljiva.si         https://nepremagljiva.si/category/zdravje/
# 2536790  nepremagljiva.si  https://nepremagljiva.si/fredagsmys-prezivljaj...
# 429620   nepremagljiva.si              https://nepremagljiva.si/tag/uporaba/
# 1243342  nepremagljiva.si  https://nepremagljiva.si/slastni-cokoladni-rec...
# 2411809  nepremagljiva.si  https://nepremagljiva.si/oktobrski-astroloski-...
# 2496389  nepremagljiva.si  https://nepremagljiva.si/iz-vsake-krizne-situa...

# %%
# Add all other domains
remaining_list = domain_sample_list[1:]

for i in remaining_list:
	added_instances = df[df["domain"] == i].sample(n=10)
	final_sample = pd.concat([final_sample, added_instances])

final_sample.shape
# Out:
# (10000, 2)

# %%
final_sample.describe()
# Out:
#                   domain                               url
# count              10000                             10000
# unique              1000                              9996
# top     nepremagljiva.si  https://www.izobrazevanjarfr.si/
# freq                  10                                 2

# %% [markdown]
# The final sample has 10.000 instances from 1000 domains.

# %%
# Save the df
final_sample.to_csv("MaCoCu-sample-domains-and-urls-sample2.csv", sep="\t")

# %% [markdown]
# ## Extract the text from the TMX based on the URL list

# %%
# Open the df with domains and urls for the sample
final_sample = pd.read_csv("MaCoCu-sample-domains-and-urls-sample2.csv", sep="\t", index_col = 0)

final_sample.head(2)
# Out:
#                      domain                                                url
# 1461252  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/seminar/in...
# 2129748  lkrv.fri.uni-lj.si  http://lkrv.fri.uni-lj.si/~ajurisic/tec_ac/np_...

# %%
final_sample.shape
# Out:
# (10000, 2)

# %%
# Create a list of urls in the sample
url_list = list(final_sample["url"].unique())
url_list[:10]
# Out:
# ['https://nepremagljiva.si/tag/dopust/',
#  'https://nepremagljiva.si/tri-noro-dobre-sladice-v-kozarcu/',
#  'https://nepremagljiva.si/vse-o-moji-vecni-bitki-s-hormoni/',
#  'https://nepremagljiva.si/spoznajte-terapijo-ki-odklene-vas-potencial/',
#  'https://nepremagljiva.si/category/zdravje/',
#  'https://nepremagljiva.si/fredagsmys-prezivljajte-petke-kot-to-pocnejo-svedi/',
#  'https://nepremagljiva.si/tag/uporaba/',
#  'https://nepremagljiva.si/slastni-cokoladni-recepti/',
#  'https://nepremagljiva.si/oktobrski-astroloski-koledar-pripnite-si-pasove/',
#  'https://nepremagljiva.si/iz-vsake-krizne-situacije-izstopim-kot-zmagovalka/']

# %%
len(url_list)
# Out:
# 9996

# %%
# Now that I have the URL list, I will extract texts from the MaCoCu-sl.xml.gz for the sample based on the URL list.

text_all_counter = 0

texts_all = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_string = ""
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
		text_string += line
	elif line.startswith("<p"):
		text_string += line
	elif line.startswith("</p"):
		text_string += line
	elif line.startswith("</doc"):
		text_string += line
		if current_url in url_list:
			current_text = [current_domain, current_url, pure_text, text_string]
			texts_all.append(current_text)
			text_all_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		text_string += line
		pure_text += line
# Out:
# 151967742it [46:34, 54375.89it/s]

# %%
text_all_counter
# Out:
# 10043

# %%
# Create a dataframe out of the text file

df_long_texts = pd.DataFrame({"domain": [x[0] for x in texts_all], "url": [x[1] for x in texts_all], "text": [x[2] for x in texts_all],"doc": [x[3] for x in texts_all]})

df_long_texts.head()
# Out:
#    domain                  url  \
# 0  zsc.si   http://www.zsc.si/
# 1  pas.si  https://www.pas.si/
# 2  fsp.si       http://fsp.si/
# 3  gzl.si  https://www.gzl.si/
# 4  zsc.si   http://www.zsc.si/
#
#                                                 text  \
# 0  Nacionalna varnost je preresna stvar, da bi jo...
# 1  Prezračevanje prostorov je nujno zaradi najman...
# 2  Vsaka talna obloga ima svoje značilnosti, zara...
# 3  Gasilska zveza Ljubljana\nJavna gasilska služb...
# 4  Mednarodna organizacija častnikov rezerve (CIO...
#
#                                                  doc
# 0  <doc id="macocu.si.283" title="ZSC - Zveza slo...
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...
# 2  <doc id="macocu.si.446" title="FSP Poslovne No...
# 3  <doc id="macocu.si.783" title="Gasilska zveza ...
# 4  <doc id="macocu.si.869" title="ZSC - Zveza slo...

# %%
df_long_texts.describe(include="all")
# Out:
#         domain                 url  \
# count    10043               10043
# unique    1000                9996
# top     zsc.si  http://www.zsc.si/
# freq        13                   4
#
#                                                      text  \
# count                                               10043
# unique                                              10043
# top     Nacionalna varnost je preresna stvar, da bi jo...
# freq                                                    1
#
#                                                       doc
# count                                               10043
# unique                                              10043
# top     <doc id="macocu.si.283" title="ZSC - Zveza slo...
# freq                                                    1

# %%
df_long_texts.domain.value_counts()
# Out:
# zsc.si                         13
# jvvz.org                       13
# zupnijabarje.si                12
# jeziki-stejejo.si              12
# os-miren.si                    12
#                                ..
# zlati-ghee.si                  10
# izvir-klub.si                  10
# davorin.net                    10
# obala.net                      10
# otroska-kosarkarska-sola.si    10
# Name: domain, Length: 1000, dtype: int64

# %% [markdown]
# Some URLs appear multiple times with different texts, so at the end, our sample consits of 10.043 texts. The problem with this is a) that some domains have more instances than other, and b) that texts under some of the URLs might be shorter than 75 words. That is why we calculated the length of the texts again and discarded those with length less than 75 words. Then we also sampled out the domains with more than 10 texts, so that at the end all domains have 10 instances.

# %%
# Add information on length
df_long_texts["length"] = df_long_texts["text"].str.split().str.len()

df_long_texts.head()
# Out:
#    domain                  url  \
# 0  zsc.si   http://www.zsc.si/
# 1  pas.si  https://www.pas.si/
# 2  fsp.si       http://fsp.si/
# 3  gzl.si  https://www.gzl.si/
# 4  zsc.si   http://www.zsc.si/
#
#                                                 text  \
# 0  Nacionalna varnost je preresna stvar, da bi jo...
# 1  Prezračevanje prostorov je nujno zaradi najman...
# 2  Vsaka talna obloga ima svoje značilnosti, zara...
# 3  Gasilska zveza Ljubljana\nJavna gasilska služb...
# 4  Mednarodna organizacija častnikov rezerve (CIO...
#
#                                                  doc  length
# 0  <doc id="macocu.si.283" title="ZSC - Zveza slo...     200
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124
# 2  <doc id="macocu.si.446" title="FSP Poslovne No...    1951
# 3  <doc id="macocu.si.783" title="Gasilska zveza ...     440
# 4  <doc id="macocu.si.869" title="ZSC - Zveza slo...     112

# %%
df_long_texts["length"].describe()
# Out:
# count    10043.000000
# mean       430.642139
# std       1186.604180
# min          9.000000
# 25%        125.000000
# 50%        220.000000
# 75%        424.000000
# max      56091.000000
# Name: length, dtype: float64

# %%
# Filter out texts, shorter than 75 words
df_long_texts = df_long_texts[df_long_texts["length"] > 75]
df_long_texts.shape
# Out:
# (10026, 5)

# %%
# Save the intermediate dataframe
df_long_texts.to_csv("MaCoCu-sl-sample.csv", sep="\t")

# %%
all_domains_frequency = df_long_texts.domain.value_counts().to_dict()

all_domains_frequency
# Out:
# {'zsc.si': 12,
#  'os-miren.si': 12,
#  'jeziki-stejejo.si': 12,
#  'mipi.si': 12,
#  'zupnijabarje.si': 12,
#  'mzpm-ljubljana.si': 12,
#  'zmos.si': 12,
#  'easistent.com': 12,
#  'ospivka6.splet.arnes.si': 11,
#  '2020.cityofwomen.org': 11,
#  'pohistvo123.si': 11,
#  'dars.si': 11,
#  'izo.sik.si': 11,
#  'karra.si': 11,
#  'jvvz.org': 11,
#  'sportnazvezavelenje.si': 11,
#  'digitalpartner.si': 11,
#  'modulninja.shop': 11,
#  'muzej-ptuj-ormoz.si': 10,
#  'imk.si': 10,
#  'matejgrudnik.si': 10,
#  'netfork-akademija.si': 10,
#  'mojstr.si': 10,
#  'purityherbsslovenija.si': 10,
#  'os-dobravlje.si': 10,
#  'tehnozvezdje.si': 10,
#  'zag.si': 10,
#  'o-md.mb.edus.si': 10,
#  'alteka.si': 10,
#  'hippocampus.si': 10,
#  'kemoplast.si': 10,
#  'lifelong.blogspot.com': 10,
#  'veganskakuharija.blogspot.com': 10,
#  'riedingcompetition.com': 10,
#  'vecna-optimistka.blogspot.com': 10,
#  'mozirskigaj.com': 10,
#  'mikrobiolog.blogspot.com': 10,
#  'maticpise.com': 10,
#  'hr.drazbe123.com': 10,
#  'congress-ambassador.si': 10,
#  'center-iris.si': 10,
#  'pionirski-dom.si': 10,
#  'projekt-gt.si': 10,
#  'kitana.si': 10,
#  'duhovna-univerza.org': 10,
#  'nutris.org': 10,
#  'kmetijskaoprema.si': 10,
#  'store.adrialog.com': 10,
#  'darjin.net': 10,
#  'mali-znanstvenik.si': 10,
#  'dr.ukm.um.si': 10,
#  'zumtobel.com': 10,
#  'blog.ognjisce.si': 10,
#  'oplast-futsal.si': 10,
#  'homopolitikus.si': 10,
#  'orehek-drulovka.si': 10,
#  'revija.ognjisce.si': 10,
#  'm2b.si': 10,
#  'bestskin.si': 10,
#  'simarine-natura.ptice.si': 10,
#  'zkstm.si': 10,
#  'renault.si': 10,
#  'dive-shop.si': 10,
#  'lezdrugimismo.si': 10,
#  'saleskibiografskileksikon.si': 10,
#  'dieta.si': 10,
#  'zelimlje.donbosko.si': 10,
#  'revija-vzgoja.si': 10,
#  'vrtnarstvostanonik.si': 10,
#  'zupnija-gomilsko.rkc.si': 10,
#  'trgovina-frama.si': 10,
#  'orz.si': 10,
#  'letalska-sola.si': 10,
#  'skei.si': 10,
#  'vojaskimuzej.si': 10,
#  'bunker.si': 10,
#  'enotnost.si': 10,
#  'avtohisazalar.si': 10,
#  'os-sturje.si': 10,
#  'lifewolfalps.eu': 10,
#  'znidarsic.net': 10,
#  'illadvised.blogspot.com': 10,
#  'parfemi.eu': 10,
#  'istracamping.com': 10,
#  'malaustvarjalnica.com': 10,
#  'terme-tuhelj.hr': 10,
#  'vzgojiteljica.si': 10,
#  'dezelaznamk.si': 10,
#  'knjiznica-celje.si': 10,
#  'help.minimax.si': 10,
#  'atletski-klub-poljane.si': 10,
#  'outletvozil.si': 10,
#  'arso.si': 10,
#  'torekobpetih.si': 10,
#  'zupnija-velesovo.si': 10,
#  'zoro.si': 10,
#  'popupdom.si': 10,
#  '72ur.si': 10,
#  'vrtec-pivka.splet.arnes.si': 10,
#  'maminamaza.si': 10,
#  'savus.si': 10,
#  'emanat.si': 10,
#  'lgbtfilmfest.si': 10,
#  'rodoslovje.si': 10,
#  'cleansport.si': 10,
#  'lojzlojz.si': 10,
#  'sempatja.si': 10,
#  'qstom.si': 10,
#  'poliestrski-bazeni.si': 10,
#  'mladizmaji.si': 10,
#  'iva.si': 10,
#  'magmaposlovnadarila.si': 10,
#  'fonti.gifmania.si': 10,
#  'poslovni-biro.si': 10,
#  'dom-hrastnik.si': 10,
#  'bamida.si': 10,
#  'boobeefoodee.si': 10,
#  'os-novejarse.si': 10,
#  'drustvo-feniks.si': 10,
#  'intimatemedicine.si': 10,
#  'rdecikrizljubljana.si': 10,
#  'dijaska.org': 10,
#  'sodobnost.com': 10,
#  'koroska2.skavt.net': 10,
#  'yoda4newage.wixsite.com': 10,
#  'mojpes.com': 10,
#  'nesnovnadediscina.si': 10,
#  'rk-slovenjgradec2011.si': 10,
#  'vrtnicekodele.si': 10,
#  'parketarstvo-princ.si': 10,
#  'blog.bambini.si': 10,
#  'g-splosno.si': 10,
#  'szosb.si': 10,
#  'klp.si': 10,
#  'limnos.si': 10,
#  'hlevcek.blogspot.com': 10,
#  'os-zelezniki.si': 10,
#  'rositeh.si': 10,
#  'leksiakov.si': 10,
#  'club.autodoc.si': 10,
#  'dijaskisvet.si': 10,
#  'x-op.eu': 10,
#  'skms.net': 10,
#  'theswingbrats.com': 10,
#  'vet4you.com': 10,
#  'janezplatise.blogspot.com': 10,
#  'malalan.eu': 10,
#  'fimaprevajanje.com': 10,
#  'potepanja.com': 10,
#  'en.adriabager.com': 10,
#  'skandizajn.si': 10,
#  'uglasena-kuhinja.com': 10,
#  'rdecirevirji.si': 10,
#  'geotmin.si': 10,
#  'optikairman.si': 10,
#  'sivkindotik.si': 10,
#  'domtaber.si': 10,
#  'intimna.si': 10,
#  'odvetnik-kutnjak.si': 10,
#  'palpung.si': 10,
#  'jvc.slak.si': 10,
#  'fgg-web.fgg.uni-lj.si': 10,
#  'imode.si': 10,
#  'karitas-nm.si': 10,
#  'pasijon.si': 10,
#  'inovacije.gzs.si': 10,
#  'ka-komunikacije.si': 10,
#  'hisakulture.si': 10,
#  'notranjaoprema.si': 10,
#  'topstrani.si': 10,
#  'korovci.si': 10,
#  'pogledi.delo.si': 10,
#  'davidkadunc.si': 10,
#  'nikolisami.si': 10,
#  'abakos.si': 10,
#  'answers.travian.si': 10,
#  'astratex.si': 10,
#  'davcninasveti.si': 10,
#  'klubkovancev.si': 10,
#  'center-pandora.si': 10,
#  'duhovnost.si': 10,
#  'virtualno.si': 10,
#  'tvu25.acs.si': 10,
#  'jelovica.si': 10,
#  'ekozmeticnisalon.si': 10,
#  'fu.uni-lj.si': 10,
#  'dolejsi.si': 10,
#  'carmina-slovenica.si': 10,
#  'raj.taborniki.si': 10,
#  'tvp.inea.si': 10,
#  'babysits.si': 10,
#  'gdnova.si': 10,
#  'hisadobrot-belekrajine.si': 10,
#  'plesnazvezda.si': 10,
#  'aas.ff.uni-lj.si': 10,
#  'izterjavadolgov.si': 10,
#  'mic.scv.si': 10,
#  'pd-sostanj.si': 10,
#  'korociv.si': 10,
#  'vodnjov.si': 10,
#  'komunala-kranj.si': 10,
#  'zeleni-dotik.si': 10,
#  'vrtec-sentjernej.si': 10,
#  'jysk.si': 10,
#  'kcstv.si': 10,
#  'vreme.dobratrgovina.si': 10,
#  'evo-magazin.si': 10,
#  'loske-novice.si': 10,
#  'tabletkapo.si': 10,
#  'fitkuhinja.si': 10,
#  'nepremagljiva.si': 10,
#  'greenhull.eu': 10,
#  'luksuz.net': 10,
#  'sloastro.com': 10,
#  'bankainfo.com': 10,
#  'babyotroskatrgovinamiska.eu': 10,
#  'netart.si': 10,
#  'genska-banka.si': 10,
#  'pravicna-trgovina.si': 10,
#  'nemscina.si': 10,
#  'ekomaratonmaribor.si': 10,
#  'makete.si': 10,
#  'artis.si': 10,
#  'jakobova-pot.si': 10,
#  'forestry.bf.uni-lj.si': 10,
#  'sde.solske-sestre.si': 10,
#  'katstik.si': 10,
#  'lestroj.si': 10,
#  'zvvs.si': 10,
#  'kopun-simto.si': 10,
#  'kozelj.si': 10,
#  'nklub-ziri.si': 10,
#  'poi.si': 10,
#  'tipk.si': 10,
#  'hisalasnihmisli.si': 10,
#  'zoom360.si': 10,
#  'manet.si': 10,
#  'hvalazaroze.si': 10,
#  'revija-vino.si': 10,
#  'icra.si': 10,
#  'e-gradiva.com': 10,
#  'ninamvseeno.org': 10,
#  'steklo-nemec.com': 10,
#  'jangregorin.eu': 10,
#  'maticmunc.net': 10,
#  'si.kompass.com': 10,
#  'atraktor.si': 10,
#  'tritel.si': 10,
#  'zupnija-vojnik.si': 10,
#  'aktualen.si': 10,
#  'mshop.si': 10,
#  'mirovni-institut.si': 10,
#  'ekolife.si': 10,
#  'pekis.si': 10,
#  'sd-trnovo.si': 10,
#  'pdkamnik.si': 10,
#  'mladi-radovljice.si': 10,
#  'spot.gov.si': 10,
#  'megacenter.si': 10,
#  '1racunovodstvo.blogspot.com': 10,
#  'spins.si': 10,
#  'lekarnaljubljana.si': 10,
#  'vrhunskaoprema.si': 10,
#  'diagnostika.mojforum.si': 10,
#  'mamaterra.si': 10,
#  'bachovekapljice.si': 10,
#  'open.spotify.com': 10,
#  'delitev.blogspot.com': 10,
#  'drustvo-ruj.mojforum.si': 10,
#  'elektro-gorenjska.si': 10,
#  'visitmaribor.si': 10,
#  'mojatrgovinica.si': 10,
#  'murjeplovec.mojforum.si': 10,
#  'pticjipajki.mojforum.si': 10,
#  'biolek.si': 10,
#  'poslovodno-racunovodstvo.si': 10,
#  'solacerkljeobkrki.splet.arnes.si': 10,
#  'megashop.si': 10,
#  'rastline.com': 10,
#  'blog.mountvacation.com': 10,
#  'go2school.com': 10,
#  'movetomaribor.festivalplatforma.si': 10,
#  'vipavska-dekanija.rkc.si': 10,
#  'unitring.si': 10,
#  'dolenjskanews.com': 10,
#  'sorarmonica.si': 10,
#  'psihoterapija-ordinacija.si': 10,
#  'zupnija-predloka.rkc.si': 10,
#  'hipp.si': 10,
#  'nkolimpija.si': 10,
#  'metabo.com': 10,
#  'prc.si': 10,
#  'ikss.zrc-sazu.si': 10,
#  'copia-biro.si': 10,
#  'fcl.si': 10,
#  'centralvod.si': 10,
#  'spletniagent.net': 10,
#  'las-bogastvopodezelja.si': 10,
#  'vojnapotovanja.si': 10,
#  'odprtakuhinja.delo.si': 10,
#  'webasto-comfort.com': 10,
#  'coloursofistria.com': 10,
#  'golgeter.com': 10,
#  'to-je-to.net': 10,
#  'czr.si': 10,
#  'sever-zasavje.si': 10,
#  'zupnija-selca.rkc.si': 10,
#  'osgorica-velenje.si': 10,
#  'razmere.e-gora.si': 10,
#  'parkvia.com': 10,
#  'old.opensoaring.com': 10,
#  'electrolux.si': 10,
#  'blizjiknjigi.si': 10,
#  'psihoforum.mojforum.si': 10,
#  'pokrajinskimuzejkoper.si': 10,
#  'muzej-velenje.si': 10,
#  'leki.com': 10,
#  'vozniski-izpit.com': 10,
#  'momacki2012.mojforum.si': 10,
#  'reprokolinska.si': 10,
#  'ef-gradiva.net': 10,
#  'diamond-realestate.hr': 10,
#  'stareslike.cerknica.org': 10,
#  'volicina-sport.si': 10,
#  'sasa.musiclab.si': 10,
#  'osha.mddsz.gov.si': 10,
#  'kingspan.com': 10,
#  'novomesto.ozrk.si': 10,
#  'zagovornik.si': 10,
#  'program-podezelja.si': 10,
#  'trelleborgslovenija.com': 10,
#  'konti.si': 10,
#  'zvezaslovenskih-godb.si': 10,
#  'ossenovo.net': 10,
#  'manager.finance.si': 10,
#  'politicniforumslovenije.mojforum.si': 10,
#  'pravniki.info': 10,
#  'bogastvozdravja.si': 10,
#  'dpm-metlika.si': 10,
#  'jazindiabetes.si': 10,
#  'uciteljska.net': 10,
#  'prips-nepremicnine.si': 10,
#  'forum-tezave-pomagajmosi.mojforum.si': 10,
#  'majdinustvarjalninemir.blogspot.com': 10,
#  'stirikolesniki.si': 10,
#  'viralko.si': 10,
#  'nkdomzale.si': 10,
#  'hoffmann-group.com': 10,
#  'radio-ptuj.si': 10,
#  'vuzenica.si': 10,
#  'asktriglav.si': 10,
#  'smskupnost.si': 10,
#  'kuharijada.blogspot.com': 10,
#  'ffa.uni-lj.si': 10,
#  'kii3.ntf.uni-lj.si': 10,
#  'kotal-trade.si': 10,
#  'zivoupanje.org': 10,
#  'zzz-strumbelj.si': 10,
#  'ilirika.si': 10,
#  'sensa.metropolitan.si': 10,
#  'support.mozilla.org': 10,
#  'lifestrzen.blogspot.com': 10,
#  'civilne-iniciative-celja.si': 10,
#  'za-ljubitelje-narave.mop.gov.si': 10,
#  'revija-energetik.si': 10,
#  'tminskimigavci.mojforum.si': 10,
#  'syncro-system.si': 10,
#  'donaulab.si': 10,
#  'akos-rs.si': 10,
#  'ak-velenje.si': 10,
#  'zalozba.pef.uni-lj.si': 10,
#  'eurogarden.si': 10,
#  'iahd-adriatic.org': 10,
#  'zlatarna-aura.si': 10,
#  'cistilazasedezne.mojforum.si': 10,
#  'sinagogamaribor.si': 10,
#  'veganska-iniciativa.blogspot.com': 10,
#  'metuljcek-kamnik.mojforum.si': 10,
#  'varnostnaspletu.si': 10,
#  'du-po.si': 10,
#  'varcevanje-energije.si': 10,
#  'policija.mojforum.si': 10,
#  'okrasnivrt.com': 10,
#  'hostelcelica.com': 10,
#  'lgelectronics.si': 10,
#  'kasaska-zveza.si': 10,
#  'ikt-projekti.uni-lj.si': 10,
#  'mojcakoprivnikar.si': 10,
#  'zivalskenovice.si': 10,
#  'gim-idrija.splet.arnes.si': 10,
#  'ossevnica.si': 10,
#  'nikaandgrega.si': 10,
#  'vitalnotelo.si': 10,
#  'odaz.si': 10,
#  'kuloar.si': 10,
#  'zupnija-skofja-loka.rkc.si': 10,
#  'jezikovna-politika.si': 10,
#  'si.openprof.com': 10,
#  'www2.24ur.com': 10,
#  'bekament.com': 10,
#  'zoranfurman.com': 10,
#  'unirec.si': 10,
#  'neplodnost.si': 10,
#  'spotur.si': 10,
#  'galarna.si': 10,
#  'organizirajsiporoko.si': 10,
#  'koopautomotive.si': 10,
#  'avtomobilski-nadstreski.si': 10,
#  'infrastruktura-bled.si': 10,
#  'aktivni-fit.si': 10,
#  'cobiss.si': 10,
#  'avicenna-isct.org': 10,
#  'maraton-savinja.si': 10,
#  'pos.splet.arnes.si': 10,
#  'si.flirtydolls.com': 10,
#  'center-pokljuka.si': 10,
#  'pinjadzazna.blogspot.com': 10,
#  'yogalishesana.com': 10,
#  'avtostoritve-rogelj.si': 10,
#  'sl.gautamblogs.com': 10,
#  'army.mojforum.si': 10,
#  'drustvovtis.si': 10,
#  'zobozdravstvo-diamant.si': 10,
#  'prisilnaprostitucija.si': 10,
#  'cheerleading.si': 10,
#  'harologi.si': 10,
#  'centereksperimentov.si': 10,
#  'pgd-cerknica.si': 10,
#  'nk-kolpa.si': 10,
#  'slo-akreditacija.si': 10,
#  'sang.mojforum.si': 10,
#  'een.si': 10,
#  'recenzijestrani.najblog.si': 10,
#  'podpora.spletnik.si': 10,
#  'geopark.si': 10,
#  'svobodensvet.wordpress.com': 10,
#  'makovopolje.wordpress.com': 10,
#  'nfhos.org': 10,
#  'cargo-partner.com': 10,
#  'mylittlewonderland21.blogspot.com': 10,
#  'zup-prevozi.eu': 10,
#  'bolnisnica-kranj.si': 10,
#  'elektronika.splet.arnes.si': 10,
#  'jernejkitchen.com': 10,
#  'pgd-cerklje.si': 10,
#  'forum.over.net': 10,
#  'drustvo-levpa.si': 10,
#  'baletna-sola.si': 10,
#  'solazazivljenje.si': 10,
#  'jantarjeve-ogrlice.si': 10,
#  'supernova-qlandia-kranj.si': 10,
#  'marjankogelnik.wordpress.com': 10,
#  'sentjanz-vg.com': 10,
#  'sam.si': 10,
#  'pd-viharnik.si': 10,
#  'ezb.ijs.si': 10,
#  'caravan.mojforum.si': 10,
#  'sdh.si': 10,
#  'lineasnella.si': 10,
#  'mojprihranek.si': 10,
#  'klub-kos.si': 10,
#  'kosarkarski-trenerji.com': 10,
#  'ansambel-spev.com': 10,
#  'aleslombergar.com': 10,
#  'ideje-ustvarjalnidotik.blogspot.com': 10,
#  'vrtickarji.substral.si': 10,
#  'darsen.si': 10,
#  'biromat.si': 10,
#  'gibalnaterapija.si': 10,
#  'cakalnedobe.si': 10,
#  'theatre-architecture.eu': 10,
#  'e-zavarovanja.com': 10,
#  'iskreni.net': 10,
#  'unis.unvienna.org': 10,
#  'letalskekarte.zletalomnapoti.si': 10,
#  'printink.si': 10,
#  'agroma.si': 10,
#  'kmetija.mojforum.si': 10,
#  'scidrom.splet.arnes.si': 10,
#  'argan.si': 10,
#  'feelfree.si': 10,
#  'individualna-potovanja.si': 10,
#  'vrtnicenter.si': 10,
#  'slovenska-hisa.si': 10,
#  'prirocnikdom.si': 10,
#  'gradovivoblakih.blogspot.com': 10,
#  'biblioum.blogspot.com': 10,
#  'sl.cottage-home-and-garden.com': 10,
#  'dnevno.si': 10,
#  'vadbenaklinika.si': 10,
#  'edsolution.si': 10,
#  'klikonline.si': 10,
#  'musicaviva.si': 10,
#  'notranjaopremastanovanja.blogspot.com': 10,
#  'zavodudarnik.wordpress.com': 10,
#  'zoso.si': 10,
#  'multilingual-prevajanje.si': 10,
#  'tvdrustvo-partizandomzale.si': 10,
#  'continentalfilm.si': 10,
#  'marika.mojforum.si': 10,
#  'virtualnagalerija.inovelmedia.si': 10,
#  'visitradece.si': 10,
#  'roko.si': 10,
#  'vlastakunej.kmeckiglas.com': 10,
#  'arstudio-avsenik.com': 10,
#  'pe.jezakon.com': 10,
#  'pms-lj.si': 10,
#  'krtina.com': 10,
#  'trgovina.amon.si': 10,
#  'ml63.si': 10,
#  'mladi-gasilec.si': 10,
#  'unikat-darila.si': 10,
#  'pismapalkijem.si': 10,
#  'kud-skofljica.si': 10,
#  'hitri-krediti.si': 10,
#  'egyptianmagic.si': 10,
#  '1aoblikovanje.si': 10,
#  'pivovarium.si': 10,
#  'saljic.si': 10,
#  'scrs.si': 10,
#  'agrarne.si': 10,
#  'zkdks.si': 10,
#  'plosca.si': 10,
#  'parokeets.com': 10,
#  'liupka.com': 10,
#  'kurentovanje.net': 10,
#  'streetpark.eu': 10,
#  'brumen.org': 10,
#  'zkds.si': 10,
#  'bushido.si': 10,
#  'spletninasveti.si': 10,
#  'agp.si': 10,
#  'zalozba.fov.um.si': 10,
#  'premik.si': 10,
#  'futunatura.si': 10,
#  'atelje-kresnik.si': 10,
#  'czs.si': 10,
#  'zdps.si': 10,
#  'mkphoto.si': 10,
#  'gast.si': 10,
#  'bucar.eu': 10,
#  'moje-mesto.com': 10,
#  'aperion.org': 10,
#  'wellis-store.si': 10,
#  'hidrosistemi.si': 10,
#  'borger-gremo.si': 10,
#  'mus.si': 10,
#  'epeka.si': 10,
#  'risp.si': 10,
#  'prostocasnik.si': 10,
#  'kocevski-med.si': 10,
#  'mojcbd.si': 10,
#  'strk.si': 10,
#  'telem.si': 10,
#  'ngn.si': 10,
#  'selih.si': 10,
#  'optimtrader.com': 10,
#  'vg-guides.com': 10,
#  'kipota.com': 10,
#  'customnanny.com': 10,
#  'slastno.com': 10,
#  'butul.net': 10,
#  'digiars.si': 10,
#  'hudakuhna.si': 10,
#  'nkkapca.si': 10,
#  'vgradna-omara.si': 10,
#  'yugotranslate.si': 10,
#  'cores.si': 10,
#  'florist.si': 10,
#  'eventus.si': 10,
#  'baby-handling.com': 10,
#  'karavanke.eu': 10,
#  'hosekra.com': 10,
#  't-2.net': 10,
#  'bazzar.hr': 10,
#  'kimdps.si': 10,
#  'rt-tri.si': 10,
#  'isys.si': 10,
#  'dom-upokojencev.si': 10,
#  'portalplus.si': 10,
#  'baba.si': 10,
#  'obcina-krizevci.si': 10,
#  'bodizdrav.si': 10,
#  'kremet.si': 10,
#  'taisa.si': 10,
#  'rep.si': 10,
#  'cotondetulear.si': 10,
#  'lddobrova.lovci.si': 10,
#  'dhs.si': 10,
#  'inz.si': 10,
#  'artros.si': 10,
#  'saleskaveterina.si': 10,
#  'iki-pro.si': 10,
#  'buythesea.si': 10,
#  'cokoladniatelje.si': 10,
#  'krasoprema.si': 10,
#  'vilboss.si': 10,
#  'lares.si': 10,
#  'tixibeauty.com': 10,
#  'martinkorosec.com': 10,
#  'ursanina.si': 10,
#  'gradnje-polak.com': 10,
#  'metta.si': 10,
#  'rotoks.si': 10,
#  'noctibenmea.si': 10,
#  'vogart.si': 10,
#  'ideart.si': 10,
#  'rossisport.si': 10,
#  'vsm.si': 10,
#  'piknik-prostor.si': 10,
#  'notpadu.si': 10,
#  'lignit.si': 10,
#  'gradprestranek.si': 10,
#  'znamza5.si': 10,
#  'ansambel-objem.si': 10,
#  'kovacnica.si': 10,
#  'skratovadezela.si': 10,
#  'kam.fmf.uni-lj.si': 10,
#  'chess.mojforum.si': 10,
#  'rodsivegavolka.si': 10,
#  'ka3.si': 10,
#  'jasminaturnsek.si': 10,
#  'podgrad.si': 10,
#  'osvodmat.si': 10,
#  'rkanal.si': 10,
#  'alpklubsg.si': 10,
#  'vedezevanje090.si': 10,
#  'tolstanutrija.com': 10,
#  'best4pet.eu': 10,
#  'trgovinaika.si': 10,
#  'bovha.si': 10,
#  'karsia.si': 10,
#  'k3-kern.si': 10,
#  'storija.si': 10,
#  'optisis.si': 10,
#  'mg-biro.si': 10,
#  'bajalka.si': 10,
#  'petrana.si': 10,
#  'os-raka.si': 10,
#  'informa.si': 10,
#  'dlesni.com': 10,
#  'epilog.net': 10,
#  'zenles.net': 10,
#  'ziri.si': 10,
#  'podbocje.si': 10,
#  'mrk-krka.si': 10,
#  'bizstore.si': 10,
#  'floradix.si': 10,
#  'rebernik.si': 10,
#  'dkps.si': 10,
#  'smrkolin.si': 10,
#  'lz-koper.si': 10,
#  'poskodba.si': 10,
#  'prestopi.si': 10,
#  'src.si': 10,
#  'lionshop.si': 10,
#  'iloq.com': 10,
#  'pekarna.net': 10,
#  'aforum.shop': 10,
#  'zadetek.org': 10,
#  'howtobe.si': 10,
#  'trendom.si': 10,
#  'dravacenter.si': 10,
#  'proskin.si': 10,
#  'fsp.si': 10,
#  'gzl.si': 10,
#  'osvp.si': 10,
#  'spol.si': 10,
#  'isak.si': 10,
#  'ipen.si': 10,
#  'imag.si': 10,
#  'leag.si': 10,
#  'upol.si': 10,
#  'dlogs.si': 10,
#  'kizej.si': 10,
#  'janim.si': 10,
#  'kreme.si': 10,
#  'aixam.si': 10,
#  'legit.si': 10,
#  'nexum.si': 10,
#  'ed-mb.si': 10,
#  'noela.si': 10,
#  'vizor.si': 10,
#  'zdsds.si': 10,
#  'ilirik.si': 10,
#  'apolis.si': 10,
#  'gvo.si': 10,
#  'parket.si': 10,
#  'algoja.si': 10,
#  'razpis.si': 10,
#  'tp-lj.si': 10,
#  'agaric.si': 10,
#  'os-verzej.si': 10,
#  'douchebag.si': 10,
#  'pavidecor.si': 10,
#  'pgd-dobrna.si': 10,
#  'odpuscanje.si': 10,
#  'bobi4ever.net': 10,
#  'klub-gros.com': 10,
#  'arslitera.org': 10,
#  'naturavit.net': 10,
#  'sampaymoo.net': 10,
#  'feniks-pro.eu': 10,
#  'eu-integra.eu': 10,
#  'cyclingpp.com': 10,
#  'harmony.hr': 10,
#  'alteks.si': 10,
#  'agrotehnika.si': 10,
#  'kop-brezice.si': 10,
#  'raka.si': 10,
#  'ddnm.si': 10,
#  'odkup-bakra.si': 10,
#  'nagode.si': 10,
#  'trafika3dva.si': 10,
#  'almavista.si': 10,
#  'kompas-holy.si': 10,
#  'izza-jeziki.si': 10,
#  'seslj.si': 10,
#  'os-mk.si': 10,
#  'slorational.si': 10,
#  'nutribiovet.si': 10,
#  'idshop.si': 10,
#  'revma-info.si': 10,
#  'parasidose.si': 10,
#  'avantgarde.si': 10,
#  'streznik.com': 10,
#  'mollonpro.si': 10,
#  'dih.si': 10,
#  'geekhouse.si': 10,
#  'europrint.si': 10,
#  'fermedica.si': 10,
#  'panta-rei.si': 10,
#  'odu-koper.si': 10,
#  'masterjob.si': 10,
#  'sd-metulj.si': 10,
#  'studioxxv.si': 10,
#  'osbakovci.si': 10,
#  'spletni.guru': 10,
#  'mojfasader.si': 10,
#  'ak-pomurje.si': 10,
#  'kk-gibanje.si': 10,
#  'next.si': 10,
#  'cremona.si': 10,
#  'kdm.si': 10,
#  'varna-pasa.si': 10,
#  'minimalist.si': 10,
#  'tehnopolis.si': 10,
#  'osmislinja.si': 10,
#  'keramtrade.si': 10,
#  'integralis.si': 10,
#  'mmol.si': 10,
#  'alenkalanz.si': 10,
#  'suman.si': 10,
#  'tvkomenda.si': 10,
#  'matejkorelc.blogspot.com': 10,
#  'kundalinijoga.si': 10,
#  'supercard.si': 10,
#  'cudhg-idrija.si': 10,
#  'complete-datacenter.si': 10,
#  'althea.si': 10,
#  'bizinaizi.si': 10,
#  'zb-kocevje.si': 10,
#  'odvetnik-mele.si': 10,
#  'sk-poljane.si': 10,
#  'trgovina.vesper.si': 10,
#  'sla.si': 10,
#  'komp-r.si': 10,
#  'kasca.si': 10,
#  'alfalaval.si': 10,
#  'oftalmologija.si': 10,
#  'vz-kranj.si': 10,
#  'kopirnistroji.si': 10,
#  'art-kozmetika.com': 10,
#  'starsevstvo.com': 10,
#  'podjetniski-portal.com': 10,
#  'malasolapodjetnikov.eu': 10,
#  's54u.blogspot.com': 10,
#  'gorec.info': 10,
#  'domacebranje.com': 10,
#  'guide2visit.eu': 10,
#  'radiokaos.info': 10,
#  'zalozba.kmeckiglas.com': 10,
#  'zavod-amo.si': 10,
#  'skladskladov.si': 10,
#  'vacations.si': 10,
#  'grantthornton.si': 10,
#  'optimizacija-strani.si': 10,
#  'kajak-tacen.si': 10,
#  'angel.si': 10,
#  'cele.si': 10,
#  'zdl.si': 10,
#  'masterline.si': 10,
#  'carpus-makeup.si': 10,
#  'ad-stajerska.si': 10,
#  'findhealthclinics.com': 10,
#  'gm-hise.com': 10,
#  'elektronik-invent.com': 10,
#  'raznolikost.eu': 10,
#  'ey.com': 10,
#  'andrej.mernik.eu': 10,
#  'gongkoncert.com': 10,
#  'stripburger.org': 10,
#  'camping-monperin.hr': 10,
#  'harpoon.si': 10,
#  'zenskilobi.si': 10,
#  'dravabike.si': 10,
#  'r4.ijs.si': 10,
#  'tramontana-net.si': 10,
#  'os-zirovnica.si': 10,
#  'vseosreci.si': 10,
#  'vrtec-joziceflander.si': 10,
#  'os-fmalgaja.si': 10,
#  'pd-smartno.si': 10,
#  'o365.arnes.si': 10,
#  'viseci-stoli.si': 10,
#  '3-port.si': 10,
#  'sociolab.si': 10,
#  'psihoterapija-metljak.si': 10,
#  'zveza-lu.si': 10,
#  'vrtec-vrhnika.si': 10,
#  'jadranje.ahil.si': 10,
#  'toshibacenter.si': 10,
#  'donbosko.si': 10,
#  'sport-bled.si': 10,
#  'at-team.si': 10,
#  'panda.formitas.si': 10,
#  'zupnija-piran.si': 10,
#  'jasminjadranje.si': 10,
#  'sportikus.splet.arnes.si': 10,
#  'kshuje.si': 10,
#  'kviz.solazaravnatelje.si': 10,
#  'slaj-anic.si': 10,
#  'psiholog-slovenija.si': 10,
#  'doggo.si': 10,
#  'blog.exploring.si': 10,
#  'pvsp.si': 10,
#  'podlehnik.si': 10,
#  'kosi.si': 10,
#  'turizem.jesenice.si': 10,
#  'therapia-dom.si': 10,
#  'shop.mobtel.si': 10,
#  'pas.si': 10,
#  'lokatiming.com': 10,
#  'savinjske.com': 10,
#  'trgovina.svetangelov.com': 10,
#  'inovateh.si': 10,
#  'vzhodna.si': 10,
#  'kpnepremicnine.si': 10,
#  'radimamsolate.si': 10,
#  'gkfb.si': 10,
#  'pasjismrcek.mojforum.si': 10,
#  'skisova-trznica.si': 10,
#  'zzds.si': 10,
#  'gov-is.si': 10,
#  'feelthefuture.si': 10,
#  'veterinabtc.si': 10,
#  'higeja.si': 10,
#  'ra-savinja.si': 10,
#  'canifit.si': 10,
#  'forbetterworld.si': 10,
#  'zatoizberi.si': 10,
#  'kandex.si': 10,
#  'slikarska-sola.si': 10,
#  'knjiznica-ravne.si': 10,
#  'pdmezica.si': 10,
#  'aclovse.si': 10,
#  'omamljen.si': 10,
#  'genivolley.eu': 10,
#  'hujsanje.info': 10,
#  'abzakladki.blogspot.com': 10,
#  'barbarasimoniti.com': 10,
#  'dr-siftar-fundacija.org': 10,
#  'ekomartina.blogspot.com': 10,
#  'vsirecepti.blogspot.com': 10,
#  'radovljica.strankasmc.si': 10,
#  'govindas.si': 10,
#  'kranjska-cebela.si': 10,
#  'ferk.si': 10,
#  'sib-mb.si': 10,
#  'rk-arcontradgona.si': 10,
#  'rd-kocevje.si': 10,
#  'zlatarstvo-stern.si': 10,
#  'go2farms.si': 10,
#  'kksfest.si': 10,
#  'izobrazevanjarfr.si': 10,
#  'tiliaestate.si': 10,
#  'dsap.si': 10,
#  'avioborza.si': 10,
#  'marijamaticerkve.si': 10,
#  'samuel.rkc.si': 10,
#  'crna-gora.si': 10,
#  'intercommerce.si': 10,
#  'blabla.si': 10,
#  'bolezni-ven.si': 10,
#  'mula.si': 10,
#  'alpepapir.si': 10,
#  'moon-power.si': 10,
#  'diete365.si': 10,
#  'binevolcic.si': 10,
#  'koperotok.si': 10,
#  'dihslovenia.si': 10,
#  'trgovina.partner.si': 10,
#  'zipiie.eu': 10,
#  'unija.com': 10,
#  'cetisidentity.com': 10,
#  'nepremicnine-m2.com': 10,
#  'ski-cerkno.com': 10,
#  'nazdravi.si': 10,
#  'la-co.si': 10,
#  'zda2011.fri.uni-lj.si': 10,
#  'sencilazgd.si': 10,
#  'mozolji.si': 10,
#  'markpro.si': 10,
#  'slo-tours.si': 10,
#  'leonmarc.si': 10,
#  'harvest.si': 10,
#  'amiroshop.si': 10,
#  'nkrudarvelenje.com': 10,
#  'medico-veritas.net': 10,
#  'flyfishingodec.com': 10,
#  'dimer-group.com': 10,
#  'honorarno-delo.com': 10,
#  'slometeo.net': 10,
#  'zelenisvet.com': 10,
#  'nkkrsko.com': 10,
#  'za-mdi.si': 10,
#  'reisswolf.si': 10,
#  'movia.si': 10,
#  'synlab.si': 10,
#  'anglunipe.si': 10,
#  'limberk.si': 10,
#  'ssff.ff.uni-lj.si': 10,
#  'fmbb2013.si': 10,
#  'cssiska.si': 10,
#  'sconto.si': 10,
#  'sloado.si': 10,
#  'gimoste.si': 10,
#  'kozmeticni-salon.si': 10,
#  'spalnice.eu': 10,
#  'mojalbum.com': 10,
#  'sola-prezivetja.com': 10,
#  'ekoanhovo.org': 10,
#  'zmajcek.net': 10,
#  'fmed.eu': 10,
#  'shop.astronumero.org': 10,
#  'pgdmaterija.si': 10,
#  'soma.si': 10,
#  'kd-ljubljana.si': 10,
#  'destrnik.si': 10,
#  'emos-si.si': 10,
#  'selca.os-zelezniki.si': 10,
#  'zavod123.si': 10,
#  'zdrava-koza.si': 10,
#  'krabat.si': 10,
#  'dentago.si': 10,
#  'mcdonalds.si': 10,
#  'irb.si': 10,
#  'znanjelovec.si': 10,
#  'lovrenc.si': 10,
#  'nk-radomlje.si': 10,
#  'dom-zalec.si': 10,
#  'migajznami.si': 10,
#  'divji-zajci.si': 10,
#  'zavod-svibna.si': 10,
#  'dimnikarstvo-kamin.si': 10,
#  'goricane.si': 10,
#  'vrturedi.si': 10,
#  'smileatwork.si': 10,
#  'tekjelek.si': 10,
#  'matejmm.blogspot.com': 10,
#  'obala.net': 10,
#  'davorin.net': 10,
#  'magicnost-gibanja.si': 10,
#  'kazalo.net': 10,
#  'trgovina.natureta.si': 10,
#  'portal-koper.si': 10,
#  'fillistahl.si': 10,
#  'generali-galerija.si': 10,
#  'toti-las.si': 10,
#  'zupnija-semic.rkc.si': 10,
#  'pgddollj.si': 10,
#  'zupnija-tomaj.rkc.si': 10,
#  'sctriglav.si': 10,
#  'zurnal24ur.si': 10,
#  'anderwald.si': 10,
#  'ctrp-kranj.si': 10,
#  'izvir-klub.si': 10,
#  'srebrna-zlica.si': 10,
#  'meavalens.si': 10,
#  'klin.si': 10,
#  'veselanovica.si': 10,
#  'smarcan.si': 10,
#  'napisigovor.si': 10,
#  'infohit.si': 10,
#  'sadmavrica.si': 10,
#  'erp-kdkrim.si': 10,
#  'geadostava.si': 10,
#  'potepuh.si': 10,
#  'zlati-ghee.si': 10,
#  'otroska-kosarkarska-sola.si': 10}

# %%
# Filter out a part of texts from domains that have more than 10 texts
for item in ['zsc.si', 'os-miren.si', 'jeziki-stejejo.si', 'mipi.si', 'zupnijabarje.si', 'mzpm-ljubljana.si', 'zmos.si', 'easistent.com']:
	df_long_texts = df_long_texts.drop(df_long_texts[df_long_texts['domain'] == item].sample(n=2).index)

for item in ['ospivka6.splet.arnes.si', '2020.cityofwomen.org', 'pohistvo123.si', 'dars.si',
 'izo.sik.si', 'karra.si', 'jvvz.org', 'sportnazvezavelenje.si', 'digitalpartner.si', 'modulninja.shop']:
	df_long_texts = df_long_texts.drop(df_long_texts[df_long_texts['domain'] == item].sample(n=1).index)

# %%
df_long_texts.describe(include="all")
# Out:
#         domain                 url  \
# count    10000               10000
# unique    1000                9974
# top     zsc.si  http://www.zsc.si/
# freq        10                   3
# mean       NaN                 NaN
# std        NaN                 NaN
# min        NaN                 NaN
# 25%        NaN                 NaN
# 50%        NaN                 NaN
# 75%        NaN                 NaN
# max        NaN                 NaN
#
#                                                      text  \
# count                                               10000
# unique                                              10000
# top     Nacionalna varnost je preresna stvar, da bi jo...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       doc        length
# count                                               10000  10000.000000
# unique                                              10000           NaN
# top     <doc id="macocu.si.283" title="ZSC - Zveza slo...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    431.505500
# std                                                   NaN   1188.840319
# min                                                   NaN     76.000000
# 25%                                                   NaN    126.000000
# 50%                                                   NaN    221.000000
# 75%                                                   NaN    424.000000
# max                                                   NaN  56091.000000

# %%
# Check if all domains have the same number of instances
df_long_texts.domain.value_counts()
# Out:
# zsc.si                         10
# o-md.mb.edus.si                10
# dieta.si                       10
# zupnija-gomilsko.rkc.si        10
# kmetijskaoprema.si             10
#                                ..
# smarcan.si                     10
# napisigovor.si                 10
# infohit.si                     10
# sadmavrica.si                  10
# otroska-kosarkarska-sola.si    10
# Name: domain, Length: 1000, dtype: int64

# %%
# Save the final sample
df_long_texts.to_csv("MaCoCu-sl-sample2.csv", sep="\t")
