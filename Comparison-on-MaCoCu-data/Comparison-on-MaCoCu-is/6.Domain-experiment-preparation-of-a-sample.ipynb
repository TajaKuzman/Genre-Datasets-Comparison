# %% [markdown]
# Here, we prepare a sample from MaCoCu-is, on which we use the genre classifiers. To prepare the sample, we first need to discard all texts with text length smaller than 75 - I created a dictionary of all domains and urls of texts that are long enough. Then I calculated the frequency of the domains. I discarded domains that have less than 10 instances (if I wouldn't, the median would be 6 texts per domain). Then I calculated the median and took random 500 domains above the median and 500 domains below the median.

# %%
import gzip
import wget
import regex as re
import pandas as pd
import numpy as np
import json
import random
from tqdm import tqdm

# %%
# Compile regex for url and domain
url_re = re.compile('url="(.*?)"')
domain_re = re.compile('domain="(.*?)"')

# %% [markdown]
# ## Download and open the XLM file

# %%
# Download the corpus
# Download the file

#Defining the zip file URL
url = "https://www.clarin.si/repository/xmlui/bitstream/handle/11356/1518/MaCoCu-is.xml.gz"

# Downloading the file by sending the request to the URL
corpus_file = wget.download(url)
print('Downloading Completed')
# Out:
# Downloading Completed

# %%
file = gzip.open('MaCoCu-is.xml.gz', 'rt', encoding='utf-8')

# %% [markdown]
# ## Create a dataframe with the most frequent domains and a sample of 10 URLs from each domain

# %% [markdown]
# First, get a list of all domains and urls of texts that have are more than 75 words long.

# %%
text_counter = 0

texts = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_length = 0
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
	elif line.startswith("<p"):
		continue
	elif line.startswith("</p"):
		continue
	elif line.startswith("</doc"):
		text_length = len(pure_text.split())
		if text_length > 75:
			current_text = [current_domain, current_url]
			texts.append(current_text)
			text_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		pure_text += line
# Out:
# 51972334it [02:43, 316944.24it/s]

# %%
# Create a dataframe
df = pd.DataFrame({"domain": [x[0] for x in texts], "url": [x[1] for x in texts]})

df.head()
# Out:
#   domain                 url
# 0   1.is       https://1.is/
# 1   7.is       https://7.is/
# 2   8.is   https://www.8.is/
# 3  vb.is  https://www.vb.is/
# 4  fa.is  https://www.fa.is/

# %%
# Sort the df based on the domain
df = df.sort_values("domain")

df.head()
# Out:
#                           domain  \
# 1038994  002galleri.blogspot.com
# 113353   002galleri.blogspot.com
# 151324            020262.blog.is
# 507738      02johann.wixsite.com
# 766658      02johann.wixsite.com
#
#                                                        url
# 1038994  http://002galleri.blogspot.com/2014/07/stasetn...
# 113353                     http://002galleri.blogspot.com/
# 151324                 https://020262.blog.is/blog/020262/
# 507738   https://02johann.wixsite.com/lokaverkefni/heim...
# 766658   https://02johann.wixsite.com/lokaverkefni/ad-b...

# %%
df.describe(include="all")
# Out:
#           domain                                               url
# count    1207915                                           1207915
# unique     14025                                           1207744
# top     visir.is  https://www.dalvikurbyggd.is/is/frettir?page=295
# freq       34272                                                 2

# %% [markdown]
# We got 1,207,744 texts in 14,025 domains.

# %%
df.domain.value_counts().to_dict()
# Out:
# {'visir.is': 34272,
#  'hugi.is': 26494,
#  'vb.is': 22817,
#  'sarpur.is': 17137,
#  'austurfrett.is': 14261,
#  'baekur.is': 14028,
#  'timarit.is': 13375,
#  'hlad.is': 13257,
#  'kjarninn.is': 12847,
#  'eyjar.net': 12104,
#  'visindavefur.is': 11644,
#  'baggalutur.is': 9516,
#  'fiskifrettir.is': 9484,
#  'stundin.is': 9327,
#  'eldri.reykjavik.is': 8598,
#  'dv.is': 8297,
#  'kvikmyndir.is': 7841,
#  'ruv.is': 7630,
#  'skemman.is': 7612,
#  'ogmundur.is': 7447,
#  'frettabladid.is': 7309,
#  'spjall.kvartmila.is': 7185,
#  'pjatt.is': 7137,
#  'althingi.is': 6579,
#  'midjan.is': 6369,
#  'omarragnarsson.blog.is': 6133,
#  'fararheill.is': 5948,
#  'nature.is': 5858,
#  'sykur.is': 5769,
#  'liverpool.is': 5727,
#  'sudurnes.net': 5710,
#  'heimaslod.is': 5590,
#  'jeppaspjall.is': 5528,
#  'blog.dv.is': 5143,
#  'fib.is': 5052,
#  'stjornarradid.is': 4814,
#  'raudikrossinn.is': 4645,
#  'biblian.is': 4551,
#  'bjorn.is': 4438,
#  'spjall.vaktin.is': 4202,
#  'reglugerd.is': 4095,
#  'gamli.rvk.is': 4042,
#  'laeknabladid.is': 4003,
#  'hedinsfjordur.is': 3934,
#  'mmafrettir.is': 3921,
#  'heilsutorg.is': 3877,
#  'bmwkraftur.is': 3867,
#  'fiskaspjall.is': 3811,
#  'itr.is': 3794,
#  'bragi.arnastofnun.is': 3729,
#  'kirkjan.is': 3701,
#  'seltjarnarnes.is': 3589,
#  'trolli.is': 3538,
#  'is.evidentista.org': 3517,
#  'spjallid.is': 3513,
#  'mannlif.is': 3450,
#  'jonas.is': 3421,
#  'old.f4x4.is': 3307,
#  'hun.is': 3286,
#  'bbl.is': 3154,
#  'vantru.is': 3086,
#  'malefnin.com': 3060,
#  'vinotek.is': 2948,
#  'icelandonline.is': 2917,
#  'lifdununa.is': 2913,
#  'veitingageirinn.is': 2826,
#  'kaffid.is': 2825,
#  'ferlir.is': 2799,
#  'akureyrihandbolti.is': 2683,
#  'old.arborg.is': 2656,
#  'reykjanesbaer.is': 2649,
#  'esveit.is': 2647,
#  'trendnet.is': 2612,
#  'reykjavik.is': 2516,
#  'hi.is': 2511,
#  'betrireykjavik.is': 2509,
#  'lhhestar.is': 2500,
#  'si.is': 2483,
#  'namskra.is': 2483,
#  'kop.is': 2472,
#  'viljinn.is': 2442,
#  'kopavogur.is': 2432,
#  'vardberg.is': 2428,
#  'eidur.is': 2408,
#  'bilabladid.is': 2393,
#  'dalvikurbyggd.is': 2384,
#  'skreytumhus.is': 2376,
#  'ka.is': 2367,
#  'hugtakasafn.utn.stjr.is': 2325,
#  'landlaeknir.is': 2304,
#  'leiklist.is': 2295,
#  'akranes.is': 2277,
#  'vma.is': 2223,
#  'sim.is': 2221,
#  'grundarfjordur.is': 2217,
#  'knattspyrna.keflavik.is': 2212,
#  'ni.is': 2205,
#  'jolaborgin.is': 2205,
#  'gardabaer.is': 2193,
#  'skagafjordur.is': 2172,
#  'truflun.net': 2119,
#  'notendur.hi.is': 2045,
#  'vegagerdin.is': 2043,
#  'emilpall.123.is': 2011,
#  'lystigardur.akureyri.is': 1989,
#  'rvk.is': 1963,
#  'isafjordur.is': 1960,
#  'bland.is': 1895,
#  'byggingar.buildingsgroup.com': 1876,
#  'fjardarfrettir.is': 1872,
#  'akureyri.is': 1863,
#  'nutiminn.is': 1854,
#  'bssl.is': 1853,
#  'heimkaup.is': 1852,
#  'bb.is': 1848,
#  'motocross.is': 1822,
#  'nordnordursins.is': 1799,
#  'obi.is': 1791,
#  'skessuhorn.is': 1787,
#  'fotbolti.net': 1787,
#  'mbclub.is': 1772,
#  'jakobk.blog.is': 1767,
#  'naut.is': 1746,
#  'lhg.is': 1722,
#  'leit.is': 1712,
#  'ismus.is': 1706,
#  'mennta.hi.is': 1641,
#  'nordurthing.is': 1632,
#  'vedur.is': 1627,
#  'bokmenntaborgin.is': 1567,
#  'is.nat.is': 1565,
#  'handrit.is': 1564,
#  'sukka.is': 1564,
#  'archive.is': 1550,
#  'lhi.is': 1537,
#  'styrmir.is': 1528,
#  'sk2102.com': 1525,
#  'skatturinn.is': 1518,
#  'thruman.blog.is': 1509,
#  'marinogn.blog.is': 1507,
#  'alberteldar.com': 1494,
#  'mos.is': 1492,
#  'hjartalif.is': 1472,
#  'bilablogg.is': 1441,
#  'gamla.matis.is': 1436,
#  'eoe.is': 1427,
#  'ry.is': 1418,
#  'neytendastofa.is': 1398,
#  'audlindin.is': 1391,
#  'ljod.is': 1387,
#  'lifeyrismal.is': 1370,
#  'brefasafn.arnastofnun.is': 1358,
#  'molar.is': 1345,
#  'hraun.vedur.is': 1341,
#  'fasteignir.visir.is': 1338,
#  'jyry.betrireykjavik.is': 1333,
#  'gudmundur.eyjan.is': 1313,
#  'fjallabyggd.is': 1305,
#  'efling.is': 1305,
#  'betraisland.is': 1302,
#  'landbunadur.is': 1296,
#  'klapptre.is': 1286,
#  'ifsport.is': 1283,
#  'selfoss.net': 1281,
#  't24.is': 1274,
#  'ragna.betra.is': 1271,
#  'ferdamalastofa.is': 1270,
#  'ru.is': 1255,
#  'bílablaðið.is': 1251,
#  'fi.is': 1250,
#  'elko.is': 1246,
#  'hugras.is': 1241,
#  'fh.is': 1238,
#  'bvg.is': 1238,
#  'norden.org': 1235,
#  'xd.is': 1232,
#  'grindavik.is': 1218,
#  'lemurinn.is': 1203,
#  'uua.is': 1181,
#  'olfus.is': 1174,
#  'hafnarfjordur.is': 1162,
#  'flugur.is': 1162,
#  'ihi.is': 1158,
#  'raududjoflarnir.is': 1154,
#  'gagolf.is': 1152,
#  'kopavogsbladid.is': 1151,
#  'langanesbyggd.is': 1150,
#  'votnogveidi.is': 1143,
#  'cafesigrun.com': 1138,
#  'atom.blonduos.is': 1132,
#  'everton.is': 1130,
#  'spjall.skyttur.is': 1121,
#  'skatamal.is': 1120,
#  'rafhladan.is': 1115,
#  'sigurjonth.blog.is': 1108,
#  'stebbifr.blog.is': 1104,
#  'grgs.is': 1100,
#  'garnstudio.com': 1099,
#  'grafarvogsbuar.is': 1098,
#  'nimbus.blog.is': 1098,
#  'siglo.is': 1082,
#  'taflfelag.is': 1073,
#  'vi.is': 1073,
#  'skodun.is': 1065,
#  'bjarg.is': 1051,
#  'herdubreid.is': 1049,
#  'english.arnastofnun.is': 1046,
#  'atvinnurekendur.is': 1038,
#  'borgarskjalasafn.is': 1025,
#  'eirikurjonsson.is': 1024,
#  'kirkju.net': 1023,
#  '847.is': 1021,
#  'games.lotto.is': 1017,
#  'vinsidan.is': 1017,
#  'ragna.is': 989,
#  'joi.betra.is': 978,
#  'stjornufraedi.is': 975,
#  'fotbolti.ka.is': 972,
#  'hofsstadaskoli.is': 970,
#  'evalaufeykjaran.is': 963,
#  'isi.is': 960,
#  'barnaheill.is': 959,
#  'sky.is': 949,
#  'vikubladid.is': 947,
#  'mast.is': 941,
#  'thorarinn.com': 937,
#  'persona.is': 926,
#  'gamli.ki.is': 924,
#  'landpostur.is': 913,
#  'strandabyggd.is': 913,
#  'saudfe.is': 908,
#  'kfum.is': 906,
#  'dalsmynni.123.is': 903,
#  'vf.is': 900,
#  'arionbanki.is': 899,
#  'fragtskip.123.is': 889,
#  'blikar.is': 882,
#  'verkis.is': 877,
#  'nordicgames.is': 875,
#  'hvalfjardarsveit.is': 869,
#  'sedlabanki.is': 868,
#  'landspitali.is': 867,
#  'borgarblod.is': 856,
#  'uia.is': 855,
#  'starafugl.is': 853,
#  'ust.is': 853,
#  'stjornartidindi.is': 853,
#  'isadopt.is': 850,
#  'byggdastofnun.is': 841,
#  'floraislands.is': 840,
#  'sameyki.is': 836,
#  'hsu.is': 835,
#  'vesturbyggd.is': 835,
#  'jensgud.blog.is': 832,
#  'hvatinn.is': 828,
#  'skak.is': 821,
#  'rml.is': 817,
#  'simon.is': 815,
#  'msfelag.is': 815,
#  'brim.123.is': 810,
#  'svanurg.blog.is': 810,
#  'huni.is': 808,
#  'salvor.blog.is': 807,
#  'einstein.is': 805,
#  'myndform.webman.is': 804,
#  'floahreppur.is': 803,
#  'heilsuhringurinn.is': 802,
#  'beautybox.is': 801,
#  'arni.hamstur.is': 800,
#  'hunathing.is': 798,
#  'sigurros.betra.is': 797,
#  'atom.skagafjordur.is': 793,
#  'myndasafn.hi.is': 791,
#  'hannesgi.blog.is': 787,
#  'sak.is': 780,
#  'djupivogur.is': 777,
#  'borgarbokasafn.is': 771,
#  'tindastoll.is': 770,
#  'samband.is': 769,
#  'hveragerdi.is': 764,
#  'grænnvettvangur.is': 764,
#  'afturelding.is': 763,
#  'spilavinir.is': 760,
#  'os.is': 757,
#  'fos.is': 756,
#  'eyjafrettir.is': 753,
#  'haestirettur.is': 748,
#  'fakur.is': 738,
#  'loftslag.is': 738,
#  'heilsuhusid.is': 736,
#  'dkg.is': 733,
#  'blind.is': 732,
#  'rafis.is': 731,
#  'norn.is': 729,
#  'bokalind.is': 726,
#  'snaefell.is': 726,
#  'verkvest.is': 722,
#  'eldri.landvernd.is': 721,
#  'holmdish.blog.is': 720,
#  'is.wikibooks.org': 716,
#  'vidreisn.is': 713,
#  'lestrarklefinn.is': 711,
#  'samgongustofa.is': 703,
#  'stjornlagarad.is': 702,
#  'mar.anomy.net': 701,
#  'spjall.frettavefur.net': 699,
#  'kerhraun.is': 696,
#  'halldorjonsson.blog.is': 696,
#  'grenivik.is': 693,
#  'leikskolar.is': 692,
#  'evropuvaktin.is': 692,
#  'giljaskoli.is': 689,
#  'skeidgnup.is': 680,
#  'ljufmeti.com': 680,
#  'islandssjodir.is': 677,
#  'kaldur.landspitali.is': 675,
#  'bondi.is': 671,
#  'hordur.is': 670,
#  'brim.is': 668,
#  'reykholar.is': 666,
#  'griman.is': 662,
#  'gamli.veidi.is': 661,
#  'rannis.is': 654,
#  'thefunky-monkey.com': 653,
#  'zeriaph.blog.is': 652,
#  'svavaralfred.blog.is': 652,
#  'arnareggert.is': 651,
#  'old.ns.is': 640,
#  'tjorvar.is': 638,
#  'evropuvefur.is': 637,
#  'ir.is': 635,
#  'vino.is': 622,
#  'kristinn.is': 615,
#  'sasport.is': 615,
#  'fjallahjolaklubburinn.is': 614,
#  'alltumflug.is': 612,
#  'borgarfjordureystri.is': 612,
#  'lbhi.is': 612,
#  'solir.blog.is': 611,
#  'nlfi.is': 611,
#  'mtr.is': 611,
#  'thorgeirbald.123.is': 610,
#  'skagastrond.is': 605,
#  'rns.is': 603,
#  'menningarstadur.123.is': 602,
#  'lifland.is': 602,
#  'hafnfirdingur.is': 602,
#  'thsof.123.is': 601,
#  'akureyri.net': 597,
#  'hafnarfrettir.is': 597,
#  'tidin.is': 595,
#  'albumm.is': 594,
#  'dfs.is': 592,
#  'mosfellingur.is': 590,
#  'kilroy.is': 589,
#  'kayakklubburinn.is': 589,
#  'rikisend.is': 588,
#  'bibbi.is': 585,
#  'krreykjavik.is': 584,
#  'storytel.com': 583,
#  'asa.is': 574,
#  'lettir.is': 574,
#  'tilveran-i-esb.blog.is': 570,
#  'landvernd.is': 568,
#  'sundsamband.is': 566,
#  'this.is': 564,
#  'ibvsport.is': 563,
#  'gottimatinn.is': 562,
#  'vm.is': 558,
#  'fases.is': 557,
#  'nytt.641.is': 550,
#  'sorli.is': 550,
#  'advania.is': 543,
#  'hirsla.lsh.is': 543,
#  'saemi7.blog.is': 542,
#  'tix.is': 540,
#  'kiwanis.is': 538,
#  'tigull.is': 537,
#  'ely.ro.is': 533,
#  'old.honnunarmidstod.is': 530,
#  'fasteignir.frettabladid.is': 530,
#  'skinna.is': 529,
#  'ikea.is': 528,
#  'eldhus.is': 527,
#  'heilsubankinn.is': 524,
#  'thingeyri.is': 524,
#  'fri.is': 518,
#  'mulathing.is': 516,
#  'vefir.mms.is': 514,
#  'ibn.is': 506,
#  'veitur.is': 505,
#  'midflokkurinn.is': 504,
#  'vatnajokulsthjodgardur.is': 504,
#  'heilsugaeslan.is': 504,
#  'sunnlenska.is': 503,
#  'verslun.tjorvar.is': 502,
#  'ticket2travel.is': 500,
#  'hanna.is': 500,
#  'foreldrajafnretti.is': 499,
#  'lhm.is': 494,
#  'lyfjastofnun.is': 489,
#  'hagstofa.is': 486,
#  'gljufrasteinn.is': 482,
#  'kraft.is': 480,
#  'oger.is': 479,
#  'harpa.blogg.is': 479,
#  'asi.is': 476,
#  'snb.is': 473,
#  'haskolautgafan.hi.is': 472,
#  'samherji.is': 466,
#  'hundalifspostur.is': 465,
#  'isor.is': 463,
#  'heradsdomstolar.is': 462,
#  'talknafjordur.is': 459,
#  'jenfo.blog.is': 458,
#  'ssnv.is': 458,
#  'mofi.blog.is': 457,
#  'heimilin.is': 455,
#  'kollajo.blog.is': 454,
#  'lyfja.is': 453,
#  'listasafnreykjavikur.is': 453,
#  'snerpa.is': 452,
#  'siv.is': 450,
#  'kvenrettindafelag.is': 450,
#  'gamli.kfia.is': 447,
#  'mmr.is': 446,
#  'mommur.is': 446,
#  'unwomen.is': 446,
#  'samradsgatt.island.is': 445,
#  'fritiminn.is': 445,
#  'lindaben.is': 445,
#  'hugarafl.is': 443,
#  'naestaskref.is': 442,
#  'hrafnista.is': 440,
#  'korfubolti.keflavik.is': 438,
#  'trj.blog.is': 437,
#  'eystrahorn.is': 434,
#  'hrokurinn.is': 433,
#  'svalbardsstrond.is': 433,
#  'sjova.is': 432,
#  'abcd.is': 432,
#  'ml.is': 432,
#  'adhd.is': 432,
#  'molinn62.123.is': 432,
#  'heilaheill.is': 430,
#  'sigsig.blog.is': 430,
#  'blonduos.is': 428,
#  'jonmagnusson.blog.is': 426,
#  'pallvil.blog.is': 425,
#  'oskarsson.is': 423,
#  'fme.is': 421,
#  'einkaskjol.is': 420,
#  'afangar.com': 419,
#  'archery.is': 419,
#  'gogg.is': 418,
#  'humanrights.is': 418,
#  'hlynurh.blog.is': 417,
#  'ferdalag.is': 416,
#  'old.bioparadis.is': 416,
#  'hlusta.is': 415,
#  'sambio.is': 415,
#  'no.is': 412,
#  'thjodmal.is': 412,
#  'volsungur.is': 412,
#  'olver.is': 412,
#  'sleipnir.is': 411,
#  'k100.mbl.is': 411,
#  'netnot.is': 409,
#  'aust.is': 407,
#  'fhg.blog.is': 407,
#  'kringlumyri.is': 407,
#  'geiragustsson.blog.is': 405,
#  'glerarkirkja.is': 402,
#  'logreglan.is': 401,
#  'omargeirsson.blog.is': 400,
#  'm.fotbolti.net': 400,
#  'coolshop.is': 400,
#  'frettatiminn.is': 399,
#  'herdis.blog.is': 399,
#  'island.is': 396,
#  'ljosid.is': 395,
#  'saudarkrokur.is': 395,
#  'landsbankinn.is': 394,
#  'brjostakrabbamein.is': 394,
#  'tibsen.blog.is': 394,
#  'roggi.eyjan.is': 393,
#  'www1.mms.is': 393,
#  'staging.frettabladid.is': 392,
#  'ahb.is': 392,
#  'maggib.blog.is': 391,
#  'baran.is': 390,
#  'va.is': 390,
#  'skjalasafn.is': 388,
#  'gudrunbergmann.is': 388,
#  'jsl210.com': 386,
#  'thingeyjarsveit.is': 385,
#  'handbolti.is': 385,
#  'skra.is': 385,
#  'postdoc.blog.is': 383,
#  'greining.is': 383,
#  'einarbb.blog.is': 383,
#  'romur.is': 380,
#  'utu.is': 380,
#  'vindashlid.is': 380,
#  'islandia.is': 378,
#  'lara.is': 378,
#  'infinite-electronic.is': 377,
#  'keilir.net': 375,
#  'tonis.is': 375,
#  'saa.is': 375,
#  'jsi.is': 375,
#  'starfsafl.is': 375,
#  'dec.is': 372,
#  'platonic.is': 370,
#  'gasamtokin.is': 370,
#  'efla.is': 369,
#  'stæ.is': 369,
#  'photo.blog.is': 368,
#  'netverslun.lyfja.is': 367,
#  'olinathorv.blog.is': 366,
#  'rikk.hi.is': 366,
#  'johanneliasson.blog.is': 365,
#  'thelamork.is': 364,
#  'sturla.is': 363,
#  'mr.is': 363,
#  'bhm.is': 363,
#  'esports.is': 362,
#  'dal.is': 358,
#  'vr.is': 357,
#  'borgarbyggd.is': 357,
#  'skaftfell.is': 356,
#  'arnastofnun.is': 356,
#  'drullusokkar.is': 353,
#  'tennissamband.is': 353,
#  'bjarnijonsson.blog.is': 352,
#  'islandsfengur.blog.is': 351,
#  'gamla.msund.is': 350,
#  'ibv.is': 349,
#  'ai.is': 349,
#  'emilhannes.blog.is': 349,
#  'hreysti.is': 347,
#  'nannar.blogspot.com': 344,
#  'thytur.123.is': 342,
#  'vorsteh.is': 341,
#  'bahai.is': 341,
#  'umfg.is': 339,
#  'is.petitions.net': 337,
#  'kari-hardarson.blog.is': 336,
#  'vertuuti.is': 336,
#  'matis.is': 336,
#  'hhfh.is': 335,
#  'fimak.is': 334,
#  'www2.rafis.is': 332,
#  'svth.is': 332,
#  'islandihnotskurn.is': 332,
#  'box12.is': 332,
#  'vatnaskogur.is': 329,
#  'rnh.is': 329,
#  'sund.keflavik.is': 326,
#  'sr.is': 326,
#  'namfullordinna.is': 325,
#  'listak.is': 324,
#  'bjartur-verold.is': 323,
#  'tonegilsstodum.fljotsdalsherad.is': 323,
#  'gydadrofn.com': 322,
#  'ferdalangur.net': 322,
#  'natkop.kopavogur.is': 322,
#  'toppfarar.is': 321,
#  'haraldsson.is': 321,
#  'grotta.is': 320,
#  'aflafrettir.is': 320,
#  'sudurnesjabaer.is': 320,
#  'kylfingur.is': 317,
#  'budardalur.is': 316,
#  'jonsig.123.is': 316,
#  '641.is': 316,
#  'paz.is': 315,
#  '49beaverbrook.blog.is': 314,
#  'fifuborg.is': 313,
#  'magnuss.blog.is': 312,
#  'ssne.is': 311,
#  'sigurdurmalari.hi.is': 309,
#  'rikkir.123.is': 309,
#  'mbl.is': 309,
#  'south.is': 307,
#  'neisti.net': 307,
#  'alda.is': 305,
#  'heilsa.is': 305,
#  'mms.is': 305,
#  'gba.is': 304,
#  'umss.is': 304,
#  'smygl.is': 304,
#  'hreinberg.is': 302,
#  'doktor.frettabladid.is': 302,
#  'sk2134.is': 301,
#  'grunnskoli.seltjarnarnes.is': 300,
#  'ojs.hi.is': 300,
#  'mjolnir.is': 298,
#  'logreglumenn.is': 298,
#  'medimarfasteignir.is': 297,
#  'leb.is': 297,
#  'fornleifur.blog.is': 295,
#  'breidablik.is': 295,
#  'sjodir.hi.is': 295,
#  'heilsuvera.is': 294,
#  'sass.is': 293,
#  'midborgin.is': 293,
#  'tjornin.is': 293,
#  'joiragnars.blog.is': 292,
#  'islandsmjoll.is': 291,
#  'bifrost.is': 290,
#  'skjolid.blog.is': 289,
#  'leor.123.is': 289,
#  'lifdutilfulls.is': 288,
#  'fitness.is': 286,
#  'halla.is': 286,
#  'jp.blog.is': 285,
#  'neway.mobi': 285,
#  'sigurlaug.arnarson.is': 282,
#  'sa.is': 281,
#  'bornogtonlist.net': 281,
#  'fridrik.eyjan.is': 281,
#  'x.piratar.is': 280,
#  'leidbeiningastod.is': 280,
#  'fiste.info': 280,
#  'riotinto.is': 279,
#  'homemaker.is': 279,
#  'xc.is': 279,
#  'stjornvisi.is': 279,
#  'unak.is': 279,
#  'airbnb.is': 277,
#  'veidikortid.is': 276,
#  'sff.nwc.is': 276,
#  'data.retriever.is': 275,
#  'varmarskoli.is': 274,
#  'gkb.nwc.is': 273,
#  'don.blog.is': 273,
#  'lmfi.is': 273,
#  'vopnafjordur.is': 273,
#  'sandgerdisskoli.is': 272,
#  'ksi.is': 272,
#  'biologia.is': 272,
#  'bjz.is': 272,
#  'umm.is': 271,
#  'gerumdaginngirnilegan.is': 270,
#  'eldadivesturheimi.com': 270,
#  'kvennakirkjan.is': 270,
#  'evaruza.is': 269,
#  'glatkistan.com': 269,
#  'hildigunnur.wordpress.com': 268,
#  'heraust.is': 268,
#  'msund.is': 267,
#  'uni.hi.is': 267,
#  'frizbee.vinirketils.com': 266,
#  'kai.is': 263,
#  'hjukrun.is': 263,
#  'fiskistofa.is': 262,
#  'dalir.is': 262,
#  'vefbirting.prentmetoddi.is': 261,
#  'ajvorulistinn.is': 261,
#  'skagafrettir.is': 260,
#  'thjodarheidur.blog.is': 260,
#  'fiskholl.blog.is': 259,
#  'styrktarfelag.is': 259,
#  'kgeysir.is': 257,
#  'heilsaogvellidan.com': 257,
#  'asatru.is': 257,
#  'hopkaup.is': 257,
#  'flensborg.is': 256,
#  'gamli.kki.is': 255,
#  'musik.is': 255,
#  'billinn.is': 254,
#  'irpa.is': 254,
#  'holmavik.123.is': 253,
#  'rmf.is': 253,
#  'tskoli.is': 252,
#  'ia.is': 252,
#  'kolsholt.123.is': 252,
#  'veidiflugur.is': 251,
#  'landsbokasafn.is': 251,
#  'handverkskunst.is': 250,
#  'oskubuska.is': 250,
#  'vinbudin.is': 250,
#  'sos.is': 250,
#  'fss.is': 248,
#  'kraftaheimar.internet.is': 247,
#  'karolinafund.com': 247,
#  'skak.blog.is': 247,
#  'islendingur.is': 247,
#  'ingolfurasgeirjohannesson.blog.is': 246,
#  'agny.blog.is': 246,
#  'heidmork.is': 245,
#  'kvenno.is': 245,
#  'ils.is': 245,
#  'gudbjornj.blog.is': 244,
#  'idan.is': 243,
#  'gurrihar.blog.is': 243,
#  'stapi.is': 242,
#  'holmasel.is': 241,
#  'utvarpsaga.is': 240,
#  'rafborg.is': 240,
#  'drgunni.wordpress.com': 238,
#  'fma.is': 238,
#  'flora-utgafa.is': 238,
#  'salir.is': 237,
#  'neminn.is': 237,
#  'fludir.is': 236,
#  'drangsnes.is': 236,
#  'safnahus.vestmannaeyjar.is': 236,
#  'raksig.blog.is': 235,
#  'skog.is': 234,
#  'simey.is': 233,
#  'ragnarfreyr.blog.is': 233,
#  'rebekkaeinars.is': 231,
#  'skardsdalur.is': 231,
#  'vis.is': 230,
#  'oddfellow.is': 230,
#  'heyiceland.is': 230,
#  'einhverfa.is': 229,
#  'tlh.haofeichemical.com': 229,
#  'netkirkja.is': 229,
#  'piratar.is': 228,
#  'fram.is': 227,
#  'sigurdurarni.is': 227,
#  'kolbrunb.blog.is': 227,
#  'bfl2015.net.dynamicweb-cms.com': 226,
#  'stakkaborg.is': 226,
#  'krumminn.is': 225,
#  'veidistadir.is': 225,
#  'heimssyn.blog.is': 224,
#  'deiglan.is': 223,
#  'pelli.blog.is': 223,
#  'bensi.is': 222,
#  'stjornuskodun.is': 222,
#  'midbaerinn.is': 222,
#  'baldvinj.blog.is': 221,
#  'hestnes.blogspot.com': 221,
#  'valgardur.blog': 221,
#  'hlf.blog.is': 221,
#  'uts.hi.is': 220,
#  'haukurn.blog.is': 220,
#  'gustafskulason.blog.is': 220,
#  'hross.blog.is': 220,
#  'listvinafelag.is': 219,
#  'arnorbl.blog.is': 219,
#  'noldrarinn.blog.is': 219,
#  'amnesty.is': 218,
#  'dolly.is': 218,
#  'kfs.is': 217,
#  'thorbergur.is': 217,
#  'is.ambafrance.org': 217,
#  'ssf.is': 216,
#  'kjalarpr.is': 215,
#  'gr.is': 215,
#  'parkinson.is': 215,
#  'gerpla.is': 214,
#  'ffar.is': 214,
#  'tl.is': 214,
#  'fimleikar.keflavik.is': 213,
#  'mni.is': 213,
#  'hmagasin.is': 213,
#  'htveir.is': 213,
#  'mh.is': 212,
#  'skoghf.is': 212,
#  'leikhusin.is': 212,
#  'leikhusid.is': 212,
#  'podcasts.apple.com': 211,
#  'taekwondo.keflavik.is': 211,
#  'visindi.is': 211,
#  'stinasaem.blogspot.com': 211,
#  'almanak.hi.is': 211,
#  'elnino.blog.is': 210,
#  'jondan.is': 210,
#  'kirkja.is': 210,
#  'saf.is': 209,
#  'f4x4.is': 209,
#  'markusth.blog.is': 209,
#  'lagasafn.hi.is': 208,
#  'skandall.is': 208,
#  'hundasamfelagid.is': 208,
#  'nna.is': 208,
#  'sjavarklasinn.is': 208,
#  'aegir.is': 208,
#  'scorpio.blog.is': 207,
#  'artasan.is': 206,
#  'hrundarblogg.blogspot.com': 206,
#  'visitakureyri.is': 206,
#  'husbilar.is': 206,
#  'heradsskjalasafn.is': 206,
#  'politik.is': 206,
#  'vefmyndavel.visitfjardabyggd.is': 206,
#  'mur.is': 205,
#  'iceberg.blog.is': 205,
#  'visitreykjanes.is': 205,
#  'hsl.is': 205,
#  'rakelhelmsdal.info': 205,
#  'eldhussogur.com': 204,
#  'smabatar.is': 204,
#  'kalak.is': 204,
#  'harhar33.blog.is': 204,
#  'lifvisindi.hi.is': 204,
#  'atlisteinn.is': 204,
#  'sigurbjorns.blog.is': 204,
#  'hask.landsbokasafn.is': 204,
#  'thorsteinnhgunnarsson.blog.is': 203,
#  'vestri.is': 202,
#  'thordisb.blog.is': 202,
#  'ira.is': 201,
#  'kattholt.is': 201,
#  'alvogen.is': 199,
#  'hverfid-mitt-2016.betrireykjavik.is': 199,
#  'tonak.is': 199,
#  'fjolnir.is': 199,
#  'thingvellir.is': 198,
#  'turisti.is': 197,
#  'lagafellbugardurfarmoghestarhorsespferd.123.is': 197,
#  'golf.is': 196,
#  'frettanetid.is': 196,
#  'thorsport.is': 196,
#  'kokteill.is': 195,
#  'nautabaninn.blog.is': 195,
#  'spitalinnokkar.is': 195,
#  'klefinn.is': 195,
#  'handritinheima.is': 194,
#  'astromix.blog.is': 194,
#  'pallijoh.blog.is': 194,
#  'fokusfelag.is': 192,
#  'systurogmakar.is': 192,
#  'thorkellhelgason.is': 192,
#  'landsnet.is': 192,
#  'golf1.is': 192,
#  'byggidn.is': 191,
#  'frimurarareglan.is': 191,
#  'blaskogabyggd.is': 191,
#  'gamla.fns.is': 191,
#  'frjalstland.is': 191,
#  'haust.is': 191,
#  'umbodsmadur.is': 190,
#  'bokmos.is': 190,
#  'eso.org': 190,
#  'redlion.blog.is': 190,
#  'gonguleidir.is': 189,
#  'live.is': 189,
#  'hamarsport.is': 189,
#  'kraftur.org': 189,
#  'silliogvaldi.is': 188,
#  'steini.is': 188,
#  'arni.eyjan.is': 188,
#  'fvsa.is': 188,
#  'arniogkristin.is': 186,
#  'hallkelsstadahlid.is': 186,
#  'fit.is': 186,
#  'spurs.is': 186,
#  '640.is': 186,
#  'slf.is': 185,
#  'vinnumalastofnun.is': 185,
#  'skautasamband.is': 185,
#  'thot.is': 184,
#  'breidholtsfrettir.is': 184,
#  'linde-gas.is': 184,
#  'thrainn.eyjan.is': 184,
#  'selfosskarfa.is': 184,
#  'bil.is': 183,
#  'jardvis.hi.is': 183,
#  'forlagid.is': 183,
#  'digicoll.library.wisc.edu': 182,
#  'fjolaogmoli.blogspot.com': 182,
#  'jafnretti.is': 181,
#  'evropa.blog.is': 181,
#  'asthildurcesil.blog.is': 181,
#  'sogurogsagnir.is': 181,
#  'skogur.is': 181,
#  'diabetes.is': 181,
#  'hvest.is': 180,
#  'ungarathafnakonur.is': 180,
#  'lady.is': 180,
#  'islenskt.is': 180,
#  'skrif.hi.is': 179,
#  'vefuppskriftir.com': 179,
#  'en.ni.is': 179,
#  'funamenn.is': 179,
#  'jaj.blog.is': 179,
#  'hjolafrettir.is': 178,
#  'smore.com': 178,
#  'honnunarsafn.is': 178,
#  'agustolafur.blog.is': 178,
#  'undirborginni.blog.is': 177,
#  'rotin.is': 177,
#  'fiskeldisbladid.is': 177,
#  'npa.is': 176,
#  'eddaagn.blog.is': 176,
#  'frjalstland.blog.is': 176,
#  'skatarnir.is': 175,
#  'boltinn.is': 175,
#  'agbjarn.blog.is': 175,
#  'axelaxelsson.blog.is': 175,
#  'ek.blogg.is': 175,
#  'krabb.is': 175,
#  'svonafolk.is': 174,
#  'skritin.is': 174,
#  'minjasafn.is': 174,
#  'utl.is': 174,
#  'lestu.is': 174,
#  'neytendatorg.is': 174,
#  'estro.blog.is': 173,
#  'vinirvatnajokuls.is': 173,
#  'vulkan.blog.is': 173,
#  'studentabladid.com': 173,
#  'ollasak.blog.is': 172,
#  'allskonar.is': 172,
#  'utivist.is': 172,
#  'nilli.blog.is': 172,
#  'skidalvik.is': 172,
#  'blogg.bakvordur.is': 172,
#  'tmm.forlagid.is': 171,
#  'booking.com': 171,
#  'piratar.betraisland.is': 171,
#  'kka.is': 171,
#  'mynd.blog.is': 170,
#  'aldish.blogspot.com': 170,
#  'leikhus.is': 170,
#  'husmus.is': 170,
#  'tonlistarsafn.is': 169,
#  'gaeludyr.is': 169,
#  'aventura.is': 169,
#  'heimspeki.hi.is': 169,
#  'lifogheil.hi.is': 169,
#  'sibs.is': 169,
#  'neistar.is': 169,
#  'xs.is': 169,
#  'skald.is': 169,
#  'geimurinn.is': 169,
#  'brimborg.is': 169,
#  'nautaskra.net': 168,
#  'gys.is': 168,
#  'hronnsig.blog.is': 167,
#  'nytjaland.is': 167,
#  'stefanjon.is': 167,
#  'seltjarnarneskirkja.is': 167,
#  'kristina.anomy.net': 166,
#  'forvarnir.is': 166,
#  'mataraudur.is': 166,
#  'landakirkja.is': 166,
#  'gaflarar.com': 165,
#  'lsr.is': 165,
#  'vinnueftirlit.is': 165,
#  'flugubullan.is': 165,
#  'transatlantic.is': 165,
#  'akademia.is': 164,
#  'amare.is': 164,
#  'kjolur.is': 163,
#  'naustaskoli.is': 163,
#  'stjornsyslustofnun.hi.is': 163,
#  'listagil.is': 163,
#  'karfan.is': 163,
#  'or.is': 163,
#  'dalviksport.is': 162,
#  'skuggsja.is': 162,
#  'heimsveldi.blogspot.com': 162,
#  'aurorafoundation.is': 161,
#  'vigdis.hi.is': 161,
#  'skattalagasafn.is': 161,
#  'vilborg.is': 161,
#  'laupur.is': 160,
#  'heilsumal.is': 160,
#  'hvatisport.is': 160,
#  'uw.is': 160,
#  'verd.lyfjastofnun.is': 160,
#  'unicef.is': 160,
#  'silfurgeitin.wordpress.com': 160,
#  'ingama.blog.is': 160,
#  'kvika.is': 160,
#  'mistur.is': 160,
#  'eidfaxi.is': 159,
#  'mannvirkjastofnun.is': 159,
#  'seydisfjardarskoli.sfk.is': 159,
#  'stefangisla.com': 158,
#  'veidin.is': 158,
#  'fle.is': 158,
#  'kaktusinn.is': 158,
#  'isak.123.is': 157,
#  'bergthoraga.blog.is': 157,
#  'ibh.is': 157,
#  'miklaborg.is': 157,
#  'varrius.blogspot.com': 156,
#  'roggur.blog.is': 156,
#  'garminbudin.is': 156,
#  'iv.is': 156,
#  'eything.com': 156,
#  'asutgafan.is': 156,
#  'mortenl.blog.is': 155,
#  'ov.is': 155,
#  'aldarafmaeli.hi.is': 155,
#  'dalbjorg.is': 155,
#  'ja.is': 154,
#  'askja.blog.is': 154,
#  'frisk.blog.is': 154,
#  'rathlaup.is': 154,
#  'gthg.blog.is': 154,
#  'sjukra.is': 154,
#  ...}

# %%
# Calculate domain distribution
domain_distribution = pd.DataFrame({"domain": list(df.domain.value_counts().to_dict().keys()), "frequency":list(df.domain.value_counts().to_dict().values())})
domain_distribution
# Out:
#                  domain  frequency
# 0              visir.is      34272
# 1               hugi.is      26494
# 2                 vb.is      22817
# 3             sarpur.is      17137
# 4        austurfrett.is      14261
# ...                 ...        ...
# 14020            hfh.is          1
# 14021    songbok.web.is          1
# 14022            nmm.is          1
# 14023  hfp.kopavogur.is          1
# 14024     secure.rsk.is          1
#
# [14025 rows x 2 columns]

# %%
# Discard instances with frequency less than 10
domain_distribution = domain_distribution[domain_distribution["frequency"] > 9]

domain_distribution.shape
# Out:
# (5431, 2)

# %% [markdown]
# I first discarded domains with less than 10 texts, then calculated the median. The remaining number of domains was 5,431.

# %%
# Find the median
domain_distribution.frequency.describe()
# Out:
# count     5431.000000
# mean       217.582213
# std       1038.590171
# min         10.000000
# 25%         17.000000
# 50%         35.000000
# 75%        100.000000
# max      34272.000000
# Name: frequency, dtype: float64

# %% [markdown]
# The median number of texts per domain is 35. Now, I'll take 500 domains with frequency below this number and 500 domains with frequency above this number. I'll split the dataset into two based on the median.

# %%
domain_distribution.head()
# Out:
#            domain  frequency
# 0        visir.is      34272
# 1         hugi.is      26494
# 2           vb.is      22817
# 3       sarpur.is      17137
# 4  austurfrett.is      14261

# %%
top_domain_distribution = domain_distribution[domain_distribution["frequency"] > 35]
top_domain_distribution.shape
# Out:
# (2698, 2)

# %%
bottom_domain_distribution = domain_distribution[domain_distribution["frequency"] < 35]
bottom_domain_distribution.shape
# Out:
# (2697, 2)

# %%
# Take a random sample from top and random sample from bottom
top_domain_distribution = top_domain_distribution.sample(n=500)
top_domain_distribution.shape
# Out:
# (500, 2)

# %%
top_domain_distribution["frequency"].describe()
# Out:
# count      500.000000
# mean       481.548000
# std       1826.161286
# min         36.000000
# 25%         59.000000
# 50%        109.000000
# 75%        252.500000
# max      26494.000000
# Name: frequency, dtype: float64

# %%
bottom_domain_distribution = bottom_domain_distribution.sample(n=500)
bottom_domain_distribution.head()
# Out:
#                  domain  frequency
# 3647  old.eldsveitir.is         21
# 5159      skeljungur.is         11
# 3199      harabanar.com         26
# 3431       uniqueart.is         23
# 3387            lysi.is         24

# %%
# Join the dataframes
domain_sample = pd.concat([top_domain_distribution, bottom_domain_distribution])
domain_sample.describe(include="all")
# Out:
#            domain     frequency
# count        1000   1000.000000
# unique       1000           NaN
# top     motivm.is           NaN
# freq            1           NaN
# mean          NaN    249.906000
# std           NaN   1311.296635
# min           NaN     10.000000
# 25%           NaN     17.000000
# 50%           NaN     35.000000
# 75%           NaN    109.000000
# max           NaN  26494.000000

# %%
# Create a list of domains
domain_sample_list = domain_sample.domain.to_list()
domain_sample_list[:10]
# Out:
# ['motivm.is',
#  'hox.is',
#  'yehi.is',
#  'emobi.is',
#  'gildi.is',
#  'sigsig.blog.is',
#  'barky.blog.is',
#  'logos.blog.is',
#  'heilsugaeslan.is',
#  'rustikus.blog.is']

# %%
# For each domain, sample out 10 texts from the initial dataframe

# First create the initial df to which all others in the loop will be added
final_sample = df[df["domain"] == domain_sample_list[0]].sample(n=10)

final_sample
# Out:
#            domain                                      url
# 64094   motivm.is        http://www.motivm.is/pictures/104
# 249612  motivm.is  http://motivm.is/blog/yearmonth/2006/09
# 55017   motivm.is             http://motivm.is/pictures/13
# 55920   motivm.is             http://motivm.is/pictures/49
# 52964   motivm.is         http://www.motivm.is/pictures/21
# 52980   motivm.is         http://www.motivm.is/pictures/57
# 51748   motivm.is         http://www.motivm.is/pictures/74
# 48987   motivm.is         http://www.motivm.is/pictures/14
# 51738   motivm.is             http://motivm.is/pictures/73
# 66213   motivm.is        http://www.motivm.is/pictures/114

# %%
# Add all other domains
remaining_list = domain_sample_list[1:]

for i in remaining_list:
	added_instances = df[df["domain"] == i].sample(n=10)
	final_sample = pd.concat([final_sample, added_instances])

final_sample.shape
# Out:
# (10000, 2)

# %%
final_sample.describe()
# Out:
#            domain                                url
# count       10000                              10000
# unique       1000                              10000
# top     motivm.is  http://www.motivm.is/pictures/104
# freq           10                                  1

# %% [markdown]
# The final sample has 10.000 instances from 1000 domains.

# %%
# Save the df
final_sample.to_csv("MaCoCu-is-sample-domains-and-urls.csv", sep="\t")

# %% [markdown]
# ## Extract the text from the TMX based on the URL list

# %%
# Open the df with domains and urls for the sample
final_sample = pd.read_csv("MaCoCu-is-sample-domains-and-urls.csv", sep="\t", index_col = 0)

final_sample.head(2)
# Out:
#            domain                                      url
# 64094   motivm.is        http://www.motivm.is/pictures/104
# 249612  motivm.is  http://motivm.is/blog/yearmonth/2006/09

# %%
final_sample.shape
# Out:
# (10000, 2)

# %%
# Create a list of urls in the sample
url_list = list(final_sample["url"].unique())
url_list[:10]
# Out:
# ['http://www.motivm.is/pictures/104',
#  'http://motivm.is/blog/yearmonth/2006/09',
#  'http://motivm.is/pictures/13',
#  'http://motivm.is/pictures/49',
#  'http://www.motivm.is/pictures/21',
#  'http://www.motivm.is/pictures/57',
#  'http://www.motivm.is/pictures/74',
#  'http://www.motivm.is/pictures/14',
#  'http://motivm.is/pictures/73',
#  'http://www.motivm.is/pictures/114']

# %%
len(url_list)
# Out:
# 10000

# %%
# Now that I have the URL list, I will extract texts from the MaCoCu-is.xml.gz for the sample based on the URL list.

text_all_counter = 0

texts_all = []

for line in tqdm(file):
	if line.startswith("<doc"):
		current_text = []
		pure_text = ""
		text_string = ""
		current_url = ""
		current_domain = ""
		current_url = url_re.search(line).group(1)
		current_domain = domain_re.search(line).group(1)
		text_string += line
	elif line.startswith("<p"):
		text_string += line
	elif line.startswith("</p"):
		text_string += line
	elif line.startswith("</doc"):
		text_string += line
		if current_url in url_list:
			current_text = [current_domain, current_url, pure_text, text_string]
			texts_all.append(current_text)
			text_all_counter += 1
	elif line.startswith("<corpus"):
		continue
	elif line.startswith("</corpus"):
		continue
	else:
		text_string += line
		pure_text += line
# Out:
# 51972334it [04:54, 176291.14it/s]

# %%
text_all_counter
# Out:
# 10000

# %%
# Create a dataframe out of the text file

df_long_texts = pd.DataFrame({"domain": [x[0] for x in texts_all], "url": [x[1] for x in texts_all], "text": [x[2] for x in texts_all],"doc": [x[3] for x in texts_all]})

df_long_texts.head()
# Out:
#    domain                 url  \
# 0   ft.is      https://ft.is/
# 1  pfi.is  http://www.pfi.is/
# 2  sfa.is     https://sfa.is/
# 3  hrt.is     https://hrt.is/
# 4  kfh.is     https://kfh.is/
#
#                                                 text  \
# 0  Félag Tölvunarfræðinga\nMarkmið félagsins er a...
# 1  Stefnt er að því að halda þessa fundi í septem...
# 2  Samtök forstöðumanna almenningsbókasafna\nSamt...
# 3  Hreinsun gatna og gangstétta\nHreinsitækni er ...
# 4  Kæru félagar, við viljum vekja athygli á að sa...
#
#                                                  doc
# 0  <doc id="macocu.is.97" title="Félag Tölvunarfr...
# 1  <doc id="macocu.is.142" title="Póstmannafélag ...
# 2  <doc id="macocu.is.143" title="Samtök forstöðu...
# 3  <doc id="macocu.is.179" title="Hreinsitækni eh...
# 4  <doc id="macocu.is.202" title="KFH | Kristileg...

# %%
df_long_texts.describe(include="all")
# Out:
#        domain             url  \
# count   10000           10000
# unique   1000           10000
# top     ft.is  https://ft.is/
# freq       10               1
#
#                                                      text  \
# count                                               10000
# unique                                              10000
# top     Félag Tölvunarfræðinga\nMarkmið félagsins er a...
# freq                                                    1
#
#                                                       doc
# count                                               10000
# unique                                              10000
# top     <doc id="macocu.is.97" title="Félag Tölvunarfr...
# freq                                                    1

# %%
df_long_texts.domain.value_counts()
# Out:
# ft.is                   10
# grodrarstod.is          10
# gudfinnur.blog.is       10
# skagafrettir.is         10
# hreysti.is              10
#                         ..
# unnurkaren.com          10
# steingerdur.com         10
# salud68.blogspot.com    10
# al.is                   10
# bilasolur.is            10
# Name: domain, Length: 1000, dtype: int64

# %%
# Add information on length
df_long_texts["length"] = df_long_texts["text"].str.split().str.len()

df_long_texts.head()
# Out:
#    domain                 url  \
# 0   ft.is      https://ft.is/
# 1  pfi.is  http://www.pfi.is/
# 2  sfa.is     https://sfa.is/
# 3  hrt.is     https://hrt.is/
# 4  kfh.is     https://kfh.is/
#
#                                                 text  \
# 0  Félag Tölvunarfræðinga\nMarkmið félagsins er a...
# 1  Stefnt er að því að halda þessa fundi í septem...
# 2  Samtök forstöðumanna almenningsbókasafna\nSamt...
# 3  Hreinsun gatna og gangstétta\nHreinsitækni er ...
# 4  Kæru félagar, við viljum vekja athygli á að sa...
#
#                                                  doc  length
# 0  <doc id="macocu.is.97" title="Félag Tölvunarfr...     255
# 1  <doc id="macocu.is.142" title="Póstmannafélag ...     304
# 2  <doc id="macocu.is.143" title="Samtök forstöðu...     421
# 3  <doc id="macocu.is.179" title="Hreinsitækni eh...     244
# 4  <doc id="macocu.is.202" title="KFH | Kristileg...    3156

# %%
df_long_texts["length"].describe()
# Out:
# count    10000.000000
# mean       582.432400
# std       1707.816705
# min         76.000000
# 25%        126.000000
# 50%        225.000000
# 75%        485.000000
# max      79573.000000
# Name: length, dtype: float64

# %%
# Save the final sample
df_long_texts.to_csv("MaCoCu-is-sample.csv", sep="\t")
