# %% [markdown]
# Import all necessary libraries and install everything you need for training:

# %%
# install the libraries necessary for data wrangling, prediction and result analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from numba import cuda
from itertools import islice
import time
from tqdm import tqdm

# %%
# Install transformers
# (this needs to be done on Kaggle each time you start the session)
#!pip install -q transformers

# Install the simpletransformers
#!pip install -q simpletransformers
from simpletransformers.classification import ClassificationModel

# Install wandb
#!pip install -q wandb
import wandb

# Login to wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tajak (use `wandb login --relogin` to force relogin)
# True

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Import the MaCoCu sample

dataset = pd.read_csv("MaCoCu-sl-sample.csv", sep="\t", index_col = 0)
dataset.head(2)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124

# %%
dataset.describe(include="all")
# Out:
#         domain                                 url  \
# count    10010                               10010
# unique    1001                                9991
# top     ahp.si  https://psj.ff.uni-lj.si/obvestila
# freq        10                                   2
# mean       NaN                                 NaN
# std        NaN                                 NaN
# min        NaN                                 NaN
# 25%        NaN                                 NaN
# 50%        NaN                                 NaN
# 75%        NaN                                 NaN
# max        NaN                                 NaN
#
#                                                      text  \
# count                                               10010
# unique                                              10010
# top     Bolnica za živali Postojna\nBolnica za živali ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       doc       length
# count                                               10010  10010.00000
# unique                                              10010          NaN
# top     <doc id="macocu.si.221" title="Domov | Bolnica...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    412.45025
# std                                                   NaN    891.60650
# min                                                   NaN     76.00000
# 25%                                                   NaN    122.00000
# 50%                                                   NaN    213.00000
# 75%                                                   NaN    418.00000
# max                                                   NaN  30002.00000

# %% [markdown]
# ## Apply classifier

# %% [markdown]
# Models used:
# - FTD classifier - original FTD data (except multi-labeled texts and non-text texts) - 10 categories, 849 instances in training data
# - GINCO-downcast classifier - used primary_level_4 downcasted GINCO labels - 9 labels. It was trained on 601 texts.
# - CORE-main classifier - main categories only - 9 instances. All texts with multiple labels were discarded. It was trained on 10256 instances.
# - GINCO X-GENRE classifier - 9 X-GENRE labels. It was trained on 535 texts (10% texts discarded - belonging to "discarded" labels)
# - FTD X-GENRE classifier - 7 X-GENRE labels. It was trained on 630 texts (23% texts were discarded).
# - CORE X-GENRE classifier - 9 X-GENRE labels. It was trained on 607 texts - large changes to the dataset were performed (change of distribution, taking only a sample to have a similar size as FTD and GINCO).
# - X-GENRE classifier - 9 X-GENRE labels. Trained on the training splits of all of the X-GENRE datasets mentioned above: 1772 instances in the training dataset.

# %% [markdown]
# ### Functions

# %%
def define_model(model_name):
	"""
	Define which model you want to use and download it.
	Args:
	- model_name: choose from "FTD", "GINCO", "CORE", "GINCO-X-GENRE", "FTD-X-GENRE", "CORE-X-GENRE", "X-GENRE"
	"""
	if model_name == "FTD":
		# Initialize Wandb: 
		run = wandb.init(project="FTD-learning-manual-hyperparameter-search", entity="tajak", name="applying-predictions-on-MaCoCu")

		# Load the FTD model from Wandb:
		artifact = run.use_artifact('tajak/FTD-learning-manual-hyperparameter-search/FTD-classifier:v1', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)

	elif model_name == "GINCO":
		# Initialize Wandb: 
		run = wandb.init(project="GINCO-hyperparameter-search", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the GINCO-downcast model from Wandb:
		artifact = run.use_artifact('tajak/GINCO-hyperparameter-search/GINCO-downcast-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "CORE":
		# Initialize Wandb: 
		run = wandb.init(project="CORE-hyperparameter-search", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the CORE-main model from Wandb:
		artifact = run.use_artifact('tajak/CORE-hyperparameter-search/CORE-main-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "GINCO-X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the GINCO-X-GENRE model from Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/SI-GINCO-X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "FTD-X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		#To load the FTD-X-GENRE model from Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/FTD-X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "CORE-X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		# To access the model from the Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/CORE-X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)
	elif model_name == "X-GENRE":
		# Initialize Wandb - for X-GENRE classifiers: 
		run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")

		# To access the model from the Wandb:
		artifact = run.use_artifact('tajak/X-GENRE classifiers/X-GENRE-classifier:v0', type='model')
		artifact_dir = artifact.download()

		# Loading a local save
		model = ClassificationModel(
			"xlmroberta", artifact_dir)

	return model

# %%
def predict(dataset, model, model_name):
	"""
	This function takes the dataset and applies the trained model on it to infer predictions.
	It saves the results to a new csv file.

	Args:
	- dataset (pandas DataFrame): dataset to apply prediction on. The text we want to predict should be in the column "text".
	- model: the model to use
	- model_name: the name of the classifier
	"""
	# Silence the model
	model.args.silent = True

	labels = model.args.labels_list

	# Split the dataframe into batches

	def chunk(arr_range, arr_size):
		arr_range = iter(arr_range)
		return iter(lambda: tuple(islice(arr_range, arr_size)), ())

	batches_list = list(chunk(dataset.text, 8))

	batches_list_new = []

	for i in batches_list:
		batches_list_new.append(list(i))

	print("The dataset is split into {} batches of {} texts.".format(len(batches_list_new),len(batches_list_new[0])))

	# Apply softmax to the raw outputs
	def softmax(x):
		#Compute softmax values for each sets of scores in x.
		return np.exp(x) / np.sum(np.exp(x), axis=0)

	y_pred = []
	y_distr = []
	most_probable = []
	batch_counter = 0

	print(f"Prediction with model {model_name} started.")
	start_time = time.time()

	for i in tqdm(batches_list_new):
		output = model.predict(i)
		current_y_pred = output[0]
		current_y_distr = output[1]
		current_y_distr_softmax = []
		current_y_distr_most_probable = []
		for i in current_y_distr:
			distr = softmax(i)
			distr_dict = {labels[i]: round(distr[i],4) for i in range(len(labels))}
			current_y_distr_softmax.append(distr_dict)
			# Also add the information for the softmax of the most probable category ("certainty")
			distr_sorted = np.sort(distr)
			current_y_distr_most_probable.append(distr_sorted[-1])

		for i in current_y_pred:
			y_pred.append(i)

		for i in current_y_distr_softmax:
			y_distr.append(i)

		for i in current_y_distr_most_probable:
			most_probable.append(i)

		batch_counter += 1
		#print("Batch {} predicted.".format(batch_counter))

	prediction_time = round((time.time() - start_time)/60,2)

	print("Prediction with model {} completed. It took {} minutes for {} instances - {} minutes per one instance.".format(model_name, prediction_time, dataset.shape[0], prediction_time/dataset.shape[0]))

	dataset[f"{model_name}"] = y_pred
	dataset[f"{model_name}_label_distribution"] = y_distr
	dataset[f"{model_name}_confidence"] = most_probable

	# Save the new dataframe which contains the y_pred values as well
	dataset.to_csv("MaCoCu-sl-sample-prediction-{}".format(model_name), sep="\t")

	return dataset

# %% [markdown]
# ### Prediction

# %% [markdown]
# #### FTD

# %%
FTD = define_model("FTD")

# Define labels
FTD_labels = [7, 8, 0, 1, 6, 5, 2, 4, 3, 9]

ftd_mapping = {'A1 (argumentative)': 0, 'A11 (personal)': 1, 'A12 (promotion)': 2, 'A14 (academic)': 3, 'A16 (information)': 4, 'A17 (review)': 5, 'A4 (fiction)': 6, 'A7 (instruction)': 7, 'A8 (news)': 8, 'A9 (legal)': 9}

ftd_mapping_reverse = {list(ftd_mapping.values())[i]: list(ftd_mapping.keys())[i] for i in range(len(list(ftd_mapping.values())))}
# Out:
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_134608-28y6u2dr</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/FTD-learning-manual-hyperparameter-search/runs/28y6u2dr" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/FTD-learning-manual-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact FTD-classifier:v1, 1081.90MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
# Predict FTD to the dataset
dataset = predict(dataset, FTD, "FTD", FTD_labels)
# Out:
# The dataset is split into 1252 batches of 8 texts.
# Prediction with model FTD started.
# Batch 1 predicted.
# Batch 2 predicted.
# Batch 3 predicted.
# Batch 4 predicted.
# Batch 5 predicted.
# Batch 6 predicted.
# Batch 7 predicted.
# Batch 8 predicted.
# Batch 9 predicted.
# Batch 10 predicted.
# Batch 11 predicted.
# Batch 12 predicted.
# Batch 13 predicted.
# Batch 14 predicted.
# Batch 15 predicted.
# Batch 16 predicted.
# Batch 17 predicted.
# Batch 18 predicted.
# Batch 19 predicted.
# Batch 20 predicted.
# Batch 21 predicted.
# Batch 22 predicted.
# Batch 23 predicted.
# Batch 24 predicted.
# Batch 25 predicted.
# Batch 26 predicted.
# Batch 27 predicted.
# Batch 28 predicted.
# Batch 29 predicted.
# Batch 30 predicted.
# Batch 31 predicted.
# Batch 32 predicted.
# Batch 33 predicted.
# Batch 34 predicted.
# Batch 35 predicted.
# Batch 36 predicted.
# Batch 37 predicted.
# Batch 38 predicted.
# Batch 39 predicted.
# Batch 40 predicted.
# Batch 41 predicted.
# Batch 42 predicted.
# Batch 43 predicted.
# Batch 44 predicted.
# Batch 45 predicted.
# Batch 46 predicted.
# Batch 47 predicted.
# Batch 48 predicted.
# Batch 49 predicted.
# Batch 50 predicted.
# Batch 51 predicted.
# Batch 52 predicted.
# Batch 53 predicted.
# Batch 54 predicted.
# Batch 55 predicted.
# Batch 56 predicted.
# Batch 57 predicted.
# Batch 58 predicted.
# Batch 59 predicted.
# Batch 60 predicted.
# Batch 61 predicted.
# Batch 62 predicted.
# Batch 63 predicted.
# Batch 64 predicted.
# Batch 65 predicted.
# Batch 66 predicted.
# Batch 67 predicted.
# Batch 68 predicted.
# Batch 69 predicted.
# Batch 70 predicted.
# Batch 71 predicted.
# Batch 72 predicted.
# Batch 73 predicted.
# Batch 74 predicted.
# Batch 75 predicted.
# Batch 76 predicted.
# Batch 77 predicted.
# Batch 78 predicted.
# Batch 79 predicted.
# Batch 80 predicted.
# Batch 81 predicted.
# Batch 82 predicted.
# Batch 83 predicted.
# Batch 84 predicted.
# Batch 85 predicted.
# Batch 86 predicted.
# Batch 87 predicted.
# Batch 88 predicted.
# Batch 89 predicted.
# Batch 90 predicted.
# Batch 91 predicted.
# Batch 92 predicted.
# Batch 93 predicted.
# Batch 94 predicted.
# Batch 95 predicted.
# Batch 96 predicted.
# Batch 97 predicted.
# Batch 98 predicted.
# Batch 99 predicted.
# Batch 100 predicted.
# Batch 101 predicted.
# Batch 102 predicted.
# Batch 103 predicted.
# Batch 104 predicted.
# Batch 105 predicted.
# Batch 106 predicted.
# Batch 107 predicted.
# Batch 108 predicted.
# Batch 109 predicted.
# Batch 110 predicted.
# Batch 111 predicted.
# Batch 112 predicted.
# Batch 113 predicted.
# Batch 114 predicted.
# Batch 115 predicted.
# Batch 116 predicted.
# Batch 117 predicted.
# Batch 118 predicted.
# Batch 119 predicted.
# Batch 120 predicted.
# Batch 121 predicted.
# Batch 122 predicted.
# Batch 123 predicted.
# Batch 124 predicted.
# Batch 125 predicted.
# Batch 126 predicted.
# Batch 127 predicted.
# Batch 128 predicted.
# Batch 129 predicted.
# Batch 130 predicted.
# Batch 131 predicted.
# Batch 132 predicted.
# Batch 133 predicted.
# Batch 134 predicted.
# Batch 135 predicted.
# Batch 136 predicted.
# Batch 137 predicted.
# Batch 138 predicted.
# Batch 139 predicted.
# Batch 140 predicted.
# Batch 141 predicted.
# Batch 142 predicted.
# Batch 143 predicted.
# Batch 144 predicted.
# Batch 145 predicted.
# Batch 146 predicted.
# Batch 147 predicted.
# Batch 148 predicted.
# Batch 149 predicted.
# Batch 150 predicted.
# Batch 151 predicted.
# Batch 152 predicted.
# Batch 153 predicted.
# Batch 154 predicted.
# Batch 155 predicted.
# Batch 156 predicted.
# Batch 157 predicted.
# Batch 158 predicted.
# Batch 159 predicted.
# Batch 160 predicted.
# Batch 161 predicted.
# Batch 162 predicted.
# Batch 163 predicted.
# Batch 164 predicted.
# Batch 165 predicted.
# Batch 166 predicted.
# Batch 167 predicted.
# Batch 168 predicted.
# Batch 169 predicted.
# Batch 170 predicted.
# Batch 171 predicted.
# Batch 172 predicted.
# Batch 173 predicted.
# Batch 174 predicted.
# Batch 175 predicted.
# Batch 176 predicted.
# Batch 177 predicted.
# Batch 178 predicted.
# Batch 179 predicted.
# Batch 180 predicted.
# Batch 181 predicted.
# Batch 182 predicted.
# Batch 183 predicted.
# Batch 184 predicted.
# Batch 185 predicted.
# Batch 186 predicted.
# Batch 187 predicted.
# Batch 188 predicted.
# Batch 189 predicted.
# Batch 190 predicted.
# Batch 191 predicted.
# Batch 192 predicted.
# Batch 193 predicted.
# Batch 194 predicted.
# Batch 195 predicted.
# Batch 196 predicted.
# Batch 197 predicted.
# Batch 198 predicted.
# Batch 199 predicted.
# Batch 200 predicted.
# Batch 201 predicted.
# Batch 202 predicted.
# Batch 203 predicted.
# Batch 204 predicted.
# Batch 205 predicted.
# Batch 206 predicted.
# Batch 207 predicted.
# Batch 208 predicted.
# Batch 209 predicted.
# Batch 210 predicted.
# Batch 211 predicted.
# Batch 212 predicted.
# Batch 213 predicted.
# Batch 214 predicted.
# Batch 215 predicted.
# Batch 216 predicted.
# Batch 217 predicted.
# Batch 218 predicted.
# Batch 219 predicted.
# Batch 220 predicted.
# Batch 221 predicted.
# Batch 222 predicted.
# Batch 223 predicted.
# Batch 224 predicted.
# Batch 225 predicted.
# Batch 226 predicted.
# Batch 227 predicted.
# Batch 228 predicted.
# Batch 229 predicted.
# Batch 230 predicted.
# Batch 231 predicted.
# Batch 232 predicted.
# Batch 233 predicted.
# Batch 234 predicted.
# Batch 235 predicted.
# Batch 236 predicted.
# Batch 237 predicted.
# Batch 238 predicted.
# Batch 239 predicted.
# Batch 240 predicted.
# Batch 241 predicted.
# Batch 242 predicted.
# Batch 243 predicted.
# Batch 244 predicted.
# Batch 245 predicted.
# Batch 246 predicted.
# Batch 247 predicted.
# Batch 248 predicted.
# Batch 249 predicted.
# Batch 250 predicted.
# Batch 251 predicted.
# Batch 252 predicted.
# Batch 253 predicted.
# Batch 254 predicted.
# Batch 255 predicted.
# Batch 256 predicted.
# Batch 257 predicted.
# Batch 258 predicted.
# Batch 259 predicted.
# Batch 260 predicted.
# Batch 261 predicted.
# Batch 262 predicted.
# Batch 263 predicted.
# Batch 264 predicted.
# Batch 265 predicted.
# Batch 266 predicted.
# Batch 267 predicted.
# Batch 268 predicted.
# Batch 269 predicted.
# Batch 270 predicted.
# Batch 271 predicted.
# Batch 272 predicted.
# Batch 273 predicted.
# Batch 274 predicted.
# Batch 275 predicted.
# Batch 276 predicted.
# Batch 277 predicted.
# Batch 278 predicted.
# Batch 279 predicted.
# Batch 280 predicted.
# Batch 281 predicted.
# Batch 282 predicted.
# Batch 283 predicted.
# Batch 284 predicted.
# Batch 285 predicted.
# Batch 286 predicted.
# Batch 287 predicted.
# Batch 288 predicted.
# Batch 289 predicted.
# Batch 290 predicted.
# Batch 291 predicted.
# Batch 292 predicted.
# Batch 293 predicted.
# Batch 294 predicted.
# Batch 295 predicted.
# Batch 296 predicted.
# Batch 297 predicted.
# Batch 298 predicted.
# Batch 299 predicted.
# Batch 300 predicted.
# Batch 301 predicted.
# Batch 302 predicted.
# Batch 303 predicted.
# Batch 304 predicted.
# Batch 305 predicted.
# Batch 306 predicted.
# Batch 307 predicted.
# Batch 308 predicted.
# Batch 309 predicted.
# Batch 310 predicted.
# Batch 311 predicted.
# Batch 312 predicted.
# Batch 313 predicted.
# Batch 314 predicted.
# Batch 315 predicted.
# Batch 316 predicted.
# Batch 317 predicted.
# Batch 318 predicted.
# Batch 319 predicted.
# Batch 320 predicted.
# Batch 321 predicted.
# Batch 322 predicted.
# Batch 323 predicted.
# Batch 324 predicted.
# Batch 325 predicted.
# Batch 326 predicted.
# Batch 327 predicted.
# Batch 328 predicted.
# Batch 329 predicted.
# Batch 330 predicted.
# Batch 331 predicted.
# Batch 332 predicted.
# Batch 333 predicted.
# Batch 334 predicted.
# Batch 335 predicted.
# Batch 336 predicted.
# Batch 337 predicted.
# Batch 338 predicted.
# Batch 339 predicted.
# Batch 340 predicted.
# Batch 341 predicted.
# Batch 342 predicted.
# Batch 343 predicted.
# Batch 344 predicted.
# Batch 345 predicted.
# Batch 346 predicted.
# Batch 347 predicted.
# Batch 348 predicted.
# Batch 349 predicted.
# Batch 350 predicted.
# Batch 351 predicted.
# Batch 352 predicted.
# Batch 353 predicted.
# Batch 354 predicted.
# Batch 355 predicted.
# Batch 356 predicted.
# Batch 357 predicted.
# Batch 358 predicted.
# Batch 359 predicted.
# Batch 360 predicted.
# Batch 361 predicted.
# Batch 362 predicted.
# Batch 363 predicted.
# Batch 364 predicted.
# Batch 365 predicted.
# Batch 366 predicted.
# Batch 367 predicted.
# Batch 368 predicted.
# Batch 369 predicted.
# Batch 370 predicted.
# Batch 371 predicted.
# Batch 372 predicted.
# Batch 373 predicted.
# Batch 374 predicted.
# Batch 375 predicted.
# Batch 376 predicted.
# Batch 377 predicted.
# Batch 378 predicted.
# Batch 379 predicted.
# Batch 380 predicted.
# Batch 381 predicted.
# Batch 382 predicted.
# Batch 383 predicted.
# Batch 384 predicted.
# Batch 385 predicted.
# Batch 386 predicted.
# Batch 387 predicted.
# Batch 388 predicted.
# Batch 389 predicted.
# Batch 390 predicted.
# Batch 391 predicted.
# Batch 392 predicted.
# Batch 393 predicted.
# Batch 394 predicted.
# Batch 395 predicted.
# Batch 396 predicted.
# Batch 397 predicted.
# Batch 398 predicted.
# Batch 399 predicted.
# Batch 400 predicted.
# Batch 401 predicted.
# Batch 402 predicted.
# Batch 403 predicted.
# Batch 404 predicted.
# Batch 405 predicted.
# Batch 406 predicted.
# Batch 407 predicted.
# Batch 408 predicted.
# Batch 409 predicted.
# Batch 410 predicted.
# Batch 411 predicted.
# Batch 412 predicted.
# Batch 413 predicted.
# Batch 414 predicted.
# Batch 415 predicted.
# Batch 416 predicted.
# Batch 417 predicted.
# Batch 418 predicted.
# Batch 419 predicted.
# Batch 420 predicted.
# Batch 421 predicted.
# Batch 422 predicted.
# Batch 423 predicted.
# Batch 424 predicted.
# Batch 425 predicted.
# Batch 426 predicted.
# Batch 427 predicted.
# Batch 428 predicted.
# Batch 429 predicted.
# Batch 430 predicted.
# Batch 431 predicted.
# Batch 432 predicted.
# Batch 433 predicted.
# Batch 434 predicted.
# Batch 435 predicted.
# Batch 436 predicted.
# Batch 437 predicted.
# Batch 438 predicted.
# Batch 439 predicted.
# Batch 440 predicted.
# Batch 441 predicted.
# Batch 442 predicted.
# Batch 443 predicted.
# Batch 444 predicted.
# Batch 445 predicted.
# Batch 446 predicted.
# Batch 447 predicted.
# Batch 448 predicted.
# Batch 449 predicted.
# Batch 450 predicted.
# Batch 451 predicted.
# Batch 452 predicted.
# Batch 453 predicted.
# Batch 454 predicted.
# Batch 455 predicted.
# Batch 456 predicted.
# Batch 457 predicted.
# Batch 458 predicted.
# Batch 459 predicted.
# Batch 460 predicted.
# Batch 461 predicted.
# Batch 462 predicted.
# Batch 463 predicted.
# Batch 464 predicted.
# Batch 465 predicted.
# Batch 466 predicted.
# Batch 467 predicted.
# Batch 468 predicted.
# Batch 469 predicted.
# Batch 470 predicted.
# Batch 471 predicted.
# Batch 472 predicted.
# Batch 473 predicted.
# Batch 474 predicted.
# Batch 475 predicted.
# Batch 476 predicted.
# Batch 477 predicted.
# Batch 478 predicted.
# Batch 479 predicted.
# Batch 480 predicted.
# Batch 481 predicted.
# Batch 482 predicted.
# Batch 483 predicted.
# Batch 484 predicted.
# Batch 485 predicted.
# Batch 486 predicted.
# Batch 487 predicted.
# Batch 488 predicted.
# Batch 489 predicted.
# Batch 490 predicted.
# Batch 491 predicted.
# Batch 492 predicted.
# Batch 493 predicted.
# Batch 494 predicted.
# Batch 495 predicted.
# Batch 496 predicted.
# Batch 497 predicted.
# Batch 498 predicted.
# Batch 499 predicted.
# Batch 500 predicted.
# Batch 501 predicted.
# Batch 502 predicted.
# Batch 503 predicted.
# Batch 504 predicted.
# Batch 505 predicted.
# Batch 506 predicted.
# Batch 507 predicted.
# Batch 508 predicted.
# Batch 509 predicted.
# Batch 510 predicted.
# Batch 511 predicted.
# Batch 512 predicted.
# Batch 513 predicted.
# Batch 514 predicted.
# Batch 515 predicted.
# Batch 516 predicted.
# Batch 517 predicted.
# Batch 518 predicted.
# Batch 519 predicted.
# Batch 520 predicted.
# Batch 521 predicted.
# Batch 522 predicted.
# Batch 523 predicted.
# Batch 524 predicted.
# Batch 525 predicted.
# Batch 526 predicted.
# Batch 527 predicted.
# Batch 528 predicted.
# Batch 529 predicted.
# Batch 530 predicted.
# Batch 531 predicted.
# Batch 532 predicted.
# Batch 533 predicted.
# Batch 534 predicted.
# Batch 535 predicted.
# Batch 536 predicted.
# Batch 537 predicted.
# Batch 538 predicted.
# Batch 539 predicted.
# Batch 540 predicted.
# Batch 541 predicted.
# Batch 542 predicted.
# Batch 543 predicted.
# Batch 544 predicted.
# Batch 545 predicted.
# Batch 546 predicted.
# Batch 547 predicted.
# Batch 548 predicted.
# Batch 549 predicted.
# Batch 550 predicted.
# Batch 551 predicted.
# Batch 552 predicted.
# Batch 553 predicted.
# Batch 554 predicted.
# Batch 555 predicted.
# Batch 556 predicted.
# Batch 557 predicted.
# Batch 558 predicted.
# Batch 559 predicted.
# Batch 560 predicted.
# Batch 561 predicted.
# Batch 562 predicted.
# Batch 563 predicted.
# Batch 564 predicted.
# Batch 565 predicted.
# Batch 566 predicted.
# Batch 567 predicted.
# Batch 568 predicted.
# Batch 569 predicted.
# Batch 570 predicted.
# Batch 571 predicted.
# Batch 572 predicted.
# Batch 573 predicted.
# Batch 574 predicted.
# Batch 575 predicted.
# Batch 576 predicted.
# Batch 577 predicted.
# Batch 578 predicted.
# Batch 579 predicted.
# Batch 580 predicted.
# Batch 581 predicted.
# Batch 582 predicted.
# Batch 583 predicted.
# Batch 584 predicted.
# Batch 585 predicted.
# Batch 586 predicted.
# Batch 587 predicted.
# Batch 588 predicted.
# Batch 589 predicted.
# Batch 590 predicted.
# Batch 591 predicted.
# Batch 592 predicted.
# Batch 593 predicted.
# Batch 594 predicted.
# Batch 595 predicted.
# Batch 596 predicted.
# Batch 597 predicted.
# Batch 598 predicted.
# Batch 599 predicted.
# Batch 600 predicted.
# Batch 601 predicted.
# Batch 602 predicted.
# Batch 603 predicted.
# Batch 604 predicted.
# Batch 605 predicted.
# Batch 606 predicted.
# Batch 607 predicted.
# Batch 608 predicted.
# Batch 609 predicted.
# Batch 610 predicted.
# Batch 611 predicted.
# Batch 612 predicted.
# Batch 613 predicted.
# Batch 614 predicted.
# Batch 615 predicted.
# Batch 616 predicted.
# Batch 617 predicted.
# Batch 618 predicted.
# Batch 619 predicted.
# Batch 620 predicted.
# Batch 621 predicted.
# Batch 622 predicted.
# Batch 623 predicted.
# Batch 624 predicted.
# Batch 625 predicted.
# Batch 626 predicted.
# Batch 627 predicted.
# Batch 628 predicted.
# Batch 629 predicted.
# Batch 630 predicted.
# Batch 631 predicted.
# Batch 632 predicted.
# Batch 633 predicted.
# Batch 634 predicted.
# Batch 635 predicted.
# Batch 636 predicted.
# Batch 637 predicted.
# Batch 638 predicted.
# Batch 639 predicted.
# Batch 640 predicted.
# Batch 641 predicted.
# Batch 642 predicted.
# Batch 643 predicted.
# Batch 644 predicted.
# Batch 645 predicted.
# Batch 646 predicted.
# Batch 647 predicted.
# Batch 648 predicted.
# Batch 649 predicted.
# Batch 650 predicted.
# Batch 651 predicted.
# Batch 652 predicted.
# Batch 653 predicted.
# Batch 654 predicted.
# Batch 655 predicted.
# Batch 656 predicted.
# Batch 657 predicted.
# Batch 658 predicted.
# Batch 659 predicted.
# Batch 660 predicted.
# Batch 661 predicted.
# Batch 662 predicted.
# Batch 663 predicted.
# Batch 664 predicted.
# Batch 665 predicted.
# Batch 666 predicted.
# Batch 667 predicted.
# Batch 668 predicted.
# Batch 669 predicted.
# Batch 670 predicted.
# Batch 671 predicted.
# Batch 672 predicted.
# Batch 673 predicted.
# Batch 674 predicted.
# Batch 675 predicted.
# Batch 676 predicted.
# Batch 677 predicted.
# Batch 678 predicted.
# Batch 679 predicted.
# Batch 680 predicted.
# Batch 681 predicted.
# Batch 682 predicted.
# Batch 683 predicted.
# Batch 684 predicted.
# Batch 685 predicted.
# Batch 686 predicted.
# Batch 687 predicted.
# Batch 688 predicted.
# Batch 689 predicted.
# Batch 690 predicted.
# Batch 691 predicted.
# Batch 692 predicted.
# Batch 693 predicted.
# Batch 694 predicted.
# Batch 695 predicted.
# Batch 696 predicted.
# Batch 697 predicted.
# Batch 698 predicted.
# Batch 699 predicted.
# Batch 700 predicted.
# Batch 701 predicted.
# Batch 702 predicted.
# Batch 703 predicted.
# Batch 704 predicted.
# Batch 705 predicted.
# Batch 706 predicted.
# Batch 707 predicted.
# Batch 708 predicted.
# Batch 709 predicted.
# Batch 710 predicted.
# Batch 711 predicted.
# Batch 712 predicted.
# Batch 713 predicted.
# Batch 714 predicted.
# Batch 715 predicted.
# Batch 716 predicted.
# Batch 717 predicted.
# Batch 718 predicted.
# Batch 719 predicted.
# Batch 720 predicted.
# Batch 721 predicted.
# Batch 722 predicted.
# Batch 723 predicted.
# Batch 724 predicted.
# Batch 725 predicted.
# Batch 726 predicted.
# Batch 727 predicted.
# Batch 728 predicted.
# Batch 729 predicted.
# Batch 730 predicted.
# Batch 731 predicted.
# Batch 732 predicted.
# Batch 733 predicted.
# Batch 734 predicted.
# Batch 735 predicted.
# Batch 736 predicted.
# Batch 737 predicted.
# Batch 738 predicted.
# Batch 739 predicted.
# Batch 740 predicted.
# Batch 741 predicted.
# Batch 742 predicted.
# Batch 743 predicted.
# Batch 744 predicted.
# Batch 745 predicted.
# Batch 746 predicted.
# Batch 747 predicted.
# Batch 748 predicted.
# Batch 749 predicted.
# Batch 750 predicted.
# Batch 751 predicted.
# Batch 752 predicted.
# Batch 753 predicted.
# Batch 754 predicted.
# Batch 755 predicted.
# Batch 756 predicted.
# Batch 757 predicted.
# Batch 758 predicted.
# Batch 759 predicted.
# Batch 760 predicted.
# Batch 761 predicted.
# Batch 762 predicted.
# Batch 763 predicted.
# Batch 764 predicted.
# Batch 765 predicted.
# Batch 766 predicted.
# Batch 767 predicted.
# Batch 768 predicted.
# Batch 769 predicted.
# Batch 770 predicted.
# Batch 771 predicted.
# Batch 772 predicted.
# Batch 773 predicted.
# Batch 774 predicted.
# Batch 775 predicted.
# Batch 776 predicted.
# Batch 777 predicted.
# Batch 778 predicted.
# Batch 779 predicted.
# Batch 780 predicted.
# Batch 781 predicted.
# Batch 782 predicted.
# Batch 783 predicted.
# Batch 784 predicted.
# Batch 785 predicted.
# Batch 786 predicted.
# Batch 787 predicted.
# Batch 788 predicted.
# Batch 789 predicted.
# Batch 790 predicted.
# Batch 791 predicted.
# Batch 792 predicted.
# Batch 793 predicted.
# Batch 794 predicted.
# Batch 795 predicted.
# Batch 796 predicted.
# Batch 797 predicted.
# Batch 798 predicted.
# Batch 799 predicted.
# Batch 800 predicted.
# Batch 801 predicted.
# Batch 802 predicted.
# Batch 803 predicted.
# Batch 804 predicted.
# Batch 805 predicted.
# Batch 806 predicted.
# Batch 807 predicted.
# Batch 808 predicted.
# Batch 809 predicted.
# Batch 810 predicted.
# Batch 811 predicted.
# Batch 812 predicted.
# Batch 813 predicted.
# Batch 814 predicted.
# Batch 815 predicted.
# Batch 816 predicted.
# Batch 817 predicted.
# Batch 818 predicted.
# Batch 819 predicted.
# Batch 820 predicted.
# Batch 821 predicted.
# Batch 822 predicted.
# Batch 823 predicted.
# Batch 824 predicted.
# Batch 825 predicted.
# Batch 826 predicted.
# Batch 827 predicted.
# Batch 828 predicted.
# Batch 829 predicted.
# Batch 830 predicted.
# Batch 831 predicted.
# Batch 832 predicted.
# Batch 833 predicted.
# Batch 834 predicted.
# Batch 835 predicted.
# Batch 836 predicted.
# Batch 837 predicted.
# Batch 838 predicted.
# Batch 839 predicted.
# Batch 840 predicted.
# Batch 841 predicted.
# Batch 842 predicted.
# Batch 843 predicted.
# Batch 844 predicted.
# Batch 845 predicted.
# Batch 846 predicted.
# Batch 847 predicted.
# Batch 848 predicted.
# Batch 849 predicted.
# Batch 850 predicted.
# Batch 851 predicted.
# Batch 852 predicted.
# Batch 853 predicted.
# Batch 854 predicted.
# Batch 855 predicted.
# Batch 856 predicted.
# Batch 857 predicted.
# Batch 858 predicted.
# Batch 859 predicted.
# Batch 860 predicted.
# Batch 861 predicted.
# Batch 862 predicted.
# Batch 863 predicted.
# Batch 864 predicted.
# Batch 865 predicted.
# Batch 866 predicted.
# Batch 867 predicted.
# Batch 868 predicted.
# Batch 869 predicted.
# Batch 870 predicted.
# Batch 871 predicted.
# Batch 872 predicted.
# Batch 873 predicted.
# Batch 874 predicted.
# Batch 875 predicted.
# Batch 876 predicted.
# Batch 877 predicted.
# Batch 878 predicted.
# Batch 879 predicted.
# Batch 880 predicted.
# Batch 881 predicted.
# Batch 882 predicted.
# Batch 883 predicted.
# Batch 884 predicted.
# Batch 885 predicted.
# Batch 886 predicted.
# Batch 887 predicted.
# Batch 888 predicted.
# Batch 889 predicted.
# Batch 890 predicted.
# Batch 891 predicted.
# Batch 892 predicted.
# Batch 893 predicted.
# Batch 894 predicted.
# Batch 895 predicted.
# Batch 896 predicted.
# Batch 897 predicted.
# Batch 898 predicted.
# Batch 899 predicted.
# Batch 900 predicted.
# Batch 901 predicted.
# Batch 902 predicted.
# Batch 903 predicted.
# Batch 904 predicted.
# Batch 905 predicted.
# Batch 906 predicted.
# Batch 907 predicted.
# Batch 908 predicted.
# Batch 909 predicted.
# Batch 910 predicted.
# Batch 911 predicted.
# Batch 912 predicted.
# Batch 913 predicted.
# Batch 914 predicted.
# Batch 915 predicted.
# Batch 916 predicted.
# Batch 917 predicted.
# Batch 918 predicted.
# Batch 919 predicted.
# Batch 920 predicted.
# Batch 921 predicted.
# Batch 922 predicted.
# Batch 923 predicted.
# Batch 924 predicted.
# Batch 925 predicted.
# Batch 926 predicted.
# Batch 927 predicted.
# Batch 928 predicted.
# Batch 929 predicted.
# Batch 930 predicted.
# Batch 931 predicted.
# Batch 932 predicted.
# Batch 933 predicted.
# Batch 934 predicted.
# Batch 935 predicted.
# Batch 936 predicted.
# Batch 937 predicted.
# Batch 938 predicted.
# Batch 939 predicted.
# Batch 940 predicted.
# Batch 941 predicted.
# Batch 942 predicted.
# Batch 943 predicted.
# Batch 944 predicted.
# Batch 945 predicted.
# Batch 946 predicted.
# Batch 947 predicted.
# Batch 948 predicted.
# Batch 949 predicted.
# Batch 950 predicted.
# Batch 951 predicted.
# Batch 952 predicted.
# Batch 953 predicted.
# Batch 954 predicted.
# Batch 955 predicted.
# Batch 956 predicted.
# Batch 957 predicted.
# Batch 958 predicted.
# Batch 959 predicted.
# Batch 960 predicted.
# Batch 961 predicted.
# Batch 962 predicted.
# Batch 963 predicted.
# Batch 964 predicted.
# Batch 965 predicted.
# Batch 966 predicted.
# Batch 967 predicted.
# Batch 968 predicted.
# Batch 969 predicted.
# Batch 970 predicted.
# Batch 971 predicted.
# Batch 972 predicted.
# Batch 973 predicted.
# Batch 974 predicted.
# Batch 975 predicted.
# Batch 976 predicted.
# Batch 977 predicted.
# Batch 978 predicted.
# Batch 979 predicted.
# Batch 980 predicted.
# Batch 981 predicted.
# Batch 982 predicted.
# Batch 983 predicted.
# Batch 984 predicted.
# Batch 985 predicted.
# Batch 986 predicted.
# Batch 987 predicted.
# Batch 988 predicted.
# Batch 989 predicted.
# Batch 990 predicted.
# Batch 991 predicted.
# Batch 992 predicted.
# Batch 993 predicted.
# Batch 994 predicted.
# Batch 995 predicted.
# Batch 996 predicted.
# Batch 997 predicted.
# Batch 998 predicted.
# Batch 999 predicted.
# Batch 1000 predicted.
# Batch 1001 predicted.
# Batch 1002 predicted.
# Batch 1003 predicted.
# Batch 1004 predicted.
# Batch 1005 predicted.
# Batch 1006 predicted.
# Batch 1007 predicted.
# Batch 1008 predicted.
# Batch 1009 predicted.
# Batch 1010 predicted.
# Batch 1011 predicted.
# Batch 1012 predicted.
# Batch 1013 predicted.
# Batch 1014 predicted.
# Batch 1015 predicted.
# Batch 1016 predicted.
# Batch 1017 predicted.
# Batch 1018 predicted.
# Batch 1019 predicted.
# Batch 1020 predicted.
# Batch 1021 predicted.
# Batch 1022 predicted.
# Batch 1023 predicted.
# Batch 1024 predicted.
# Batch 1025 predicted.
# Batch 1026 predicted.
# Batch 1027 predicted.
# Batch 1028 predicted.
# Batch 1029 predicted.
# Batch 1030 predicted.
# Batch 1031 predicted.
# Batch 1032 predicted.
# Batch 1033 predicted.
# Batch 1034 predicted.
# Batch 1035 predicted.
# Batch 1036 predicted.
# Batch 1037 predicted.
# Batch 1038 predicted.
# Batch 1039 predicted.
# Batch 1040 predicted.
# Batch 1041 predicted.
# Batch 1042 predicted.
# Batch 1043 predicted.
# Batch 1044 predicted.
# Batch 1045 predicted.
# Batch 1046 predicted.
# Batch 1047 predicted.
# Batch 1048 predicted.
# Batch 1049 predicted.
# Batch 1050 predicted.
# Batch 1051 predicted.
# Batch 1052 predicted.
# Batch 1053 predicted.
# Batch 1054 predicted.
# Batch 1055 predicted.
# Batch 1056 predicted.
# Batch 1057 predicted.
# Batch 1058 predicted.
# Batch 1059 predicted.
# Batch 1060 predicted.
# Batch 1061 predicted.
# Batch 1062 predicted.
# Batch 1063 predicted.
# Batch 1064 predicted.
# Batch 1065 predicted.
# Batch 1066 predicted.
# Batch 1067 predicted.
# Batch 1068 predicted.
# Batch 1069 predicted.
# Batch 1070 predicted.
# Batch 1071 predicted.
# Batch 1072 predicted.
# Batch 1073 predicted.
# Batch 1074 predicted.
# Batch 1075 predicted.
# Batch 1076 predicted.
# Batch 1077 predicted.
# Batch 1078 predicted.
# Batch 1079 predicted.
# Batch 1080 predicted.
# Batch 1081 predicted.
# Batch 1082 predicted.
# Batch 1083 predicted.
# Batch 1084 predicted.
# Batch 1085 predicted.
# Batch 1086 predicted.
# Batch 1087 predicted.
# Batch 1088 predicted.
# Batch 1089 predicted.
# Batch 1090 predicted.
# Batch 1091 predicted.
# Batch 1092 predicted.
# Batch 1093 predicted.
# Batch 1094 predicted.
# Batch 1095 predicted.
# Batch 1096 predicted.
# Batch 1097 predicted.
# Batch 1098 predicted.
# Batch 1099 predicted.
# Batch 1100 predicted.
# Batch 1101 predicted.
# Batch 1102 predicted.
# Batch 1103 predicted.
# Batch 1104 predicted.
# Batch 1105 predicted.
# Batch 1106 predicted.
# Batch 1107 predicted.
# Batch 1108 predicted.
# Batch 1109 predicted.
# Batch 1110 predicted.
# Batch 1111 predicted.
# Batch 1112 predicted.
# Batch 1113 predicted.
# Batch 1114 predicted.
# Batch 1115 predicted.
# Batch 1116 predicted.
# Batch 1117 predicted.
# Batch 1118 predicted.
# Batch 1119 predicted.
# Batch 1120 predicted.
# Batch 1121 predicted.
# Batch 1122 predicted.
# Batch 1123 predicted.
# Batch 1124 predicted.
# Batch 1125 predicted.
# Batch 1126 predicted.
# Batch 1127 predicted.
# Batch 1128 predicted.
# Batch 1129 predicted.
# Batch 1130 predicted.
# Batch 1131 predicted.
# Batch 1132 predicted.
# Batch 1133 predicted.
# Batch 1134 predicted.
# Batch 1135 predicted.
# Batch 1136 predicted.
# Batch 1137 predicted.
# Batch 1138 predicted.
# Batch 1139 predicted.
# Batch 1140 predicted.
# Batch 1141 predicted.
# Batch 1142 predicted.
# Batch 1143 predicted.
# Batch 1144 predicted.
# Batch 1145 predicted.
# Batch 1146 predicted.
# Batch 1147 predicted.
# Batch 1148 predicted.
# Batch 1149 predicted.
# Batch 1150 predicted.
# Batch 1151 predicted.
# Batch 1152 predicted.
# Batch 1153 predicted.
# Batch 1154 predicted.
# Batch 1155 predicted.
# Batch 1156 predicted.
# Batch 1157 predicted.
# Batch 1158 predicted.
# Batch 1159 predicted.
# Batch 1160 predicted.
# Batch 1161 predicted.
# Batch 1162 predicted.
# Batch 1163 predicted.
# Batch 1164 predicted.
# Batch 1165 predicted.
# Batch 1166 predicted.
# Batch 1167 predicted.
# Batch 1168 predicted.
# Batch 1169 predicted.
# Batch 1170 predicted.
# Batch 1171 predicted.
# Batch 1172 predicted.
# Batch 1173 predicted.
# Batch 1174 predicted.
# Batch 1175 predicted.
# Batch 1176 predicted.
# Batch 1177 predicted.
# Batch 1178 predicted.
# Batch 1179 predicted.
# Batch 1180 predicted.
# Batch 1181 predicted.
# Batch 1182 predicted.
# Batch 1183 predicted.
# Batch 1184 predicted.
# Batch 1185 predicted.
# Batch 1186 predicted.
# Batch 1187 predicted.
# Batch 1188 predicted.
# Batch 1189 predicted.
# Batch 1190 predicted.
# Batch 1191 predicted.
# Batch 1192 predicted.
# Batch 1193 predicted.
# Batch 1194 predicted.
# Batch 1195 predicted.
# Batch 1196 predicted.
# Batch 1197 predicted.
# Batch 1198 predicted.
# Batch 1199 predicted.
# Batch 1200 predicted.
# Batch 1201 predicted.
# Batch 1202 predicted.
# Batch 1203 predicted.
# Batch 1204 predicted.
# Batch 1205 predicted.
# Batch 1206 predicted.
# Batch 1207 predicted.
# Batch 1208 predicted.
# Batch 1209 predicted.
# Batch 1210 predicted.
# Batch 1211 predicted.
# Batch 1212 predicted.
# Batch 1213 predicted.
# Batch 1214 predicted.
# Batch 1215 predicted.
# Batch 1216 predicted.
# Batch 1217 predicted.
# Batch 1218 predicted.
# Batch 1219 predicted.
# Batch 1220 predicted.
# Batch 1221 predicted.
# Batch 1222 predicted.
# Batch 1223 predicted.
# Batch 1224 predicted.
# Batch 1225 predicted.
# Batch 1226 predicted.
# Batch 1227 predicted.
# Batch 1228 predicted.
# Batch 1229 predicted.
# Batch 1230 predicted.
# Batch 1231 predicted.
# Batch 1232 predicted.
# Batch 1233 predicted.
# Batch 1234 predicted.
# Batch 1235 predicted.
# Batch 1236 predicted.
# Batch 1237 predicted.
# Batch 1238 predicted.
# Batch 1239 predicted.
# Batch 1240 predicted.
# Batch 1241 predicted.
# Batch 1242 predicted.
# Batch 1243 predicted.
# Batch 1244 predicted.
# Batch 1245 predicted.
# Batch 1246 predicted.
# Batch 1247 predicted.
# Batch 1248 predicted.
# Batch 1249 predicted.
# Batch 1250 predicted.
# Batch 1251 predicted.
# Batch 1252 predicted.
# Prediction with model FTD completed. It took 23.79 minutes for 10010 instances - 0.0023766233766233766 minutes per one instance.

# %%
dataset.head(3)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
# 2  osi.si  https://www.osi.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
# 2  OSI je podjetje z dolgoletnimi izkušnjami na p...
#
#                                                  doc  length  FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841    2
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124    2
# 2  <doc id="macocu.si.712" title="OSI sistemske i...     173    2
#
#                               FTD_label_distribution  FTD_confidence
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
# 2  {7: 0.0132, 8: 0.0125, 0: 0.0184, 1: 0.006, 6:...        0.899391

# %%
# Map the FTD labels to names
dataset["FTD"] = [ftd_mapping_reverse[x] for x in dataset["FTD"]]

dataset.head(3)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
# 2  osi.si  https://www.osi.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
# 2  OSI je podjetje z dolgoletnimi izkušnjami na p...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841  A12 (promotion)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
# 2  <doc id="macocu.si.712" title="OSI sistemske i...     173  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
# 2  {7: 0.0132, 8: 0.0125, 0: 0.0184, 1: 0.006, 6:...        0.899391

# %%
# At the end of each prediction and before downloading the next model, delete the previous one from the folder to release space.

# Remove previous classifier
# %rm -rf wandb
# %rm -rf artifacts

# %%
# Save the dataset with results
dataset.to_csv("MaCoCu-sl_with_predictions.csv", sep="\t")

# %% [markdown]
# #### Loop through other classifiers

# %%
def prediction_pipeline(model_name, dataset):
	"""Choose from ["GINCO", "CORE", "GINCO-X-GENRE", "FTD-X-GENRE", "CORE-X-GENRE", "X-GENRE"]"""

	# Define the model
	model = define_model(model_name)

	# Predict genre labels to the dataset
	dataset = predict(dataset, model, model_name)

	# Before downloading the next model, delete the previous one to release space.
	# %rm -rf wandb
	# %rm -rf artifacts

# %%
prediction_pipeline("GINCO", dataset)
# Out:
# Finishing last run (ID:1pm1k7zu) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">applying-predictions-on-MaCoCu</strong>: <a href="https://wandb.ai/tajak/GINCO-hyperparameter-search/runs/1pm1k7zu" target="_blank">https://wandb.ai/tajak/GINCO-hyperparameter-search/runs/1pm1k7zu</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221118_144255-1pm1k7zu/logs</code>
# Successfully finished last run (ID:1pm1k7zu). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_144344-j6iwdddu</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/GINCO-hyperparameter-search/runs/j6iwdddu" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/GINCO-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact GINCO-downcast-classifier:v0, 1081.89MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1252 batches of 8 texts.
# Prediction with model GINCO started.
# 100%|██████████| 1252/1252 [32:14<00:00,  1.54s/it]
# Prediction with model GINCO completed. It took 32.23 minutes for 10010 instances - 0.0032197802197802194 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841  A12 (promotion)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence
# 0  {'Forum': 0.0017, 'News/Reporting': 0.0019, 'O...          0.954012
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...          0.919409

# %%
prediction_pipeline("CORE", dataset)
# Out:
# Finishing last run (ID:j6iwdddu) before initializing another...
# Successfully finished last run (ID:j6iwdddu). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_151941-oslosrdd</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/CORE-hyperparameter-search/runs/oslosrdd" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/CORE-hyperparameter-search" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact CORE-main-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1252 batches of 8 texts.
# Prediction with model CORE started.
# 100%|██████████| 1252/1252 [23:54<00:00,  1.15s/it]
# Prediction with model CORE completed. It took 23.9 minutes for 10010 instances - 0.0023876123876123874 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841  A12 (promotion)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0017, 'News/Reporting': 0.0019, 'O...          0.954012
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...          0.919409
#
#                                     CORE  \
# 0  Informational Description/Explanation
# 1  Informational Description/Explanation
#
#                              CORE_label_distribution  CORE_confidence
# 0  {'Interactive Discussion': 0.0013, 'Narrative'...         0.958831
# 1  {'Interactive Discussion': 0.0251, 'Narrative'...         0.650196

# %%
dataset.CORE.value_counts(normalize=True)
# Out:
# Informational Description/Explanation    0.670130
# Informational Persuasion                 0.122577
# Narrative                                0.096803
# How-To/Instructional                     0.051648
# Opinion                                  0.036563
# Interactive Discussion                   0.012587
# Spoken                                   0.005994
# Lyrical                                  0.003696
# Name: CORE, dtype: float64

# %%
prediction_pipeline("GINCO-X-GENRE", dataset)
# Out:
# Finishing last run (ID:oslosrdd) before initializing another...
# Successfully finished last run (ID:oslosrdd). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_154455-286r8zkx</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/286r8zkx" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact SI-GINCO-X-GENRE-classifier:v0, 1081.88MB. 44 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1252 batches of 8 texts.
# Prediction with model GINCO-X-GENRE started.
# 100%|██████████| 1252/1252 [24:20<00:00,  1.17s/it]
# Prediction with model GINCO-X-GENRE completed. It took 24.35 minutes for 10010 instances - 0.002432567432567433 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841  A12 (promotion)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0017, 'News/Reporting': 0.0019, 'O...          0.954012
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...          0.919409
#
#                                     CORE  \
# 0  Informational Description/Explanation
# 1  Informational Description/Explanation
#
#                              CORE_label_distribution  CORE_confidence  \
# 0  {'Interactive Discussion': 0.0013, 'Narrative'...         0.958831
# 1  {'Interactive Discussion': 0.0251, 'Narrative'...         0.650196
#
#   GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0     Promotion  {'Information/Explanation': 0.001, 'Opinion/Ar...
# 1     Promotion  {'Information/Explanation': 0.0029, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence
# 0                  0.992724
# 1                  0.984429

# %%
dataset["GINCO-X-GENRE"].value_counts(normalize=True)
# Out:
# Promotion                  0.481718
# Information/Explanation    0.146354
# News                       0.125175
# Opinion/Argumentation      0.090310
# Instruction                0.072428
# Other                      0.059640
# Forum                      0.013586
# Legal                      0.009291
# Prose/Lyrical              0.001499
# Name: GINCO-X-GENRE, dtype: float64

# %%
prediction_pipeline("FTD-X-GENRE", dataset)
# Out:
# Finishing last run (ID:286r8zkx) before initializing another...
# Successfully finished last run (ID:286r8zkx). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_161113-eewlcopo</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/eewlcopo" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact FTD-X-GENRE-classifier:v0, 1081.88MB. 44 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1252 batches of 8 texts.
# Prediction with model FTD-X-GENRE started.
# 100%|██████████| 1252/1252 [23:54<00:00,  1.15s/it]
# Prediction with model FTD-X-GENRE completed. It took 23.9 minutes for 10010 instances - 0.0023876123876123874 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841  A12 (promotion)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  GINCO_confidence  \
# 0  {'Forum': 0.0017, 'News/Reporting': 0.0019, 'O...          0.954012
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...          0.919409
#
#                                     CORE  \
# 0  Informational Description/Explanation
# 1  Informational Description/Explanation
#
#                              CORE_label_distribution  CORE_confidence  \
# 0  {'Interactive Discussion': 0.0013, 'Narrative'...         0.958831
# 1  {'Interactive Discussion': 0.0251, 'Narrative'...         0.650196
#
#   GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0     Promotion  {'Information/Explanation': 0.001, 'Opinion/Ar...
# 1     Promotion  {'Information/Explanation': 0.0029, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence FTD-X-GENRE  \
# 0                  0.992724   Promotion
# 1                  0.984429   Promotion
#
#                       FTD-X-GENRE_label_distribution  FTD-X-GENRE_confidence
# 0  {'Promotion': 0.9176, 'Opinion/Argumentation':...                0.917588
# 1  {'Promotion': 0.4754, 'Opinion/Argumentation':...                0.475421

# %%
dataset["FTD-X-GENRE"].value_counts(normalize=True)
# Out:
# Promotion                  0.654645
# Information/Explanation    0.157642
# News                       0.063536
# Instruction                0.058242
# Opinion/Argumentation      0.031069
# Legal                      0.027173
# Prose/Lyrical              0.007692
# Name: FTD-X-GENRE, dtype: float64

# %%
prediction_pipeline("CORE-X-GENRE", dataset)
# Out:
# Finishing last run (ID:eewlcopo) before initializing another...
# Successfully finished last run (ID:eewlcopo). Initializing new run:<br/>
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_165202-2uobdodu</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/2uobdodu" target="_blank">applying-predictions-on-MaCoCu</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact CORE-X-GENRE-classifier:v0, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(
# The dataset is split into 1252 batches of 8 texts.
# Prediction with model CORE-X-GENRE started.
# 100%|██████████| 1252/1252 [24:19<00:00,  1.17s/it]
# Prediction with model CORE-X-GENRE completed. It took 24.32 minutes for 10010 instances - 0.0024295704295704294 minutes per one instance.

# %%
dataset.head(2)
# Out:
#    domain                  url  \
# 0  ahp.si      https://ahp.si/
# 1  pas.si  https://www.pas.si/
#
#                                                 text  \
# 0  Bolnica za živali Postojna\nBolnica za živali ...
# 1  Prezračevanje prostorov je nujno zaradi najman...
#
#                                                  doc  length              FTD  \
# 0  <doc id="macocu.si.221" title="Domov | Bolnica...     841  A12 (promotion)
# 1  <doc id="macocu.si.390" title="Preverjeno - Ak...     124  A12 (promotion)
#
#                               FTD_label_distribution  FTD_confidence  \
# 0  {7: 0.0115, 8: 0.009, 0: 0.0149, 1: 0.0047, 6:...        0.917997
# 1  {7: 0.1273, 8: 0.0115, 0: 0.08, 1: 0.0467, 6: ...        0.446781
#
#                         GINCO  \
# 0                   Promotion
# 1  List of Summaries/Excerpts
#
#                             GINCO_label_distribution  ...  CORE_confidence  \
# 0  {'Forum': 0.0017, 'News/Reporting': 0.0019, 'O...  ...         0.958831
# 1  {'Forum': 0.0041, 'News/Reporting': 0.0195, 'O...  ...         0.650196
#
#   GINCO-X-GENRE                   GINCO-X-GENRE_label_distribution  \
# 0     Promotion  {'Information/Explanation': 0.001, 'Opinion/Ar...
# 1     Promotion  {'Information/Explanation': 0.0029, 'Opinion/A...
#
#    GINCO-X-GENRE_confidence FTD-X-GENRE  \
# 0                  0.992724   Promotion
# 1                  0.984429   Promotion
#
#                       FTD-X-GENRE_label_distribution  FTD-X-GENRE_confidence  \
# 0  {'Promotion': 0.9176, 'Opinion/Argumentation':...                0.917588
# 1  {'Promotion': 0.4754, 'Opinion/Argumentation':...                0.475421
#
#               CORE-X-GENRE                    CORE-X-GENRE_label_distribution  \
# 0  Information/Explanation  {'Other': 0.0322, 'Information/Explanation': 0...
# 1    Opinion/Argumentation  {'Other': 0.0831, 'Information/Explanation': 0...
#
#    CORE-X-GENRE_confidence
# 0                 0.550356
# 1                 0.521125
#
# [2 rows x 23 columns]

# %%
dataset["CORE-X-GENRE"].value_counts(normalize=True)
# Out:
# Information/Explanation    0.442957
# Instruction                0.195804
# Opinion/Argumentation      0.140559
# News                       0.125075
# Forum                      0.055145
# Other                      0.020380
# Prose/Lyrical              0.020080
# Name: CORE-X-GENRE, dtype: float64

# %%
prediction_pipeline("X-GENRE", dataset)
# Out:
# Finishing last run (ID:2uobdodu) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Thread SenderThread:
# Traceback (most recent call last):
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/internal/internal_util.py", line 54, in run
#     self._run()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/internal/internal_util.py", line 105, in _run
#     self._process(record)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/internal/internal.py", line 312, in _process
#     self._sm.send(record)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/internal/sender.py", line 237, in send
#     send_handler(record)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/internal/sender.py", line 375, in send_exit
#     self._update_summary()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/internal/sender.py", line 842, in _update_summary
#     with open(summary_path, "w") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/tajak/Genre-Datasets-Comparison/Genre-Datasets-Comparison/wandb/run-20221118_165202-2uobdodu/files/wandb-summary.json'
# wandb: ERROR Internal wandb error: file data was not synced
# Problem at: /tmp/ipykernel_19465/2728970569.py 76 define_model
# Traceback (most recent call last):
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 1711, in _atexit_cleanup
#     self._on_finish()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 1829, in _on_finish
#     self._backend.interface.communicate_poll_exit()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface.py", line 617, in communicate_poll_exit
#     resp = self._communicate_poll_exit(poll_exit)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 411, in _communicate_poll_exit
#     result = self._communicate(rec)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 222, in _communicate
#     return self._communicate_async(rec, local=local).get(timeout=timeout)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 227, in _communicate_async
#     raise Exception("The wandb backend process has shutdown")
# Exception: The wandb backend process has shutdown
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_init.py", line 954, in init
#     run = wi.init()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_init.py", line 471, in init
#     self._wl._global_run_stack[-1].finish()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 1545, in finish
#     self._atexit_cleanup(exit_code=exit_code)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 1722, in _atexit_cleanup
#     self._backend.cleanup()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/backend/backend.py", line 248, in cleanup
#     self.interface.join()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 467, in join
#     super().join()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface.py", line 630, in join
#     _ = self._communicate_shutdown()
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 464, in _communicate_shutdown
#     _ = self._communicate(record)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 222, in _communicate
#     return self._communicate_async(rec, local=local).get(timeout=timeout)
#   File "/home/tajak/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 227, in _communicate_async
#     raise Exception("The wandb backend process has shutdown")
# Exception: The wandb backend process has shutdown
# wandb: ERROR Abnormal program exit
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py in _atexit_cleanup(self, exit_code)
#    1710         try:
# -> 1711             self._on_finish()
#    1712         except KeyboardInterrupt as ki:
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py in _on_finish(self)
#    1828                 self._poll_exit_response = (
# -> 1829                     self._backend.interface.communicate_poll_exit()
#    1830                 )
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface.py in communicate_poll_exit(self)
#     616         poll_exit = pb.PollExitRequest()
# --> 617         resp = self._communicate_poll_exit(poll_exit)
#     618         return resp
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in _communicate_poll_exit(self, poll_exit)
#     410         rec = self._make_request(poll_exit=poll_exit)
# --> 411         result = self._communicate(rec)
#     412         if result is None:
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in _communicate(self, rec, timeout, local)
#     221     ) -> Optional[pb.Result]:
# --> 222         return self._communicate_async(rec, local=local).get(timeout=timeout)
#     223
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in _communicate_async(self, rec, local)
#     226         if self._process_check and self._process and not self._process.is_alive():
# --> 227             raise Exception("The wandb backend process has shutdown")
#     228         future = self._router.send_and_receive(rec, local=local)
#
# Exception: The wandb backend process has shutdown
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_init.py in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, settings)
#     953         try:
# --> 954             run = wi.init()
#     955             except_exit = wi.settings._except_exit
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_init.py in init(self)
#     470
# --> 471                 self._wl._global_run_stack[-1].finish()
#     472
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py in finish(self, exit_code, quiet)
#    1544
# -> 1545         self._atexit_cleanup(exit_code=exit_code)
#    1546         if self._wl and len(self._wl._global_run_stack) > 0:
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_run.py in _atexit_cleanup(self, exit_code)
#    1721             self._console_stop()
# -> 1722             self._backend.cleanup()
#    1723             logger.error("Problem finishing run", exc_info=e)
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/backend/backend.py in cleanup(self)
#     247         if self.interface:
# --> 248             self.interface.join()
#     249         if self.wandb_process:
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in join(self)
#     466     def join(self) -> None:
# --> 467         super().join()
#     468
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface.py in join(self)
#     629             return
# --> 630         _ = self._communicate_shutdown()
#     631
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in _communicate_shutdown(self)
#     463         record = self._make_record(request=request)
# --> 464         _ = self._communicate(record)
#     465
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in _communicate(self, rec, timeout, local)
#     221     ) -> Optional[pb.Result]:
# --> 222         return self._communicate_async(rec, local=local).get(timeout=timeout)
#     223
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py in _communicate_async(self, rec, local)
#     226         if self._process_check and self._process and not self._process.is_alive():
# --> 227             raise Exception("The wandb backend process has shutdown")
#     228         future = self._router.send_and_receive(rec, local=local)
#
# Exception: The wandb backend process has shutdown
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_19465/3945553402.py in <module>
# ----> 1 prediction_pipeline("X-GENRE", dataset)
#
# /tmp/ipykernel_19465/3880319819.py in prediction_pipeline(model_name, dataset)
#       3
#       4         # Define the model
# ----> 5         model = define_model(model_name)
#       6
#       7         # Predict genre labels to the dataset
#
# /tmp/ipykernel_19465/2728970569.py in define_model(model_name)
#      74         elif model_name == "X-GENRE":
#      75                 # Initialize Wandb - for X-GENRE classifiers:
# ---> 76                 run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="applying-predictions-on-MaCoCu")
#      77
#      78                 # To access the model from the Wandb:
#
# ~/anaconda3/lib/python3.9/site-packages/wandb/sdk/wandb_init.py in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, settings)
#     990             if except_exit:
#     991                 os._exit(-1)
# --> 992             six.raise_from(Exception("problem"), error_seen)
#     993     return run
#
# ~/anaconda3/lib/python3.9/site-packages/six.py in raise_from(value, from_value)
#
# Exception: problem

# %%
# View the final dataset
dataset.describe(include="all")

# %%
dataset.head(2)

# %%
# Save the final dataset with results
dataset.to_csv("MaCoCu-sl_with_predictions.csv", sep="\t")
